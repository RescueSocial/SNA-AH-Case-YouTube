# %% [markdown]
# # Obtaining channels infos by channel ID

# %%
import pandas as pd
import json
import requests
from io import StringIO
from csv import reader
import os
import glob

# %%
class YTstats:
    '''
    this class takes api_key and channel id
    then obtain infor for the channel
    '''    
  
    def __init__(self, api_key, channel_id):
        self.api_key = api_key
        self.channel_id = channel_id
        self.video_statistics = None
  
    def get_video_statistics(self):
        url = f'https://youtube.googleapis.com/youtube/v3/channels?part=snippet&part=contentDetails&part=brandingSettings&part=contentOwnerDetails&part=id&part=localizations&part=statistics&part=status&part=topicDetails&id={self.channel_id}&maxResults=200&key={self.api_key}'
        json_url = requests.get(url)
        data = json.loads(json_url.text)
        nextPageToken = data.get("nextPageToken")
        
        i = 0
        a = ''
        if nextPageToken:
            while nextPageToken != a:
                a = nextPageToken
                i += 1
                url = f'https://youtube.googleapis.com/youtube/v3/channels?part=snippet&part=contentDetails&part=brandingSettings&part=contentOwnerDetails&part=id&part=localizations&part=statistics&part=status&part=topicDetails&id={self.channel_id}&maxResults=200&key={self.api_key}&pageToken={nextPageToken}'
                json_url = requests.get(url)
                data1 = json.loads(json_url.text)
                nextPageToken = data1.get("nextPageToken")
                data['items'] = data['items'] + data1['items']
                
                if nextPageToken is None:
                    break
                print('page number:', i+1)
              #  print(nextPageToken, len(data['items']))
            
            
        try:
            data = data["items"]#[0]["statistics"]
        except:
            data = None
  
        self.video_statistics = data
        return data
  
    def dump(self):
        if self.video_statistics is None:
            print('________________nothing happend________________')
            return 
  
        video_title = self.channel_id
        video_title = video_title.replace(" ", "_")
  
        # generate a json file with all the statistics data of the youtube video
        file_name = video_title + '.json'
        with open(file_name, 'w') as f:
            json.dump(self.video_statistics, f, indent=4)
        print('file dumped')

# %% [markdown]
# # make sure we will not obtainig channels we already have info for it:

# %%
# read channel IDs for channels we want to obtain:
channels_id_new = pd.read_csv(r'C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels IDs for obtaining\batch_1_channels_id.csv')
channels_id_list_new = set(channels_id_new['snippet.topLevelComment.snippet.authorChannelId.value'])
#channels_id_list_new = set(channels_id_list_new)
channels_id_list_new= list(channels_id_list_new)
len(channels_id_list_new)
# Out:
# 476630

# %%
# read all json files in folder and subfolder:
path_to_json = r"C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info"
names = []
for root, dirs, files in os.walk(path_to_json):
    for name in files:
        if name.endswith((".json")):
            names.append(name.split('.')[0])
            full_path = os.path.join(root, name)
len(names)
# Out:
# 4732

# %%
# make a new list with data we don't have info for it:
channels_id = []
for d in channels_id_list_new:
    if d not in names:
        channels_id.append(d)
len(channels_id)
# Out:
# 476354

# %% [markdown]
# # obtaining Data for CHANNELS

# %%
len(channels_id)
# Out:
# 412030

# %%
# recive data using API and save it on PC
 
API_KEY1 = "AIzaSyCQHI5RSbHoKGh6sPPnnOywja7qLS6TXnA"
API_KEY2 = "AIzaSyA-0KfpLK04NpQN1XghxhSlzG-WkC3DHLs"
API_KEY3 = "AIzaSyDjJaoIrNIoaIPvX5mTniBHaDNLRGBjpMw"
API_KEY4 = "AIzaSyB6dfr3l6p5Z7DYhCdXYE8TvCEhsID2qdI"
API_KEY5 = "AIzaSyAeAJ_SVt-gf8fZ3gorCN0kgX0cTBB_5Ys"
API_KEY6 = "AIzaSyAbvbNBsZs3TT2XUFLd-6yBb4cWT43bk0Y"

# paste the channel id here
while len(channels_id) !=0:
    
    for video in channels_id[:12000]:
        print(video)
        yt = YTstats(API_KEY1, video)
        yt.get_video_statistics()
        yt.dump()
        channels_id.remove(video)
        print('channels to scrape remain: ', len(channels_id))
        break
# Out:
# UCKDUnNysVb17cZ1yyzcLq5Q
# file dumped
# channels to scrape remain:  412029
# UC08tmHUliVYcgy77OCXQYWA
# file dumped
# channels to scrape remain:  412028
# UCbistm-Ym58lVfhNUK7deQw
# file dumped
# channels to scrape remain:  412027
# UCfkx6Li7YET8b4m1DAHpC7g
# file dumped
# channels to scrape remain:  412026
# UCujN7OFOJpmoWq1AOW4ElAQ
# file dumped
# channels to scrape remain:  412025
# UCZ77pHaDGu3yF8RX3z6T2wQ
# file dumped
# channels to scrape remain:  412024
# UCKe81fFJGTTqlOgwpfa7-7g
# file dumped
# channels to scrape remain:  412023
# UC_SZI9EjqkYqS-0BREJwfWA
# file dumped
# channels to scrape remain:  412022
# UC29dqFx5R4UYrREy0dAa62Q
# file dumped
# channels to scrape remain:  412021
# UCREHZpFxkKsbLSjm2uoPwyQ
# file dumped
# channels to scrape remain:  412020
# UCQF3A6HS-58jjRLmcSk90RQ
# file dumped
# channels to scrape remain:  412019
# UCRoJdTXca9yHTs2oOOy5dQg
# file dumped
# channels to scrape remain:  412018
# UCyMD_fRtyV-4TWoXJM--Teg
# file dumped
# channels to scrape remain:  412017
# UCzweN4x8waoIJoThM1pTFmA
# file dumped
# channels to scrape remain:  412016
# UCaGiP0ROMZVPu-AnPaasehg
# file dumped
# channels to scrape remain:  412015
# UCxBmonekzJ0kYkK87DxILzg
# file dumped
# channels to scrape remain:  412014
# UChdwY9wcdAbBJaY_LbQcy-Q
# file dumped
# channels to scrape remain:  412013
# UCpExTC1hTxHeDDPQeExyNnw
# file dumped
# channels to scrape remain:  412012
# UCeh4c5iqqiTdaPpy6HbI3hw
# file dumped
# channels to scrape remain:  412011
# UCBkx9xdl7RfWwFcpnYZRTjw
# file dumped
# channels to scrape remain:  412010
# UCNePsdhfTwNvL-pECSPIejQ
# file dumped
# channels to scrape remain:  412009
# UC3RLYGkLH5S-Bb5nMH2NGPg
# file dumped
# channels to scrape remain:  412008
# UCUTuTZ0-8485AiDLeCxdnnw
# file dumped
# channels to scrape remain:  412007
# UCEtG00vuUWMT2FYdJKFmF3g
# file dumped
# channels to scrape remain:  412006
# UCWhaBR5lbP_CayayuiNugJA
# file dumped
# channels to scrape remain:  412005
# UC4O5U7PH6J-JvMus8hZSxPg
# file dumped
# channels to scrape remain:  412004
# UC3va2Dw-skj_xqmfYSwLxfQ
# file dumped
# channels to scrape remain:  412003
# UCibrdsy6S4WhjCoAmvtGgjA
# file dumped
# channels to scrape remain:  412002
# UCkRX9r-dizK2Xc8Nhm68xSA
# file dumped
# channels to scrape remain:  412001
# UC2ZB6cyYPUiItSPI_xzJ2Aw
# file dumped
# channels to scrape remain:  412000
# UC5hRJ9lXHXOgJ9SD2xpldiw
# file dumped
# channels to scrape remain:  411999
# UCIRwXmGVkBpXbmKI5WZSVXw
# file dumped
# channels to scrape remain:  411998
# UC8dHQPhBqeGHbUitfblQmCg
# file dumped
# channels to scrape remain:  411997
# UCBGUr6tY1MHYadQrz2-fnzw
# file dumped
# channels to scrape remain:  411996
# UCZlHHExLhF0BzH0qicbVmHw
# file dumped
# channels to scrape remain:  411995
# UCT6jrLxGtAAdV9hMjfUMLUw
# file dumped
# channels to scrape remain:  411994
# UCv_IKZGfAGTIYCk1mHsH-dQ
# file dumped
# channels to scrape remain:  411993
# UCdEYu6gO-ioceKkPGeR_qOw
# file dumped
# channels to scrape remain:  411992
# UCvdBPl7Y_nmahTHsq82m3SA
# file dumped
# channels to scrape remain:  411991
# UCCA2ulmUhJOBSGVqRBScdXw
# file dumped
# channels to scrape remain:  411990
# UC6K7ScFHCSSmETWbR6c4JZw
# file dumped
# channels to scrape remain:  411989
# UCtIY3xm9ffmWqaq9ekT8x7A
# file dumped
# channels to scrape remain:  411988
# UC34VJttG1HdiJPEzLO6lh0w
# file dumped
# channels to scrape remain:  411987
# UC4hbsbLq3M6CrmLlUrVqoow
# file dumped
# channels to scrape remain:  411986
# UCHjZ10jS2zQ7O68i-0hZB-A
# file dumped
# channels to scrape remain:  411985
# UCNX-b68h5p0pp1XR2E3anng
# file dumped
# channels to scrape remain:  411984
# UCIKiAb4GQuSbQyIegCjMSXg
# file dumped
# channels to scrape remain:  411983
# UC-nWASVe3WFVMsOt0aBSmAA
# file dumped
# channels to scrape remain:  411982
# UCx-ssVV1fhztiGDVvEjnkXQ
# file dumped
# channels to scrape remain:  411981
# UCiLqS__yAKnV5L3v349vxoA
# file dumped
# channels to scrape remain:  411980
# UCX-EXw0GsoXQPcIZIv83Puw
# file dumped
# channels to scrape remain:  411979
# UCOT_j5K7H0KZ92wv9ygUZ6Q
# file dumped
# channels to scrape remain:  411978
# UC7wgsnrbSEMaOfqLz8oRbXg
# file dumped
# channels to scrape remain:  411977
# UCJE_0-uoWaoM9TAtiSCzQsg
# file dumped
# channels to scrape remain:  411976
# UCLUF7u_uKkfcsV3Qe3OBqyA
# file dumped
# channels to scrape remain:  411975
# UCn4Ip-EYw5BlgySRS5iugLg
# file dumped
# channels to scrape remain:  411974
# UCKwr1XasHuG28sUV2b7mJlQ
# file dumped
# channels to scrape remain:  411973
# UC3geIMf6mn8tbZmLBq-zLCA
# file dumped
# channels to scrape remain:  411972
# UCLlWIaAmGoKCo-QGgsWwQGA
# file dumped
# channels to scrape remain:  411971
# UC78al3Jjp2oohT7F2E7mk1g
# file dumped
# channels to scrape remain:  411970
# UCdoCyPmOWYGivthI_wS4Ipg
# file dumped
# channels to scrape remain:  411969
# UC1sxRdW3E8yuBxUuW870mXA
# file dumped
# channels to scrape remain:  411968
# UCTbNtHaiHjQNH2oeiQ5mK_A
# file dumped
# channels to scrape remain:  411967
# UCjhytfPQlJEdCWrjRmiRotQ
# file dumped
# channels to scrape remain:  411966
# UCvo35rDsoRpZ1Vnrznhehww
# file dumped
# channels to scrape remain:  411965
# UClbbRQR_D0hEw8gM7upmluQ
# file dumped
# channels to scrape remain:  411964
# UCdl29P80bRaXwuzyiuqqKfA
# file dumped
# channels to scrape remain:  411963
# UCtPB-qci1s7g0-ylefztwHQ
# file dumped
# channels to scrape remain:  411962
# UCvoQ5O_d_J9tYRASGxheK6Q
# file dumped
# channels to scrape remain:  411961
# UCHVKJNiwmBvv88ywNLx4Nfg
# file dumped
# channels to scrape remain:  411960
# UC0VxmsRg7Og5OXsuObleseQ
# file dumped
# channels to scrape remain:  411959
# UCqELn3haoxU3GhrCV7cykwQ
# file dumped
# channels to scrape remain:  411958
# UCIxHARP79fDoRy-ki0TvGEg
# file dumped
# channels to scrape remain:  411957
# UCNpjUKlQ-xdUB24NDnIpppA
# file dumped
# channels to scrape remain:  411956
# UCxiJ3JTfnF7I6jTTOI5rY3Q
# file dumped
# channels to scrape remain:  411955
# UCo05a_SFpIVPYfGChmqwoRg
# file dumped
# channels to scrape remain:  411954
# UCd_tBJ_rA_WECTb4uL-DW8Q
# file dumped
# channels to scrape remain:  411953
# UCUPBvOINbaOMIcRrWT-TUZg
# file dumped
# channels to scrape remain:  411952
# UCCJG_c5D335aJAWOszpjccQ
# file dumped
# channels to scrape remain:  411951
# UC5FXwHHPOsa44a0BzyAWwjw
# file dumped
# channels to scrape remain:  411950
# UCQQPTtvwESXXzov_jht_nyw
# file dumped
# channels to scrape remain:  411949
# UCi2Q-JF2fSnzFWe5oRh-eqA
# file dumped
# channels to scrape remain:  411948
# UC75-6oE9B6zeFDyWkiOCJOA
# file dumped
# channels to scrape remain:  411947
# UCQHdJyV8HM6ZsHTIiafJEtA
# file dumped
# channels to scrape remain:  411946
# UC6HSo3q4lkFNXPN91rWVYtA
# file dumped
# channels to scrape remain:  411945
# UCfF0xpy6K4fSeQEb6gtx63Q
# file dumped
# channels to scrape remain:  411944
# UCtYl7ZX_gqpZf4tXv88aLbQ
# file dumped
# channels to scrape remain:  411943
# UCc2WPfA0xWnedBvasiBfAHA
# file dumped
# channels to scrape remain:  411942
# UCrJyTnIxqgJBTinkKop44kw
# file dumped
# channels to scrape remain:  411941
# UCy6llrlWtlSih2mUG287Cig
# file dumped
# channels to scrape remain:  411940
# UCSAtBsE5AkAh4yj_6iqelyQ
# file dumped
# channels to scrape remain:  411939
# UCmS_FqbkxUtuP4rFXTdL9CQ
# file dumped
# channels to scrape remain:  411938
# UCaMVMnryuY-hyBo22ZoQv5g
# file dumped
# channels to scrape remain:  411937
# UCzVhX9uCWHVdoYNvcHt_rqA
# file dumped
# channels to scrape remain:  411936
# UCHRak5OGjEQyVnFzZZ4ykzQ
# file dumped
# channels to scrape remain:  411935
# UCz-KZwOsIkcO8qwtnyZHXkA
# file dumped
# channels to scrape remain:  411934
# UCvTMoe0XNp4nk51KPfHPOGQ
# file dumped
# channels to scrape remain:  411933
# UCxOYp97bg-KUVDJ8lMXJS1g
# file dumped
# channels to scrape remain:  411932
# UCeypRwRqqvDF7FtO2QzfTwg
# file dumped
# channels to scrape remain:  411931
# UCN5mPtDfqLVeqyIcQcQDFcQ
# file dumped
# channels to scrape remain:  411930
# UCp0Gb56lN-hqkKpwQuLvuOQ
# file dumped
# channels to scrape remain:  411929
# UC6DssFZOyG1XlJa3dzyOjcg
# file dumped
# channels to scrape remain:  411928
# UCJb5oC9pJRg-4xArRMTEFgw
# file dumped
# channels to scrape remain:  411927
# UCVq-363pt05jL-PMFJ8GG2Q
# file dumped
# channels to scrape remain:  411926
# UCyrgZKF0ZirCdjy-q8ULOlg
# ________________nothing happend________________
# channels to scrape remain:  411925
# UCVWsBc-dCJJpvHvBd9-izAA
# file dumped
# channels to scrape remain:  411924
# UCngmQHEd8i-TlQaSVKmI7jw
# file dumped
# channels to scrape remain:  411923
# UCkCqqWqGgXAKuUIxZAr_ofQ
# file dumped
# channels to scrape remain:  411922
# UCu_K9BhF8qGSQpznTq9UOYg
# file dumped
# channels to scrape remain:  411921
# UCVDjd47aK9Wc8TlXbfAxfLg
# file dumped
# channels to scrape remain:  411920
# UCxx4x5w4VYy-TGMvOQ2AMEQ
# file dumped
# channels to scrape remain:  411919
# UCFh4JfKG_flyKJC2lNPEQbw
# file dumped
# channels to scrape remain:  411918
# UCgynexioXmaEfJ3oWHzkwSw
# file dumped
# channels to scrape remain:  411917
# UCZI8eKV3MEMuS3YnR7-xmjA
# file dumped
# channels to scrape remain:  411916
# UC27jAocSlDMPj87JMi-1Y9w
# file dumped
# channels to scrape remain:  411915
# UC55WXTmNwTCqmaGlD00SJQQ
# file dumped
# channels to scrape remain:  411914
# UCFq4uX_EmJDztwZVjC5wyKw
# file dumped
# channels to scrape remain:  411913
# UCxuIQ1NKKRgz5-SQnUCrT4g
# file dumped
# channels to scrape remain:  411912
# UCTJkdmyTo2PPR0-gd4B3Ziw
# file dumped
# channels to scrape remain:  411911
# UCmJ-tyR7ytsmq8xtVdGgq2Q
# file dumped
# channels to scrape remain:  411910
# UCACAsmPfSiThXogvtAEJ1ag
# file dumped
# channels to scrape remain:  411909
# UC72fV3nZBQPa9NqKiH7hkHg
# file dumped
# channels to scrape remain:  411908
# UCwOX-Lj4i9Gu4gNw4OuKuhA
# file dumped
# channels to scrape remain:  411907
# UCBY4npPd2599ZN-faug_2Pg
# file dumped
# channels to scrape remain:  411906
# UCV66s_Z-Ik_IASDNL1-2hPA
# file dumped
# channels to scrape remain:  411905
# UCzfOH0mMuhRC7hadfOLbAOg
# file dumped
# channels to scrape remain:  411904
# UC05qJuQgLEDiNlsQ_iObBwA
# file dumped
# channels to scrape remain:  411903
# UCLYiAWIucJ-oyIa9ykV9bMg
# file dumped
# channels to scrape remain:  411902
# UCAN4ySN1BjwsbIFXVaQWH9g
# file dumped
# channels to scrape remain:  411901
# UCN8T_iWOze9nPOqHW20UIKA
# file dumped
# channels to scrape remain:  411900
# UCo9_UouF2M3LIEOa8guwCxg
# file dumped
# channels to scrape remain:  411899
# UCykD0yVq9LCNybFRep6ThFw
# file dumped
# channels to scrape remain:  411898
# UC7cI3zuBx6osGO2-OJldZyg
# file dumped
# channels to scrape remain:  411897
# UCfNQi-P5izNCC1AvR2ghzyg
# file dumped
# channels to scrape remain:  411896
# UCpqlsB-fR1wgpeOPtXwCkoQ
# file dumped
# channels to scrape remain:  411895
# UChPQEOeC5WiJz5FsP9tRMAg
# file dumped
# channels to scrape remain:  411894
# UCiSnsdSPGE9QBtuL5nHX4gw
# file dumped
# channels to scrape remain:  411893
# UCHGXfea-rZyFQS2lG0hPzJg
# file dumped
# channels to scrape remain:  411892
# UCrkhU0AsICifFdMOQ0JCpsw
# file dumped
# channels to scrape remain:  411891
# UCTpdAIaFJYRJgkEE1jwUK5A
# file dumped
# channels to scrape remain:  411890
# UCxoRCe4YGgmZEfiSUswpBCQ
# file dumped
# channels to scrape remain:  411889
# UC2FhyljBBqMFpzjeVHuKxsg
# file dumped
# channels to scrape remain:  411888
# UCiQGCNN8o9miTX_PLDisQPg
# file dumped
# channels to scrape remain:  411887
# UC9BNrDXn3JoTgwv_o0alznQ
# file dumped
# channels to scrape remain:  411886
# UCb_GM8siKaiedwuo5L9btQA
# file dumped
# channels to scrape remain:  411885
# UCXbbuk6_bDZ6lTlIDEttE4w
# file dumped
# channels to scrape remain:  411884
# UC_hNQWEKIObdi7x_wCyVUkQ
# file dumped
# channels to scrape remain:  411883
# UCoCULiueIRVYwiMM2KsnL7w
# file dumped
# channels to scrape remain:  411882
# UC4YoHY_dGpGHDzjnzuJyfbw
# file dumped
# channels to scrape remain:  411881
# UC762Pm-UNNqc0wN6UJb7XKA
# file dumped
# channels to scrape remain:  411880
# UCf7ComBcorD0rfdWJO43hRQ
# file dumped
# channels to scrape remain:  411879
# UCBLf4dUBpJVp7gzaaCzAGwg
# file dumped
# channels to scrape remain:  411878
# UCekqaMQQMr9HqBgKoLLeE2Q
# file dumped
# channels to scrape remain:  411877
# UCVFQmp7PUTZEoKUQBsmVzuw
# file dumped
# channels to scrape remain:  411876
# UCO0vJL_yXzLPrgaH5oDCLww
# file dumped
# channels to scrape remain:  411875
# UCPuszOjd8eBmyQaHSHOTcLw
# file dumped
# channels to scrape remain:  411874
# UC8BFujc-29WUj9WzP98tgaQ
# file dumped
# channels to scrape remain:  411873
# UCVXtUxqQj1SY0izI0AWoEeQ
# file dumped
# channels to scrape remain:  411872
# UCUN3dWS60DsxeQ8ILFSf6eQ
# file dumped
# channels to scrape remain:  411871
# UCbp4z7lzXylMjykOoHKlq2A
# file dumped
# channels to scrape remain:  411870
# UCkpox255AUa32Nuu1ALkKzw
# file dumped
# channels to scrape remain:  411869
# UCyoInf1XTCbbTiZJXgqcLZw
# file dumped
# channels to scrape remain:  411868
# UCXNxSXUjvPmlNbHgRg0zemg
# file dumped
# channels to scrape remain:  411867
# UC_mSm_BxLmtp29feoskPqNw
# file dumped
# channels to scrape remain:  411866
# UCGoyfPaYk4VPaXEsRj78MyQ
# file dumped
# channels to scrape remain:  411865
# UCgLOczZFy7AezBcZmhGFoyA
# file dumped
# channels to scrape remain:  411864
# UCB4Rft9yW1g3oCIEsQRecEA
# file dumped
# channels to scrape remain:  411863
# UCQpclgYCsUlhBUjEM6nCHeg
# file dumped
# channels to scrape remain:  411862
# UC47np-y6QKIRdoSRk6UjbCQ
# file dumped
# channels to scrape remain:  411861
# UCVq410nY9UDmWbBmfDvHT_w
# file dumped
# channels to scrape remain:  411860
# UCwtf1EQS-Si41hI3iFcYNug
# file dumped
# channels to scrape remain:  411859
# UCkUnKjhHOOgLFuX_g4wQQdA
# file dumped
# channels to scrape remain:  411858
# UCqHWSnfBI0ow-UQJ-qhyIvg
# file dumped
# channels to scrape remain:  411857
# UCyuhfqpxpUBKTGw1YE2-6NQ
# file dumped
# channels to scrape remain:  411856
# UCWJ8dAw_BdhfL6vf-scqj9Q
# file dumped
# channels to scrape remain:  411855
# UCQ_dfc_Ul17Mae4K6xrx7Gg
# file dumped
# channels to scrape remain:  411854
# UCiwuDj-8vkWDKUaEiZFThJA
# file dumped
# channels to scrape remain:  411853
# UCPLAqshuyegincdt72LGMkg
# file dumped
# channels to scrape remain:  411852
# UCN_umSNIbJCduNXZI8yS4Yw
# file dumped
# channels to scrape remain:  411851
# UCgbNxmOHD2NeyZdpK2d1vCg
# file dumped
# channels to scrape remain:  411850
# UCSZ2ZpHHehLjtODgfBfxSGg
# file dumped
# channels to scrape remain:  411849
# UCrIuNMhfVEvWjEclhl1suAg
# file dumped
# channels to scrape remain:  411848
# UCO_K4ThpQOMPeQB4PM9qphw
# file dumped
# channels to scrape remain:  411847
# UCpRDGJC1ZuCDelHgsIDj77w
# file dumped
# channels to scrape remain:  411846
# UCT5wRljE1Hu3YivwpizsgTA
# file dumped
# channels to scrape remain:  411845
# UC7wj4S3D4Ds4yBmgqZzCKvw
# file dumped
# channels to scrape remain:  411844
# UCIwWOOyttuPeyezHKxX-4Ew
# file dumped
# channels to scrape remain:  411843
# UCYhIz6ibqmRG7LhMzwu18Bg
# file dumped
# channels to scrape remain:  411842
# UCUL_GzXKg8Khe4VfRzdMFuw
# file dumped
# channels to scrape remain:  411841
# UCYym91QVgQioGV5283ki2Rw
# file dumped
# channels to scrape remain:  411840
# UCNcorY4ZLCewQV6ia-BlNKw
# file dumped
# channels to scrape remain:  411839
# UCcIznRxgSGZSYz2tXLSiGJw
# file dumped
# channels to scrape remain:  411838
# UC6aXYX0iEaBpmf8Zr3Smu2g
# file dumped
# channels to scrape remain:  411837
# UCRlhUEEFfBgPEy4Qb-Pi0zQ
# file dumped
# channels to scrape remain:  411836
# UCLlFM9PttteY-Ec5LVzQFxg
# file dumped
# channels to scrape remain:  411835
# UC6T-3Nj5taDM2Ktujlrnb1A
# file dumped
# channels to scrape remain:  411834
# UCgUTJh_5c-lbL9ZwM8-qU4Q
# file dumped
# channels to scrape remain:  411833
# UCItP4fBRtxyL5KkTgcd5eHw
# file dumped
# channels to scrape remain:  411832
# UCovLFWpyaScYdryayiEpmLQ
# file dumped
# channels to scrape remain:  411831
# UCdfwHbBLDpemZiCm9DTGNPQ
# file dumped
# channels to scrape remain:  411830
# UCUoNQjw6W2ZuPLkxQUcKFdw
# file dumped
# channels to scrape remain:  411829
# UC8fpOiZKt06AkLJbvEJHZcQ
# file dumped
# channels to scrape remain:  411828
# UCA4Fgs_7VRU9SCie7N7BUTg
# file dumped
# channels to scrape remain:  411827
# UCoGLaYYonX8gQEOvIq9SvBw
# file dumped
# channels to scrape remain:  411826
# UC2EG_8DngMuHanlP-XKIzyA
# file dumped
# channels to scrape remain:  411825
# UCJlVzu4MjR4kKu7ayADy1UA
# file dumped
# channels to scrape remain:  411824
# UCczT40uox-cJZ_SAQW9OTvQ
# file dumped
# channels to scrape remain:  411823
# UCxgOaX_012x8r2A5qnYhblg
# file dumped
# channels to scrape remain:  411822
# UCRUjppeSLmIhIb08lqqBjtg
# file dumped
# channels to scrape remain:  411821
# UClRSERSW48nb0LDGnVH_OkQ
# file dumped
# channels to scrape remain:  411820
# UC8b46ww7sPaVgnPjHL2vQog
# file dumped
# channels to scrape remain:  411819
# UCeNBfIAwxwIqvHxYSWhmifA
# file dumped
# channels to scrape remain:  411818
# UCjHF_piiEtJlff6O7PPrMCA
# file dumped
# channels to scrape remain:  411817
# UCV5Oz-qJSvbnMauCjpiKacg
# file dumped
# channels to scrape remain:  411816
# UCW1dxRKk5iA8yVVbbG4hfbQ
# file dumped
# channels to scrape remain:  411815
# UCxPMewO9DGIKLWymDVO8JxQ
# file dumped
# channels to scrape remain:  411814
# UCTM3phRri6Czg0dT_Fsd7Aw
# file dumped
# channels to scrape remain:  411813
# UCEmwsFOjwSdfJgpOCHKuV0Q
# file dumped
# channels to scrape remain:  411812
# UCHjpqauV2s9zyUtMFPQ0zQA
# file dumped
# channels to scrape remain:  411811
# UCFFqDFSC0ifiQrYqJIJrPbg
# file dumped
# channels to scrape remain:  411810
# UC9oNJaOIdZcBlR3i8VCmpbQ
# file dumped
# channels to scrape remain:  411809
# UCUKR-W23fS1XQ-ygtrq3Puw
# file dumped
# channels to scrape remain:  411808
# UC4ExHAuLSfjG39Of-oekplQ
# file dumped
# channels to scrape remain:  411807
# UC1TRFtP3C33GhQakDX-0VOg
# file dumped
# channels to scrape remain:  411806
# UCY6XwY4FspdBKYuD2nPOnwQ
# file dumped
# channels to scrape remain:  411805
# UCPajhlFMGprOYoe3oVUURrQ
# file dumped
# channels to scrape remain:  411804
# UCP4LIK_cJR2BKeTPR7aMN5w
# file dumped
# channels to scrape remain:  411803
# UC_CHm0R7uMcl7AFwqJiND6w
# file dumped
# channels to scrape remain:  411802
# UCzJGeU_PpY7Qyx6zKEBF0YA
# file dumped
# channels to scrape remain:  411801
# UCvNB0tFvWRgrScStlMAJ_Vw
# file dumped
# channels to scrape remain:  411800
# UCEywmwdMJa1cUZhLpZjDFcQ
# file dumped
# channels to scrape remain:  411799
# UCTYCTXIEjK546Q0oWVHW9kA
# file dumped
# channels to scrape remain:  411798
# UCtwRhmEk1olacRXQK-4rOyA
# file dumped
# channels to scrape remain:  411797
# UC9yTbHd_mjuAII1ddBjNnkg
# file dumped
# channels to scrape remain:  411796
# UCKnNV81CvKRyhWkCl6WVa5g
# file dumped
# channels to scrape remain:  411795
# UClpeHDKGTfuwKVIMmlVvixg
# file dumped
# channels to scrape remain:  411794
# UCYgoitom1WUaS4MLlsOCptw
# file dumped
# channels to scrape remain:  411793
# UCobKgPZmNBqOw6U1IGe3U8Q
# file dumped
# channels to scrape remain:  411792
# UCt8EGbCxjgH87FJhX38NHqg
# file dumped
# channels to scrape remain:  411791
# UCEW0YeGpfdLU_Ls5SZWsa6g
# file dumped
# channels to scrape remain:  411790
# UCHHR--sa-EYvacYMnYaA3ww
# file dumped
# channels to scrape remain:  411789
# UCnmejFY_d0aATpOoliKmHzQ
# file dumped
# channels to scrape remain:  411788
# UCnmZVb_iP27Gbq8CvnF_iWg
# file dumped
# channels to scrape remain:  411787
# UCEmOn8GFCeXM5fZ0Wk4QjoQ
# file dumped
# channels to scrape remain:  411786
# UCWsxNrI7-j7fQQMZe4UJzUA
# file dumped
# channels to scrape remain:  411785
# UCps1_Pe2CM9aVY3gQnXzvtw
# file dumped
# channels to scrape remain:  411784
# UCtdKG3Bxw6UV_ksbkql6HnQ
# file dumped
# channels to scrape remain:  411783
# UC02LcCb1NSOVHTXXkjWFA2A
# file dumped
# channels to scrape remain:  411782
# UCDlnhm964jRkx7ZmNzBpFgA
# file dumped
# channels to scrape remain:  411781
# UCAroLa-W4Q3mUsQbB_6oJng
# file dumped
# channels to scrape remain:  411780
# UC1cSbTcS2eR-3CvfV0-5d1Q
# file dumped
# channels to scrape remain:  411779
# UCl3W1mlBwOO3r7f8zr0u6Tg
# file dumped
# channels to scrape remain:  411778
# UCGVoA0YPG-KpnQXSsMtPqvA
# file dumped
# channels to scrape remain:  411777
# UCDgy48LgHZWxqXHhgkt-JeQ
# file dumped
# channels to scrape remain:  411776
# UCx4Wbz1BD3fPdjjiPBcddaw
# file dumped
# channels to scrape remain:  411775
# UCyIovnTXTnjr-GfAs-JOStQ
# file dumped
# channels to scrape remain:  411774
# UC4bA-krweo8XJqChAfnKjOA
# file dumped
# channels to scrape remain:  411773
# UC2u_LFyfu-GnVClhcgxJqKg
# file dumped
# channels to scrape remain:  411772
# UCILo576iLztnxS6Ff_E0qgQ
# file dumped
# channels to scrape remain:  411771
# UCBHRuG_A32gnCZO3eJlPxHw
# file dumped
# channels to scrape remain:  411770
# UCpudDb6RGGl7I0Yv4HyYpig
# file dumped
# channels to scrape remain:  411769
# UCTHiN5I3A03PtIhu6HWmExw
# file dumped
# channels to scrape remain:  411768
# UCEE8GpEY3uKRMhMchx3vjBg
# file dumped
# channels to scrape remain:  411767
# UCX0-By6MdEutR6LdIZud8TA
# file dumped
# channels to scrape remain:  411766
# UCtQuW4q7NREpoDUkX2QTg1w
# file dumped
# channels to scrape remain:  411765
# UCxRp74RE7-2Vzlb64bZ9YNg
# file dumped
# channels to scrape remain:  411764
# UCVdDaNAISpWdGAfRq0D_GSg
# file dumped
# channels to scrape remain:  411763
# UCyMQErYOf-ui2Dxm1OuM5nQ
# file dumped
# channels to scrape remain:  411762
# UCNDKLr2r95J64Fk4Zj9Onrw
# file dumped
# channels to scrape remain:  411761
# UCwhzWHvEUZZL8znArknxR3g
# file dumped
# channels to scrape remain:  411760
# UCFh-EfjpY-j8var_hzNrqdQ
# file dumped
# channels to scrape remain:  411759
# UCJJPElatrqbGIWzPiDFPLNg
# file dumped
# channels to scrape remain:  411758
# UCjICBz-OwYXE-Dz3vWcI4JQ
# file dumped
# channels to scrape remain:  411757
# UC8NHRfQuSgt3_nD2B5jUF2g
# file dumped
# channels to scrape remain:  411756
# UCIzW3lvXursibCLfqOGMmDg
# file dumped
# channels to scrape remain:  411755
# UCmAWw8O39VBY4Q11gEDoerw
# file dumped
# channels to scrape remain:  411754
# UC-dB1HwPl78pY6jHoA6wixQ
# file dumped
# channels to scrape remain:  411753
# UCKJNQ3NzXKl-QSKTPLHqJ_w
# file dumped
# channels to scrape remain:  411752
# UCukNoFNSeZSxJ11IoYmwJfQ
# file dumped
# channels to scrape remain:  411751
# UCQxcwMgvwOyF84fkVsZ1ELg
# file dumped
# channels to scrape remain:  411750
# UC-xZ9GBOqlKSwHzPjS7huXg
# file dumped
# channels to scrape remain:  411749
# UCEF4SsNTte_cOCa1nkVS3ew
# file dumped
# channels to scrape remain:  411748
# UCXuBM5AqlyftzmI1I81YmVw
# file dumped
# channels to scrape remain:  411747
# UC_BqZtqFxnT9Mg87QHcpbrQ
# file dumped
# channels to scrape remain:  411746
# UCe_-ApFkXDOars2V04ZLVDg
# file dumped
# channels to scrape remain:  411745
# UCftCUURoCQ9ng2IgAL7uFQw
# file dumped
# channels to scrape remain:  411744
# UCYR7j_spdRIEPcxq11I4Ucw
# file dumped
# channels to scrape remain:  411743
# UClKTXdxn9pagJxG14_Z-Dew
# file dumped
# channels to scrape remain:  411742
# UCTvj2PBTMfzRWWxo4gY_kCg
# file dumped
# channels to scrape remain:  411741
# UCBBYZbNBDSMAPdT41J4BCcg
# file dumped
# channels to scrape remain:  411740
# UCodYcwq2JC2qQLaJxOBYiHQ
# file dumped
# channels to scrape remain:  411739
# UCb2dad5YkxEU3ve7-QD_E4g
# file dumped
# channels to scrape remain:  411738
# UC0ioVTGO8Szg7WfeNBxL2JQ
# file dumped
# channels to scrape remain:  411737
# UCMRkdR_ZsgdNHFVV8KbhI3w
# file dumped
# channels to scrape remain:  411736
# UCa96QHLjRQIQW2gNgEZ4dWQ
# file dumped
# channels to scrape remain:  411735
# UCDg5VVeY2tX7QxQ8PSXJJVw
# file dumped
# channels to scrape remain:  411734
# UCNEw60HJZ1sK_1ZGGJ11FZw
# file dumped
# channels to scrape remain:  411733
# UCDS4QzNgrhfxMuauUd5z2pA
# file dumped
# channels to scrape remain:  411732
# UCVMJQp6Rhr6z-N-Hrv6ZTsA
# file dumped
# channels to scrape remain:  411731
# UCsZ5K6TJwiihmfJgnSl89_g
# file dumped
# channels to scrape remain:  411730
# UCfdOxPKXnIQWNJROicTzCbw
# file dumped
# channels to scrape remain:  411729
# UCRPsw0qGM3QF2si0hVKbqJg
# file dumped
# channels to scrape remain:  411728
# UC31P_aQmusgMQUa80DL_PGQ
# file dumped
# channels to scrape remain:  411727
# UC-J7OW8_r0bXt0qlncSo1Yg
# file dumped
# channels to scrape remain:  411726
# UC4X-GEx1BWcgCXM9foZMPVg
# file dumped
# channels to scrape remain:  411725
# UCu3UDUfHC6bs-kDk_l0zdmw
# file dumped
# channels to scrape remain:  411724
# UCjxTbmnjXPctVlqybd0IAIw
# file dumped
# channels to scrape remain:  411723
# UC-KUYkz8oWAZQgDWbHa3Fig
# file dumped
# channels to scrape remain:  411722
# UC8YRXDQ6H4b3U4VCVGFp2FQ
# file dumped
# channels to scrape remain:  411721
# UCyYTeMWC0WL-pIlpwYIPPaA
# file dumped
# channels to scrape remain:  411720
# UCZTyGvh2gQqbykAPCxHM0sg
# file dumped
# channels to scrape remain:  411719
# UCKQF_M2S6YG7GCSvIxdBIOQ
# file dumped
# channels to scrape remain:  411718
# UCuskSjVZfLwG8q5RrQjWt4w
# file dumped
# channels to scrape remain:  411717
# UCWac7byz2KTrSu15ZwNIj2A
# file dumped
# channels to scrape remain:  411716
# UCnslMZHSRy_Uan_Zo5zMYtg
# file dumped
# channels to scrape remain:  411715
# UCOImAyVNykg0Xg30R-dnlKA
# file dumped
# channels to scrape remain:  411714
# UCfSs5qMwG2yk8bNTExvUpVA
# file dumped
# channels to scrape remain:  411713
# UCIz5KcTb7--efxTI049mbWQ
# file dumped
# channels to scrape remain:  411712
# UCmBdgfM_VPYedo490MrjDMg
# file dumped
# channels to scrape remain:  411711
# UCFLKKivqxzS9EN-KIslRuKw
# file dumped
# channels to scrape remain:  411710
# UCmIDvJD4XwUXlsKngUr2mPw
# file dumped
# channels to scrape remain:  411709
# UCA9LSvamf-F_ExFq5hY4DKw
# file dumped
# channels to scrape remain:  411708
# UCC7QGYbuUDQNUp4mZsz3fSQ
# file dumped
# channels to scrape remain:  411707
# UCpMZgWP1pe3_IYzhxGcrOUg
# file dumped
# channels to scrape remain:  411706
# UChIa_xxhs8oLauHwxiRAIBg
# file dumped
# channels to scrape remain:  411705
# UCFgGUYtbVodUpgtJJBLgvlA
# file dumped
# channels to scrape remain:  411704
# UCXT1f2Zdmx25HSRLRwCQjCA
# file dumped
# channels to scrape remain:  411703
# UC5MPCR6Ii0SYx-NX3GXf9xA
# file dumped
# channels to scrape remain:  411702
# UCpIbFQZrmsyAdjBMCdqk6lA
# file dumped
# channels to scrape remain:  411701
# UCbZRnokJozToUPtVtKboYKQ
# file dumped
# channels to scrape remain:  411700
# UC9-QJTxo65AS_NfHts3cTHQ
# file dumped
# channels to scrape remain:  411699
# UCUSavfPh_J3IBgu-9YItfDw
# file dumped
# channels to scrape remain:  411698
# UCKebLrT1ymfObbsx7CA-d-g
# file dumped
# channels to scrape remain:  411697
# UCnMSyyn6OgdyVgwSLYwaljw
# file dumped
# channels to scrape remain:  411696
# UCYfWJ8aKYyW-t-YYnTLkJaw
# file dumped
# channels to scrape remain:  411695
# UCrO1qkCE4fOHkmOP0AlmpZg
# file dumped
# channels to scrape remain:  411694
# UCbEiYuVo4mmlMbvieudae_Q
# file dumped
# channels to scrape remain:  411693
# UCV-6RtdUlogExo2mzYYYbvQ
# file dumped
# channels to scrape remain:  411692
# UCvLOpYH2Ageu63FxzY1yr-g
# file dumped
# channels to scrape remain:  411691
# UCXz202UpLUU-HjWnwzWO7-Q
# file dumped
# channels to scrape remain:  411690
# UCGRcY1NZyxGbSltx9c23q2g
# file dumped
# channels to scrape remain:  411689
# UCH8ffT04u3y_HdpDd3IqlkQ
# file dumped
# channels to scrape remain:  411688
# UC6D2T1SYLWkNP09X-BhpZqg
# file dumped
# channels to scrape remain:  411687
# UC8pqDydOgTmhgBHmlT5A5PQ
# file dumped
# channels to scrape remain:  411686
# UC2HpBXbi5QE0Y5Gs5hD2jIw
# file dumped
# channels to scrape remain:  411685
# UCFsMhTiVEQqOUqxZbnakmeQ
# file dumped
# channels to scrape remain:  411684
# UCyfQhRG6pqNCz39ms3Zd0Jw
# file dumped
# channels to scrape remain:  411683
# UC6NZeabIkO9MHht95RMlV9w
# file dumped
# channels to scrape remain:  411682
# UC2zGybZeNgHHnBCBYlrp7ig
# file dumped
# channels to scrape remain:  411681
# UCA2IOdx5yiQaXRP3uI9WXfQ
# file dumped
# channels to scrape remain:  411680
# UCEigt8kmmC2DhyRFYuY8Sug
# file dumped
# channels to scrape remain:  411679
# UCLXAjY8OXacbh-KvkA_49rA
# file dumped
# channels to scrape remain:  411678
# UCSDkMnPVcnjmCVngweDc_Ag
# file dumped
# channels to scrape remain:  411677
# UCfrhzwB3Chpf3O3pfuyN0bA
# file dumped
# channels to scrape remain:  411676
# UCktZCTLbV7UzX4t1ONbX9dA
# file dumped
# channels to scrape remain:  411675
# UCAp3I0Dlog3vx8puqPs5jig
# file dumped
# channels to scrape remain:  411674
# UC6_jKHrWIWOQ2tn52vDChmA
# file dumped
# channels to scrape remain:  411673
# UCp4cIwlzh_QImGIMmPDgEZw
# file dumped
# channels to scrape remain:  411672
# UCI8SzUlagNdz0HNpXBtoCKA
# file dumped
# channels to scrape remain:  411671
# UCgWHu81fqM_pe9qnI90ZFDQ
# file dumped
# channels to scrape remain:  411670
# UCWSh4gaQiXVKtlJmQh-daGQ
# file dumped
# channels to scrape remain:  411669
# UC8VDXh51Xx_Qmsk2H1EiNMg
# file dumped
# channels to scrape remain:  411668
# UClLQRcKlXfGFMeNBCMmE5oQ
# file dumped
# channels to scrape remain:  411667
# UCgO6i1u-MPgMNndgD82uJtA
# file dumped
# channels to scrape remain:  411666
# UCORU2FlJZhTi7nbA8ZEQd_Q
# file dumped
# channels to scrape remain:  411665
# UC0K6KmVR4s5ZwW9b4OQ2VHw
# file dumped
# channels to scrape remain:  411664
# UCk3u2l9Kz6o_O5Bs3LaTFPA
# file dumped
# channels to scrape remain:  411663
# UCqPUBrt9ux1MEFs9GmgiaTQ
# file dumped
# channels to scrape remain:  411662
# UC-sZ2L35rb2yNCDfOVGCsvA
# file dumped
# channels to scrape remain:  411661
# UC1BSCI_XWYGRdx81RfsZg9Q
# file dumped
# channels to scrape remain:  411660
# UCZAkPAeVwC5Z10qSURXULzQ
# file dumped
# channels to scrape remain:  411659
# UCtIArfiqqZhzxwAtIZ95QSg
# file dumped
# channels to scrape remain:  411658
# UCA-t9ijcH9ENKWWf5hrRITQ
# file dumped
# channels to scrape remain:  411657
# UC0n7p1fp4WjjWGluCMZjRSg
# file dumped
# channels to scrape remain:  411656
# UC9852P0ywm5m6YSwLJONJQg
# file dumped
# channels to scrape remain:  411655
# UCaM1-DsBp4T6D-iVW0hMcIA
# file dumped
# channels to scrape remain:  411654
# UCDibKYF_RRNqG7uEYopXf_Q
# file dumped
# channels to scrape remain:  411653
# UC5gx8iiLhjnx8UQdnsrvOJg
# file dumped
# channels to scrape remain:  411652
# UCH6R0vfZ88eDFoxBuc9I3eQ
# file dumped
# channels to scrape remain:  411651
# UCM3nYVTVWQDyiBKpsceeRQQ
# file dumped
# channels to scrape remain:  411650
# UC7EbIds0KJ-1VgolQrhqqIw
# file dumped
# channels to scrape remain:  411649
# UCYDTRRU-joy9blpFIle8G2Q
# file dumped
# channels to scrape remain:  411648
# UCjozjWfIetwvU4etHtrW1ng
# file dumped
# channels to scrape remain:  411647
# UCs3yU1xsyAAElwdATiK-KQg
# file dumped
# channels to scrape remain:  411646
# UCO6XgZt1z6JGzEXUkC2PBPw
# file dumped
# channels to scrape remain:  411645
# UCy6kO7mXYCFde063AhI0rfg
# file dumped
# channels to scrape remain:  411644
# UCAIDAhSrhm5wUrKCng23L5Q
# file dumped
# channels to scrape remain:  411643
# UCoeb3tqIwKVjf3S3kZ2fe_g
# file dumped
# channels to scrape remain:  411642
# UCKfEZKJXZwifk0s9GSBv5jw
# file dumped
# channels to scrape remain:  411641
# UCaSp4siC-aWT8KnSPcd_Hkg
# file dumped
# channels to scrape remain:  411640
# UCfQvnAsrpR9ynPzl66bWP8Q
# file dumped
# channels to scrape remain:  411639
# UC8j8jZ3rnOHjrHwu4C0QNHA
# file dumped
# channels to scrape remain:  411638
# UCDzoTPW1UXcbrCMOnOwRPBQ
# file dumped
# channels to scrape remain:  411637
# UCVioXKKDzBG7Gi4pt2DqiLg
# file dumped
# channels to scrape remain:  411636
# UCC7Iip8etivXXEHzTrA6LFg
# file dumped
# channels to scrape remain:  411635
# UCjby9r9pIKzJsLhWSMwc6yA
# file dumped
# channels to scrape remain:  411634
# UCRvAq8SfVT5kt79q1WtWhMw
# file dumped
# channels to scrape remain:  411633
# UCGpy-81U9EKIo1yPJf3gFDQ
# file dumped
# channels to scrape remain:  411632
# UCKGByDDrGdoywM7CX9I7P8Q
# file dumped
# channels to scrape remain:  411631
# UC5F0BD1lzU8eBF9TMOSNRSg
# file dumped
# channels to scrape remain:  411630
# UC0REsuuv6uGt5Ad_NgiPDDw
# file dumped
# channels to scrape remain:  411629
# UCKishk5e_jULCIpclxtT0xw
# file dumped
# channels to scrape remain:  411628
# UCqinQnJsEhCbaAhuBe5x6LA
# file dumped
# channels to scrape remain:  411627
# UCJPQ4N3h9W-YZ3dsqHjLRFA
# file dumped
# channels to scrape remain:  411626
# UCGmCs3qMqgvUKeAIuDnfxpA
# file dumped
# channels to scrape remain:  411625
# UCdaZrpFG81WGXAcd67p7RKA
# file dumped
# channels to scrape remain:  411624
# UCAlUBCR_0P07sjsUUv-D8Wg
# file dumped
# channels to scrape remain:  411623
# UCbqlg_z2IBZ-8DknihHw0RQ
# file dumped
# channels to scrape remain:  411622
# UCXXq-10mG6kUiMK9NE1kYnw
# file dumped
# channels to scrape remain:  411621
# UCcbsQ66-CeR_C5392mHFwRA
# file dumped
# channels to scrape remain:  411620
# UCko-D8oLp4nnQ2-FrgRVhXw
# file dumped
# channels to scrape remain:  411619
# UC-LkXieAgV_MGplrZo9wmZA
# file dumped
# channels to scrape remain:  411618
# UCS6f6pM4Rw417s7sBO-43qg
# file dumped
# channels to scrape remain:  411617
# UCphCTaVgidolzVmS3IjhjGA
# file dumped
# channels to scrape remain:  411616
# UCxAs6gFzL6Zp1ymRur2hMtQ
# file dumped
# channels to scrape remain:  411615
# UCwdGeA0rAuWzKZ5JPbyZB4Q
# file dumped
# channels to scrape remain:  411614
# UC89NSMbaSDK9Q8a6cw2f32Q
# file dumped
# channels to scrape remain:  411613
# UCI4nUQok0LxMU8eBfZdMNyA
# file dumped
# channels to scrape remain:  411612
# UCRDtBxyrHaqILcIG5XvMFwQ
# file dumped
# channels to scrape remain:  411611
# UC8W8HV-EFENjEyHJV64BBiw
# file dumped
# channels to scrape remain:  411610
# UC4_CvyejzFPtp4fAw2BLvnQ
# file dumped
# channels to scrape remain:  411609
# UCE-FUF0x3KakSz-DzLI4NuA
# file dumped
# channels to scrape remain:  411608
# UCqUP_HkFtdk6EBWtTrF1kLQ
# file dumped
# channels to scrape remain:  411607
# UCe136OOkpTOjUMh-lWbO59Q
# file dumped
# channels to scrape remain:  411606
# UCXqmXbv8vpLMOLQQv2rrM4g
# file dumped
# channels to scrape remain:  411605
# UC2V--SPixkFg0nx_9EFAOCw
# file dumped
# channels to scrape remain:  411604
# UCP7zFEymRb9DqWU6IJhADlQ
# file dumped
# channels to scrape remain:  411603
# UCogMH0sarSIvXSAyfJoyo2g
# file dumped
# channels to scrape remain:  411602
# UCCGAQrrsMhUVzegMtbMDgOw
# file dumped
# channels to scrape remain:  411601
# UCd5uFuCH7s3rm5hQqy48D5w
# file dumped
# channels to scrape remain:  411600
# UCpWxXbC6PE-eiOkHTei9uyQ
# file dumped
# channels to scrape remain:  411599
# UCKgE6FnmZQYm4I_yPEVR-tg
# file dumped
# channels to scrape remain:  411598
# UCxSd6vHbEL8xVzulcxx0zmQ
# file dumped
# channels to scrape remain:  411597
# UCNd8k0rr9XbhwLYc3qKMG5w
# file dumped
# channels to scrape remain:  411596
# UCl31LG3Rym9-eq1924OpACw
# file dumped
# channels to scrape remain:  411595
# UCd0ojIqF-OckPyqMRvNH1gg
# file dumped
# channels to scrape remain:  411594
# UC-PvV-AZwsMDtbktKF7e3vg
# file dumped
# channels to scrape remain:  411593
# UCCA-AYH5wHGJ3n0_nFN_x4w
# file dumped
# channels to scrape remain:  411592
# UCn1hjEcsY6QNVTB3oFPCaPA
# file dumped
# channels to scrape remain:  411591
# UCes6XLaDYv3vCrhiAwx8mQw
# file dumped
# channels to scrape remain:  411590
# UCNgcBoJW0swmYi3pLHPXi3g
# file dumped
# channels to scrape remain:  411589
# UCPo41j3k0TNjDoo-O3RcORw
# file dumped
# channels to scrape remain:  411588
# UCO4q7knFfL-m3Qpvnpj_eHw
# file dumped
# channels to scrape remain:  411587
# UCXqh-urTKM-FuB95rqGOatQ
# file dumped
# channels to scrape remain:  411586
# UCgEWa2JvJKzJjvR4ThYBGAQ
# file dumped
# channels to scrape remain:  411585
# UCojK1jicoJE__0fXGVAYKbA
# file dumped
# channels to scrape remain:  411584
# UCqVTJ3STQloqT2ozpIBY9Bw
# file dumped
# channels to scrape remain:  411583
# UCpchx1E-Eqn84GxQHj3m7hg
# file dumped
# channels to scrape remain:  411582
# UCwNYkOgxjx2mIirD6jkOmhw
# file dumped
# channels to scrape remain:  411581
# UCxpsSA3cqosS5U6ciXCkgIQ
# file dumped
# channels to scrape remain:  411580
# UCrgqiPFYJlXH2mvliyAL7JA
# file dumped
# channels to scrape remain:  411579
# UCROViu2I4pT_SNgpPocmgTg
# file dumped
# channels to scrape remain:  411578
# UCO9h9f_D6S2C3Q6VMEbGVTg
# file dumped
# channels to scrape remain:  411577
# UC_iARFdH0TEK_aFRHXnCt7A
# file dumped
# channels to scrape remain:  411576
# UC5nGzl5tiOGfSkhYk9_VqIQ
# file dumped
# channels to scrape remain:  411575
# UC9n9ZPRvSia3IlxjWPneaWw
# file dumped
# channels to scrape remain:  411574
# UCWMkPvB8YlPVKZ2UOiRQGdA
# file dumped
# channels to scrape remain:  411573
# UCOXuzIRwRBYwWA88LovjMkg
# file dumped
# channels to scrape remain:  411572
# UCFzYlOaBEbYwVCkgaZ-9r6g
# file dumped
# channels to scrape remain:  411571
# UCO1mGFz1H-z5NbVggkgJhDw
# file dumped
# channels to scrape remain:  411570
# UCgjlyg27mp-ak9EWKu12nOw
# file dumped
# channels to scrape remain:  411569
# UCcsoUvBLF0VHI-dFYnzkxAA
# file dumped
# channels to scrape remain:  411568
# UCBSTlZkjpHevU48sPxlmNxw
# file dumped
# channels to scrape remain:  411567
# UCSd_ws2w6XN-JArGz9p0awA
# file dumped
# channels to scrape remain:  411566
# UCZ35nR8WeA9WMXwBv6YhD3g
# file dumped
# channels to scrape remain:  411565
# UCkUx97gqFauT5yw1TrXlnig
# file dumped
# channels to scrape remain:  411564
# UCkICEZZGsQS-5vll8BRJWYQ
# file dumped
# channels to scrape remain:  411563
# UCnemKAKkUspiQ3iL4nDO8NA
# file dumped
# channels to scrape remain:  411562
# UCJhQ8cZrmp9eKxALc8Y6rvw
# file dumped
# channels to scrape remain:  411561
# UCRyHlncT8QpQ0lZpBhgoVig
# file dumped
# channels to scrape remain:  411560
# UC8-CyPZEf-K9IP8ReIphPSg
# file dumped
# channels to scrape remain:  411559
# UCsSnrl_EBrXo6yZYkOkl2iQ
# file dumped
# channels to scrape remain:  411558
# UCT_tTPeisGu-jNdsFKrcFkw
# file dumped
# channels to scrape remain:  411557
# UCKUBRi7PPOz0m6K_-zKxIZg
# file dumped
# channels to scrape remain:  411556
# UCD_AMKpD3e5jfIe5jho-XVQ
# file dumped
# channels to scrape remain:  411555
# UC3oNA1ly-3lClLkjNLRdg_g
# file dumped
# channels to scrape remain:  411554
# UCKnFrQd_Z7Y-rwU4rNBH3uA
# file dumped
# channels to scrape remain:  411553
# UCZ7w6XgEm9PAbwQcLW395rA
# file dumped
# channels to scrape remain:  411552
# UCcl73E83OOg2yMGgO_l2c5g
# file dumped
# channels to scrape remain:  411551
# UCAfs61QCrIRX3pxH8LDNDrA
# file dumped
# channels to scrape remain:  411550
# UCYMQsa7KcqeggfMC1gvaMhQ
# file dumped
# channels to scrape remain:  411549
# UCHsWgH-1qcSosBjAqx4ZxdA
# file dumped
# channels to scrape remain:  411548
# UCyYidNL5LxhUSVQ0SOnIXXg
# file dumped
# channels to scrape remain:  411547
# UCwh6xmYbJEMnz_64cZRI_6A
# file dumped
# channels to scrape remain:  411546
# UCojGZgFnodjMsdrGTgfv0-w
# file dumped
# channels to scrape remain:  411545
# UCNNXEj9WcMXLDKE_uL5JJ4A
# file dumped
# channels to scrape remain:  411544
# UCj-jz5vpEjkvQuB52omAgqg
# file dumped
# channels to scrape remain:  411543
# UCR5Bwd4bAEB6Irt3EHYEa9g
# file dumped
# channels to scrape remain:  411542
# UCCaXlTh83UKdA42AMBy5Riw
# file dumped
# channels to scrape remain:  411541
# UC8Ll1TP90DE1jmuB8Q-kLww
# file dumped
# channels to scrape remain:  411540
# UCCCOlCcyFMweqFxhCZDsECQ
# file dumped
# channels to scrape remain:  411539
# UCSWhkMBKhq2RBzkUGX9f3gg
# file dumped
# channels to scrape remain:  411538
# UCCRbKuqKtU4--rAdfY2jV-Q
# file dumped
# channels to scrape remain:  411537
# UC9z2gyHshVj3EGxmSXoqaKg
# file dumped
# channels to scrape remain:  411536
# UCGbpPCj8C7BN4Io75CbQfwA
# file dumped
# channels to scrape remain:  411535
# UClABAHOFuPjS4gVrgN3Iydg
# file dumped
# channels to scrape remain:  411534
# UCY0s3n18wxdd2A0GY3El3tg
# file dumped
# channels to scrape remain:  411533
# UCWj0F4q_sIX3NwZtqJeKM_g
# file dumped
# channels to scrape remain:  411532
# UCwWlkMDM_9kzJzpE5pvx6eQ
# file dumped
# channels to scrape remain:  411531
# UCNfCzra2Gm2tZeH5Fom8tHQ
# file dumped
# channels to scrape remain:  411530
# UCltHNWEbl4evjgrnmha3BJg
# file dumped
# channels to scrape remain:  411529
# UCVdLxI0P2j1o-oHs-W8eX1w
# file dumped
# channels to scrape remain:  411528
# UCCwSK59Pq2PtYREHuQWjC4g
# file dumped
# channels to scrape remain:  411527
# UCRj013S6rDDJYVMx9O1y7RQ
# file dumped
# channels to scrape remain:  411526
# UCAGV4HbRDKPu9ogog74n8zg
# file dumped
# channels to scrape remain:  411525
# UCfiMUo1t9VggX1bDamWVrVQ
# file dumped
# channels to scrape remain:  411524
# UCV9ary1QNTKjSGpHp9165Pw
# file dumped
# channels to scrape remain:  411523
# UCp_FvWYR31J4dBzCySZw7-Q
# file dumped
# channels to scrape remain:  411522
# UCCidabBPzzJLfSWaxYwL-bA
# file dumped
# channels to scrape remain:  411521
# UCqYmRh5BtNkGCAYb2MZ6U1g
# file dumped
# channels to scrape remain:  411520
# UCcXOecExMIAOpnA1lWaDokw
# file dumped
# channels to scrape remain:  411519
# UCrypjuq_vW_8E_A1peujA_g
# file dumped
# channels to scrape remain:  411518
# UCS66Kzl0uIfnug1Z4MgVaVw
# file dumped
# channels to scrape remain:  411517
# UCeVgVNQ7w6x-Zy38JPclsmg
# file dumped
# channels to scrape remain:  411516
# UCyfuJ8Plhc4hRP_TzgcR9Xw
# file dumped
# channels to scrape remain:  411515
# UC763rDGj3xPfXSxSH-ZGrUA
# file dumped
# channels to scrape remain:  411514
# UCNAtLeHa8mpJEl7Krdmo4ZQ
# file dumped
# channels to scrape remain:  411513
# UCHD-fFPvagvbcMxEuOXpbgQ
# file dumped
# channels to scrape remain:  411512
# UCWhMI0oyR_0M0oxF1xgTpbg
# file dumped
# channels to scrape remain:  411511
# UCHTC9amrkQTkCNAhYjDNaIA
# file dumped
# channels to scrape remain:  411510
# UCPSnQtyzXsO7DQvUIgAsQOg
# file dumped
# channels to scrape remain:  411509
# UCFlo4SjTbPLphC4dq8YVmvw
# file dumped
# channels to scrape remain:  411508
# UCI_GEF6rYQABg1KB5OrCyVg
# file dumped
# channels to scrape remain:  411507
# UCq11U660Potwa5R73e5bXPA
# file dumped
# channels to scrape remain:  411506
# UC8yCiYJ5h80PO2EK1q4XI-w
# file dumped
# channels to scrape remain:  411505
# UCrZQZxLAWMfsytP1-lDBwFw
# file dumped
# channels to scrape remain:  411504
# UC2dh64mMQJyk-n_OpwNJA6w
# file dumped
# channels to scrape remain:  411503
# UCotQBccXHP01Qtnk0AmHQWw
# file dumped
# channels to scrape remain:  411502
# UC1MNbjYHD1MKvZnvLId0pSQ
# file dumped
# channels to scrape remain:  411501
# UCXPU4rSccm1SnwpRLQsSC-A
# file dumped
# channels to scrape remain:  411500
# UCeB1wvfVuUM30Djj-6rLDbw
# file dumped
# channels to scrape remain:  411499
# UCyCBDbW_gH2Wj2YYoJ_Vc2g
# file dumped
# channels to scrape remain:  411498
# UCK3ZteaKDD46KN6FhZ6G7Tw
# file dumped
# channels to scrape remain:  411497
# UC85Ev6KM5HgbY4X8hdxWxIw
# file dumped
# channels to scrape remain:  411496
# UCuJYOqF546q_NAXOGajVAVw
# file dumped
# channels to scrape remain:  411495
# UC-3r93jwe3FQrYWxDBQI8LQ
# file dumped
# channels to scrape remain:  411494
# UCAgBT5KJHXGeIRxpGvX0j4A
# file dumped
# channels to scrape remain:  411493
# UC4-KC5n9pXVVTaw5v8LEadw
# file dumped
# channels to scrape remain:  411492
# UCU9O0IObsDio2dqxcRg0n8g
# file dumped
# channels to scrape remain:  411491
# UCkwnoGZhSZUICpPPp7tU-wA
# file dumped
# channels to scrape remain:  411490
# UCtpDNVldy6p7oAyqfkCZlaQ
# file dumped
# channels to scrape remain:  411489
# UCn3OXQL0HA7PZD18FgVmlIA
# file dumped
# channels to scrape remain:  411488
# UCcXItLC44K4EdgiD-yvTnbw
# file dumped
# channels to scrape remain:  411487
# UCd4GPRtPDHYvPVI4MQIIvww
# file dumped
# channels to scrape remain:  411486
# UCuE3ILOyD7EZk-XZjIhf2EA
# file dumped
# channels to scrape remain:  411485
# UC3656WwWVtJUPD_9NgJ6WEg
# file dumped
# channels to scrape remain:  411484
# UCGviUJWGcTCucK4PvpRaIwg
# file dumped
# channels to scrape remain:  411483
# UCR19hJgMbWassVu9G7j5FbQ
# file dumped
# channels to scrape remain:  411482
# UCOcyUL9jEwLFPlXde5tznKw
# file dumped
# channels to scrape remain:  411481
# UCXYcCvnDR0mYusn8RX5d5sg
# file dumped
# channels to scrape remain:  411480
# UCN7_3F3U5RW82khcim5qxiQ
# file dumped
# channels to scrape remain:  411479
# UCOfa3Tq5uNJR0Cs-yUby9nA
# file dumped
# channels to scrape remain:  411478
# UCYbm4KSUE1p_nvYzhZr7Mig
# file dumped
# channels to scrape remain:  411477
# UCtv3vKWP48xsucsDoR2iCVQ
# file dumped
# channels to scrape remain:  411476
# UCZ67Yhpu1fmq8JLzm5nKtoQ
# file dumped
# channels to scrape remain:  411475
# UClCsV5LeHIxQTZ_fxfE97Tg
# file dumped
# channels to scrape remain:  411474
# UCQX4Cy64fw0neybFUdrgwsg
# file dumped
# channels to scrape remain:  411473
# UCCEkLDekMAI7Lpdn9D6J8Jg
# file dumped
# channels to scrape remain:  411472
# UCAl6cOHapRb0Mb166Y2YnQA
# file dumped
# channels to scrape remain:  411471
# UCUgAHBV4_Cac2sjdDEy4lIA
# file dumped
# channels to scrape remain:  411470
# UCC87oLkVi6_h07oqK_nws1w
# file dumped
# channels to scrape remain:  411469
# UCk3OzO3_EZJzOAt7a5gl5iQ
# file dumped
# channels to scrape remain:  411468
# UCyrkq55nO5LOxWY-2W836zg
# file dumped
# channels to scrape remain:  411467
# UCCJlgWv4BH5HJjCiB_AS37w
# file dumped
# channels to scrape remain:  411466
# UCsQjnXtBTscr5-kMGVJLpLw
# file dumped
# channels to scrape remain:  411465
# UCMo62tNnelhmATBO2jnkijg
# file dumped
# channels to scrape remain:  411464
# UCERaYDXjNrxoYH3yDh1WJ8Q
# file dumped
# channels to scrape remain:  411463
# UCZ_cImdkQKettoXw9pOcG4A
# file dumped
# channels to scrape remain:  411462
# UCht939pJTnjXlzaPaIPc1Yg
# file dumped
# channels to scrape remain:  411461
# UCBZ6zFMgi0UWokNbhnQbhKw
# file dumped
# channels to scrape remain:  411460
# UCQmejf2RWV-KRrMEukiOJjw
# file dumped
# channels to scrape remain:  411459
# UCFe-gShrfO1-htUg4m0PoGw
# file dumped
# channels to scrape remain:  411458
# UCyqQSrPlXqH6WtnO9wx2UGg
# file dumped
# channels to scrape remain:  411457
# UCDo2q0HIJQ_d2YnpIcDfcBw
# file dumped
# channels to scrape remain:  411456
# UCleQwVVHRAo5hJU-0wwN5ag
# file dumped
# channels to scrape remain:  411455
# UCz5eOU1hecBFCF6izImnjQA
# file dumped
# channels to scrape remain:  411454
# UCSPhPtHRF2gNQ821QC1Gokg
# file dumped
# channels to scrape remain:  411453
# UC3HEkBsn7ST9vVNqDGA2YGA
# file dumped
# channels to scrape remain:  411452
# UC-M82y1Paw6DwFim1B7rLug
# file dumped
# channels to scrape remain:  411451
# UCwWuoHW61dJwZxK0xugWAzg
# file dumped
# channels to scrape remain:  411450
# UCEEOlQKskTIiDIJuoBveSQw
# file dumped
# channels to scrape remain:  411449
# UCWUKr29MzI-EdM2kRPl6gmg
# file dumped
# channels to scrape remain:  411448
# UCEV3SBj0RT0bmrjqK6PJd5A
# file dumped
# channels to scrape remain:  411447
# UClOb2okATZvNwkx78ZV3dcw
# file dumped
# channels to scrape remain:  411446
# UCnt7OzyAThRufTZN72SuKzQ
# file dumped
# channels to scrape remain:  411445
# UCrSwfw-CyUq9VfHXiU83QaA
# file dumped
# channels to scrape remain:  411444
# UCOZbHM8wGl7rziKJy7w7GKA
# file dumped
# channels to scrape remain:  411443
# UCa26eHk5YqtORuEOfIX1_Hg
# file dumped
# channels to scrape remain:  411442
# UCDjf28Q--KF_O4XP1oGLWQA
# file dumped
# channels to scrape remain:  411441
# UC2IN2F4Fzjl5Cnnood4pDfA
# file dumped
# channels to scrape remain:  411440
# UCVPwrsYq2silcZ8SgtYtzEQ
# file dumped
# channels to scrape remain:  411439
# UCyNjMuEWx9l_17ihzeaiDlA
# file dumped
# channels to scrape remain:  411438
# UC9fQ-e2bVvbmLZOc9MCH1rw
# file dumped
# channels to scrape remain:  411437
# UCOZq0mXJBAU_zeuuoxmJEwg
# file dumped
# channels to scrape remain:  411436
# UCykgxQHo5hhTFShbeIEQozw
# file dumped
# channels to scrape remain:  411435
# UCrL8yGKNWIent0TB5PkJr5g
# file dumped
# channels to scrape remain:  411434
# UC-Ujc7L31XLOmXUifbYwHzw
# file dumped
# channels to scrape remain:  411433
# UCQvXsuq52dAh6PSk3v-G3EA
# file dumped
# channels to scrape remain:  411432
# UCfGAPhIAOawGXV7SxWzcLEA
# file dumped
# channels to scrape remain:  411431
# UC_t7nBcmd5IpbL-Wat1lsXA
# file dumped
# channels to scrape remain:  411430
# UCEvz8tNNisBACktozBy501Q
# file dumped
# channels to scrape remain:  411429
# UCEpRc8rqa8ydcajypWOshBQ
# file dumped
# channels to scrape remain:  411428
# UCrcS0vRhFWayGeu_TUQGtUw
# file dumped
# channels to scrape remain:  411427
# UCljnuGdlITTjiU0tDi3swsA
# file dumped
# channels to scrape remain:  411426
# UCT6x3mcU2we0_WIldFgoFMw
# file dumped
# channels to scrape remain:  411425
# UCP8QfIldIbDeA8_Ar-Qk3qQ
# file dumped
# channels to scrape remain:  411424
# UCZ4BQhv6YaO4Y5Qf-8JqGhw
# file dumped
# channels to scrape remain:  411423
# UCHLOqscVXo_Odj2bZ229nFg
# file dumped
# channels to scrape remain:  411422
# UCJsObUxBGG_Rikr5SqHXPxQ
# file dumped
# channels to scrape remain:  411421
# UCVlSSkC47r_6eLKRBVxg3FA
# file dumped
# channels to scrape remain:  411420
# UCz2ILUHaaahPY2tMzK7mO4A
# file dumped
# channels to scrape remain:  411419
# UCG1gYYOoPEI7H1AvNpUQxKQ
# file dumped
# channels to scrape remain:  411418
# UCsJ3LtMUQ--qWBQjpUoyDng
# file dumped
# channels to scrape remain:  411417
# UClmCwaepOCp3wEGXaen3aog
# file dumped
# channels to scrape remain:  411416
# UCK-gxZ8MFpMleR2TgfFjziw
# file dumped
# channels to scrape remain:  411415
# UCyglZvWciyr5Cm6NPsZQTWA
# file dumped
# channels to scrape remain:  411414
# UCIFd4qbQTAHM_bPVh-SpZXg
# file dumped
# channels to scrape remain:  411413
# UCFbm6n7OZgtTiRLOer4BAQQ
# file dumped
# channels to scrape remain:  411412
# UCuop6PZKy9tKG60h4VSdGBg
# file dumped
# channels to scrape remain:  411411
# UCm8PUSDINN7HAUXTQ3832SQ
# file dumped
# channels to scrape remain:  411410
# UC7Y_eA00lg1vtSfs3BEeTfw
# file dumped
# channels to scrape remain:  411409
# UCIsEPo8j14FGrGvQg-4qq1Q
# file dumped
# channels to scrape remain:  411408
# UCRtG8D441pawvYBjs3pPE4A
# file dumped
# channels to scrape remain:  411407
# UC3ccqsPULHv1G3Lu4tiz3Ug
# file dumped
# channels to scrape remain:  411406
# UCsm19RC4SfXO8uXfzcWqyPQ
# file dumped
# channels to scrape remain:  411405
# UC4ZbJdDli4RBa9BkYyG4cBQ
# file dumped
# channels to scrape remain:  411404
# UCuWpoYCcxSkLIBPVsq50xzg
# file dumped
# channels to scrape remain:  411403
# UCNPTtyr_r2QtWQethXOSEcw
# file dumped
# channels to scrape remain:  411402
# UCW2yieZeBGOpZRAoabMZ3VQ
# file dumped
# channels to scrape remain:  411401
# UCWuGzfWStnrkmrba6qCK8uQ
# file dumped
# channels to scrape remain:  411400
# UCM4I6AXAzdBB_JP1RNbXK5Q
# file dumped
# channels to scrape remain:  411399
# UCQnEZ3YMqU8t9Hl3qTzDWxw
# file dumped
# channels to scrape remain:  411398
# UCq1noPwmgXz_MWi1Czaz5wA
# file dumped
# channels to scrape remain:  411397
# UCWLu-J6v3n2iYI2x5hfmSYA
# file dumped
# channels to scrape remain:  411396
# UCI7ccwnF9-pdTxWMCyonqzQ
# file dumped
# channels to scrape remain:  411395
# UC5wO10zxDK5QztYRw3v-wpg
# file dumped
# channels to scrape remain:  411394
# UCnpnwqT5HOl13QlrBPiKQFw
# file dumped
# channels to scrape remain:  411393
# UC35Q3ERwwYOCtz9a3aAIYww
# file dumped
# channels to scrape remain:  411392
# UCYAAz4LTX4T2eJ0_xUTyYpw
# file dumped
# channels to scrape remain:  411391
# UCWfPYiJCSswAw94BEMPBTNg
# file dumped
# channels to scrape remain:  411390
# UCcUlA-iRkLssngrbIEQiUTg
# file dumped
# channels to scrape remain:  411389
# UCNzZuX_7imfYJ07yc_xXing
# file dumped
# channels to scrape remain:  411388
# UC8yv_JTcA6u4S015dD7Jujg
# file dumped
# channels to scrape remain:  411387
# UC8ZpDyhoGT2xTQxYZB_WP4A
# file dumped
# channels to scrape remain:  411386
# UC0ZjcvYuyBLXsGhZOZvPi6w
# file dumped
# channels to scrape remain:  411385
# UCpER06OJlpxyDmeB1oQTWNQ
# file dumped
# channels to scrape remain:  411384
# UCjnaLfviWr_nP3xS2kS1X8g
# file dumped
# channels to scrape remain:  411383
# UCrrShwevhxcFVbm8KTFLvxw
# file dumped
# channels to scrape remain:  411382
# UCGAdKzFdhFCU3-TilitGIYw
# file dumped
# channels to scrape remain:  411381
# UCsZ2Ttyn6_RIlyC02iU0yEQ
# file dumped
# channels to scrape remain:  411380
# UCHK-HPWcUo-aGHs3udyGWZw
# file dumped
# channels to scrape remain:  411379
# UC5V3TmKMWaQ8kGAhsCQQRPA
# file dumped
# channels to scrape remain:  411378
# UCKdnYLRxa1P2sBOmB4opfIg
# file dumped
# channels to scrape remain:  411377
# UC1bEe3kZOJ32h1SkhzGCrxQ
# file dumped
# channels to scrape remain:  411376
# UC5pLMDyUWAYAOKiILu_0qXQ
# file dumped
# channels to scrape remain:  411375
# UCuCLQW1PKV-zsYTuI_gU6GQ
# file dumped
# channels to scrape remain:  411374
# UCp_bZMf2XCwA0wU_CIZgNKw
# file dumped
# channels to scrape remain:  411373
# UCtFjka6sjN3JTYFp0ZCqdTg
# file dumped
# channels to scrape remain:  411372
# UCCrFEGNkk0CwcM6F9eazDww
# file dumped
# channels to scrape remain:  411371
# UCHLB2_S9YKimhBvpG1mdwnA
# file dumped
# channels to scrape remain:  411370
# UC0-hhUjQoIpvjarJvbU71cQ
# file dumped
# channels to scrape remain:  411369
# UC_Pd0i_b8c2ckWZtWBHmlOQ
# file dumped
# channels to scrape remain:  411368
# UC2LJY_ML06v5MdfVVa-uOpA
# file dumped
# channels to scrape remain:  411367
# UCd8F1clp0UGtOLULWVh7aig
# file dumped
# channels to scrape remain:  411366
# UCRMwuRP4ekmdiHyw8qckopg
# file dumped
# channels to scrape remain:  411365
# UCfUM50nwy8j2kgzDsh9JaNQ
# file dumped
# channels to scrape remain:  411364
# ...
# file dumped
# channels to scrape remain:  408030
# UCqAGavlsPigBY_kklzNrxFg
# file dumped
# channels to scrape remain:  408029
# UCyH9OWX1-k3vFos7fK-mdjA
# file dumped
# channels to scrape remain:  408028
# UCy2iNB04lwTVHX8YIkWgLXA
# file dumped
# channels to scrape remain:  408027
# UCky8nLWvrtBYSoZaMxnudqg
# file dumped
# channels to scrape remain:  408026
# UCzLc5_aOV6UPn4gzgwNPq1Q
# file dumped
# channels to scrape remain:  408025
# UCHp3VzYwZkH70syGYlkXYWg
# file dumped
# channels to scrape remain:  408024
# UCqzpAYAFrWZUFicoYIe6uCw
# file dumped
# channels to scrape remain:  408023
# UChtseKppFjRfKiz5Pgi4Gtw
# file dumped
# channels to scrape remain:  408022
# UCYuRZ5gKTy10D06UmAq58gA
# file dumped
# channels to scrape remain:  408021
# UCc7nCfzDAs6GmfqI7U3CXlA
# file dumped
# channels to scrape remain:  408020
# UCIO8I9_baWe2yAaxs76jfGg
# file dumped
# channels to scrape remain:  408019
# UChHoGw9yyWJZe0mJsq-igyw
# file dumped
# channels to scrape remain:  408018
# UCj7a3hLWj7qgWAwTQvhRqdw
# file dumped
# channels to scrape remain:  408017
# UCVmv1TMa18qu0nbgWOESlTg
# file dumped
# channels to scrape remain:  408016
# UCx0kanu7vLuuAT8t5tvnDPA
# file dumped
# channels to scrape remain:  408015
# UCzLj4G4eBzwuHZ1aeVfRg4w
# file dumped
# channels to scrape remain:  408014
# UCbmdOW7TVCT8ES14hs7QqVA
# file dumped
# channels to scrape remain:  408013
# UCwHu6kVz3z1vde2ybkMZhUA
# file dumped
# channels to scrape remain:  408012
# UCS7qHYQ4_i2WeaZfcAhE_9g
# file dumped
# channels to scrape remain:  408011
# UCo3KHjhMBNrlrp3bXfxxHKw
# file dumped
# channels to scrape remain:  408010
# UCcrtpeY8gNU0y5cyBLri_HA
# file dumped
# channels to scrape remain:  408009
# UCgX2CG4JGIvjJFVS2ho_ufg
# file dumped
# channels to scrape remain:  408008
# UCF7abtSzV6rKSRV1QP2wxbw
# file dumped
# channels to scrape remain:  408007
# UCN9xb-3kL_Zb25CFWo_03xg
# file dumped
# channels to scrape remain:  408006
# UC5Hg9GkN4VeMob_-haeNgSQ
# file dumped
# channels to scrape remain:  408005
# UCGuooadIwVHFmoVZkG2SGTg
# file dumped
# channels to scrape remain:  408004
# UC_MjitzGBbEb0uYuGGJbJVw
# file dumped
# channels to scrape remain:  408003
# UCa9SE0oo8gw6pKsj4-Ven6Q
# file dumped
# channels to scrape remain:  408002
# UC3979L3-k7QT0LNqGAwCoLA
# file dumped
# channels to scrape remain:  408001
# UC8hClNLrtZLLjtdsC2x-1dQ
# file dumped
# channels to scrape remain:  408000
# UCm2JcW17kqSLUVh9GJp8oDg
# file dumped
# channels to scrape remain:  407999
# UCZzDhiG9mxefWu1OC5X2wwg
# file dumped
# channels to scrape remain:  407998
# UCiNaS7h9m0iw4jN1usOUGXw
# file dumped
# channels to scrape remain:  407997
# UCIGkMkWsoF5O05f7JimCy4A
# file dumped
# channels to scrape remain:  407996
# UC2AWFgIP7Pmw4yoJjAkpXug
# file dumped
# channels to scrape remain:  407995
# UC1ph786092w0NAgKcczKFag
# file dumped
# channels to scrape remain:  407994
# UCkCXNvc15OMKm7kjNaGghYQ
# file dumped
# channels to scrape remain:  407993
# UCDfhwr0qEuPnECwOc0pfiNg
# file dumped
# channels to scrape remain:  407992
# UCsncLG4iuEOprvJw2WNErPw
# file dumped
# channels to scrape remain:  407991
# UCeqq-oLWl1gz6J50dJktGew
# file dumped
# channels to scrape remain:  407990
# UCb1sGXTfuZq5Q7vqXhHDMjg
# file dumped
# channels to scrape remain:  407989
# UCdHZNltOD6QmnkmfMNnPXPg
# file dumped
# channels to scrape remain:  407988
# UC4LURiN_ZgsFj7aRqhOQvIQ
# file dumped
# channels to scrape remain:  407987
# UC6cxXHKSgbc-OoI9cDnzCAg
# file dumped
# channels to scrape remain:  407986
# UCOXfaspqLCTUxCQ7Sqq1vpw
# file dumped
# channels to scrape remain:  407985
# UC5WPeo79JC5WODEUXtjBIhQ
# file dumped
# channels to scrape remain:  407984
# UCf-m-FWdttghjP8jjoYzZ0g
# file dumped
# channels to scrape remain:  407983
# UCPR2zNRkWrKQbx7HMhp_sUw
# file dumped
# channels to scrape remain:  407982
# UCD3rGiRj0KKj-dQSEd7HVLQ
# file dumped
# channels to scrape remain:  407981
# UCLBPEDcuCFgcuiylqlJg7gQ
# file dumped
# channels to scrape remain:  407980
# UC1t9azKE8ktQQWfp1VCAugg
# file dumped
# channels to scrape remain:  407979
# UCLB0o_y8FveXkVj_XaxNVfQ
# file dumped
# channels to scrape remain:  407978
# UC4qibUchMukJ7Ld4Tezf2Qg
# file dumped
# channels to scrape remain:  407977
# UC5NxegDs5tru__mzXr9rPKA
# file dumped
# channels to scrape remain:  407976
# UCp2UWbtXxGjDaUIUUEXg6Ng
# file dumped
# channels to scrape remain:  407975
# UCfTjaF1LnRiAO2ne_wZ2G4A
# file dumped
# channels to scrape remain:  407974
# UCjILcMh6D1iqHGKfF3hA3JA
# file dumped
# channels to scrape remain:  407973
# UCXV3qcAsarez59wxCc5ZFAw
# file dumped
# channels to scrape remain:  407972
# UCibz2cey9ETXDX6VN6f7YRw
# file dumped
# channels to scrape remain:  407971
# UCrmjoJSaOCx1I5XNvUz3K_g
# file dumped
# channels to scrape remain:  407970
# UCvjwejvMt19nma7BdRP1Xkg
# file dumped
# channels to scrape remain:  407969
# UC81gTliIH93PTu3qsb50E7Q
# file dumped
# channels to scrape remain:  407968
# UCZTmxID7BW09zkwZOCMmdMg
# file dumped
# channels to scrape remain:  407967
# UCav2oiFOw6q1AiFySgMz_OQ
# file dumped
# channels to scrape remain:  407966
# UCvTalGGv_XSHz2t32NXVeyA
# file dumped
# channels to scrape remain:  407965
# UCa2xfyfnZMOel2E4OHFnO0Q
# file dumped
# channels to scrape remain:  407964
# UClcOew0pQw42iDkeunsnnYw
# file dumped
# channels to scrape remain:  407963
# UCUzrfxxGi2H6lTDtwO-kHcg
# file dumped
# channels to scrape remain:  407962
# UCGsPrVZdxaCVXfoj0qr4P7Q
# file dumped
# channels to scrape remain:  407961
# UCuQl5eK-3JyPx5lMnSV7h-w
# file dumped
# channels to scrape remain:  407960
# UCbj_yTytUD9ZM3oon3CGn3Q
# file dumped
# channels to scrape remain:  407959
# UCD1sHHGyYrBOwS5EGrt3Hdw
# file dumped
# channels to scrape remain:  407958
# UC5RFX_dT6l-A7DvZo5wnhbg
# file dumped
# channels to scrape remain:  407957
# UC0hUQA2ZAeSoVzAdhxVB8Xw
# file dumped
# channels to scrape remain:  407956
# UCBLHGrwjEhhFWX2Ne1ATa-Q
# file dumped
# channels to scrape remain:  407955
# UCgEHmdVZdiWQa0PfQKQmqIg
# file dumped
# channels to scrape remain:  407954
# UCQCk861LRgy-7ExLaoAW_fg
# file dumped
# channels to scrape remain:  407953
# UCGTKGhL4IF0Bh_vRuwduDmw
# file dumped
# channels to scrape remain:  407952
# UCRFh0u4oorehLsLdsH3J83A
# file dumped
# channels to scrape remain:  407951
# UCbLekdpxeQpwj0hTNvPUwaQ
# file dumped
# channels to scrape remain:  407950
# UC8qP3xN2epTp1O2OFyQ2xaA
# file dumped
# channels to scrape remain:  407949
# UCtJr7wuMExwm354aT7Lf01g
# file dumped
# channels to scrape remain:  407948
# UC7WYnAjLXgXn6cV_yLMqotA
# file dumped
# channels to scrape remain:  407947
# UCN2UUNo-ATcHnmRiz86mYtA
# file dumped
# channels to scrape remain:  407946
# UCDvVUE3aF-7GsyYRKhhJQCw
# file dumped
# channels to scrape remain:  407945
# UCfvVhNgsBCvWzlLLTrFP7qw
# file dumped
# channels to scrape remain:  407944
# UCuGsj9RBpcucPMIbu5QAmrw
# file dumped
# channels to scrape remain:  407943
# UCQNB3geVJ01vqLHV14hp0SA
# file dumped
# channels to scrape remain:  407942
# UCDOjS8rq0RY0STDXeKsi8Ew
# file dumped
# channels to scrape remain:  407941
# UCHyJfHnlIFEHkXWxFfUORkA
# file dumped
# channels to scrape remain:  407940
# UCqXDcpOJZgVRUCfTRRrLrSA
# file dumped
# channels to scrape remain:  407939
# UCYy2ikzJnxNfEfM3tZnsKHQ
# file dumped
# channels to scrape remain:  407938
# UCiulxhH2KARa2tayOtpCs_A
# file dumped
# channels to scrape remain:  407937
# UCaDP3IUJnykeGQhsnRwKJXw
# file dumped
# channels to scrape remain:  407936
# UCgcW8RLpozhuYnPbZ8tCzGg
# file dumped
# channels to scrape remain:  407935
# UCa7EvqiuE7N0sg5_OB-XA-Q
# file dumped
# channels to scrape remain:  407934
# UCIMqIef0v7rK4kBvOcfL43g
# file dumped
# channels to scrape remain:  407933
# UCjwahQ0ZO8iKsuTIlF8hqqA
# file dumped
# channels to scrape remain:  407932
# UCXmYS3UtQDAo0pN5bz3jXhg
# file dumped
# channels to scrape remain:  407931
# UCPfChbWqpbiKqzA4KQTBh9Q
# file dumped
# channels to scrape remain:  407930
# UCRNSDqyPA-C4Qk3S6Oug_wA
# file dumped
# channels to scrape remain:  407929
# UCjILfVD-A8CXEkKcBSTkKZQ
# file dumped
# channels to scrape remain:  407928
# UCIcvjOwE-pAStyFqvK23AOw
# file dumped
# channels to scrape remain:  407927
# UCBtfIyPKx3lsLyqgzkIm3pA
# file dumped
# channels to scrape remain:  407926
# UCbprFO7wIicLH3IlDY9rUmw
# file dumped
# channels to scrape remain:  407925
# UC1fOjuho5IHBQRhwy8zRhaw
# file dumped
# channels to scrape remain:  407924
# UCqR2_gfNskV_7RCMywTLkhA
# file dumped
# channels to scrape remain:  407923
# UC5LxEvNuMsdYeBcEmjtMbww
# file dumped
# channels to scrape remain:  407922
# UCBnM-dFAxvYOezd9pFghA-A
# file dumped
# channels to scrape remain:  407921
# UCU0zi-EgU_W09EAQ4qexwOQ
# file dumped
# channels to scrape remain:  407920
# UCXYlv9S8harIZR0mgiejTeA
# file dumped
# channels to scrape remain:  407919
# UCi889gA4BpT0fROwBRwnYvQ
# file dumped
# channels to scrape remain:  407918
# UCU65lXLSpmQwbAAB1HcMykg
# file dumped
# channels to scrape remain:  407917
# UCtIkE8rM6RJtAt6yvChMLeQ
# file dumped
# channels to scrape remain:  407916
# UCEZD13a7NDmzBcq2trnSAmg
# file dumped
# channels to scrape remain:  407915
# UCM1_sRu-qtt3q1z65AAlwSQ
# file dumped
# channels to scrape remain:  407914
# UCuw-p8v9awNlzIrS5vlfbnA
# file dumped
# channels to scrape remain:  407913
# UC-7ItHcLWf9pp_VIi5QtpbA
# file dumped
# channels to scrape remain:  407912
# UCbLDaHADzhej1XSKELdBh5Q
# file dumped
# channels to scrape remain:  407911
# UC0CBlqxczyi-xNEhbLdQ04g
# file dumped
# channels to scrape remain:  407910
# UCNfOrMy3s43so-la8_uOKaw
# file dumped
# channels to scrape remain:  407909
# UC-0VLjBjUnPHBD82ncdUCSA
# file dumped
# channels to scrape remain:  407908
# UC2QVJYv3Xl2LWAgtuxPyAnA
# file dumped
# channels to scrape remain:  407907
# UC2QCTdTG4BP_WilR3sxjBfw
# file dumped
# channels to scrape remain:  407906
# UC-3xoBN8AkXF-p2A9XkUYBg
# file dumped
# channels to scrape remain:  407905
# UCXnDYhQvsAOleI2mJWxx16g
# file dumped
# channels to scrape remain:  407904
# UCb3nsd1Xt5EYS1o_yt_u1pw
# file dumped
# channels to scrape remain:  407903
# UCXG1ClCmP8kOkEsP60wmlxA
# file dumped
# channels to scrape remain:  407902
# UCduWyokZIT7oY_EEuLuRPtQ
# file dumped
# channels to scrape remain:  407901
# UCMnQ3uw3_kvOI4_3X8SwRJw
# file dumped
# channels to scrape remain:  407900
# UCAYlf6VdJw-hO-34OrpqHWw
# file dumped
# channels to scrape remain:  407899
# UCYA-EftaExOpKbrQ-ObVIZA
# file dumped
# channels to scrape remain:  407898
# UCt-GcYu2hz6fnNghg2H-EAg
# file dumped
# channels to scrape remain:  407897
# UCcvcxOTwJysRcKo-yZLtLqA
# file dumped
# channels to scrape remain:  407896
# UC8MYlB_3rPSJSJHaqEBPEzA
# file dumped
# channels to scrape remain:  407895
# UCu2O7KO3zQQjnxB5nyg6QvQ
# file dumped
# channels to scrape remain:  407894
# UCkHUMJZ-iElPb8RDIzRKjOA
# file dumped
# channels to scrape remain:  407893
# UCXKO_RS_8UkomdSQCoAJvXw
# file dumped
# channels to scrape remain:  407892
# UCIZFw-erkhdkqH92-qWwgaw
# file dumped
# channels to scrape remain:  407891
# UCMweiIT4AYe9I2AaKWegqFA
# file dumped
# channels to scrape remain:  407890
# UCJa-gQOHEfaz7PlmTc6RG6A
# file dumped
# channels to scrape remain:  407889
# UC_sRjXJr3dkP6tGaeYKZVHA
# file dumped
# channels to scrape remain:  407888
# UCdznCf6E0ZX4BEKUkFjR5tQ
# file dumped
# channels to scrape remain:  407887
# UCWckWljqwFWjuxoMrHUj32w
# file dumped
# channels to scrape remain:  407886
# UC2HdjKm0NL3W10KG0Q0jlfg
# file dumped
# channels to scrape remain:  407885
# UCKPvnhAfVjXHrJpQoW3AE5w
# file dumped
# channels to scrape remain:  407884
# UC7dH3l5K4TWOy6BNE0NvaPQ
# file dumped
# channels to scrape remain:  407883
# UCvbTyAR0be___rBWeG_4qLg
# file dumped
# channels to scrape remain:  407882
# UC1wJuIo0gudVZwJ4R4ZvCwA
# file dumped
# channels to scrape remain:  407881
# UCw63l86pP2RX1v6BHHUbDow
# file dumped
# channels to scrape remain:  407880
# UCQEKBpGJxza5gZOjXDOmZcw
# file dumped
# channels to scrape remain:  407879
# UCEuk9OsSeyVkdpUoDtq2udg
# file dumped
# channels to scrape remain:  407878
# UCKNeQsT8aSeYY20Mpdwg7dw
# file dumped
# channels to scrape remain:  407877
# UCmskFjsVdEpJOkvRr4wKjEw
# file dumped
# channels to scrape remain:  407876
# UCtA_OijLgOHR1DmknAqanZg
# file dumped
# channels to scrape remain:  407875
# UCBHd6kJOWE13dbcl71uiHkw
# file dumped
# channels to scrape remain:  407874
# UCybVl8zHoIwlq6sfk-DeL0Q
# file dumped
# channels to scrape remain:  407873
# UCm-b1hRkMUI8R0G6idVMJLA
# file dumped
# channels to scrape remain:  407872
# UCr0Aw13RCTTiYFbmGZFlDtw
# file dumped
# channels to scrape remain:  407871
# UCd8prVdlQtUe5PWkgY-1cYw
# file dumped
# channels to scrape remain:  407870
# UCXmSydp6eCs8nEnquFnQrNg
# file dumped
# channels to scrape remain:  407869
# UC4cRF4gAxOxyVzxFyODlyVg
# file dumped
# channels to scrape remain:  407868
# UCKDYh-yp_jGbJb7KqDT2JWQ
# file dumped
# channels to scrape remain:  407867
# UC1mBjrRsryER20hjJO3FOPg
# file dumped
# channels to scrape remain:  407866
# UCCCNgUHbh8dQXd0ufRJ6OIA
# file dumped
# channels to scrape remain:  407865
# UC_zku6hpjct2_Y9tju7LqoA
# file dumped
# channels to scrape remain:  407864
# UCkRqpFLHGpu_mrr2RwBaDeQ
# file dumped
# channels to scrape remain:  407863
# UC2j59icPkFSTLQznJFWdOWw
# file dumped
# channels to scrape remain:  407862
# UCkP-jXlBEfg2JZ7QEMMHm6w
# file dumped
# channels to scrape remain:  407861
# UCeR-PXfMWXXJ_iDwTiqBoBA
# file dumped
# channels to scrape remain:  407860
# UCTqleWsNH-KwU5Cdr9wviiA
# file dumped
# channels to scrape remain:  407859
# UC28m2YTCVs5VTDvpuF91kZg
# file dumped
# channels to scrape remain:  407858
# UC1tt6yxOrEMz3TsvLUYT5JA
# file dumped
# channels to scrape remain:  407857
# UC-5mgqfaP1i963lrfMBt9OA
# file dumped
# channels to scrape remain:  407856
# UCQJwcxFPg7K7fR77vwaD-0g
# file dumped
# channels to scrape remain:  407855
# UCTpVPqpEA7wOredDKBDHq0A
# file dumped
# channels to scrape remain:  407854
# UCIJz9ewQNPsw91lsRJL-1Ag
# file dumped
# channels to scrape remain:  407853
# UCNLN2L6F2Yyg4ZQjqrmFCng
# file dumped
# channels to scrape remain:  407852
# UCg3Y6ilknZXMp9BC2AwSpsg
# file dumped
# channels to scrape remain:  407851
# UCAKrICal7fVnfW3fw1tk51w
# file dumped
# channels to scrape remain:  407850
# UCygaNIQUTDE8rO5gesAv5-A
# file dumped
# channels to scrape remain:  407849
# UCW3HxNGFR2apwy30pGIJg2g
# file dumped
# channels to scrape remain:  407848
# UCXuV7tzmAvyjZJXECiyfokA
# file dumped
# channels to scrape remain:  407847
# UCcQbuOFOKS-fOM3oJHOnN_Q
# file dumped
# channels to scrape remain:  407846
# UC9f2FwoAkjhlG2SDCH5KGgw
# file dumped
# channels to scrape remain:  407845
# UCH2wCC2vlTNCo_1aeVxo1SQ
# file dumped
# channels to scrape remain:  407844
# UCl8AI72GAtFzwfhDz8c1w4w
# file dumped
# channels to scrape remain:  407843
# UCK_nm1aT-EadRbYXRSaKFww
# file dumped
# channels to scrape remain:  407842
# UCDKtRg_y4vK3joN9Hz38qQg
# file dumped
# channels to scrape remain:  407841
# UCaAczOeJ7s5b5pHXFjRYlbA
# file dumped
# channels to scrape remain:  407840
# UCOIcV10vGUCKYMfAvtcTj0g
# file dumped
# channels to scrape remain:  407839
# UCCXeqSYnlfcEyj2iwjKQ1VA
# file dumped
# channels to scrape remain:  407838
# UCTCvxwyaeoHp4h9trtXU2Hw
# file dumped
# channels to scrape remain:  407837
# UCf0nugUUOFzSl1Ekk5S28Gg
# file dumped
# channels to scrape remain:  407836
# UC1JyMQyjPgbXFG14k8iadmQ
# file dumped
# channels to scrape remain:  407835
# UCbYSLopZksvdp1ITcY-5D3Q
# file dumped
# channels to scrape remain:  407834
# UCIYfXJBTaw0u_URcub3OdXw
# file dumped
# channels to scrape remain:  407833
# UC-09IQIy77Qvf19DZyb0lRQ
# file dumped
# channels to scrape remain:  407832
# UCWG_dm4ovn6pdwOLmC4sNwQ
# file dumped
# channels to scrape remain:  407831
# UCRf7WJJc1kKq2HT_bZ3yzYw
# file dumped
# channels to scrape remain:  407830
# UCq68_MNpSjc6CVDOIRTh5aQ
# file dumped
# channels to scrape remain:  407829
# UCXJgFUjxRJxBXUbp4NQwxDw
# file dumped
# channels to scrape remain:  407828
# UCyrC0mjpVzGoeDik99HRXuQ
# file dumped
# channels to scrape remain:  407827
# UCh-Az-7nkwwZbXqPMu5ptYQ
# file dumped
# channels to scrape remain:  407826
# UCIaFL_7nFQhXvQwz_CaJ1Fw
# file dumped
# channels to scrape remain:  407825
# UCfDlzgIAtsb5jhcTmPAF_Dw
# file dumped
# channels to scrape remain:  407824
# UCjpe87Fzuiu6amTo0991qXg
# file dumped
# channels to scrape remain:  407823
# UCiaroXejjvTbXwY4H3B_tyQ
# file dumped
# channels to scrape remain:  407822
# UCYk8YQoXtNu24QhGz0Wb8Fg
# file dumped
# channels to scrape remain:  407821
# UCiCkk0JrT326g5pYzl5MZhw
# file dumped
# channels to scrape remain:  407820
# UCBsyBAuT5Hjhd8l3nL9dBSw
# file dumped
# channels to scrape remain:  407819
# UCk7kqMQFUT9MXRy7QbINuQQ
# file dumped
# channels to scrape remain:  407818
# UC88eL4qAKJ6Esu7HYVW5qew
# file dumped
# channels to scrape remain:  407817
# UCYHCpEno2IPMVgg7lPd-16g
# file dumped
# channels to scrape remain:  407816
# UCVFd9enVX3g6hMvER5ZfGgg
# file dumped
# channels to scrape remain:  407815
# UCEbviW8c25rblVeg-jERnVw
# file dumped
# channels to scrape remain:  407814
# UCogrw4kNKXO5brBL2m_pMxg
# file dumped
# channels to scrape remain:  407813
# UCdIVDc7ZvbdkTi7ydQVenVQ
# file dumped
# channels to scrape remain:  407812
# UCXOul5uJKnIvNX27lA3JnOw
# file dumped
# channels to scrape remain:  407811
# UCWPi4h4AaC0pYWk2vcLP4ng
# file dumped
# channels to scrape remain:  407810
# UCE6jiQpovYhlmcm5ltFJA6w
# file dumped
# channels to scrape remain:  407809
# UCo9sd3O8k80syRv9yuS_UKg

# %% [markdown]
# # read josn file and combine:

# %%
# read josn files and make a list with json files
# (make 1 change)

path_to_json = r'C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]
json_files;  
len(json_files)
# Out:
# 28647

# %%
# create a data frame with all json files:
# (make 1 change)
i=0
df = pd.DataFrame()
for file in json_files[14000:14070]:
    file_path = path_to_json + '/' + file
    with open(file_path) as data_file:
        i +=1
        print(file_path, i)
        data = json.load(data_file)
        df = df.append(pd.json_normalize(data))
df.shape
# Out:
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkACYr4hVgb4IKLByvFGxdw.json 1
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkAEDUnIi-IRXdQpI0r_sLQ.json 2
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkAfJtPfKbuR2NywlBWWxyg.json 3
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkaGIH_2HtuS3DhUCseIAqQ.json 4
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKaGpfQw38bIpdcZk0n-xgQ.json 5
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkAh9lRxxNuBa-iba5hWd6g.json 6
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKAhe6uJ_dlGkGd8Y5zfHXg.json 7
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkaOOIkyUG7KZ-C1NPad_Cg.json 8
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKAp2HX7QuUgTBbE4w8EEqw.json 9
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKATpXDStPeq5a_JhgA_nfQ.json 10
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKAv2V_a2pqs8NmKgerngyw.json 11
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkaw5enNE1qfSaRIZcUOmWw.json 12
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkaYr0SNOAK4rLOtmaMX6DA.json 13
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKa_hmVjdM5BmdFtftBLsaQ.json 14
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKB-9K382twqLM2D04VUOJQ.json 15
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKB-ElXXVX_qmtktdWUjjNg.json 16
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkB-QTxIwPe47RAI6G6c7_A.json 17
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkB2ExVDc5-mTqf6BGgGFDA.json 18
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkB2qjwXfiad34f-GKSnMOQ.json 19
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKb4BbWlBXRlBRA-byrB6Lg.json 20
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkb4m3bbySycNL60yQgmCKA.json 21
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKBahPnKxP0dIz13y4Tx4_w.json 22
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkbFcEMd632W8VU4UCPmOdQ.json 23
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKbFjXJaVbZ_KGO5PM7upEQ.json 24
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKBmvCd3Q0oEpnE9W1hoHng.json 25
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKbpLO2dLWMXG-APVYV5LMA.json 26
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkBPvB0Eu6mFXvgAaK9bwJA.json 27
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKbpyJhO5v4NnGvG35S3JSg.json 28
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKbq1vBS58EUMyltkBxA9yg.json 29
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkBrjHxOIQwLjGkDwMHHxCQ.json 30
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkbU4yXq_EA7QbQVCK-DuOQ.json 31
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkbuxquD0mGmKksy8TORdaw.json 32
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKbvSBkDaZEGuWc7k3QT12w.json 33
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKBwJWpZTu3Z70h4ZR4rS5w.json 34
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkbZ2AyRWtphwTNS6r9KE5A.json 35
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkBzfU2cym4UW5uZBBnAqmg.json 36
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkC03ZYN-U5f8EQhIg0I1WQ.json 37
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkC0E_ClcqydPbRe9_QyIFA.json 38
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKc2bgAt_FIrULFcHJIxVtA.json 39
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkc4Gel6IY561kRLUPfCUow.json 40
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkc7c9MdaWdJusD763DO4-g.json 41
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkcAG8x8husrRxwEdsNE-Sg.json 42
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKCBHEMyCJG4Qbxoh-IpNgw.json 43
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKCCFsTOwhQ04VG-6P_36Fg.json 44
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkCcp6oOgYyqi7PWHImJZqw.json 45
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkcej-c6xBFcl8jU8GA_JVQ.json 46
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkcFsMmbA7t6D7Apmh3kEYQ.json 47
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkcG1Dl4pqhEpP_zttXVZ8w.json 48
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkCi30ygzjVP0RkE_UDpFDg.json 49
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKCIxhYtrI45yUOUBnjRTPQ.json 50
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKCK4XOIu91gRqBqGh-lBYA.json 51
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkClGmjQPhvuLQ64HrVw-fw.json 52
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKCLIG6SULh4W4uYk37WnIg.json 53
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkCM2UK6pmuE_tm6u9gK8pQ.json 54
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkCmlwqB5o9kk_x-eknft1Q.json 55
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkCPCbt-XQc_3xmPpBvTeAg.json 56
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKCqHQw-W-F4euNfmmAGq9w.json 57
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkCqV5zfZflGyQlPYoARxJQ.json 58
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkcUEqxhwEnUVjxYYT8S81w.json 59
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKcxfSZ_4Reuqdp_ibTXpsw.json 60
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKD0mwL4nr62Wq7AQkM9RpA.json 61
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKd0x3u8hQcdDI6gI6839wg.json 62
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKd1SACBase0tuzwaMKyXpw.json 63
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKd6Mxu6HoqKZRV3IXahifA.json 64
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKd9xfCyMEWpowjHixsuetQ.json 65
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkDbiHLaCfXh3GsCZVjRXaA.json 66
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKDbkcH7jwmbDDmYjc0Y3UA.json 67
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCkDdCn_qmUxpc7YoYp0JMXQ.json 68
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKDeVIZtuB2aa5OcOL1dSXw.json 69
# C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info for commenters\channels info for commenters - 2 batch 1/UCKdf7ZErJL1i3GAif_z9LwA.json 70
# (70, 36)

# %%
df_3 = df.copy()

# %%
df = df.append(df_3, ignore_index=True)

# %%
df.shape, df_1.shape, df_2.shape
# Out:
# ((28617, 118), (14000, 107), (14547, 91))

# %%
df = df[df.columns.drop(list(df.filter(regex='thumbnails')))]

# %%
df.shape
# Out:
# (28617, 32)

# %%
column_head_list = list(df.columns)
column_head_list
# Out:
# ['kind',
#  'etag',
#  'id',
#  'snippet.title',
#  'snippet.description',
#  'snippet.publishedAt',
#  'snippet.localized.title',
#  'snippet.localized.description',
#  'contentDetails.relatedPlaylists.likes',
#  'contentDetails.relatedPlaylists.uploads',
#  'statistics.viewCount',
#  'statistics.subscriberCount',
#  'statistics.hiddenSubscriberCount',
#  'statistics.videoCount',
#  'status.privacyStatus',
#  'status.isLinked',
#  'status.longUploadsStatus',
#  'brandingSettings.channel.title',
#  'topicDetails.topicIds',
#  'topicDetails.topicCategories',
#  'brandingSettings.channel.description',
#  'brandingSettings.image.bannerExternalUrl',
#  'snippet.country',
#  'brandingSettings.channel.country',
#  'brandingSettings.channel.moderateComments',
#  'brandingSettings.channel.keywords',
#  'snippet.customUrl',
#  'brandingSettings.channel.unsubscribedTrailer',
#  'status.madeForKids',
#  'snippet.defaultLanguage',
#  'brandingSettings.channel.defaultLanguage',
#  'brandingSettings.channel.trackingAnalyticsAccountId']

# %%
df.to_csv(r'C:\Users\David\Amber Heard Case\Youtube\Data\combined files for channels\combined accounts info of commenters 2 batch 1.csv')

# %% [markdown]
# email: some20738@gmail.com
