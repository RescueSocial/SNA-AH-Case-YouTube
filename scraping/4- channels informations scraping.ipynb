# %% [markdown]
# # Obtaining channels infos by channel ID

# %%
import pandas as pd
import json
import requests
from io import StringIO
from csv import reader
import os
import glob

# %%
class YTstats:
    '''
    this class takes api_key and channel id
    then obtain infor for the channel
    '''    
  
    def __init__(self, api_key, channel_id):
        self.api_key = api_key
        self.channel_id = channel_id
        self.video_statistics = None
  
    def get_video_statistics(self):
        url = f'https://youtube.googleapis.com/youtube/v3/channels?part=snippet&part=contentDetails&part=brandingSettings&part=contentOwnerDetails&part=id&part=localizations&part=statistics&part=status&part=topicDetails&id={self.channel_id}&maxResults=200&key={self.api_key}'
        json_url = requests.get(url)
        data = json.loads(json_url.text)
        nextPageToken = data.get("nextPageToken")
        
        i = 0
        a = ''
        if nextPageToken:
            while nextPageToken != a:
                a = nextPageToken
                i += 1
                url = f'https://youtube.googleapis.com/youtube/v3/channels?part=snippet&part=contentDetails&part=brandingSettings&part=contentOwnerDetails&part=id&part=localizations&part=statistics&part=status&part=topicDetails&id={self.channel_id}&maxResults=200&key={self.api_key}&pageToken={nextPageToken}'
                json_url = requests.get(url)
                data1 = json.loads(json_url.text)
                nextPageToken = data1.get("nextPageToken")
                data['items'] = data['items'] + data1['items']
                
                if nextPageToken is None:
                    break
                print('page number:', i+1)
              #  print(nextPageToken, len(data['items']))
            
            
        try:
            data = data["items"]#[0]["statistics"]
        except:
            data = None
  
        self.video_statistics = data
        return data
  
    def dump(self):
        if self.video_statistics is None:
            print('nothing happend')
            return 
  
        video_title = self.channel_id
        video_title = video_title.replace(" ", "_")
  
        # generate a json file with all the statistics data of the youtube video
        file_name = video_title + '.json'
        with open(file_name, 'w') as f:
            json.dump(self.video_statistics, f, indent=4)
        print('file dumped')

# %% [markdown]
# # make sure we will not obtainig channels we already have info for it:

# %%
# read data for channels we have info for
obtainded_channels_ids = pd.read_csv(r'C:\Users\David\Amber Heard Case\Youtube\Data\combined files for channels/combined accounts info batch1&2.csv')
obtainded_channels_ids_list = list(old['id'])
len(obtainded_channels_ids_list)
# Out:
# 2251

# %%
# read channel IDs for all data we have:
channels_id_new = pd.read_csv('total_channels_id-batch-3.csv')
channels_id_list_new = list(channels_id_new['id'])
len(set(channels_id_list_new))
# Out:
# 3696

# %%
# make a new list with data we don't have info for it:
channels_id = []
for d in channels_id_list_new:
    if d not in obtainded_channels_ids_list:
        channels_id.append(d)
len(channels_id)
# Out:
# 1614

# %%
# recive data using API and save it on PC

API_KEY = "AIzaSyCQHI5RSbHoKGh6sPPnnOywja7qLS6TXnA"
API_KEY2 = "AIzaSyA-0KfpLK04NpQN1XghxhSlzG-WkC3DHLs"  

# paste the channel id here
while len(channels_id) !=0:
    
    for video in channels_id:
        print(video)
        yt = YTstats(API_KEY, video)
        yt.get_video_statistics()
        yt.dump()
        channels_id.remove(video)
        print('channels to scrape remain: ', len(channels_id))
        break
# Out:
# UCMvLMoLRXJWVPKt13TRgGqw
# file dumped
# channels to scrape remain:  1613
# UCdRVe2tTgsNA7xVzW1qszSA
# file dumped
# channels to scrape remain:  1612
# UC2_sABdHZub1zCPdI12p6CA
# file dumped
# channels to scrape remain:  1611
# UCVhekdkVuEjXrsyxR8ObiLg
# file dumped
# channels to scrape remain:  1610
# UCkbTToezbJlEr5qCOpU_BVA
# nothing happend
# channels to scrape remain:  1609
# UCEZedLMX2mZb6Jpwd3bJzMw
# file dumped
# channels to scrape remain:  1608
# UCzD8fjDWUrKe5uo9OeMrlxw
# file dumped
# channels to scrape remain:  1607
# UCWTkpYvniGIUe1jeCncFzKw
# file dumped
# channels to scrape remain:  1606
# UCe_50rGX7LZQ8cMCwKqYOtg
# file dumped
# channels to scrape remain:  1605
# UCB3G61AIUOwqndcsQvoF9Qg
# file dumped
# channels to scrape remain:  1604
# UCGqmrsLwDLDO8zcMKXbirJw
# file dumped
# channels to scrape remain:  1603
# UCllBkxwMHVPmLORTLbqdIhg
# file dumped
# channels to scrape remain:  1602
# UC5664f6TkaeHgwBly50DWZQ
# file dumped
# channels to scrape remain:  1601
# UCz12_kwz1zn3kDPmqg45nZQ
# file dumped
# channels to scrape remain:  1600
# UCGdHC5UYOMMX9-m0BlhxEfQ
# file dumped
# channels to scrape remain:  1599
# UCKv79goLXvzqsJqVMd8PJQQ
# file dumped
# channels to scrape remain:  1598
# UCgVZ0mrM3liHNhRYC5Mchgg
# file dumped
# channels to scrape remain:  1597
# UC2tcZ4d1jh80kqrNw9yXgbw
# file dumped
# channels to scrape remain:  1596
# UC1Cwxr3CClNJ3Xo2SOEIxmQ
# file dumped
# channels to scrape remain:  1595
# UC7rccpN0lORMROY_UcTJEcQ
# file dumped
# channels to scrape remain:  1594
# UCjUIGIp04jSlRU6yjj7eQhw
# file dumped
# channels to scrape remain:  1593
# UCQtapIeAdnInkUW4jkSldcA
# file dumped
# channels to scrape remain:  1592
# UCxI_Us_PF9RI2MXFCiRk7ww
# file dumped
# channels to scrape remain:  1591
# UCZ_24VX2Rnr_no_RaDDq_Xg
# file dumped
# channels to scrape remain:  1590
# UC6F8VlBZkENYY0GsKLlxdcQ
# file dumped
# channels to scrape remain:  1589
# UC3pKUjOqPna0hRYj_lyPH0A
# file dumped
# channels to scrape remain:  1588
# UC1Gz1YkPBoLzQSBKbswBHAw
# file dumped
# channels to scrape remain:  1587
# UCBm52JIrdWlbtiMVY8sbGsQ
# file dumped
# channels to scrape remain:  1586
# UC8_K9Id8od2CPnNVO54Rwrw
# file dumped
# channels to scrape remain:  1585
# UC_aqJ19jsXcg8cNLw1utH9Q
# file dumped
# channels to scrape remain:  1584
# UCcTbwSeD5zuOjSEuy1Qc0Dw
# file dumped
# channels to scrape remain:  1583
# UCZ_24VX2Rnr_no_RaDDq_Xg
# file dumped
# channels to scrape remain:  1582
# UCeDWbVi7jopA8t7UvZGqK0Q
# file dumped
# channels to scrape remain:  1581
# UCkh6T8TkwKBVy3UqnqtuHpg
# file dumped
# channels to scrape remain:  1580
# UChlCnec8QIeWMD3qxCmKxww
# file dumped
# channels to scrape remain:  1579
# UCNJ5huePedGmDrTLIUDbA8Q
# file dumped
# channels to scrape remain:  1578
# UCIW_MGvurF8n3LKB16LCgzw
# file dumped
# channels to scrape remain:  1577
# UCrFGMkHpKdyIEPscm4YS_0g
# file dumped
# channels to scrape remain:  1576
# UCxWKtClYzg7llQferT0SN1Q
# file dumped
# channels to scrape remain:  1575
# UCsxq5C3Sa2jfAzy7xX492tQ
# file dumped
# channels to scrape remain:  1574
# UC4n1nn9VEOk0Y99tCpWCXng
# file dumped
# channels to scrape remain:  1573
# UC8ahj5sEx34dIVL1ELZG0lw
# file dumped
# channels to scrape remain:  1572
# UC8q1Xl8GGdVtsMwiR8EFUvA
# file dumped
# channels to scrape remain:  1571
# UCnp8ZAgkWljak61xE7dIEOw
# file dumped
# channels to scrape remain:  1570
# UCOMOCu5P4WzjuEHs6zOFwlw
# file dumped
# channels to scrape remain:  1569
# UCx2-BlORNqvwn6rfpsDap8w
# file dumped
# channels to scrape remain:  1568
# UCOleiujepiJ-X4vAJl3JACw
# file dumped
# channels to scrape remain:  1567
# UCeX8vPN5j4gkn8DDYO8EKNA
# file dumped
# channels to scrape remain:  1566
# UC4n1nn9VEOk0Y99tCpWCXng
# file dumped
# channels to scrape remain:  1565
# UCZ5hTF_PHR1r9ch_l1AsOTA
# file dumped
# channels to scrape remain:  1564
# UCwdXkb8jtAZnxg8JMm4ZEMQ
# file dumped
# channels to scrape remain:  1563
# UCNo74GFuWh1Srb2vgHD9egw
# file dumped
# channels to scrape remain:  1562
# UCNrsaRug0YRs2fiZ1nKbD3Q
# file dumped
# channels to scrape remain:  1561
# UCgRLwwBVIdyy0--DIeEakPQ
# file dumped
# channels to scrape remain:  1560
# UCgmyskTTAQngqLUrs6auNBA
# file dumped
# channels to scrape remain:  1559
# UCsmKH_7Id_cO8NYwNOeIN9g
# file dumped
# channels to scrape remain:  1558
# UCTKKGdgEDxThhiTNWzzGEfg
# file dumped
# channels to scrape remain:  1557
# UCOJ7XkxFJgHI8iQbWRePSjQ
# file dumped
# channels to scrape remain:  1556
# UCz8K1occVvDTYDfFo7N5EZw
# file dumped
# channels to scrape remain:  1555
# UC8C4ip1tLybhlGWnSH8ibFQ
# file dumped
# channels to scrape remain:  1554
# UCjpzEgbbDUg4YC6vpSrzsyg
# file dumped
# channels to scrape remain:  1553
# UCz8K1occVvDTYDfFo7N5EZw
# file dumped
# channels to scrape remain:  1552
# UC6ixOYo0hsL547i9sYvvsjA
# file dumped
# channels to scrape remain:  1551
# UCVlGAiSwixuKBEm-W3Hjpyg
# file dumped
# channels to scrape remain:  1550
# UCk630zBwAeV4qtTjb0pPdeA
# file dumped
# channels to scrape remain:  1549
# UCoPiz8byeKY1X2aBQoMjHXw
# file dumped
# channels to scrape remain:  1548
# UC9mdBnpuZXimNcmepAL8aFw
# file dumped
# channels to scrape remain:  1547
# UCijcd0GR0fkxCAZwkiuWqtQ
# file dumped
# channels to scrape remain:  1546
# UCahfy_XV7nFYceg6GIthwMQ
# file dumped
# channels to scrape remain:  1545
# UC3H7IiWif0YqE4Ox1kmDfNw
# file dumped
# channels to scrape remain:  1544
# UCXEuHfgy4q0CAObWdCKrcVg
# file dumped
# channels to scrape remain:  1543
# UCqtwZeRl8IAu9-06uED1afQ
# file dumped
# channels to scrape remain:  1542
# UCvlVuntLjdURVD3b3Hx7kxw
# file dumped
# channels to scrape remain:  1541
# UCVysanxAn9yh-Zr26vB2S3A
# file dumped
# channels to scrape remain:  1540
# UC8N0ISBV0PE2tPVmgmUJABQ
# file dumped
# channels to scrape remain:  1539
# UCEkpcbCuXCHSUD3oMarGd4g
# file dumped
# channels to scrape remain:  1538
# UCaf93eUSSdrScaGlMhY9rSw
# file dumped
# channels to scrape remain:  1537
# UCnhT4fBE1OWOn7c0Quxdf4w
# file dumped
# channels to scrape remain:  1536
# UCBon5m860qshNbKVssGUabQ
# file dumped
# channels to scrape remain:  1535
# UCtNdVINwfYFTQEEZgMiQ8FA
# file dumped
# channels to scrape remain:  1534
# UCAupwzNGsBh1nMV6_0eDX4Q
# file dumped
# channels to scrape remain:  1533
# UCt38MfPs8HwhsYrl-G6ZJeg
# file dumped
# channels to scrape remain:  1532
# UCUpD2CtnUF6oWYQgMHGYTNQ
# file dumped
# channels to scrape remain:  1531
# UCeHgajYvGU-jHgf1QCa1lbg
# file dumped
# channels to scrape remain:  1530
# UC7yT-PkS0bPwTfupWc5iM9Q
# file dumped
# channels to scrape remain:  1529
# UCFV1G9g4yYakW94R0FGFW-w
# file dumped
# channels to scrape remain:  1528
# UC4AIWUgVg6uPKepImpbJQ8A
# file dumped
# channels to scrape remain:  1527
# UC3jPeHvOxtc7_7xBcc79R0Q
# file dumped
# channels to scrape remain:  1526
# UCQL1VtH1G5Q3QA4IkkOulAg
# file dumped
# channels to scrape remain:  1525
# UCHVrex3itiwG5yaZrnJAjgQ
# file dumped
# channels to scrape remain:  1524
# UCd-wrcpADHT-rEk9ywwgHtQ
# file dumped
# channels to scrape remain:  1523
# UCzfXhhH8_L1B6B1SURAskXQ
# file dumped
# channels to scrape remain:  1522
# UC0myDhe-tCQtjFH6umsyvrQ
# file dumped
# channels to scrape remain:  1521
# UCIohZcJpvnFwlFz_JzlRRhw
# file dumped
# channels to scrape remain:  1520
# UCxDs8x5wvKwGR4nuER6h87A
# file dumped
# channels to scrape remain:  1519
# UCBEil7M7_DMCu4AvZQAIccg
# file dumped
# channels to scrape remain:  1518
# UCizBORctg2OKqI9QNK5Lqrw
# file dumped
# channels to scrape remain:  1517
# UCntX6_cV3labt8C16u55EfA
# file dumped
# channels to scrape remain:  1516
# UC5sqmi33b7l9kIYa0yASOmQ
# file dumped
# channels to scrape remain:  1515
# UCSJsjWw-wCypnQ_FBUqIpoA
# file dumped
# channels to scrape remain:  1514
# UCPuPR2SH2xri_m3geQc_f9A
# file dumped
# channels to scrape remain:  1513
# UCYEWp_vovVxsQTzKbHTu9Og
# file dumped
# channels to scrape remain:  1512
# UC_hBneA8h_0a_GOzlwTot6Q
# file dumped
# channels to scrape remain:  1511
# UCJ7dtuZhjFSJvb_CZjWJkng
# file dumped
# channels to scrape remain:  1510
# UCeY5vqr5-oCcDTUJXgcSWug
# file dumped
# channels to scrape remain:  1509
# UCXjhJbviBl0M4JAC3cxDXqA
# file dumped
# channels to scrape remain:  1508
# UCVOLt6wOvK-YDkCLmFI1NPQ
# file dumped
# channels to scrape remain:  1507
# UCcH6ibWROf18SVWqGTY9_Dg
# file dumped
# channels to scrape remain:  1506
# UC43XbxjX7RZZ_gK9Vt8Z8FA
# file dumped
# channels to scrape remain:  1505
# UCLSPmGfPWsRdMHpI4eBrBIg
# file dumped
# channels to scrape remain:  1504
# UC9a4c9XBp1QxOsN4MKuvSDQ
# file dumped
# channels to scrape remain:  1503
# UCBcvxEVmUC5b8eAmdOFVKRA
# file dumped
# channels to scrape remain:  1502
# UCWQObgVpCJ1ScisibwpQhNQ
# file dumped
# channels to scrape remain:  1501
# UCm_DBXCiiU1RKAWhl-GDHNQ
# file dumped
# channels to scrape remain:  1500
# UCt38MfPs8HwhsYrl-G6ZJeg
# file dumped
# channels to scrape remain:  1499
# UCOzwB5mbRVD06JJT2IbIOOw
# file dumped
# channels to scrape remain:  1498
# UCeYWRn5HGIrie8PvjHPl3mA
# file dumped
# channels to scrape remain:  1497
# UCf65PoqsyuMm7YIQVoRzY-w
# file dumped
# channels to scrape remain:  1496
# UCdA2aG7kLNVgVlHdynG6gdw
# file dumped
# channels to scrape remain:  1495
# UCjH0RBT-7QhpSgLFnPLgD0Q
# file dumped
# channels to scrape remain:  1494
# UC8oZ14k0VlrG9bvEXTppjqg
# file dumped
# channels to scrape remain:  1493
# UC4I8ObTn0IkIhRdTBflObJg
# file dumped
# channels to scrape remain:  1492
# UC1tA70uEPMDLaEZjxusiFCg
# file dumped
# channels to scrape remain:  1491
# UCe-enk0KyKlf1A67RquYO3g
# file dumped
# channels to scrape remain:  1490
# UCN7B-QD0Qgn2boVH5Q0pOWg
# file dumped
# channels to scrape remain:  1489
# UCl6LnwGSOSoSFAHuIKWZIXQ
# file dumped
# channels to scrape remain:  1488
# UC6UcjqhROKEWmz7aGzees9A
# file dumped
# channels to scrape remain:  1487
# UCAhZoLMEKXv04BzihB2EbPA
# file dumped
# channels to scrape remain:  1486
# UC6oiYZRXXxUYSOFKxqZjJ0A
# file dumped
# channels to scrape remain:  1485
# UCLzJ6fHwgjm8xwKPvMiRJ3w
# file dumped
# channels to scrape remain:  1484
# UCUamipOJgQ5wLkqY510Resw
# file dumped
# channels to scrape remain:  1483
# UCpwj3jlEO5K929mZBI6znJg
# file dumped
# channels to scrape remain:  1482
# UCX15yQQOgUllNFd8wNRV1KQ
# file dumped
# channels to scrape remain:  1481
# UC4w20dXVKYd9A81PTNkyzXQ
# file dumped
# channels to scrape remain:  1480
# UCodZVJl22OUX1705uuCm0Fg
# file dumped
# channels to scrape remain:  1479
# UCrKlscFWmaNkDkqkH2EsyfA
# file dumped
# channels to scrape remain:  1478
# UCWbOgmmhIvrmcxKiAF8twPA
# file dumped
# channels to scrape remain:  1477
# UCdRRDHDeNoLi2UJF_qV-1RQ
# file dumped
# channels to scrape remain:  1476
# UCN9OqpdgmOBQpknpJZYOHOQ
# file dumped
# channels to scrape remain:  1475
# UCqTkkb-S9f4XBYBbOisEWZA
# file dumped
# channels to scrape remain:  1474
# UCGwcn0lC2nY-GDwCX_o1Wkg
# file dumped
# channels to scrape remain:  1473
# UCKeG6jlNCUaJZ1XoYyzpJbA
# file dumped
# channels to scrape remain:  1472
# UCnn5xXZ3PsWFGZyS6wqi08g
# file dumped
# channels to scrape remain:  1471
# UCJJngs3SFQxO_ZxWLKNIOlQ
# file dumped
# channels to scrape remain:  1470
# UCcIY7WfFSsrwsoiBnr4shiA
# file dumped
# channels to scrape remain:  1469
# UCqbHGJVaAFZRz1vCYL4vplw
# file dumped
# channels to scrape remain:  1468
# UCBl4reKrfIIsRI4hjQ4Il_w
# file dumped
# channels to scrape remain:  1467
# UCKu825ikffVh01jSN-Ia0uA
# file dumped
# channels to scrape remain:  1466
# UCo1J7vHQ6lb8hMbz1q3Z0pg
# file dumped
# channels to scrape remain:  1465
# UCXEuHfgy4q0CAObWdCKrcVg
# file dumped
# channels to scrape remain:  1464
# UCv4bdkxXT_h4NlnmNhDbq4w
# file dumped
# channels to scrape remain:  1463
# UCgHJ-gsN1eFWRhxDmWC3VDA
# file dumped
# channels to scrape remain:  1462
# UChcOwGRRyeXx1WYrdR6asgw
# file dumped
# channels to scrape remain:  1461
# UCnFpzNNl2WYYJrMbdgxlf4w
# file dumped
# channels to scrape remain:  1460
# UCPWv9S6rXNNIrZ1cRt26CKw
# file dumped
# channels to scrape remain:  1459
# UCbj_e0TSJK-FRy6mmPBm34A
# file dumped
# channels to scrape remain:  1458
# UC6i5k2Zo0Xb9-oFpvDV95cg
# file dumped
# channels to scrape remain:  1457
# UCfJdfQGtvv7IN8YAIz4yfGw
# file dumped
# channels to scrape remain:  1456
# UCIdvTZ6Y2JghQLFwnE0otzQ
# file dumped
# channels to scrape remain:  1455
# UCDxiUtTgwDeo-Ewx0d2cByA
# file dumped
# channels to scrape remain:  1454
# UCcH6ibWROf18SVWqGTY9_Dg
# file dumped
# channels to scrape remain:  1453
# UCFPRJAk5PTylG45BpLI5Xqw
# file dumped
# channels to scrape remain:  1452
# UCca9zSt7oR9RINeRyabUK_w
# file dumped
# channels to scrape remain:  1451
# UC4n1nn9VEOk0Y99tCpWCXng
# file dumped
# channels to scrape remain:  1450
# UC4pVQglwQuygkEd8L4_8s-A
# file dumped
# channels to scrape remain:  1449
# UC8oimTPVHKiC7oL3QgdKbgg
# file dumped
# channels to scrape remain:  1448
# UCBmdwD8i1QJeNBAFjbUNfzg
# file dumped
# channels to scrape remain:  1447
# UCOKFh7_OpbKrWZJLGunFt0w
# nothing happend
# channels to scrape remain:  1446
# UCl4Fm5Gapo_7Ow34YgfJ96Q
# file dumped
# channels to scrape remain:  1445
# UCiEwUz0msK9ijRJVEsttl6Q
# file dumped
# channels to scrape remain:  1444
# UC_f_bW_r7VaJjb05xmvePbg
# file dumped
# channels to scrape remain:  1443
# UCeY0bbntWzzVIaj2z3QigXg
# file dumped
# channels to scrape remain:  1442
# UCMlk9gp1WNndfOjs0_1gG3g
# file dumped
# channels to scrape remain:  1441
# UC2IMSFLnwwHtgVdyppDWVtw
# file dumped
# channels to scrape remain:  1440
# UCykrkuL-Kl_nAha1HxO63_g
# file dumped
# channels to scrape remain:  1439
# UCTvD-zqmTM3Qm1JAmkmsEOA
# file dumped
# channels to scrape remain:  1438
# UCEVmm9wx7Tq0W9OdnlYjZHw
# file dumped
# channels to scrape remain:  1437
# UCoknrzFPcAk7IFKBurHvUbw
# file dumped
# channels to scrape remain:  1436
# UCdjhYi8sXERn9rOo8vnS6lw
# file dumped
# channels to scrape remain:  1435
# UCFObu61cQNY-qqFUti19iBA
# file dumped
# channels to scrape remain:  1434
# UCv18msmM-TjCOi0QwODJUqg
# file dumped
# channels to scrape remain:  1433
# UCN-2UCVIQSiozt5jmhtb5IQ
# file dumped
# channels to scrape remain:  1432
# UCWvXlD36ZhgOQ5tGlZfa8AQ
# file dumped
# channels to scrape remain:  1431
# UCDkjjloUFt7KQjQmkyzKwjQ
# file dumped
# channels to scrape remain:  1430
# UCRDKtuX7DZDqAYoM_TX-iCw
# file dumped
# channels to scrape remain:  1429
# UCgrNz-aDmcr2uuto8_DL2jg
# file dumped
# channels to scrape remain:  1428
# UCl-radPCbXcrYCE4EdNH3QA
# file dumped
# channels to scrape remain:  1427
# UCcTTiHZtNpiqD2EubIO5HFw
# file dumped
# channels to scrape remain:  1426
# UCdnZdQxYXnbN4uWJg96oGxw
# file dumped
# channels to scrape remain:  1425
# UCIks5sbjPPyDevywkmbGSSQ
# file dumped
# channels to scrape remain:  1424
# UCV61VqLMr2eIhH4f51PV0gA
# file dumped
# channels to scrape remain:  1423
# UCLpo7e-FGsjRImC8_xrG1EQ
# file dumped
# channels to scrape remain:  1422
# UC-8mjoe4oRWVLk0n5AWhoaQ
# file dumped
# channels to scrape remain:  1421
# UCdcz6_o00J0XhSPQNeI_vWw
# file dumped
# channels to scrape remain:  1420
# UC2aLOPmcUfKAYCNIbc5d_0A
# file dumped
# channels to scrape remain:  1419
# UCHqLryT41R1zDSMemciXh0g
# file dumped
# channels to scrape remain:  1418
# UCh0aJSUm_sYr7nuTzhW806g
# file dumped
# channels to scrape remain:  1417
# UC0vn8ISa4LKMunLbzaXLnOQ
# file dumped
# channels to scrape remain:  1416
# UCbQofpGfudo6nVDG8DyMFtg
# file dumped
# channels to scrape remain:  1415
# UCevQo_mUkq5UIWD5YZuOtPA
# file dumped
# channels to scrape remain:  1414
# UC7-E5xhZBZdW-8d7V80mzfg
# file dumped
# channels to scrape remain:  1413
# UC99fNIzyZUd5oxlzyrKU3Fg
# file dumped
# channels to scrape remain:  1412
# UC-JqIHCElJ_cnt89wB4lFVw
# file dumped
# channels to scrape remain:  1411
# UCw-XqkVAvdl4QFGUzDcZEZg
# file dumped
# channels to scrape remain:  1410
# UCVTiI4pYsiuTFDL7UJ-yOyg
# file dumped
# channels to scrape remain:  1409
# UCfR6kiQaeJLkxUyPaeouZTw
# file dumped
# channels to scrape remain:  1408
# UC7WG__fP265pRDbAgQFO3iw
# file dumped
# channels to scrape remain:  1407
# UC1dWsFevTpXh1fLMpLTtoAg
# file dumped
# channels to scrape remain:  1406
# UC9YIU_TqkTEEREoX1gXScCA
# file dumped
# channels to scrape remain:  1405
# UC6o2KfCvkbJv6CDjkEMN4ag
# file dumped
# channels to scrape remain:  1404
# UCV9CJrDM9kntaQ4vyQE5isg
# file dumped
# channels to scrape remain:  1403
# UCKIGPu2lcZXVtaMsLpQ9_OQ
# file dumped
# channels to scrape remain:  1402
# UCtf6ekdIoilOPgKG4728WZA
# file dumped
# channels to scrape remain:  1401
# UCm_Ca3vsZujxXxIrFG_CjsA
# file dumped
# channels to scrape remain:  1400
# UChWnKhN2IQeJTUJY5mNesBw
# file dumped
# channels to scrape remain:  1399
# UCN9OqpdgmOBQpknpJZYOHOQ
# file dumped
# channels to scrape remain:  1398
# UC9dGqMAPJRpA7M0oSdgtQgg
# file dumped
# channels to scrape remain:  1397
# UCzN1HiBrPNw35fZNB28jgrQ
# file dumped
# channels to scrape remain:  1396
# UCVJzgJ1u9YANbvHDHryZO2g
# file dumped
# channels to scrape remain:  1395
# UCb8PGmJ6SILfyOvOWJvHZIg
# file dumped
# channels to scrape remain:  1394
# UCy7r6GYTGA1gpHEZfqnscQA
# file dumped
# channels to scrape remain:  1393
# UCAkmVsd_pi2eLlfaPJ0iSCA
# file dumped
# channels to scrape remain:  1392
# UCHP2wWIFhVeSoFEfkBV0n_w
# file dumped
# channels to scrape remain:  1391
# UCXZpQgX1897wYDLtvzmgyIA
# file dumped
# channels to scrape remain:  1390
# UCTb-SL_XEr262rbKPiBxAWg
# file dumped
# channels to scrape remain:  1389
# UC_lDWQIubkdUaSoATWByMgA
# file dumped
# channels to scrape remain:  1388
# UCqTkkb-S9f4XBYBbOisEWZA
# file dumped
# channels to scrape remain:  1387
# UCOGrRzXFGtaYJ7AfzWOrsUQ
# file dumped
# channels to scrape remain:  1386
# UCANd3ZWnmMwjBywAtTNI2TQ
# file dumped
# channels to scrape remain:  1385
# UCMFZmCGquGpOV5nFWJjzI7g
# file dumped
# channels to scrape remain:  1384
# UCKGg9ISYFpe_0fi_FzjAtjA
# file dumped
# channels to scrape remain:  1383
# UCXMOeEiz0vAJeHpNasF0GmQ
# file dumped
# channels to scrape remain:  1382
# UCnHwaAgT9ePuM07yo6QRgLQ
# file dumped
# channels to scrape remain:  1381
# UCYr96nq2Hz-Bi7NgNOh1HCw
# file dumped
# channels to scrape remain:  1380
# UCbmNph6atAoGfqLoCL_duAg
# file dumped
# channels to scrape remain:  1379
# UCWWNiYnq8uhlcWGAsaQSioQ
# file dumped
# channels to scrape remain:  1378
# UClyeSFFmMI05crCxScf1fTQ
# file dumped
# channels to scrape remain:  1377
# UCu5EPqj_fNjZ23wtufxx_xQ
# file dumped
# channels to scrape remain:  1376
# UCeY0bbntWzzVIaj2z3QigXg
# file dumped
# channels to scrape remain:  1375
# UCKu825ikffVh01jSN-Ia0uA
# file dumped
# channels to scrape remain:  1374
# UC-9QoQPlLzVCrAZplemJuPQ
# file dumped
# channels to scrape remain:  1373
# UCRpZ3cfbcywkMhRfzqMrrzQ
# file dumped
# channels to scrape remain:  1372
# UC4Ifdob6-dYBGl5rxYOjZ0A
# file dumped
# channels to scrape remain:  1371
# UC2IdQ6liLSKNCxq9CfPjEBw
# file dumped
# channels to scrape remain:  1370
# UCXZpQgX1897wYDLtvzmgyIA
# file dumped
# channels to scrape remain:  1369
# UCUuk8Y9BUq0um_mdWgteEEg
# file dumped
# channels to scrape remain:  1368
# UCXNXT_9LlguJeQY7q_W43Fw
# file dumped
# channels to scrape remain:  1367
# UCEVBir9A-WQIOZq4JmAifUg
# file dumped
# channels to scrape remain:  1366
# UCgs6-jrl6rNRQJNcNMI9zHg
# file dumped
# channels to scrape remain:  1365
# UCOFkxIS0NHoffbbdOEydMlw
# file dumped
# channels to scrape remain:  1364
# UCHFyV-DSr0_fbxqaB10VnNg
# file dumped
# channels to scrape remain:  1363
# UCLxYvHQOJm_Q_ZaqKQuEjzQ
# file dumped
# channels to scrape remain:  1362
# UCYtM_IZdo7NFOAylxrxf3DQ
# file dumped
# channels to scrape remain:  1361
# UCYeF244yNGuFefuFKqxIAXw
# file dumped
# channels to scrape remain:  1360
# UCKb1B_0Yqa6r7m3qkE3yt8Q
# file dumped
# channels to scrape remain:  1359
# UCKaAFdOqEE1iuCoTk1vb4Dg
# file dumped
# channels to scrape remain:  1358
# UCCDXU_43IIkFb7qJcJei5cw
# file dumped
# channels to scrape remain:  1357
# UCc2crTFxw5qI6a96mt5IMqg
# file dumped
# channels to scrape remain:  1356
# UCg85XbUoEK51gZX3g650AAw
# file dumped
# channels to scrape remain:  1355
# UCqbHGJVaAFZRz1vCYL4vplw
# file dumped
# channels to scrape remain:  1354
# UCzBCWpLwGI9J7WEZzuzEDpw
# file dumped
# channels to scrape remain:  1353
# UC1h8EoQlMLP7sZN1yuqHG9A
# file dumped
# channels to scrape remain:  1352
# UCjSKDpYQkGS005Vf13NAe8A
# file dumped
# channels to scrape remain:  1351
# UCJWKjrrUh2KL1d3zXQW79cQ
# file dumped
# channels to scrape remain:  1350
# UCD0HRGRbXZEA_AFpkgGE-OQ
# file dumped
# channels to scrape remain:  1349
# UC6Arrv8WD3Z2CehgFefCXTA
# file dumped
# channels to scrape remain:  1348
# UC3PZrG-YB_H0lJG-y7wfE-g
# file dumped
# channels to scrape remain:  1347
# UC-m2GbL7AG9p25AWMuIltEg
# file dumped
# channels to scrape remain:  1346
# UC2evIriV11eJVa2EMz1BQlg
# file dumped
# channels to scrape remain:  1345
# UCFJwQd7Rj_dyn-Y1rDUpZsw
# file dumped
# channels to scrape remain:  1344
# UCQi3JpNjCUQngE6V1r5zi8g
# file dumped
# channels to scrape remain:  1343
# UC5uyL6Tco1DyW8PMjLSgyDg
# file dumped
# channels to scrape remain:  1342
# UC8D3BeV7T9LEXQF2xieS46g
# file dumped
# channels to scrape remain:  1341
# UCJ7dtuZhjFSJvb_CZjWJkng
# file dumped
# channels to scrape remain:  1340
# UCaGCraBhCqXkRPGxVKLcs0A
# file dumped
# channels to scrape remain:  1339
# UCQLhClnd1oOJ-mLyr_yr9SQ
# file dumped
# channels to scrape remain:  1338
# UCuCulBExKLgyM53IwRBsYYw
# file dumped
# channels to scrape remain:  1337
# UCWVBfvVTf3UrPA-z5gos60w
# file dumped
# channels to scrape remain:  1336
# UCArEVkiKITYW527u9dWhugQ
# file dumped
# channels to scrape remain:  1335
# UCcs7nOou9KhLtX1iZEIOfEw
# file dumped
# channels to scrape remain:  1334
# UC1baB4wrepl6nQ2-vHBK7FQ
# file dumped
# channels to scrape remain:  1333
# UCeqC-kZGg65Au2tgcRwY1ag
# file dumped
# channels to scrape remain:  1332
# UCFmcbqxRQlCaXJp1y-LUYOw
# file dumped
# channels to scrape remain:  1331
# UCCeV7DgnQx6eqZsOvQsKPRg
# file dumped
# channels to scrape remain:  1330
# UC5v9h8IjFHjCz0_Ghh7Rv6w
# file dumped
# channels to scrape remain:  1329
# UCMmuHfeLHhAA5Q8WWc1e0eA
# file dumped
# channels to scrape remain:  1328
# UCZEQZQ8HhFbyFjXUT46XH8g
# file dumped
# channels to scrape remain:  1327
# UCofXFskZSRZV7ehHPhOlfiA
# file dumped
# channels to scrape remain:  1326
# UCPtmUWIx8wB2N9WjJVVhVww
# file dumped
# channels to scrape remain:  1325
# UC2sgoh6YCrf8df1UMpUciTw
# file dumped
# channels to scrape remain:  1324
# UCW_u8kvFNHh5EQCKQdJ3L0w
# file dumped
# channels to scrape remain:  1323
# UCxmhq2JrT2iKfQ6eUxwNpGQ
# file dumped
# channels to scrape remain:  1322
# UCi4o_qZcn-_nNVSv0Idnqfw
# file dumped
# channels to scrape remain:  1321
# UCzRQPzCKIi9TN5EmF17dIDg
# file dumped
# channels to scrape remain:  1320
# UCaHERuiCaTHwf4CuQF6kK8Q
# file dumped
# channels to scrape remain:  1319
# UC7CtNXG6xv65mk7-Vm7ptUw
# file dumped
# channels to scrape remain:  1318
# UCEal3kN_u-Qigs9arDZkD_g
# file dumped
# channels to scrape remain:  1317
# UCm9n5yxoBLgrskgnsEGAzMw
# file dumped
# channels to scrape remain:  1316
# UCP12ZUfPtrhCOgoGfqLq8TQ
# file dumped
# channels to scrape remain:  1315
# UCniqtXw3nZho_0HEO5IBqvg
# file dumped
# channels to scrape remain:  1314
# UCCCOh7LQ7daiQld4gRbbRMQ
# file dumped
# channels to scrape remain:  1313
# UC0VOyT2OCBKdQhF3BAbZ-1g
# file dumped
# channels to scrape remain:  1312
# UCnfzflHk7rJUJFkvVmVyU9A
# file dumped
# channels to scrape remain:  1311
# UCYsWqViUNFkLaXKNR9clGLQ
# file dumped
# channels to scrape remain:  1310
# UC1185Leip-bScu6G7XoulNA
# file dumped
# channels to scrape remain:  1309
# UC_gzB8olvwmZIbifaWHzuhQ
# file dumped
# channels to scrape remain:  1308
# UCx44QacXD1C8gMyJ9Us79Eg
# file dumped
# channels to scrape remain:  1307
# UCLgiVZ_UHehM4nS2pjX5wAQ
# file dumped
# channels to scrape remain:  1306
# UCoNPAZLlCK-1dKvYVIFPJJA
# file dumped
# channels to scrape remain:  1305
# UCIFbvKwrpY0Avh-t3jcqIHw
# file dumped
# channels to scrape remain:  1304
# UC2MwZ9jlRU0uSLNLI7_J9DA
# file dumped
# channels to scrape remain:  1303
# UCl36O7rb35xZeBhFsd2u8Eg
# file dumped
# channels to scrape remain:  1302
# UCmqyLXPtSW9u8lXXV3cWFLQ
# file dumped
# channels to scrape remain:  1301
# UCfl2OhP1LHPs4h9_klGEG6w
# file dumped
# channels to scrape remain:  1300
# UCh5J_9YXpTw0cY6fIvPtskw
# file dumped
# channels to scrape remain:  1299
# UCXGHHEqbTNi8E_Wch7pP0Nw
# file dumped
# channels to scrape remain:  1298
# UCZn7hETm79vEeavluBxGrnQ
# file dumped
# channels to scrape remain:  1297
# UCcKvdt1qMa1IkppzPZgiZQQ
# file dumped
# channels to scrape remain:  1296
# UCdsB93a_NpxCndYwdJFrHGg
# file dumped
# channels to scrape remain:  1295
# UCT-00G8yHHv-PpmWv_Ltl7Q
# file dumped
# channels to scrape remain:  1294
# UCOGJmYUQvKN9j1oCPin0yPA
# file dumped
# channels to scrape remain:  1293
# UCiS882YPwZt1NfaM0gR0D9Q
# file dumped
# channels to scrape remain:  1292
# UCNSyZcDTp_K_fJbgfonTaEg
# file dumped
# channels to scrape remain:  1291
# UCoktvIbvsgFfrl23q8BfAPg
# file dumped
# channels to scrape remain:  1290
# UCGfTnIqYR-F14AEBF8nc08Q
# file dumped
# channels to scrape remain:  1289
# UChq-An8K9SUQjxRKJY2QPFw
# file dumped
# channels to scrape remain:  1288
# UCxIail7PEroqyWaLV7JXfGw
# file dumped
# channels to scrape remain:  1287
# UCkQRHXuUZ3fTnl6Nk3TfnuQ
# file dumped
# channels to scrape remain:  1286
# UCvVrBu30uKMSEG0eqhy3zZg
# file dumped
# channels to scrape remain:  1285
# UChq-An8K9SUQjxRKJY2QPFw
# file dumped
# channels to scrape remain:  1284
# UCGYD27r9v30AwDX1N1wiEUA
# file dumped
# channels to scrape remain:  1283
# UCE9mjmRb542v6UiwPxQDbQg
# file dumped
# channels to scrape remain:  1282
# UCMpn3xVjGSB8zztwLjENjvw
# file dumped
# channels to scrape remain:  1281
# UCzIuj-HcPpOY5Bc3WqlGh5A
# file dumped
# channels to scrape remain:  1280
# UC5ozrmddtITuRapduaUz4iQ
# file dumped
# channels to scrape remain:  1279
# UCJYaS2ogetYrHNgSOotAcXg
# file dumped
# channels to scrape remain:  1278
# UCYb_yLPFpVj9w08B_4cP0EQ
# file dumped
# channels to scrape remain:  1277
# UC0VOyT2OCBKdQhF3BAbZ-1g
# file dumped
# channels to scrape remain:  1276
# UCmBdh2TcJng8V6yKKRhZaKg
# file dumped
# channels to scrape remain:  1275
# UCe2RiKheFegUAwVfOReRh-A
# file dumped
# channels to scrape remain:  1274
# UCfQbyC-gfJ-CKWLOWNRng4w
# file dumped
# channels to scrape remain:  1273
# UCYxrALY_UAQ6ydE3xd95_Ow
# file dumped
# channels to scrape remain:  1272
# UCKX8w1LgLsnkYpj-_iIDCTg
# file dumped
# channels to scrape remain:  1271
# UCT2NRWhQucZ4qDVsoyuRIfA
# file dumped
# channels to scrape remain:  1270
# UCZmyg_MP4M03xuCBjATneew
# file dumped
# channels to scrape remain:  1269
# UCYzzvGs_SfMEn0M2Cvpq_pQ
# file dumped
# channels to scrape remain:  1268
# UCOg5VRGeMqyUmpZLZMBGS0A
# file dumped
# channels to scrape remain:  1267
# UCa2yyqFh3IctD6OLsfsXokw
# file dumped
# channels to scrape remain:  1266
# UCsg_1BR_T7dZiDj4Uzk2XKg
# file dumped
# channels to scrape remain:  1265
# UCNvzrZl9MVO76lKviKGAlVA
# file dumped
# channels to scrape remain:  1264
# UCP12ZUfPtrhCOgoGfqLq8TQ
# file dumped
# channels to scrape remain:  1263
# UC273g_TYetGmuTH_3Ugkp1Q
# file dumped
# channels to scrape remain:  1262
# UCG_Nlvx1EoxkeZkuLjelWdA
# file dumped
# channels to scrape remain:  1261
# UCc33gH-WEXpSuTYZ5WItDeA
# file dumped
# channels to scrape remain:  1260
# UCbeqKwLksOD4V8-xy-cXmnQ
# file dumped
# channels to scrape remain:  1259
# UCNIFiHaLZkYASaWDdkC1njg
# file dumped
# channels to scrape remain:  1258
# UCQ00zWTLrgRQJUb8MHQg21A
# file dumped
# channels to scrape remain:  1257
# UCFR6sruqEq52xEqjE84tq4A
# file dumped
# channels to scrape remain:  1256
# UC6xSN0oY2I9U_9xTo2RjE7g
# file dumped
# channels to scrape remain:  1255
# UCTGnVKLRLGbF-jeqvux5FPg
# file dumped
# channels to scrape remain:  1254
# UCat712XpoVjaCEvGEnRzY_Q
# file dumped
# channels to scrape remain:  1253
# UCKaCalz5N5ienIbfPzEbYuA
# file dumped
# channels to scrape remain:  1252
# UC69xJNfFK6s7MFyaI3WkVHQ
# file dumped
# channels to scrape remain:  1251
# UCUI8mj2ypUA4Ze06MRKkzzQ
# file dumped
# channels to scrape remain:  1250
# UC7Gf2tZ8coTX2ckTPgn62iQ
# file dumped
# channels to scrape remain:  1249
# UCVi_GtP-1stDmhPuWCCQ5KA
# file dumped
# channels to scrape remain:  1248
# UCUJdOffaAvG98xTv6YqShpg
# file dumped
# channels to scrape remain:  1247
# UCv-6OlG8qGY-mKlE_IUkI3w
# file dumped
# channels to scrape remain:  1246
# UCgWPhVC5h4RRnalIUmXwkow
# file dumped
# channels to scrape remain:  1245
# UCpI7A5Zz-FdH_8TUir2DQ9g
# file dumped
# channels to scrape remain:  1244
# UCCj956IF62FbT7Gouszaj9w
# file dumped
# channels to scrape remain:  1243
# UC8sia1lXsDh0EzIT7QfGbWQ
# file dumped
# channels to scrape remain:  1242
# UCmzxts0YGES5tN-oJ9abTQg
# file dumped
# channels to scrape remain:  1241
# UCUB0_JsZUKMYGjdQSwSFw0w
# file dumped
# channels to scrape remain:  1240
# UCHe1df6ScDMYRUA0oR_4X8Q
# file dumped
# channels to scrape remain:  1239
# UCzRQPzCKIi9TN5EmF17dIDg
# file dumped
# channels to scrape remain:  1238
# UChq-An8K9SUQjxRKJY2QPFw
# file dumped
# channels to scrape remain:  1237
# UC9gVCa6ap-KDayMRPg5wjIg
# file dumped
# channels to scrape remain:  1236
# UChJmLj_gjQ2u4btx4kQMYDw
# file dumped
# channels to scrape remain:  1235
# UCVDiB5ltHaWOD1bAVKxqBFg
# file dumped
# channels to scrape remain:  1234
# UCtOrhR0QICP0tOYuxUUMQlQ
# file dumped
# channels to scrape remain:  1233
# UCDx94U8zVhzXNIrtDpY7vkg
# file dumped
# channels to scrape remain:  1232
# UCsv4YOF2RBYh0NQ1vuHQ-hg
# file dumped
# channels to scrape remain:  1231
# UClKh7vgw-_2aeDja6YJR1DA
# file dumped
# channels to scrape remain:  1230
# UCRRu9OXVYd5clj2Bs29gUVQ
# file dumped
# channels to scrape remain:  1229
# UCxgOXIkW0Kt95Qm9SOVJWLw
# file dumped
# channels to scrape remain:  1228
# UC20D718p_EzFY0kSRONA99Q
# file dumped
# channels to scrape remain:  1227
# UC5BMQOsAB8hKUyHu9KI6yig
# file dumped
# channels to scrape remain:  1226
# UCZCzXkB0H03mMxVI3NpJDmQ
# file dumped
# channels to scrape remain:  1225
# UCMvETSFFkMOADyrGBj3gbWA
# file dumped
# channels to scrape remain:  1224
# UCHLyP4MuA-JAFBCwxXOEDdA
# file dumped
# channels to scrape remain:  1223
# UC_CV4--a-1jzyuIWv0MdUFg
# file dumped
# channels to scrape remain:  1222
# UCt38MfPs8HwhsYrl-G6ZJeg
# file dumped
# channels to scrape remain:  1221
# UC-b1JdevG6fVeb06rRN_Xhw
# file dumped
# channels to scrape remain:  1220
# UC5uItZ5InfVuqRegsoir_dQ
# file dumped
# channels to scrape remain:  1219
# UCP12ZUfPtrhCOgoGfqLq8TQ
# file dumped
# channels to scrape remain:  1218
# UCWNHC6iTcaQbedoDUhWghAw
# file dumped
# channels to scrape remain:  1217
# UCrUqjv7ExZRIVhLT64pY7aw
# file dumped
# channels to scrape remain:  1216
# UCA2ORP5cive5B7jBvzesdsg
# file dumped
# channels to scrape remain:  1215
# UCrlcqlqYJV28LvH1iYgw4DA
# file dumped
# channels to scrape remain:  1214
# UCt466lRTu1RLYHgEjc_gIzw
# file dumped
# channels to scrape remain:  1213
# UCLjodVTY_kZzd3cQ7D82DhA
# file dumped
# channels to scrape remain:  1212
# UCjgC38I6C4pl5gEZBrYZGZw
# file dumped
# channels to scrape remain:  1211
# UCe7flOfHOQdOjIh7CPOrtcQ
# file dumped
# channels to scrape remain:  1210
# UC5Jt8CZQikS3GXj8_Aoat-g
# file dumped
# channels to scrape remain:  1209
# UC4G10tk3AHFuyMIuD3rHOBA
# file dumped
# channels to scrape remain:  1208
# UCnSR7_Oq-MdsZxfogsfk-Ug
# file dumped
# channels to scrape remain:  1207
# UCQn_Knm6RQfYOLpYGkkDCPw
# file dumped
# channels to scrape remain:  1206
# UCe_50rGX7LZQ8cMCwKqYOtg
# file dumped
# channels to scrape remain:  1205
# UC6jZvmJ7QJ_LAH-DpMpLf2Q
# file dumped
# channels to scrape remain:  1204
# UClhloyJ-ss_6vngYJWmJFRA
# file dumped
# channels to scrape remain:  1203
# UC5ksavsuuri0tJpcVS2gCBg
# file dumped
# channels to scrape remain:  1202
# UCkQRHXuUZ3fTnl6Nk3TfnuQ
# file dumped
# channels to scrape remain:  1201
# UCd7xBMTWIFDN2xaSpgYhquw
# file dumped
# channels to scrape remain:  1200
# UC7xTERSqzzI2craBm-EPE-g
# file dumped
# channels to scrape remain:  1199
# UCqNxhPZoLJ81i5QaK4nqn8A
# file dumped
# channels to scrape remain:  1198
# UCP12ZUfPtrhCOgoGfqLq8TQ
# file dumped
# channels to scrape remain:  1197
# UCeBnbqt4VRhotq2TQjkIi2A
# file dumped
# channels to scrape remain:  1196
# UC5iarypeZOBQU_uXAUDnU3w
# file dumped
# channels to scrape remain:  1195
# UCmQmF8Uzrh4ACgxafOWf6Ww
# file dumped
# channels to scrape remain:  1194
# UCLbyJSPEe2lx3jY-G0CFR3g
# file dumped
# channels to scrape remain:  1193
# UCPPaFQnKHu73s6MZDxmNtUg
# file dumped
# channels to scrape remain:  1192
# UCzSoH92KxHSJA0Ig4fEEWIA
# file dumped
# channels to scrape remain:  1191
# UCt38MfPs8HwhsYrl-G6ZJeg
# file dumped
# channels to scrape remain:  1190
# UCcScV0WODY1YGyi4B3L0PdQ
# file dumped
# channels to scrape remain:  1189
# UC5rmjonujSXJBYOsRJjA3FQ
# file dumped
# channels to scrape remain:  1188
# UCnSR7_Oq-MdsZxfogsfk-Ug
# file dumped
# channels to scrape remain:  1187
# UCRiiOvJbq1SWiGtzyeeldEw
# file dumped
# channels to scrape remain:  1186
# UCEwBH3RWEZE91R8PteYkNQg
# file dumped
# channels to scrape remain:  1185
# UCw6cQ7z_H6EkhfhCd6kzgaw
# file dumped
# channels to scrape remain:  1184
# UC2CCXzC56k0b8L49R_iW-Yw
# file dumped
# channels to scrape remain:  1183
# UC5GdoDlsqueyke8W-aH_mLw
# file dumped
# channels to scrape remain:  1182
# UCDzur9Zl_4jnhDihqdvm_1Q
# file dumped
# channels to scrape remain:  1181
# UC9-eoxoyevtmi73qPRqJwUA
# file dumped
# channels to scrape remain:  1180
# UCqHZdrDcZhhRO11m67Tgz4A
# file dumped
# channels to scrape remain:  1179
# UC4p2uXRpVJjk8kvcxkRi98A
# file dumped
# channels to scrape remain:  1178
# UCSa8IUd1uEjlREMa21I3ZPQ
# file dumped
# channels to scrape remain:  1177
# UC0J-rDco5EQwPcqHmd1gybg
# file dumped
# channels to scrape remain:  1176
# UCjZpKJHg5E3e5VlAoixDoOg
# file dumped
# channels to scrape remain:  1175
# UCzzXsnHsEmGorQ6xAKL2sZA
# file dumped
# channels to scrape remain:  1174
# UCOEbhCV9n-3Qgh_NWAKWd-A
# file dumped
# channels to scrape remain:  1173
# UC2Kte4oAzF8ENO-wO0Dysbw
# file dumped
# channels to scrape remain:  1172
# UC7UR74QDplHNne0uGAaSfBg
# file dumped
# channels to scrape remain:  1171
# UCFYAV08AhF39WKagmgfgFRA
# file dumped
# channels to scrape remain:  1170
# UCCeV7DgnQx6eqZsOvQsKPRg
# file dumped
# channels to scrape remain:  1169
# UCF9YLs2jYVaxHHwtonKcveQ
# file dumped
# channels to scrape remain:  1168
# UCyrl3My_zBoJO8gX9UHId3g
# file dumped
# channels to scrape remain:  1167
# UCeSHo5kTvzoik4STh7MuMCA
# file dumped
# channels to scrape remain:  1166
# UCfnf3zaINdlVjxZQW2Qd1HA
# file dumped
# channels to scrape remain:  1165
# UCpd-XDZsYaI12oEq1H3_NUQ
# file dumped
# channels to scrape remain:  1164
# UCelMeixAOTs2OQAAi9wU8-g
# file dumped
# channels to scrape remain:  1163
# UCxdNV6w_xZRfgxNSi7wDzig
# file dumped
# channels to scrape remain:  1162
# UC2IbKgetx0qzxVKVZ8NlIfw
# file dumped
# channels to scrape remain:  1161
# UC6zhI71atP7YLoZyIyCIGNw
# file dumped
# channels to scrape remain:  1160
# UCo1J7vHQ6lb8hMbz1q3Z0pg
# file dumped
# channels to scrape remain:  1159
# UC_FujeFEMeUMuL0Vsz9okyw
# file dumped
# channels to scrape remain:  1158
# UCjzEF5kUZypUftfHD1MKuCg
# file dumped
# channels to scrape remain:  1157
# UCnQLzz7-SXuz_BYgSC_9ciA
# file dumped
# channels to scrape remain:  1156
# UCouK2xKynWUBlknnuhdTTgg
# file dumped
# channels to scrape remain:  1155
# UCANLZYMidaCbLQFWXBC95Jg
# file dumped
# channels to scrape remain:  1154
# UC_gzB8olvwmZIbifaWHzuhQ
# file dumped
# channels to scrape remain:  1153
# UCQLhClnd1oOJ-mLyr_yr9SQ
# file dumped
# channels to scrape remain:  1152
# UCGzyeVCt3lZVSxmC2WxatgA
# file dumped
# channels to scrape remain:  1151
# UCMq7uHPpGVsv4FR3aKV_Svw
# file dumped
# channels to scrape remain:  1150
# UCm0SfebVZRQwQNf5SOjLjmA
# file dumped
# channels to scrape remain:  1149
# UCUJhIWsnBHMTdcQ0grWHvbQ
# file dumped
# channels to scrape remain:  1148
# UCrUqjv7ExZRIVhLT64pY7aw
# file dumped
# channels to scrape remain:  1147
# UCPBosmGxYyOPyhE49Emt2gg
# file dumped
# channels to scrape remain:  1146
# UCk8_XRT1O3-tx1M4JsMRjiw
# nothing happend
# channels to scrape remain:  1145
# UC4zWG9LccdWGUlF77LZ8toA
# file dumped
# channels to scrape remain:  1144
# UC2RsvpubRNsThaueNbpRkpA
# file dumped
# channels to scrape remain:  1143
# UCHQbbZQoEdMsLY1YizKxQFw
# file dumped
# channels to scrape remain:  1142
# UCE2e5F0nPY3uXiGs1Xs2k2A
# file dumped
# channels to scrape remain:  1141
# UCelMeixAOTs2OQAAi9wU8-g
# file dumped
# channels to scrape remain:  1140
# UCp_Ryuc-wcc06IGtgV7caXQ
# file dumped
# channels to scrape remain:  1139
# UCeX8vPN5j4gkn8DDYO8EKNA
# file dumped
# channels to scrape remain:  1138
# UCO7uoZ4bfGDHek_zm_tvbQQ
# file dumped
# channels to scrape remain:  1137
# UCuQ6QD3P3eLVFDmTEryfRlA
# file dumped
# channels to scrape remain:  1136
# UCa0CVCACLqno5kVmA-eFP5w
# file dumped
# channels to scrape remain:  1135
# UCb_vq0JLFH01ajN5GaeTa4A
# file dumped
# channels to scrape remain:  1134
# UCaHMyrUHRrmA3j_Qn4Tg-gw
# file dumped
# channels to scrape remain:  1133
# UC7ODRDjH_QWguN0tJiXdyvQ
# file dumped
# channels to scrape remain:  1132
# UCmIaztc4t_eMF3AqjkgF3HA
# file dumped
# channels to scrape remain:  1131
# UCYIE6wIemIxlKQA_aflPWWg
# file dumped
# channels to scrape remain:  1130
# UCBCvuW7T7NCDQ0RLnP8xigA
# file dumped
# channels to scrape remain:  1129
# UC0fTbhgouDMneMzSluKaXAA
# file dumped
# channels to scrape remain:  1128
# UCB1s7E7gsB2kzSwGFawTzXw
# file dumped
# channels to scrape remain:  1127
# UCWO2h3nL5KFCxEl_BJoszEA
# file dumped
# channels to scrape remain:  1126
# UCt2JXOLNxqry7B_4rRZME3Q
# file dumped
# channels to scrape remain:  1125
# UCEC4fJsSL67sshzrR6n0GVA
# file dumped
# channels to scrape remain:  1124
# UC2ceFy63WAKXOndTPLLfmDg
# file dumped
# channels to scrape remain:  1123
# UCgP22Sq2oQs0AgwxFuk4VqQ
# file dumped
# channels to scrape remain:  1122
# UCdELgQa14PVwem_2iD8RjHQ
# file dumped
# channels to scrape remain:  1121
# UCPXPwvnGUNFN83uD9R5o86A
# file dumped
# channels to scrape remain:  1120
# UCXmSzYyPQ6CuCzwitLclnjg
# file dumped
# channels to scrape remain:  1119
# UCeUEg4HnW82Xk2rzxROOY9A
# file dumped
# channels to scrape remain:  1118
# UCpsJhp0wzfhN4ALeI-ByogQ
# file dumped
# channels to scrape remain:  1117
# UCkslLSjSSm1NBR7tya-J7JA
# file dumped
# channels to scrape remain:  1116
# UCn2ftDpTtDabm7xy4o20A3w
# file dumped
# channels to scrape remain:  1115
# UCNHI2abE0OHnbkOT8cIbW1A
# file dumped
# channels to scrape remain:  1114
# UCul9agDzTZxruNd9wEUWL7w
# file dumped
# channels to scrape remain:  1113
# UCs9tHGGpNjOMiCnbqTGA1PQ
# file dumped
# channels to scrape remain:  1112
# UCEBj9vE4-GCmJgMOaq3GpbQ
# file dumped
# channels to scrape remain:  1111
# UCBQKU1cJHtWMIoxW8bLhN9w
# file dumped
# channels to scrape remain:  1110
# UCNXxJ37jA7N4tlaN9zrBHBA
# file dumped
# channels to scrape remain:  1109
# UCtbm9kgq0_M7r_VHDxqVD4g
# file dumped
# channels to scrape remain:  1108
# UCy2s3kMR8oI1M099sVQd_ig
# file dumped
# channels to scrape remain:  1107
# UCjZZ7uch3DMqVRy_Mb8W3_g
# file dumped
# channels to scrape remain:  1106
# UC4mDr5_7fS9Jr4Tj1tBK5bg
# file dumped
# channels to scrape remain:  1105
# UCl4ITiotqPkWCaafOS9BJIQ
# file dumped
# channels to scrape remain:  1104
# UCeB8txbSWFaeQJNxsiD7tEg
# file dumped
# channels to scrape remain:  1103
# UCP11M518RD4BnljwNa4u4Xw
# file dumped
# channels to scrape remain:  1102
# UC3uuSCPhgtFiqh4082IxgUw
# file dumped
# channels to scrape remain:  1101
# UCcyoDsbN46mdXLT17KcCJZA
# file dumped
# channels to scrape remain:  1100
# UCWMNUCpx68DruHVG9T1Bh0A
# file dumped
# channels to scrape remain:  1099
# UCeAkyM1uDZnclXiEaUl9jJg
# file dumped
# channels to scrape remain:  1098
# UC80hvWc5W9vLqWua8pN_cgg
# file dumped
# channels to scrape remain:  1097
# UCwQ3q9C6IbTMPzsaTyK7QCw
# file dumped
# channels to scrape remain:  1096
# UCuguSGk9mtUCeG4FcC26ZPg
# file dumped
# channels to scrape remain:  1095
# UCl2z8h3deLfxZIE8iJksubA
# file dumped
# channels to scrape remain:  1094
# UCWJok21eIRN5gu666Ulkpog
# file dumped
# channels to scrape remain:  1093
# UC7WjM67e72LV2lh7ArN70Vw
# file dumped
# channels to scrape remain:  1092
# UCDeuvRq3xgXFLZZxDz-JdAg
# file dumped
# channels to scrape remain:  1091
# UC55os7K-eMLTJy_aXzm5sHw
# file dumped
# channels to scrape remain:  1090
# UCuNhJ8nMszsjxO0W6biXtzw
# file dumped
# channels to scrape remain:  1089
# UC12nCCQvva9mTnkn3mWbL5Q
# file dumped
# channels to scrape remain:  1088
# UCCi-08eU3cjFO5GIZ6HM5KA
# file dumped
# channels to scrape remain:  1087
# UCthgNrusoPi376crBHLN2Dg
# file dumped
# channels to scrape remain:  1086
# UCQWLbDozM3SUZ2jHtrgKPaw
# file dumped
# channels to scrape remain:  1085
# UCpJN7kiUkDrH11p0GQhLyFw
# file dumped
# channels to scrape remain:  1084
# UCCemL2J2Y2_gIQ3mDH8TKNg
# file dumped
# channels to scrape remain:  1083
# UCx0eQsDrjn-EXMWeusTh2cQ
# file dumped
# channels to scrape remain:  1082
# UCR9MmZ6VylTaF_ELUEpjrjA
# file dumped
# channels to scrape remain:  1081
# UCM6rExtP_VaIOaMiCihtIQw
# file dumped
# channels to scrape remain:  1080
# UCceFXxsXykrnQa1dH7yTjQQ
# file dumped
# channels to scrape remain:  1079
# UCQINtj0SU9UOUj8DRauk1yQ
# file dumped
# channels to scrape remain:  1078
# UC6u9WqHgKSUb4nrj2aliOjA
# file dumped
# channels to scrape remain:  1077
# UCq6toogtUXacXsIjQLcxWVg
# file dumped
# channels to scrape remain:  1076
# UCqLJSayFjBjWmF9KWY4lkMQ
# file dumped
# channels to scrape remain:  1075
# UCt1M_mIlXA0TvlLIxWJr03Q
# file dumped
# channels to scrape remain:  1074
# UCpWMSvkqs-bnz923_a390oQ
# file dumped
# channels to scrape remain:  1073
# UCrbOQs7L2Nh87ErQU4GIJRQ
# file dumped
# channels to scrape remain:  1072
# UC0epn6Jx_tZEXy-Di_6KUjg
# file dumped
# channels to scrape remain:  1071
# UCAtROhj02h1npdxxk08es3A
# file dumped
# channels to scrape remain:  1070
# UCFd8pZQKLC5GfqXtbx1OQvA
# file dumped
# channels to scrape remain:  1069
# UCLxrVHu8kyOJENdoSGz0jXQ
# file dumped
# channels to scrape remain:  1068
# UCNsw51uoNzOkVvur3jH_sQQ
# file dumped
# channels to scrape remain:  1067
# UCMHBnAJ4bskW5TZObDHykEg
# file dumped
# channels to scrape remain:  1066
# UC7DuLcUHJwtAaLFRlFISPJQ
# file dumped
# channels to scrape remain:  1065
# UC1zxT0yrs8tZ-lJyRXeVfvw
# file dumped
# channels to scrape remain:  1064
# UCSx_w4q5PkAOg9i45uMFHmA
# file dumped
# channels to scrape remain:  1063
# UC15YhiwzJ-Eg-mWhmsrDfyg
# file dumped
# channels to scrape remain:  1062
# UCAdJaKKSZR7-At0JzJiuf3A
# file dumped
# channels to scrape remain:  1061
# UC1jccu8pW8ELd5n4eXAKFKw
# file dumped
# channels to scrape remain:  1060
# UCSrAOzPLUvnGFqZSv2w01og
# file dumped
# channels to scrape remain:  1059
# UCWOA1ZGywLbqmigxE4Qlvuw
# file dumped
# channels to scrape remain:  1058
# UCONOMmegqWl_YKM80B3wl7g
# file dumped
# channels to scrape remain:  1057
# UCbhGPLb4WP5qSoNo-McoFtQ
# file dumped
# channels to scrape remain:  1056
# UCpJN7kiUkDrH11p0GQhLyFw
# file dumped
# channels to scrape remain:  1055
# UChyabXnav5woqTWFWaL7-jA
# file dumped
# channels to scrape remain:  1054
# UCi8Sok5IKJluqoJ1tGncnug
# file dumped
# channels to scrape remain:  1053
# UCh0pVkO1MNTb-ZfSLVx3c_g
# file dumped
# channels to scrape remain:  1052
# UCoZVNRHEUmPThIFVvlbImSQ
# file dumped
# channels to scrape remain:  1051
# UCXXCXNVgIfQbOVQlpCaUcdQ
# file dumped
# channels to scrape remain:  1050
# UCCyi2xohWIhgREesljuZfeg
# file dumped
# channels to scrape remain:  1049
# UC1zZE_kJ8rQHgLTVfobLi_g
# file dumped
# channels to scrape remain:  1048
# UCn9BuiRZGR_tPM2GGT4jN-w
# file dumped
# channels to scrape remain:  1047
# UChi08h4577eFsNXGd3sxYhw
# file dumped
# channels to scrape remain:  1046
# UCWOSgEKGpS5C026lY4Y4KGw
# file dumped
# channels to scrape remain:  1045
# UCExfygTJkjlFXulKfaRGx-A
# file dumped
# channels to scrape remain:  1044
# UCbQfGAa1WQioqKwB2ZijEPA
# file dumped
# channels to scrape remain:  1043
# UC_gzK30pkcmNTwzzN1frUwA
# file dumped
# channels to scrape remain:  1042
# UCf-e6YbQXvjY64TKq3-xDvg
# file dumped
# channels to scrape remain:  1041
# UCAWFy3PWUdjYZXFyhUAnMIA
# file dumped
# channels to scrape remain:  1040
# UCvLXa04mPkW-ymKo4y-FF7A
# file dumped
# channels to scrape remain:  1039
# UCpJN7kiUkDrH11p0GQhLyFw
# file dumped
# channels to scrape remain:  1038
# UCyKa1YNZLio6XfjMR7fw45Q
# file dumped
# channels to scrape remain:  1037
# UCUs8sGiP4avNaYNVO22INhQ
# file dumped
# channels to scrape remain:  1036
# UCMMfNEPCze48r4G8k7Eg0yA
# file dumped
# channels to scrape remain:  1035
# UC9p4Ao-WoO7RP4UxKjUZFFg
# file dumped
# channels to scrape remain:  1034
# UCry519bbJBidgOJeay6hr7g
# file dumped
# channels to scrape remain:  1033
# UCwvHZZwk9TFoUjoXX3yqBgg
# file dumped
# channels to scrape remain:  1032
# UC8nZEEBWm5HU8N1IZdBY0Ug
# file dumped
# channels to scrape remain:  1031
# UChGJGhZ9SOOHvBB0Y4DOO_w
# file dumped
# channels to scrape remain:  1030
# UCVIvCKj-wsJybDxryNwnTzw
# file dumped
# channels to scrape remain:  1029
# UC-b9eaX0_9Wz0ug1fmx-YfQ
# file dumped
# channels to scrape remain:  1028
# UCH2ou8Ugtk_95jLJCYHkInQ
# file dumped
# channels to scrape remain:  1027
# UCaghde-ZTe0DDKwEe2Klpig
# file dumped
# channels to scrape remain:  1026
# UCvxwx-onhMZ7lGkKcayBfxQ
# nothing happend
# channels to scrape remain:  1025
# UCRsoe29t0_pO2pXw9LjW7LQ
# file dumped
# channels to scrape remain:  1024
# UCOnEg6q3s1W3VQg71WHFheA
# file dumped
# channels to scrape remain:  1023
# UCVuaHiDBIlKfzgc4hBR4ZjQ
# file dumped
# channels to scrape remain:  1022
# UCTnRD1BAPlTfI6g7g76yj3w
# file dumped
# channels to scrape remain:  1021
# UCpVqzaoo6_5dKbmgFGK1M_Q
# file dumped
# channels to scrape remain:  1020
# UCpJN7kiUkDrH11p0GQhLyFw
# file dumped
# channels to scrape remain:  1019
# UCIZNw_VUxLm08eHVgBRc1VA
# file dumped
# channels to scrape remain:  1018
# UCj8vBfV_4-eHh6uX6AD9H4g
# file dumped
# channels to scrape remain:  1017
# UC6MrMqZs9bma1IwgXJKJgdQ
# file dumped
# channels to scrape remain:  1016
# UC5_w8C5K77uo-EcOkceu4NQ
# file dumped
# channels to scrape remain:  1015
# UC7llcWZBhR9nvIzquktSzqg
# file dumped
# channels to scrape remain:  1014
# UCbTl7epOYkXtXNFdohCq3nA
# file dumped
# channels to scrape remain:  1013
# UCNzzPzUaLFP2INDiZvb-GLA
# file dumped
# channels to scrape remain:  1012
# UChVV6ezEYnPv9XaLZtUlZdw
# file dumped
# channels to scrape remain:  1011
# UCes0wTZdzDDXERSw-qGE6HQ
# file dumped
# channels to scrape remain:  1010
# UCCUFMMvIWqvf699wIGfsFeg
# file dumped
# channels to scrape remain:  1009
# UC9qgVkKRZUXcgHdf35Z-8dw
# file dumped
# channels to scrape remain:  1008
# UCcjGPWj9PP7z7R8Lyj0OBiA
# file dumped
# channels to scrape remain:  1007
# UCjd9U9QJv1tbHIOQG4dh3vw
# file dumped
# channels to scrape remain:  1006
# UCwXjmeYRodMekdfeivx-ppw
# file dumped
# channels to scrape remain:  1005
# UCOP-gP2WgKUKfFBMnkR3iaA
# file dumped
# channels to scrape remain:  1004
# UCpJN7kiUkDrH11p0GQhLyFw
# file dumped
# channels to scrape remain:  1003
# UCXbfLj2xLeaT-1u6ScWFG-g
# file dumped
# channels to scrape remain:  1002
# UCCEgdmjNMpFUQYA0iGpyVsA
# file dumped
# channels to scrape remain:  1001
# UC1dWsFevTpXh1fLMpLTtoAg
# file dumped
# channels to scrape remain:  1000
# UCbtp5vakBUSuWWX6ISTIZKg
# file dumped
# channels to scrape remain:  999
# UCvxXs8ssF1KlNUByTUibbPg
# file dumped
# channels to scrape remain:  998
# UC2289QxFoXCXP6lE1PVvAHA
# file dumped
# channels to scrape remain:  997
# UCXwyXuLskuYsZiWNh0STJdw
# file dumped
# channels to scrape remain:  996
# UCtA4jPoqFz0jtmQZ-dM2BWA
# file dumped
# channels to scrape remain:  995
# UCZ595zBsH90CFnQIr000JiA
# file dumped
# channels to scrape remain:  994
# UCXfNn1EQd-HTKC5RWTU_vtg
# file dumped
# channels to scrape remain:  993
# UCeBRj3fAENAN2mPBRvIiQUA
# file dumped
# channels to scrape remain:  992
# UCHvypozF6UZ7SqoVdWZHrJA
# file dumped
# channels to scrape remain:  991
# UC7HaCtggKyWz4uh7szLlQrA
# file dumped
# channels to scrape remain:  990
# UCKfISk5blphK-04QTUoLjsg
# file dumped
# channels to scrape remain:  989
# UCazbthRuuZJyxIetZljxHfg
# file dumped
# channels to scrape remain:  988
# UCVFpG4lS8k-uGJX9CNc1zMg
# file dumped
# channels to scrape remain:  987
# UC16Ne7V6Fe_bp1omKLiymFg
# file dumped
# channels to scrape remain:  986
# UCWOSgEKGpS5C026lY4Y4KGw
# file dumped
# channels to scrape remain:  985
# UCz7h6Eshwht37ryP7up2NmQ
# file dumped
# channels to scrape remain:  984
# UCVdn98qnBNBzz0gEpXso4bQ
# file dumped
# channels to scrape remain:  983
# UCqi5-L83BIVmnp-0psdZFnA
# file dumped
# channels to scrape remain:  982
# UCm1r4Fcp9NySvcT-58FTIZQ
# file dumped
# channels to scrape remain:  981
# UC8nZEEBWm5HU8N1IZdBY0Ug
# file dumped
# channels to scrape remain:  980
# UCXZ3_HqxUzq-XkwTAUn8-WQ
# file dumped
# channels to scrape remain:  979
# UC8lf84pvz3bNU9Xq0NvbiEg
# file dumped
# channels to scrape remain:  978
# UCqOIQxGSTEWTHwI36D1RnsQ
# file dumped
# channels to scrape remain:  977
# UC83jt4dlz1Gjl58fzQrrKZg
# file dumped
# channels to scrape remain:  976
# UCWChoBDVJKpoo8n8xyamNmA
# file dumped
# channels to scrape remain:  975
# UClaSZbrLgabkmA8e52KhDSQ
# file dumped
# channels to scrape remain:  974
# UCIETeoNRPdEhPDslmyDIXvQ
# file dumped
# channels to scrape remain:  973
# UC-Yzz2q5vFkCxbUiqJQzcEQ
# file dumped
# channels to scrape remain:  972
# UCKgXZvH1nsIAhsqcc2mK5Sg
# file dumped
# channels to scrape remain:  971
# UCIAefUMGpYd---IJq0ktDqw
# file dumped
# channels to scrape remain:  970
# UC8f1U3h2TAcKOktgonnL0Yw
# file dumped
# channels to scrape remain:  969
# UCMdZlTIQMBNaZpS7jO8U6ow
# file dumped
# channels to scrape remain:  968
# UC_OvL0wyiqJR4x2P04Xefuw
# file dumped
# channels to scrape remain:  967
# UCxPC46cce6T7hNBPRrN96CQ
# file dumped
# channels to scrape remain:  966
# UCz2si8w1MqVtl1moygyGqpQ
# file dumped
# channels to scrape remain:  965
# UCHDwUrtPMkxD4lcD1yN6u6Q
# file dumped
# channels to scrape remain:  964
# UCGFLa8vQBZIzn-Coxjcfi8w
# file dumped
# channels to scrape remain:  963
# UCRVeWBBoxQONj27psCHw9Iw
# file dumped
# channels to scrape remain:  962
# UCOGXpNIGXqvl4Q7HfR7Qxyg
# file dumped
# channels to scrape remain:  961
# UCvpMVcnccc1MqigWjFF9yUA
# file dumped
# channels to scrape remain:  960
# UC_BXdFRayEfaXw_rJgsWHJA
# file dumped
# channels to scrape remain:  959
# UCpd21W3qWyzIl8-PXvyDA2g
# file dumped
# channels to scrape remain:  958
# UC94_c_N43zTYENqApU4fM8w
# file dumped
# channels to scrape remain:  957
# UCxOLOFlURiy2fcAy59OlsVQ
# file dumped
# channels to scrape remain:  956
# UCdKG1nft7GLjLkzf8wHTpJw
# file dumped
# channels to scrape remain:  955
# UCSpvhvDjbg5zhnyeOQIWyzg
# file dumped
# channels to scrape remain:  954
# UCLpDzmnOyj50sszJ8LKAN5A
# file dumped
# channels to scrape remain:  953
# UCExfygTJkjlFXulKfaRGx-A
# file dumped
# channels to scrape remain:  952
# UCYAGUzkDTmejocmLGq_oGag
# file dumped
# channels to scrape remain:  951
# UCi78pUY0xOrD2AsmMZqO6gA
# file dumped
# channels to scrape remain:  950
# UCSZnvcdY3FxQAlx6Jn83rtA
# file dumped
# channels to scrape remain:  949
# UCJTWqqBgwNNzF3p-YwPApKA
# file dumped
# channels to scrape remain:  948
# UCHEGUTj8EIBPJ2-WVIQGxRA
# file dumped
# channels to scrape remain:  947
# UCEwUe6c7Qnl-n32dWijs-wg
# file dumped
# channels to scrape remain:  946
# UCZHaTu2VdVk4X312PsXb9dw
# file dumped
# channels to scrape remain:  945
# UCUOcznaX3e5DtcWrII7c5vw
# file dumped
# channels to scrape remain:  944
# UC9T-kMm5AJCPwa7LzQqBRPQ
# file dumped
# channels to scrape remain:  943
# UCbw9id8cyqDW7ZCRvYnI_xg
# file dumped
# channels to scrape remain:  942
# UCF6uiv8F3SZoy2TgXCBV8Lw
# file dumped
# channels to scrape remain:  941
# UCFMbX7frWZfuWdjAML0babA
# file dumped
# channels to scrape remain:  940
# UCwAoeMnynao1SE1TnBMeYcQ
# file dumped
# channels to scrape remain:  939
# UCWOA1ZGywLbqmigxE4Qlvuw
# file dumped
# channels to scrape remain:  938
# UCBGUfuGBDzv2zpM5NSK1slw
# file dumped
# channels to scrape remain:  937
# UCbf7OYinARqXaMmJSy3jUPg
# file dumped
# channels to scrape remain:  936
# UCpLB7kBu9O5dbBKhaIOmqcQ
# file dumped
# channels to scrape remain:  935
# UCqF24aNSQwuAp6hbMTKjg5Q
# file dumped
# channels to scrape remain:  934
# UCTrqmZBt-FWUWnxWD2x5Ucg
# file dumped
# channels to scrape remain:  933
# UC5LGPvoUOfwcLi4Ck8LiR4A
# file dumped
# channels to scrape remain:  932
# UCh6C5LG14uZKmwCgGxf-nDQ
# file dumped
# channels to scrape remain:  931
# UCIALMKvObZNtJ6AmdCLP7Lg
# file dumped
# channels to scrape remain:  930
# UCvMioIM1lEDZCiz7rWJt7wg
# file dumped
# channels to scrape remain:  929
# UC_vz6SvmIkYs1_H3Wv2SKlg
# file dumped
# channels to scrape remain:  928
# UCfFsZu7Ed20xKDOmzdpF3EQ
# ...
# UCwWhs_6x42TyRM4Wstoq8HA
# file dumped
# channels to scrape remain:  232
# UCPCoutmVTI2QdjrO1FCyCQQ
# file dumped
# channels to scrape remain:  231
# UCIWLVmZmI63CO7e1UutgYjg
# file dumped
# channels to scrape remain:  230
# UCsqNq-urRKfinnaUd-QRFUg
# file dumped
# channels to scrape remain:  229
# UC1cVTv6C0Unv6TtadjBvYRA
# file dumped
# channels to scrape remain:  228
# UCsqNq-urRKfinnaUd-QRFUg
# file dumped
# channels to scrape remain:  227
# UCrqa0xfSE3V2ybB0iV6QEKQ
# file dumped
# channels to scrape remain:  226
# UC4Pl26JKinpj9cBSPyiOemA
# file dumped
# channels to scrape remain:  225
# UC69uYUqvx-vw4luuX7aHNLQ
# file dumped
# channels to scrape remain:  224
# UCtn2JIYrqmkhloz4ctRns5w
# file dumped
# channels to scrape remain:  223
# UCKlGjB7t71eMfbbZjW0sNow
# file dumped
# channels to scrape remain:  222
# UCGwmN6UJ71Ghw4LTyjOIH_w
# file dumped
# channels to scrape remain:  221
# UCqBVadUfG3BdOhCLOVzBwGw
# file dumped
# channels to scrape remain:  220
# UCLjLzfHYN1u8vsJiqZm4Fhg
# file dumped
# channels to scrape remain:  219
# UC8zAiZUuUXe-touFVopBbZw
# file dumped
# channels to scrape remain:  218
# UCDojPrpBqYWJrAmzQ2ewhdA
# file dumped
# channels to scrape remain:  217
# UCOP-gP2WgKUKfFBMnkR3iaA
# file dumped
# channels to scrape remain:  216
# UC_qY2B-lbCy7NtK7t5lSvpg
# file dumped
# channels to scrape remain:  215
# UCg8Pz1cQ8wcCizZ_hVvvy5g
# file dumped
# channels to scrape remain:  214
# UCihyyKgok1QAXzY-H1Gvgfg
# file dumped
# channels to scrape remain:  213
# UCTivm7DVKSRafbvwbpg2HvA
# file dumped
# channels to scrape remain:  212
# UCj6HhiX_MPi9qYNFESy1isw
# file dumped
# channels to scrape remain:  211
# UCZYV2ss1YPaD6u-yLV_bBdA
# file dumped
# channels to scrape remain:  210
# UCdmMvAC00gFl4gz2M9W1Q4Q
# file dumped
# channels to scrape remain:  209
# UCqZTjDOBJsZsDDlJK-rYKZQ
# file dumped
# channels to scrape remain:  208
# UCXc2VYUIXG0vXu9cDXgQyMQ
# file dumped
# channels to scrape remain:  207
# UCX8fXL7L6UEHmUD7rsUHh5A
# file dumped
# channels to scrape remain:  206
# UC94I54g49VIQMlDvJfErj1w
# file dumped
# channels to scrape remain:  205
# UCJAPj8RYrUAwlMXZmj9up1A
# file dumped
# channels to scrape remain:  204
# UCqUpDkuI3ovttG_0hZeHz2A
# file dumped
# channels to scrape remain:  203
# UC7H3hGbdGkiyKjdU4AQ1zkw
# file dumped
# channels to scrape remain:  202
# UC-pi_mLzGF4RoMfpHbYgtUg
# file dumped
# channels to scrape remain:  201
# UCFaD-LoknJBHTxtS0YdvAPw
# file dumped
# channels to scrape remain:  200
# UCJCM8kLrPjgPcEJEuIV-ELw
# file dumped
# channels to scrape remain:  199
# UCyp5i6QSI-SDdBedE-u8wug
# file dumped
# channels to scrape remain:  198
# UCN-DmzCFdN0bNINLkn0QD6A
# file dumped
# channels to scrape remain:  197
# UCdXtD2bEI8tZ-1D_bECOy1Q
# file dumped
# channels to scrape remain:  196
# UCtn2JIYrqmkhloz4ctRns5w
# file dumped
# channels to scrape remain:  195
# UCuomGEU_WR8eWFD89yUezZg
# file dumped
# channels to scrape remain:  194
# UC4Pl2Is5G-gbXZHo8T0AYRg
# file dumped
# channels to scrape remain:  193
# UC4WyNpChnK7vR0yxsI3nlHA
# file dumped
# channels to scrape remain:  192
# UC5w0-dvOQfcQIH7CMklZUjw
# file dumped
# channels to scrape remain:  191
# UCITYu3Dv69sJdKJ-NEfn4Pg
# file dumped
# channels to scrape remain:  190
# UC0d4vAQ-YUDMcBFKMRONMDQ
# file dumped
# channels to scrape remain:  189
# UCoxhox1hQfO0KVL0o5fxc1w
# file dumped
# channels to scrape remain:  188
# UCcRHd1TwHS7-fZ_sVq0ugeA
# file dumped
# channels to scrape remain:  187
# UC6tYGlHZma1HiA-Xop9qR1A
# file dumped
# channels to scrape remain:  186
# UC2VPziGCmoV9N5VfCm_a5XA
# file dumped
# channels to scrape remain:  185
# UCGtr4VtU2XZEZqHbRx1WdJw
# file dumped
# channels to scrape remain:  184
# UCP0axk3bepLZTZzNSpnFfMg
# file dumped
# channels to scrape remain:  183
# UCwVpjRTwIs6_z5fsyYBCRjQ
# file dumped
# channels to scrape remain:  182
# UCyy-q1DQfJXKUdbWnq5P5ZA
# file dumped
# channels to scrape remain:  181
# UCQSATsSglMx2cfhVwSAWR8Q
# file dumped
# channels to scrape remain:  180
# UC5rmjonujSXJBYOsRJjA3FQ
# file dumped
# channels to scrape remain:  179
# UCOP-gP2WgKUKfFBMnkR3iaA
# file dumped
# channels to scrape remain:  178
# UCpIc_XK7aZ5lJSHj9_R_VXw
# file dumped
# channels to scrape remain:  177
# UC5N2asRYkdATmJ9dtr1fO1w
# file dumped
# channels to scrape remain:  176
# UCkk39Cyy7j-BI6JqtVU7JVg
# file dumped
# channels to scrape remain:  175
# UCxps9cbNgWrekrOMyt520aw
# file dumped
# channels to scrape remain:  174
# UC7tE3V2C_PBHplywOW_5VMA
# file dumped
# channels to scrape remain:  173
# UCbGAFSv27XRtnctb9WohZ0w
# file dumped
# channels to scrape remain:  172
# UC92d2VNoH_3PdlwLJifFbYw
# file dumped
# channels to scrape remain:  171
# UCmJHp21CdwdvYAcUekTHRHg
# file dumped
# channels to scrape remain:  170
# UCzkX5li0jyBCEI-RnzK45Tg
# file dumped
# channels to scrape remain:  169
# UCOAuKpUX4Hy2oNgGkjViGbg
# file dumped
# channels to scrape remain:  168
# UCrF5eiuG4qAyZ0XDS2w9gzQ
# file dumped
# channels to scrape remain:  167
# UCSwCcLiGqxIYmNjq-nTV2RA
# file dumped
# channels to scrape remain:  166
# UCyLC4EcXI2rC0hSKFSVI3iw
# file dumped
# channels to scrape remain:  165
# UCK8XJDyYUPge9pF2prhtgZg
# file dumped
# channels to scrape remain:  164
# UCZKWtxbMmc25miei3PJ-q_w
# file dumped
# channels to scrape remain:  163
# UC94I54g49VIQMlDvJfErj1w
# file dumped
# channels to scrape remain:  162
# UCuHOpnUAiAha-S31Ip1u47A
# file dumped
# channels to scrape remain:  161
# UCH4llwBmjEe8bCOv4Tn-OeQ
# file dumped
# channels to scrape remain:  160
# UC2m3J-vicFgs7wRdxHnYh7w
# file dumped
# channels to scrape remain:  159
# UCPgj-dhrdajrJDP2WQjgPvQ
# file dumped
# channels to scrape remain:  158
# UCYCEK7i8Uq-XtFtWolofxFg
# file dumped
# channels to scrape remain:  157
# UCrQJ6GXFvgkBuyqlIexy5Hg
# file dumped
# channels to scrape remain:  156
# UCwIJHAeRFzpJqhw_vaL0K4A
# file dumped
# channels to scrape remain:  155
# UCCtcx6_LTkfbq_GARwY-3bQ
# file dumped
# channels to scrape remain:  154
# UCYz9qO0bQTTzjJdPh0Ns9OQ
# file dumped
# channels to scrape remain:  153
# UCujzqF63Fi0QA5VacHrRvrw
# file dumped
# channels to scrape remain:  152
# UCA4dzpb_Q_v4HXxrh_MwsaQ
# file dumped
# channels to scrape remain:  151
# UCglpNXUOWPr6c7gZB3ktuRg
# file dumped
# channels to scrape remain:  150
# UCnRPXIqhd4NITAy0k6z_9qA
# file dumped
# channels to scrape remain:  149
# UCGhLxQ3b1zya2GWape8Ci5A
# file dumped
# channels to scrape remain:  148
# UCm3zYhIMEIuzFIl23pdEV6w
# file dumped
# channels to scrape remain:  147
# UCpdPFa4ySFFxQpf_t-h_Z5A
# file dumped
# channels to scrape remain:  146
# UCZOg-aJMB3KMPoHkV41J5dA
# file dumped
# channels to scrape remain:  145
# UClk12qEsqchxKgX7DVTRi6w
# file dumped
# channels to scrape remain:  144
# UCd0fOkcnWmbE2FKIJly8cBw
# file dumped
# channels to scrape remain:  143
# UCaeAVvAQkL7aEGF3BcJ4gEw
# file dumped
# channels to scrape remain:  142
# UCtn2JIYrqmkhloz4ctRns5w
# file dumped
# channels to scrape remain:  141
# UCLxrVHu8kyOJENdoSGz0jXQ
# file dumped
# channels to scrape remain:  140
# UCtn2JIYrqmkhloz4ctRns5w
# file dumped
# channels to scrape remain:  139
# UC_LKhBiSqiBLbFC3wFY2BRA
# file dumped
# channels to scrape remain:  138
# UCWOA1ZGywLbqmigxE4Qlvuw
# file dumped
# channels to scrape remain:  137
# UCZEQZQ8HhFbyFjXUT46XH8g
# file dumped
# channels to scrape remain:  136
# UCfUhI2tJIKL__1DHW4B0Yrg
# file dumped
# channels to scrape remain:  135
# UCXsxHs-Ujs5dCGEicw-PDKg
# file dumped
# channels to scrape remain:  134
# UCY6VB6PidbvVZFwyVmUcvEg
# file dumped
# channels to scrape remain:  133
# UC7qH5f2DeWO9Bz1Z8N22euw
# file dumped
# channels to scrape remain:  132
# UCYjkt3A0ka5pIx_YftaUVNw
# file dumped
# channels to scrape remain:  131
# UCgFDhIHieq-a7PjeOsNT0dg
# file dumped
# channels to scrape remain:  130
# UCv0e9AgH5L4LvyX97aihfaQ
# file dumped
# channels to scrape remain:  129
# UCMOB6uDg7e-h8OuCw8dK2_Q
# file dumped
# channels to scrape remain:  128
# UCr5GW9GbP59LH2QHQsfjioQ
# file dumped
# channels to scrape remain:  127
# UCBPkj2ynoXLzKQ9kk47k9mw
# file dumped
# channels to scrape remain:  126
# UCh0U8XiEt7JyOG-TGJNIkPw
# file dumped
# channels to scrape remain:  125
# UCGISdMmwbeITAePSHrnHOkw
# file dumped
# channels to scrape remain:  124
# UCTk9Xbgf9iIgoJWf041UqYQ
# file dumped
# channels to scrape remain:  123
# UCBPkj2ynoXLzKQ9kk47k9mw
# file dumped
# channels to scrape remain:  122
# UCNl9LUgT_E1hxd4JMinnwkw
# file dumped
# channels to scrape remain:  121
# UChu01UQWmLVzcfA-o2CCtVA
# file dumped
# channels to scrape remain:  120
# UCsT3Cuse4tfrtp1Tn7wEzuQ
# file dumped
# channels to scrape remain:  119
# UC6tYGlHZma1HiA-Xop9qR1A
# file dumped
# channels to scrape remain:  118
# UCPGwc4aKsjALiRx748vmOgQ
# file dumped
# channels to scrape remain:  117
# UCZ0HTcomOLeUVlc4-1WeYuQ
# file dumped
# channels to scrape remain:  116
# UCrDe1lQf8dHxyMf9A3_EttQ
# file dumped
# channels to scrape remain:  115
# UC0iKz7rHTINeZsPVO1wfGQA
# file dumped
# channels to scrape remain:  114
# UCR2_AYQ_sNb3NTdXWjC93Cw
# file dumped
# channels to scrape remain:  113
# UCmQFMbw2jsRxtLjP6XDwXiw
# file dumped
# channels to scrape remain:  112
# UCPLilbt5ar2oxyGuvxxYnSg
# file dumped
# channels to scrape remain:  111
# UCDHv5A6lFccm37oTZ5Mp7NA
# file dumped
# channels to scrape remain:  110
# UCIBPO8UasUvHrVwCzGVvsFQ
# file dumped
# channels to scrape remain:  109
# UCmNzRBEBLgkq9asHtXiB63Q
# file dumped
# channels to scrape remain:  108
# UC6tYGlHZma1HiA-Xop9qR1A
# file dumped
# channels to scrape remain:  107
# UC06ZZlWlVoT5AteuadCiuEw
# file dumped
# channels to scrape remain:  106
# UCVXO1_7BI7cCJFdIqXKGhuA
# file dumped
# channels to scrape remain:  105
# UCtqD1NLgjbZgFNH90QhnG4g
# file dumped
# channels to scrape remain:  104
# UC6CVzdb-vCMwquGCIya5JPw
# file dumped
# channels to scrape remain:  103
# UCiS882YPwZt1NfaM0gR0D9Q
# file dumped
# channels to scrape remain:  102
# UCiS882YPwZt1NfaM0gR0D9Q
# file dumped
# channels to scrape remain:  101
# UCE_kbnmsYvI_shG13ly9ewQ
# file dumped
# channels to scrape remain:  100
# UCv_2ajvWQ_O976gRm015Pvw
# file dumped
# channels to scrape remain:  99
# UCaH02uiAaEbNmNjEfN0NT_w
# file dumped
# channels to scrape remain:  98
# UClLdCbmAudkPs3AIQtozimw
# file dumped
# channels to scrape remain:  97
# UCYZOAcPyss375BrECmP3idw
# file dumped
# channels to scrape remain:  96
# UCWgbTnIywqap3iZo00itlng
# file dumped
# channels to scrape remain:  95
# UCM1LVD5a5509fzL-4khritA
# file dumped
# channels to scrape remain:  94
# UC0KxtvMQ6DqvZhtwAzFRmoQ
# file dumped
# channels to scrape remain:  93
# UCtn2JIYrqmkhloz4ctRns5w
# file dumped
# channels to scrape remain:  92
# UCji2wcAurS6ZCMfU_7EQN4w
# file dumped
# channels to scrape remain:  91
# UCIlMoE4a6jAriaby6iSracw
# file dumped
# channels to scrape remain:  90
# UCx0fwK1CQ4kT49qcQi_jsMA
# file dumped
# channels to scrape remain:  89
# UCOP-gP2WgKUKfFBMnkR3iaA
# file dumped
# channels to scrape remain:  88
# UCK6ZjaMxlXzrZnWa3cCtEpg
# file dumped
# channels to scrape remain:  87
# UCELo5KuPEKHPaGUY-GxksOw
# file dumped
# channels to scrape remain:  86
# UCYZOAcPyss375BrECmP3idw
# file dumped
# channels to scrape remain:  85
# UCWdX4g8Tg9b7XSuxRdO2v8A
# file dumped
# channels to scrape remain:  84
# UCCBpb3t8YOb3dmSTEzTPgCQ
# file dumped
# channels to scrape remain:  83
# UCFXxuDNL3K3R7OGHYtaI61g
# file dumped
# channels to scrape remain:  82
# UCe-D60vtTrHrJop1DtvROkw
# file dumped
# channels to scrape remain:  81
# UClzKvxmngzhBk5-RpX_967g
# file dumped
# channels to scrape remain:  80
# UCpJN7kiUkDrH11p0GQhLyFw
# file dumped
# channels to scrape remain:  79
# UCTIqWC-v6rORlUZKdRzNRBg
# file dumped
# channels to scrape remain:  78
# UCxFkhyItW88zs-8IhTOZ-Dw
# file dumped
# channels to scrape remain:  77
# UCzRy4WYepJbGQpdJntX1x5w
# file dumped
# channels to scrape remain:  76
# UC-KNcyoP6wTpFkeCgqilwTQ
# file dumped
# channels to scrape remain:  75
# UCoHihEsNYcO1FjCF8irMt7w
# file dumped
# channels to scrape remain:  74
# UCjJ9MlwftUlV6ivKfK-2aqA
# file dumped
# channels to scrape remain:  73
# UCt_S0UBhMcC4irEERlKKxxQ
# file dumped
# channels to scrape remain:  72
# UCRrFpSZfKnoQG99Kub_p1eA
# file dumped
# channels to scrape remain:  71
# UCo2uQIqoN55w-ilv2WenDUQ
# file dumped
# channels to scrape remain:  70
# UCB9U0iEZ7mg4ysOkhFqzbAw
# file dumped
# channels to scrape remain:  69
# UCc8d14ksSbSu23NjaWO3JJA
# file dumped
# channels to scrape remain:  68
# UCooVYzDxdwTtGYAkcPmOgOw
# file dumped
# channels to scrape remain:  67
# UCuWfIx-clNfJ8hf_9EMnPtg
# file dumped
# channels to scrape remain:  66
# UCLRlryMfL8ffxzrtqv0_k_w
# file dumped
# channels to scrape remain:  65
# UCyKtQVHyq5fZcyW4E9ZqH6g
# file dumped
# channels to scrape remain:  64
# UCspf4FRtxNBHspyR3a56CmQ
# file dumped
# channels to scrape remain:  63
# UCe0DNp0mKMqrYVaTundyr9w
# file dumped
# channels to scrape remain:  62
# UCWZ_G58kHgwcnnJ7-TLLq3Q
# file dumped
# channels to scrape remain:  61
# UCNosjkvg8QP0PYzpYgaxL6w
# file dumped
# channels to scrape remain:  60
# UCGie8GMlUo3kBKIopdvumVQ
# file dumped
# channels to scrape remain:  59
# UCGDnb-yHcNMn3JqOUa8j3lw
# file dumped
# channels to scrape remain:  58
# UCtn2JIYrqmkhloz4ctRns5w
# file dumped
# channels to scrape remain:  57
# UCGjVyKdnlikxF_BPEftJdmQ
# file dumped
# channels to scrape remain:  56
# UCJS8vl5zeUQpLh0QuOwCpCw
# file dumped
# channels to scrape remain:  55
# UCFSILgKCKo35QYGz8Kob51g
# file dumped
# channels to scrape remain:  54
# UCLs20FEDcyKUa2nQ5IxHAwg
# file dumped
# channels to scrape remain:  53
# UCA9g5DK2QPj-jeQgZcrM_QQ
# file dumped
# channels to scrape remain:  52
# UCLlHQpMI6NCzSBRRT1_D7eA
# file dumped
# channels to scrape remain:  51
# UCqWo9UKAfm63Bfuc1-2NfvQ
# file dumped
# channels to scrape remain:  50
# UCQ2y00sM_b_7j87XTuPM0eQ
# file dumped
# channels to scrape remain:  49
# UCVXO1_7BI7cCJFdIqXKGhuA
# file dumped
# channels to scrape remain:  48
# UCq1mJywKrEA4Hz_T7NoI78Q
# file dumped
# channels to scrape remain:  47
# UCIF3gTdTptrcJg6T-vHCVcw
# file dumped
# channels to scrape remain:  46
# UCtI3eHfFyPbGx9Bizh5rPKQ
# file dumped
# channels to scrape remain:  45
# UCPRDhYEw5TWXsbDAkGarMeA
# file dumped
# channels to scrape remain:  44
# UCzw9sWPpk986T5-GmXI8c_A
# file dumped
# channels to scrape remain:  43
# UCENNxhWzfSD4xNcmAvdCMWQ
# file dumped
# channels to scrape remain:  42
# UCK-mbSYwKZghJDr1Pn1WiFQ
# file dumped
# channels to scrape remain:  41
# UCYuPl8pevVl2et1LR94LEsA
# file dumped
# channels to scrape remain:  40
# UCbGAFSv27XRtnctb9WohZ0w
# file dumped
# channels to scrape remain:  39
# UCti3uswa5GBAhPbXnpOgzuQ
# file dumped
# channels to scrape remain:  38
# UCjHuFuuuBwXW3Sluf0TleAQ
# file dumped
# channels to scrape remain:  37
# UC3ZXQ1jwwAwYpJSpOeY8Zyg
# file dumped
# channels to scrape remain:  36
# UCpSTrE1oD-RnKyEj3KlZmqg
# file dumped
# channels to scrape remain:  35
# UCzHUPzjcCVJucRRhk3jv2yQ
# file dumped
# channels to scrape remain:  34
# UCD2-weSAzPkHxH4bZW_SxRA
# file dumped
# channels to scrape remain:  33
# UC49ubBi7M028DIWtRKuWV1g
# file dumped
# channels to scrape remain:  32
# UC8xa66CAtqMZhHsxB_tVb3g
# file dumped
# channels to scrape remain:  31
# UCyhuidcl1W1l5m1rwbmj9FQ
# file dumped
# channels to scrape remain:  30
# UCbIi1ydOGTdoOlJS2Jp8Bng
# file dumped
# channels to scrape remain:  29
# UCdQtA1TiaEo9a-rn4AmTmIg
# file dumped
# channels to scrape remain:  28
# UCOudOvNgQdlDqNz5PEpM9TQ
# file dumped
# channels to scrape remain:  27
# UCEN7gTeumGdaIrzFyQOdOIw
# file dumped
# channels to scrape remain:  26
# UCELImNdpeM_aSEEiWVTtxrQ
# file dumped
# channels to scrape remain:  25
# UCgB8M6Wwjrl22zOAOMXtLsA
# file dumped
# channels to scrape remain:  24
# UCgAQHyJ3ZSZ7rJewWlyfXqQ
# file dumped
# channels to scrape remain:  23
# UCC-1QhB1bDG-Q9RIfkUwfxg
# file dumped
# channels to scrape remain:  22
# UCVXO1_7BI7cCJFdIqXKGhuA
# file dumped
# channels to scrape remain:  21
# UCoyCuplNnyIHQ0oF0zPLSdw
# file dumped
# channels to scrape remain:  20
# UClegaGQouZZfx0COZ-9y7Mw
# file dumped
# channels to scrape remain:  19
# UCtn2JIYrqmkhloz4ctRns5w
# file dumped
# channels to scrape remain:  18
# UCimCIPzLzBYKNIxLKBTV0YQ
# file dumped
# channels to scrape remain:  17
# UCypKdgt6xdbZGOSMoAMPDZA
# file dumped
# channels to scrape remain:  16
# UCOP-gP2WgKUKfFBMnkR3iaA
# file dumped
# channels to scrape remain:  15
# UCBnbynQGc9yKTxri_dhsEDw
# file dumped
# channels to scrape remain:  14
# UClo4qjUjUC9NcFPEGRSeBAQ
# file dumped
# channels to scrape remain:  13
# UCX8fXL7L6UEHmUD7rsUHh5A
# file dumped
# channels to scrape remain:  12
# UCP4n48jVBDDXopJuGhKsWeQ
# file dumped
# channels to scrape remain:  11
# UCOtswdLgU6otiAy4EWbNd4Q
# file dumped
# channels to scrape remain:  10
# UCiS882YPwZt1NfaM0gR0D9Q
# file dumped
# channels to scrape remain:  9
# UC2v1PAoSTALNwHbWPkqYYNw
# file dumped
# channels to scrape remain:  8
# UCRzYovoofsz7qMIL-AV8eDA
# file dumped
# channels to scrape remain:  7
# UC5lDVbmgb-sAcx2fjwy3KQA
# file dumped
# channels to scrape remain:  6
# UCfoBQY1ViPDDuWtrGZ1pbvw
# file dumped
# channels to scrape remain:  5
# UCyLe82PgC5_ENdJmprv0IDg
# file dumped
# channels to scrape remain:  4
# UC2DdT5vKLfrJpLWMssrWlQw
# file dumped
# channels to scrape remain:  3
# UCiS882YPwZt1NfaM0gR0D9Q
# file dumped
# channels to scrape remain:  2
# UCeDigFgrZksWaahR6WI_uEQ
# file dumped
# channels to scrape remain:  1
# UCs9e9Pp0GaEntGDvqYFH7vQ
# nothing happend
# channels to scrape remain:  0

# %% [markdown]
# # read josn file and combine:

# %%
# read josn files and make a list with json files
# (make 1 change)

path_to_json = r'C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Channels info\channels info batch 3'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]
json_files;  
len(json_files)
# Out:
# 1440

# %%
# create a data frame with all json files:
# (make 1 change)

df = pd.DataFrame()
for file in json_files:
    file_path = path_to_json + '/' + file
    with open(file_path) as data_file:    
        data = json.load(data_file)
        df = df.append(pd.json_normalize(data))
df.shape
# Out:
# (1440, 168)

# %%
df.head()
# Out:
#               kind                         etag                        id  \
# 0  youtube#channel  z3erkf936wGVDVAikz3ycw0PXxY  UC-5pJ6MCb7YAlceStfv4r7A
# 0  youtube#channel  NcZ8o0Yl2qncP9tEJRZWev8ICuU  UC-8mjoe4oRWVLk0n5AWhoaQ
# 0  youtube#channel  xLIVo9aW7-PylQLC0Ql6ZSRvExI  UC-9QoQPlLzVCrAZplemJuPQ
# 0  youtube#channel  eNdO0d0-RFQWRJ8bt8PaR_23jw4  UC-b1JdevG6fVeb06rRN_Xhw
# 0  youtube#channel  t06Bk2XzRTaVeX3A7iCpHWQywqU  UC-b9eaX0_9Wz0ug1fmx-YfQ
#
#               snippet.title  \
# 0                Red Big'un
# 0                  PEO ACWA
# 0  the travelling surrogate
# 0                40/29 News
# 0               Lailah Lynn
#
#                                  snippet.description  \
# 0  An unqualified movie reviewer.\nA boring Let's...
# 0  Welcome to the Program Executive Office, Assem...
# 0  I am happily childfree but I have always had a...
# 0  4029tv.com is your top source for Northwest Ar...
# 0  I discuss celebrity news & entertainment...wit...
#
#            snippet.publishedAt  \
# 0         2014-06-09T15:51:16Z
# 0         2009-03-17T02:46:21Z
# 0  2020-11-20T20:26:10.954491Z
# 0         2007-08-09T18:13:39Z
# 0         2013-05-16T17:40:13Z
#
#                       snippet.thumbnails.default.url  \
# 0  https://yt3.ggpht.com/ytc/AKedOLQ-Si7vhxsCZnkC...
# 0  https://yt3.ggpht.com/ytc/AKedOLQqy4wew_MCxFXM...
# 0  https://yt3.ggpht.com/WS9hk1e-flpsbqJlrbdOsavj...
# 0  https://yt3.ggpht.com/ytc/AKedOLTJurGZA2UKyImq...
# 0  https://yt3.ggpht.com/ytc/AKedOLTkZ2c865lVQRY7...
#
#    snippet.thumbnails.default.width  snippet.thumbnails.default.height  \
# 0                                88                                 88
# 0                                88                                 88
# 0                                88                                 88
# 0                                88                                 88
# 0                                88                                 88
#
#                        snippet.thumbnails.medium.url  ...  \
# 0  https://yt3.ggpht.com/ytc/AKedOLQ-Si7vhxsCZnkC...  ...
# 0  https://yt3.ggpht.com/ytc/AKedOLQqy4wew_MCxFXM...  ...
# 0  https://yt3.ggpht.com/WS9hk1e-flpsbqJlrbdOsavj...  ...
# 0  https://yt3.ggpht.com/ytc/AKedOLTJurGZA2UKyImq...  ...
# 0  https://yt3.ggpht.com/ytc/AKedOLTkZ2c865lVQRY7...  ...
#
#    localizations.th_TH.description  localizations.ro_RO.title  \
# 0                              NaN                        NaN
# 0                              NaN                        NaN
# 0                              NaN                        NaN
# 0                              NaN                        NaN
# 0                              NaN                        NaN
#
#   localizations.ro_RO.description  localizations.pa_IN.title  \
# 0                             NaN                        NaN
# 0                             NaN                        NaN
# 0                             NaN                        NaN
# 0                             NaN                        NaN
# 0                             NaN                        NaN
#
#    localizations.pa_IN.description localizations.ms_MY.title  \
# 0                              NaN                       NaN
# 0                              NaN                       NaN
# 0                              NaN                       NaN
# 0                              NaN                       NaN
# 0                              NaN                       NaN
#
#   localizations.ms_MY.description localizations.ne_NP.title  \
# 0                             NaN                       NaN
# 0                             NaN                       NaN
# 0                             NaN                       NaN
# 0                             NaN                       NaN
# 0                             NaN                       NaN
#
#   localizations.ne_NP.description localizations.te_IN.title
# 0                             NaN                       NaN
# 0                             NaN                       NaN
# 0                             NaN                       NaN
# 0                             NaN                       NaN
# 0                             NaN                       NaN
#
# [5 rows x 168 columns]

# %%
df = df[df.columns.drop(list(df.filter(regex='localizations')))]

# %%
df.shape
# Out:
# (1440, 32)

# %%
column_head_list = list(df.columns)
column_head_list
# Out:
# ['kind',
#  'etag',
#  'id',
#  'snippet.title',
#  'snippet.description',
#  'snippet.publishedAt',
#  'snippet.localized.title',
#  'snippet.localized.description',
#  'contentDetails.relatedPlaylists.likes',
#  'contentDetails.relatedPlaylists.uploads',
#  'statistics.viewCount',
#  'statistics.subscriberCount',
#  'statistics.hiddenSubscriberCount',
#  'statistics.videoCount',
#  'topicDetails.topicIds',
#  'topicDetails.topicCategories',
#  'status.privacyStatus',
#  'status.isLinked',
#  'status.longUploadsStatus',
#  'status.madeForKids',
#  'brandingSettings.channel.title',
#  'brandingSettings.channel.description',
#  'brandingSettings.image.bannerExternalUrl',
#  'snippet.country',
#  'brandingSettings.channel.keywords',
#  'brandingSettings.channel.trackingAnalyticsAccountId',
#  'brandingSettings.channel.unsubscribedTrailer',
#  'brandingSettings.channel.country',
#  'snippet.customUrl',
#  'brandingSettings.channel.moderateComments',
#  'snippet.defaultLanguage',
#  'brandingSettings.channel.defaultLanguage',
#  'localizations.en_IN.title',
#  'localizations.en_IN.description',
#  'localizations.ml_IN.title',
#  'localizations.ml_IN.description',
#  'localizations.mr_IN.title',
#  'localizations.mr_IN.description',
#  'localizations.en_US.title',
#  'localizations.en_US.description',
#  'localizations.es_ES.title',
#  'localizations.es_ES.description',
#  'localizations.zh_CN.title',
#  'localizations.zh_CN.description',
#  'localizations.bn_BD.title',
#  'localizations.bn_BD.description',
#  'localizations.sv_SE.title',
#  'localizations.sv_SE.description',
#  'localizations.de_DE.title',
#  'localizations.de_DE.description',
#  'localizations.es_MX.title',
#  'localizations.es_MX.description',
#  'localizations.tr_TR.title',
#  'localizations.tr_TR.description',
#  'localizations.ru_RU.title',
#  'localizations.ru_RU.description',
#  'localizations.ja_JP.title',
#  'localizations.ja_JP.description',
#  'localizations.it_IT.title',
#  'localizations.it_IT.description',
#  'localizations.ar_EG.title',
#  'localizations.ar_EG.description',
#  'localizations.fr_FR.title',
#  'localizations.fr_FR.description',
#  'localizations.hi_IN.title',
#  'localizations.hi_IN.description',
#  'localizations.es_US.title',
#  'localizations.es_US.description',
#  'localizations.nl_NL.title',
#  'localizations.nl_NL.description',
#  'localizations.fr_CA.title',
#  'localizations.fr_CA.description',
#  'localizations.en_GB.title',
#  'localizations.en_GB.description',
#  'localizations.ur_PK.title',
#  'localizations.ur_PK.description',
#  'localizations.vi_VN.title',
#  'localizations.vi_VN.description',
#  'localizations.pt_BR.title',
#  'localizations.pt_BR.description',
#  'localizations.id_ID.title',
#  'localizations.id_ID.description',
#  'localizations.fil_PH.title',
#  'localizations.fil_PH.description',
#  'localizations.uz_UZ.title',
#  'localizations.uz_UZ.description',
#  'localizations.is_IS.title',
#  'localizations.is_IS.description',
#  'localizations.gl_ES.title',
#  'localizations.gl_ES.description',
#  'localizations.bg_BG.title',
#  'localizations.bg_BG.description',
#  'localizations.ky_KG.title',
#  'localizations.ky_KG.description',
#  'localizations.be_BY.title',
#  'localizations.be_BY.description',
#  'localizations.az_AZ.title',
#  'localizations.az_AZ.description',
#  'localizations.as_IN.title',
#  'localizations.as_IN.description',
#  'localizations.da_DK.title',
#  'localizations.da_DK.description',
#  'localizations.kn_IN.title',
#  'localizations.kn_IN.description',
#  'localizations.gu_IN.title',
#  'localizations.gu_IN.description',
#  'localizations.hu_HU.title',
#  'localizations.hu_HU.description',
#  'localizations.km_KH.title',
#  'localizations.km_KH.description',
#  'localizations.ca_ES.title',
#  'localizations.ca_ES.description',
#  'localizations.kk_KZ.title',
#  'localizations.kk_KZ.description',
#  'localizations.eu_ES.title',
#  'localizations.eu_ES.description',
#  'localizations.bs_BA.title',
#  'localizations.bs_BA.description',
#  'localizations.hr_HR.title',
#  'localizations.hr_HR.description',
#  'localizations.af_ZA.title',
#  'localizations.af_ZA.description',
#  'localizations.am_ET.title',
#  'localizations.am_ET.description',
#  'localizations.ko_KR.title',
#  'localizations.ko_KR.description',
#  'localizations.ka_GE.title',
#  'localizations.ka_GE.description',
#  'localizations.hy_AM.title',
#  'localizations.hy_AM.description',
#  'localizations.et_EE.title',
#  'localizations.et_EE.description',
#  'localizations.cs_CZ.title',
#  'localizations.cs_CZ.description',
#  'localizations.my_MM.title',
#  'localizations.my_MM.description',
#  'localizations.iw_IL.title',
#  'localizations.iw_IL.description',
#  'localizations.sq_AL.title',
#  'localizations.sq_AL.description',
#  'localizations.pt_PT.title',
#  'localizations.pt_PT.description',
#  'localizations.zh_TW.title',
#  'localizations.zh_TW.description',
#  'localizations.pl_PL.title',
#  'localizations.pl_PL.description',
#  'localizations.fi_FI.title',
#  'localizations.fi_FI.description',
#  'localizations.th_TH.title',
#  'localizations.th_TH.description',
#  'localizations.ro_RO.title',
#  'localizations.ro_RO.description',
#  'localizations.pa_IN.title',
#  'localizations.pa_IN.description',
#  'localizations.ms_MY.title',
#  'localizations.ms_MY.description',
#  'localizations.ne_NP.title',
#  'localizations.ne_NP.description',
#  'localizations.te_IN.title']

# %%
df.to_csv(r'C:\Users\David\Amber Heard Case\Youtube\Data\combined files for channels\combined accounts info batch 3.csv')
