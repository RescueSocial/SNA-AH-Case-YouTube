# %% [markdown]
# ##  Collect data from youtube

# %%
import pandas as pd
import json
import requests
from io import StringIO
from csv import reader
import os
import glob

# %%
# read data and save videos code to a list
def vid_list(address):
    ytvid = pd.read_csv(address)
    x = ytvid['link'].str.split('=')
    vid_cod = []
    for i in range(len(x)):
        vid_cod.append(x[i][1])
    return vid_cod

# %%
class YTstats:
  
    def __init__(self, api_key, video_id):
        self.api_key = api_key
        self.video_id = video_id
        self.video_statistics = None
  
    def get_video_statistics(self):
        url = f'https://www.googleapis.com/youtube/v3/videos?id={self.video_id}&key={self.api_key}&part=snippet,contentDetails,statistics,status'
        json_url = requests.get(url)
        data = json.loads(json_url.text)
  
        try:
            data = data["items"]#[0]["statistics"]
        except:
            data = None
  
        self.video_statistics = data
        return data
  
    def dump(self):
        if self.video_statistics is None:
            print('nothing happend')
            return 
  
        video_title = self.video_id
        video_title = video_title.replace(" ", "_").lower()
  
        # generate a json file with all the statistics data of the youtube video
        file_name = video_title + '.json'
        with open(file_name, 'w') as f:
            json.dump(self.video_statistics, f, indent=4)
        print('file dumped')

# %%
#read data from youtube file and extratc video code for each and make a list of the videos code:
# (make 3 changes)

address = r'C:\Users\David\OneDrive\Documents\Social Media Analysis\Amber Heard Case\Youtube\SNA-AH-Case-YouTube - NOT git\YouTube Videos URLS scraped & manual\Amber_Heard.csv'
Amber_Heard = vid_list(address)
len(Amber_Heard)
# Out:
# 355

# %%
# recive data using API and save it on PC
# (make 1 change)

API_KEY = "AIzaSyA-0KfpLK04NpQN1XghxhSlzG-WkC3DHLs"
  
 # paste the channel id here
for video in Amber_Heard:
    print(video)
    yt = YTstats(API_KEY, video)
    yt.get_video_statistics()
    yt.dump()
# Out:
# wgfUsGLfPpQ
# file dumped
# mhVfeiACVUQ
# file dumped
# IVxZM3taWPg
# file dumped
# M3pSG8v3lEE
# file dumped
# Y_UkrYDu-VA
# file dumped
# 5Pyqq3KZCOg
# file dumped
# zGWheCDobKM
# file dumped
# clAb4LQ5wic
# file dumped
# kNIX9_jhC2A
# file dumped
# Vveu5aY3d7I
# file dumped
# bUJTw20Qtkg
# file dumped
# Jka1JsBBmCU
# file dumped
# ZEbrWa6IY5w
# file dumped
# VzG4rT-BDEA
# file dumped
# iRkweYsD_Jg
# file dumped
# 3R_emk-Fzh8
# file dumped
# HNwoRxZzbjM
# file dumped
# Xlf58om_C9E
# file dumped
# Bu1uOt5Tyoc
# file dumped
# F7flOBTSiCE
# file dumped
# VjNKo0H7GjU
# file dumped
# Wahd_gszuBA
# file dumped
# lGbPKZrs368
# file dumped
# g7QY3uedq5k
# file dumped
# FLOlOYsKsZs
# file dumped
# xgDDvD49sak
# file dumped
# f4ivPgqaFb4
# file dumped
# jnUHvaBQ5Ng
# file dumped
# iT2Kiyt7-rk
# file dumped
# 8oiB_u4RDiM
# file dumped
# So9UkwrMQjM
# file dumped
# ATf-o9qerTo
# file dumped
# h-wpBkiMKd0
# file dumped
# -Puv-V2NDXc
# file dumped
# neQOHMNa-lk
# file dumped
# RAbwipKD9cE
# file dumped
# bx1_Kok59aQ
# file dumped
# F3bqW4uI8lA
# file dumped
# wYiU3yOUx6w
# file dumped
# wSUW_8wcT6I
# file dumped
# pZR2_v4UpgI
# file dumped
# M1lxGj_KkyQ
# file dumped
# tdXBUL9WunQ
# file dumped
# gJ4C74byhEE
# file dumped
# iX63Sqkr8sE
# file dumped
# Sdf-x2_wedU
# file dumped
# poyCzmHadrM
# file dumped
# uTMkPIsSn50
# file dumped
# pd-iJRfKPuI
# file dumped
# kHTp6HdKI_Y
# file dumped
# 0L_AkpaiTzs
# file dumped
# UCCh-zVJWCs
# file dumped
# U8kIY_JREHk
# file dumped
# PpS55f5yBsY
# file dumped
# ApaFjM2Hs-o
# file dumped
# WzJD3RhAuI4
# file dumped
# LMx8qjwI_Ww
# file dumped
# L2y6ED9Cu8s
# file dumped
# gECq8x8b6bo
# file dumped
# FzB3uX9z4s4
# file dumped
# Ar1Kk-X0GG8
# file dumped
# QdVsTIniocQ
# file dumped
# 7iqqFEfT82Q
# file dumped
# aKeYSCQeFlE
# file dumped
# j94ckfo6DnU
# file dumped
# iT3u5xSvT6s
# file dumped
# pB8jpj4srvE
# file dumped
# BDgktmMv1ZE
# file dumped
# 3YHmbJEvn40
# file dumped
# 5iVs0VfiuU4
# file dumped
# qRXSqkh4tyg
# file dumped
# B9ZaUwfDvg4
# file dumped
# RricSNwtleQ
# file dumped
# IfZzdVZrPuI
# file dumped
# SffKG2-KHTM
# file dumped
# znAVQD4tgBk
# file dumped
# dHWWWCGuoS8
# file dumped
# zis29lX5xqQ
# file dumped
# -qHw0PtrdQI
# file dumped
# syCVIAP0La4
# file dumped
# Lc4hf4w7QXA
# file dumped
# B9MtG3e1ubw
# file dumped
# VzG4rT-BDEA
# file dumped
# xFaa6c4iCHc
# file dumped
# O1Rrb3ET21c
# file dumped
# i3x_TuQigw8
# file dumped
# g8whj8pfdF8
# file dumped
# tDyEIfYRIME
# file dumped
# AKSQk1KayeA
# file dumped
# NuGM3z8cO6c
# file dumped
# dJe8bl_BLDE
# file dumped
# RovrVHHQXK4
# file dumped
# NfOaNcuySr4
# file dumped
# eDswApK6vR8
# file dumped
# qgnkeDWNzgc
# file dumped
# hYXqDheAzfo
# file dumped
# 74z8RUi3Tu0
# file dumped
# Y9wJrXvVLZY
# file dumped
# OrK7O1ES-gs
# file dumped
# zsu0ORKvq9o
# file dumped
# 6b6CBo8aYVY
# file dumped
# xF1yyij4FAA
# file dumped
# Jzyfbqc15T0
# file dumped
# -2ZWF-DW3TQ
# file dumped
# CgA2iLului4
# file dumped
# rzD87uGjuq0
# file dumped
# e18H8DSmE3Q
# file dumped
# C1Qe3rAUj1c
# file dumped
# BKPZcUAhKhs
# file dumped
# qg9H0_ulnCE
# file dumped
# c5SkTaaUbIU
# file dumped
# GGM0sk2naHA
# file dumped
# RZLagV4cd00
# file dumped
# -mIU5PYWfzs
# file dumped
# Vjejpodph54
# file dumped
# fR8j5o68zpQ
# file dumped
# ShObyc9vqXM
# file dumped
# woULP7tJYWk
# file dumped
# hBH5O1ukpq8
# file dumped
# gEfWUbRfFR8
# file dumped
# QQ4OVWGMAXk
# file dumped
# u7EQYh2ScbE
# file dumped
# SMQblIBEDqo
# file dumped
# G0Ui9JOXNjk
# file dumped
# BcKRsYHoKIM
# file dumped
# OVVeHLuJegA
# file dumped
# t1Q8KRRlEFg
# file dumped
# eoJzY6B4WaQ
# file dumped
# dBaTzs9tEJQ
# file dumped
# MzZSEWEqDx4
# file dumped
# 6-6bRaotgDg
# file dumped
# QR9_W4jVEcQ
# file dumped
# fnPhgQYUMPs
# file dumped
# U9y03XWbUiM
# file dumped
# hYNyAmk2yrg
# file dumped
# 6yUzdcJsXzI
# file dumped
# vNCZ8Zy7J5U
# file dumped
# oRLok2-X4s4
# file dumped
# DzcQK6buuNc
# file dumped
# Wmsvy4yrKfQ
# file dumped
# fBcDN_eWZK4
# file dumped
# XNRsWtL7nMo
# file dumped
# gsB_nI07k6U
# file dumped
# JxzqsYMneoE
# file dumped
# 5vRd21X3K-k
# file dumped
# s4hKyfXZvzA
# file dumped
# 0EdLoENqVtw
# file dumped
# xd7lNNacO0Q
# file dumped
# zTuqxVOrAGk
# file dumped
# dvc_HbwjIco
# file dumped
# 7-yz2IP_knA
# file dumped
# DkRFRQA2nk8
# file dumped
# npea0hTrVK8
# file dumped
# tMOqCTsr8Yc
# file dumped
# dEhhgg43AiI
# file dumped
# bCk2xMs6j8M
# file dumped
# kjwsCStgLtM
# file dumped
# pF-lqnM0kbM
# file dumped
# -cqVoAzrhs8
# file dumped
# XyMEZYv1hB8
# file dumped
# tBU3jnuuSJE
# file dumped
# VTXaatdiBps
# file dumped
# P5k5mHmSLyA
# file dumped
# xpADcOjZzlE
# file dumped
# 2A0tXMEXrX8
# file dumped
# iRkweYsD_Jg
# file dumped
# YVPyBraRags
# file dumped
# Zb7zNZeDgZg
# file dumped
# E6UdCB9htTw
# file dumped
# mpJLRodyNTs
# file dumped
# 641Ap5N97xM
# file dumped
# GZNKlZu-i2o
# file dumped
# YZHhdvfSQ3Y
# file dumped
# ehC4a60G_pE
# file dumped
# Sdt6z357q_k
# file dumped
# 6EjpDSwKLAk
# file dumped
# gpYzJkm_5os
# file dumped
# RNxOnso7j5c
# file dumped
# jWqHBv9IXI4
# file dumped
# I2hsmifH7oo
# file dumped
# yANbdh_gK6c
# file dumped
# Yuf3ZT7Pj4M
# file dumped
# q65lJArzDng
# file dumped
# 3beBArjSd60
# file dumped
# DTlOZn2F0Xc
# file dumped
# G9J0th19v1U
# file dumped
# pvyeJxMUIcQ
# file dumped
# E_G8UNqhK6Y
# file dumped
# 3R_emk-Fzh8
# file dumped
# BKHLUMnCPTw
# file dumped
# Zkbp5MVZW14
# file dumped
# BZtuJ2QYRVo
# file dumped
# 3_1qn0BbsWo
# file dumped
# aBgHjlrv-0E
# file dumped
# S6qYFt_8wfw
# file dumped
# NYjNLktP3lI
# file dumped
# xU-leHhdV8A
# file dumped
# VjG-zaFVoLw
# file dumped
# k3DzT-eARE4
# file dumped
# A7hCC1PNYt4
# file dumped
# lHy1ORGQ0xM
# file dumped
# YAcdzMRadhQ
# file dumped
# iM2gB3Nhuh0
# file dumped
# lDwQ5zpHMD0
# file dumped
# znMtuv4W0Bc
# file dumped
# bgcuD5BSy3s
# file dumped
# Fby6YdDEpFM
# file dumped
# SPQfyxpywps
# file dumped
# 2XtaTEAt9N4
# file dumped
# -xSMIbR0Cic
# file dumped
# r1vQod8BJk4
# file dumped
# 2HBoBIsYHoE
# file dumped
# Z-8ljh8ub4U
# file dumped
# jCU18BbfAhY
# file dumped
# j_XOf43VV8w
# file dumped
# Mdrefh3zTbg
# file dumped
# 4o4HDfaNNnM
# file dumped
# 9vSwSEadEaY
# file dumped
# Ls5Ybqj83iI
# file dumped
# pAEPlldbnuc
# file dumped
# mQ1p4H50Cgk
# file dumped
# M2dmoT8Lscc
# file dumped
# 4HYIYW8uwUg
# file dumped
# R_WOylGwJrk
# file dumped
# 9AAaaZGiDo0
# file dumped
# GZA4XIW7BZE
# file dumped
# b8RTbVdnqso
# file dumped
# 6qEgXqmSwl8
# file dumped
# 8q5G_aFdRqw
# file dumped
# X7PWjY8g3gk
# file dumped
# UjVEaOxJqhg
# file dumped
# poSU5v1y5m4
# file dumped
# I7I7MY8A6xw
# file dumped
# ZkhUbKhmb9M
# file dumped
# PpXrp_VuJu8
# file dumped
# unAONxmeGeU
# file dumped
# jQTD2pDwoz4
# file dumped
# 0mUOxTQoPqA
# file dumped
# 7Kqq9LT-Pk8
# file dumped
# ip3OBqUeGLk
# file dumped
# 0FThv_a-xo4
# file dumped
# hN8bZmmZK_4
# file dumped
# RiNuB0HG78w
# file dumped
# T2mTdosMbIE
# file dumped
# WpnC0BaNKRs
# file dumped
# J2k3brWabyE
# file dumped
# S5N8Grc3n0I
# file dumped
# agcbWc4oGiU
# file dumped
# QWHk-08HkBA
# file dumped
# TadJiYYjufw
# file dumped
# vjWOd9EOjzY
# file dumped
# PRSghFFOY48
# file dumped
# jQsPosbb3Xk
# file dumped
# ItlTfcxr9Ck
# file dumped
# JTifBCtUPjY
# file dumped
# q6ynGI_FY-8
# file dumped
# 1A_A3S9QkMU
# file dumped
# EGS-ZB_2Gsw
# file dumped
# PaVtBzuBJaY
# file dumped
# EM0FOEzowak
# file dumped
# 59S6TOxsW3Q
# file dumped
# WdAD8GO0Yjw
# file dumped
# 3Vywz8T4_M4
# file dumped
# NCZUqJc-jhU
# file dumped
# EYo38Ffrzxk
# file dumped
# eTrNf4RRvEo
# file dumped
# FOYAyE3XL58
# file dumped
# vyI_k__Dupg
# file dumped
# tl6DbXTue9k
# file dumped
# Pw2J1sExZPo
# file dumped
# UvsHWTGHmts
# file dumped
# Qw9L6zYkuMU
# file dumped
# P3dQYnzG75w
# file dumped
# zi079huC3Oc
# file dumped
# QeYRrzb9HK0
# file dumped
# 8-AE441SoHU
# file dumped
# XVL4Bn3uLxs
# file dumped
# g4h1BavIDnk
# file dumped
# LryuqQ-Pb_M
# file dumped
# df249mYJ3o0
# file dumped
# lsdDSGMXZHc
# file dumped
# TGkUT5vsO68
# file dumped
# 5-cqZ8-Mi6U
# file dumped
# uFOu6HBgNm8
# file dumped
# 4r8UJv97GjM
# file dumped
# gkXopJSPK4I
# file dumped
# 6JlrYRnqty8
# file dumped
# mZtXnBmIaOQ
# file dumped
# wsoj6fGF8fQ
# file dumped
# 3gLxNtqhR18
# file dumped
# 7nITnSIfqec
# file dumped
# n2q-kN4GIwg
# file dumped
# U16bgD5Bjww
# file dumped
# rTd15KqHEe0
# file dumped
# 1EEYwI-7ZUU
# file dumped
# TmcfzG0IY7Q
# file dumped
# zg78KGkfcyA
# file dumped
# 8wkdX7slq7E
# file dumped
# hxdvXoOBIhs
# file dumped
# kJQ7h3TahgA
# file dumped
# bcIBateEM98
# file dumped
# voQn3Yfdz-g
# file dumped
# ucRsDXgrGME
# file dumped
# IRDVIXa_5EM
# file dumped
# Pp1NbpdVTms
# file dumped
# 3lBStqzf0lA
# file dumped
# yBhFDZ5AK1c
# file dumped
# 0EnWvkLrBo0
# file dumped
# eGNYl1qcXYI
# file dumped
# YO_Kq-CYpTM
# file dumped
# 79v7Jg9qUXI
# file dumped
# eDXxjVQO6tg
# file dumped
# ECBgokbr8HA
# file dumped
# s8XEA4tEMMI
# file dumped
# HDufGkXqhv4
# file dumped
# tH-fSbOeUbE
# file dumped
# QmKcX0CxDdo
# file dumped
# qDznaAOYgLQ
# file dumped
# hpe6K1XwO6k
# file dumped
# rjb6H6h6QpQ
# file dumped
# yt0JnU_Iwsk
# file dumped
# TuE8XwIJ-QA
# file dumped
# WWezsWF_Rok
# file dumped
# VPUUrdgxIa8
# file dumped
# -ZDxSWjFvyM
# file dumped
# K8Jjaw0YT3c
# file dumped
# bkbCZI7NjAo
# file dumped
# j8pnMR7ZFD0
# file dumped
# S9aITMV6Nk8
# file dumped
# KnXnTK4ixV0
# file dumped
# rGn3aJZmO2U
# file dumped
# 756Fz875IxU
# file dumped
# 8E7OGeyaSBg
# file dumped
# YfX71vZ3Q8U
# file dumped
# w8pxTY5urbw
# file dumped
# poSU5v1y5m4
# file dumped
# I7I7MY8A6xw
# file dumped
# -B1LFjDUh9g
# file dumped
# ZkhUbKhmb9M
# file dumped
# PpXrp_VuJu8
# file dumped
# lMTaTbtiaR0
# file dumped
# RNxzI_PyNfQ
# file dumped
# --72sgCB0_c
# file dumped
# 92d5OKc242M
# file dumped
# unAONxmeGeU
# file dumped
# jQTD2pDwoz4
# file dumped
# 0mUOxTQoPqA
# file dumped
# Grlao4wLRBc
# file dumped
# gMqDD7Z7Fnw
# file dumped
# 7Kqq9LT-Pk8
# file dumped
# mDGm8MTQw-M
# file dumped
# ip3OBqUeGLk
# file dumped
# 0FThv_a-xo4
# file dumped
# hN8bZmmZK_4
# file dumped
# kISALzjLUZY
# file dumped

# %%
# read josn files and make a list with json files
# (make 1 change)

path_to_json = './5- Amber_Heard'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]
json_files;  
len(json_files)
# Out:
# 341

# %%
# create a data frame with all json files:
# (make 1 change)

df = pd.DataFrame()
i = 0
for file in json_files:
    file_path = "5- Amber_Heard/" + file
    with open(file_path) as data_file:    
        data = json.load(data_file)
        df = df.append(pd.json_normalize(data))
df.shape
# Out:
# (326, 49)

# %%
# save this dataframe to a file:
# (make 1 change)

df.to_csv('5- Amber_Heard --scraped.csv')
