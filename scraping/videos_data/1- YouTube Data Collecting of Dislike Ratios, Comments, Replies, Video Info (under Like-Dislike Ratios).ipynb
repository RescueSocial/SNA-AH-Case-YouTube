# %% [markdown]
# #  Collect data from youtube for videos using video ID

# %%
import pandas as pd
import json
import requests
from io import StringIO
from csv import reader
import os
import glob

# %%
class YTstats:
    '''
    this class takes api_key and video id
    then obtain data for the video
    '''
  
    def __init__(self, api_key, video_id):
        self.api_key = api_key
        self.video_id = video_id
        self.video_statistics = None
  
    def get_video_statistics(self):
        url = f'https://www.googleapis.com/youtube/v3/videos?id={self.video_id}&key={self.api_key}&part=snippet,contentDetails,statistics,status'
        json_url = requests.get(url)
        data = json.loads(json_url.text)
  
        try:
            data = data["items"]#[0]["statistics"]
        except:
            data = None
  
        self.video_statistics = data
        return data
  
    def dump(self):
        if self.video_statistics is None:
            print('nothing happend')
            return 
  
        video_title = self.video_id
        #video_title = video_title.replace(" ", "_")
  
        # generate a json file with all the statistics data of the youtube video
        file_name = video_title + '.json'
        with open(file_name, 'w') as f:
            json.dump(self.video_statistics, f, indent=4)
        print('file dumped')

# %% [markdown]
# ### Start from here

# %% [markdown]
# # cleaning the ids - read them then delete any id we obtained before

# %%
# file url and folder url:
file_url = "./24- scraped ids by david  amber heard trailer.csv"
folder_url = "./24- amber heard trailer/"

# %%
# read videos IDs we get by search:
file_url = file_url

new_ids = pd.read_csv(file_url)
new_ids.shape
# Out:
# (283, 1)

# %%
# remvove duplicates from its
new_ids.drop_duplicates(inplace=True)
print(new_ids.shape)
# Out:
# (283, 1)

# %%
# read totals ids we have data for it:
total_ids = pd.read_csv(r'C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping/IDs_for_all_videos_we_have_data_for.csv')

# %%
#make lists for new and old IDs to comparing
new_ids_list = list(new_scraped_ids['id'])
total_ids_list = list(total_ids['id'])
len(total_ids_list) , len(new_ids)
# Out:
# (7557, 283)

# %%
# see if we collected a video id we have it and save it to a list with name: not_duplicated_ids:
not_duplicated_ids = []
for new_id in new_ids_list:
    if new_id not in total_ids_list:
        not_duplicated_ids.append(new_id)
len(not_duplicated_ids)
# Out:
# 0

# %%
# update the csv file to have no duplicated with any ID all the time
not_duplicated_ids_df = pd.DataFrame(not_duplicated_ids, columns=['id'])
not_duplicated_ids_df.to_csv(file_url, index=None)

# %%
# adding new IDs to the IDs_for_all_videos_we_have_data_for file:
new_total_ids = total_ids.append(new_ids_list)
new_total_ids_df = pd.DataFrame(new_total_ids, columns=['id'])
new_total_ids_df.to_csv(r'C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping/IDs_for_all_videos_we_have_data_for.csv', index=None)

# %% [markdown]
# ### end of cleaning
#
# # Obtaining

# %%
#read data from youtube file and extratc video code for each and make a list of the videos code:

# read dat for the same file we just dropped duplicate from:
address = file_url
Amber_Heard = pd.read_csv(address)
Amber_Heard = Amber_Heard.melt().drop('variable',axis=1).rename({'value':'id'},axis=1)
Amber_Heard = list(Amber_Heard['id']) # make a list with IDs we will obtain data from
len(Amber_Heard)
# Out:
# 283

# %%
Amber_Heard[:3] #first 3 items
# Out:
# ['fjx90nOU6AQ', 'v9Kiy8vzwf4', 'ZAeu0lNz01c']

# %%
# recive data using API and save it on PC

API_KEY = "AIzaSyA-0KfpLK04NpQN1XghxhSlzG-WkC3DHLs"
API_KEY2 = "AIzaSyA-0KfpLK04NpQN1XghxhSlzG-WkC3DHLs"
API_KEY3 = "AIzaSyBcoNKqXd-bQ--bsLwKplkdHkGdKPtaa_8"

# read IDs form list to obtaining data:
while len(Amber_Heard) != 0:
    
    for video in Amber_Heard:
        print(video)
        yt = YTstats(API_KEY, video)
        yt.get_video_statistics()
        Amber_Heard.remove(video)
        print('ids remain: ', len(Amber_Heard))
        yt.dump()
# Out:
# fjx90nOU6AQ
# ids remain:  282
# file dumped
# ZAeu0lNz01c
# ids remain:  281
# file dumped
# TBSzAdB78EE
# ids remain:  280
# file dumped
# s2mvnu74Tfw
# ids remain:  279
# file dumped
# tgveYJUBihc
# ids remain:  278
# file dumped
# VseiLpeHzD8
# ids remain:  277
# file dumped
# Xkr4yxnD2iY
# ids remain:  276
# file dumped
# 3DcOBT-3EdU
# ids remain:  275
# file dumped
# BtowZeQnou8
# ids remain:  274
# file dumped
# MfzryPixUps
# ids remain:  273
# file dumped
# dnvanpCuua0
# ids remain:  272
# file dumped
# aiwdQQFXEMo
# ids remain:  271
# file dumped
# TmGV714XceU
# ids remain:  270
# file dumped
# CjZ7MZI_M9A
# ids remain:  269
# file dumped
# dVi2Pcq6U38
# ids remain:  268
# file dumped
# SB5C2E3R42M
# ids remain:  267
# file dumped
# zFHpzAoz5SU
# ids remain:  266
# file dumped
# FORiTf2GsZE
# ids remain:  265
# file dumped
# MMSvm6_I6pw
# ids remain:  264
# file dumped
# TepJRRNSRu4
# ids remain:  263
# file dumped
# OUMYIGWcLA0
# ids remain:  262
# file dumped
# pg7Dv7cWVHI
# ids remain:  261
# file dumped
# 3OJPTCam0Ks
# ids remain:  260
# file dumped
# ittCG_6nZ7I
# ids remain:  259
# file dumped
# HxkvJkSIOGk
# ids remain:  258
# file dumped
# MQohI6HH6qU
# ids remain:  257
# file dumped
# FELg8DuD3bo
# ids remain:  256
# file dumped
# 5MydwUYWlqQ
# ids remain:  255
# file dumped
# bBHNKqbFvKg
# ids remain:  254
# file dumped
# RgMP-ZBcRAU
# ids remain:  253
# file dumped
# ppbZDsmEOEs
# ids remain:  252
# file dumped
# 2L4yB-xzC9o
# ids remain:  251
# file dumped
# PMlHDNdLGU8
# ids remain:  250
# file dumped
# ggKTXlhIaZQ
# ids remain:  249
# file dumped
# uvPykrKpUNc
# ids remain:  248
# file dumped
# B_TA_O4ufEM
# ids remain:  247
# file dumped
# hvPZUVNXkHo
# ids remain:  246
# file dumped
# r87vxRYSeyM
# ids remain:  245
# file dumped
# BKwvnhhCabE
# ids remain:  244
# file dumped
# BgclngsEFpM
# ids remain:  243
# file dumped
# Ft7VR4H1-_U
# ids remain:  242
# file dumped
# Y4RaxoOOLCY
# ids remain:  241
# file dumped
# 9qbhaWX9Yiw
# ids remain:  240
# file dumped
# brDUuCzGcpI
# ids remain:  239
# file dumped
# DiTq6_dFm2I
# ids remain:  238
# file dumped
# HpyJOCUidWs
# ids remain:  237
# file dumped
# fvs0W76Rvcs
# ids remain:  236
# file dumped
# iE_6RwA6krs
# ids remain:  235
# file dumped
# J-pNBZPc_nM
# ids remain:  234
# file dumped
# rHhrVrtP8CE
# ids remain:  233
# file dumped
# mY7lerp0LDE
# ids remain:  232
# file dumped
# NfIhfBs-Zsk
# ids remain:  231
# file dumped
# he_TFJ6yKZM
# ids remain:  230
# file dumped
# O9ePHdXtTtE
# ids remain:  229
# file dumped
# _kmHXRVTCYk
# ids remain:  228
# file dumped
# 54M_sIW6GVw
# ids remain:  227
# file dumped
# zmudq9paz0c
# ids remain:  226
# file dumped
# kq0HxO3nZXE
# ids remain:  225
# file dumped
# 0ou7yghHTZU
# ids remain:  224
# file dumped
# GrQmjjp57QQ
# ids remain:  223
# file dumped
# Q59qPyYLw4c
# ids remain:  222
# file dumped
# aYzKHvyC5yo
# ids remain:  221
# file dumped
# q5oT9Lizm18
# ids remain:  220
# file dumped
# naMaYoLgxP8
# ids remain:  219
# file dumped
# GfqbW-n62-0
# ids remain:  218
# file dumped
# ARNkExJPZtA
# ids remain:  217
# file dumped
# DVoGI_vhquE
# ids remain:  216
# file dumped
# cvgOCL_2LG4
# ids remain:  215
# file dumped
# pRItnG3P7-Q
# ids remain:  214
# file dumped
# i3Q701DNfwk
# ids remain:  213
# file dumped
# bnbxa3fF6XY
# ids remain:  212
# file dumped
# gjffswi7M_Q
# ids remain:  211
# file dumped
# 7mlugzz4H-s
# ids remain:  210
# file dumped
# Kcj-BVZoqFE
# ids remain:  209
# file dumped
# Z8S_0yyNaVY
# ids remain:  208
# file dumped
# WzJ9YCv5u34
# ids remain:  207
# file dumped
# s-E1f3C_cBk
# ids remain:  206
# file dumped
# FuCkbZBaSz4
# ids remain:  205
# file dumped
# ALgVtTMptfs
# ids remain:  204
# file dumped
# pBKvqE1rDlE
# ids remain:  203
# file dumped
# wQ04u5soUu4
# ids remain:  202
# file dumped
# LGLIERI41l0
# ids remain:  201
# file dumped
# BM_9WVai6qE
# ids remain:  200
# file dumped
# z9nuD671RAo
# ids remain:  199
# file dumped
# JFAi_g3KoBc
# ids remain:  198
# file dumped
# nTTMeo5TwkA
# ids remain:  197
# file dumped
# kgiUR4ZTOLE
# ids remain:  196
# file dumped
# bLCYAJLu11Q
# ids remain:  195
# file dumped
# I6wkxVRjayo
# ids remain:  194
# file dumped
# zs8ewvuwZW4
# ids remain:  193
# file dumped
# oL7j8BrlF6U
# ids remain:  192
# file dumped
# mBv5AvxwMvQ
# ids remain:  191
# file dumped
# aOZ3QLF2mQo
# ids remain:  190
# file dumped
# OxRIWBoluzs
# ids remain:  189
# file dumped
# HWuc5L5ZAZ4
# ids remain:  188
# file dumped
# je1Kw0edn28
# ids remain:  187
# file dumped
# Rz8XFmGyis0
# ids remain:  186
# file dumped
# joF0HwXkzd0
# ids remain:  185
# file dumped
# JW5fa3P5SlU
# ids remain:  184
# file dumped
# Me_K7d8c_3I
# ids remain:  183
# file dumped
# L-FMinP2sxI
# ids remain:  182
# file dumped
# 9i90t7-ffWI
# ids remain:  181
# file dumped
# IeyHBNodwOk
# ids remain:  180
# file dumped
# IIQ1OiiHnqU
# ids remain:  179
# file dumped
# t0vtsPJvRQA
# ids remain:  178
# file dumped
# i1A6ewMVysI
# ids remain:  177
# file dumped
# 9YkpCt48HnY
# ids remain:  176
# file dumped
# kuLkPigM8Mg
# ids remain:  175
# file dumped
# 6f92udY5WUA
# ids remain:  174
# file dumped
# pCUNB8ylH1g
# ids remain:  173
# file dumped
# ecmjchOC6Ss
# ids remain:  172
# file dumped
# HSACbBVZLRc
# ids remain:  171
# file dumped
# X9dCdsCbDh8
# ids remain:  170
# file dumped
# iVcZ5naKcXQ
# ids remain:  169
# file dumped
# 5siD-KMTdVY
# ids remain:  168
# file dumped
# 4XjPnMpRpQU
# ids remain:  167
# file dumped
# YxJBeBu2JZ8
# ids remain:  166
# file dumped
# nm_5AtHoBfA
# ids remain:  165
# file dumped
# k-3p1H6fj0A
# ids remain:  164
# file dumped
# ngRc9NhpmUs
# ids remain:  163
# file dumped
# Xeq0yTyha6I
# ids remain:  162
# file dumped
# K3Fffvsf5Mc
# ids remain:  161
# file dumped
# XF6Lm7coXlE
# ids remain:  160
# file dumped
# 0cKnFtVcbcc
# ids remain:  159
# file dumped
# iAn5kN-yF1g
# ids remain:  158
# file dumped
# HfOJbrc7N6A
# ids remain:  157
# file dumped
# ez1Le7K0l3w
# ids remain:  156
# file dumped
# 5EAFOrKzeos
# ids remain:  155
# file dumped
# n8-N9ZRLKy8
# ids remain:  154
# file dumped
# 66pg3A1NwWk
# ids remain:  153
# file dumped
# KIAOPINfNnM
# ids remain:  152
# file dumped
# 5kYckU9Dft8
# ids remain:  151
# file dumped
# BCNdBAJ0Wz4
# ids remain:  150
# file dumped
# FBONn9ID5WM
# ids remain:  149
# file dumped
# 2plwEdAIhOs
# ids remain:  148
# file dumped
# s8nXynYDZ0w
# ids remain:  147
# file dumped
# JZzTr-K1eEY
# ids remain:  146
# file dumped
# bt0cdbDWQYA
# ids remain:  145
# file dumped
# SQQms8Hx-Bk
# ids remain:  144
# file dumped
# jkeQcSB5Cuk
# ids remain:  143
# file dumped
# FrBYm8s54LY
# ids remain:  142
# file dumped
# Fhz1-RKFEd8
# ids remain:  141
# file dumped
# v9Kiy8vzwf4
# ids remain:  140
# file dumped
# 0bdZWrW6HnA
# ids remain:  139
# file dumped
# 1wDEVG25jCM
# ids remain:  138
# file dumped
# HCAaonjgDEA
# ids remain:  137
# file dumped
# AzS10dNGY7Y
# ids remain:  136
# file dumped
# d7eougMXloc
# ids remain:  135
# file dumped
# uzJz1PpkohM
# ids remain:  134
# file dumped
# VQ4cKnkYFrw
# ids remain:  133
# file dumped
# ZuGC4acpuF4
# ids remain:  132
# file dumped
# O-ps5pu_r7U
# ids remain:  131
# file dumped
# 2Xdp7FLpj78
# ids remain:  130
# file dumped
# EqYIUDvMBHY
# ids remain:  129
# file dumped
# S1RVgeorcEo
# ids remain:  128
# file dumped
# OyUZaC4f-fc
# ids remain:  127
# file dumped
# DqhBgh0HLgk
# ids remain:  126
# file dumped
# nRk_Zl2K9_s
# ids remain:  125
# file dumped
# oSOzFjjm6GA
# ids remain:  124
# file dumped
# Vj-WmylPGrg
# ids remain:  123
# file dumped
# K7kxl5Odq1Y
# ids remain:  122
# file dumped
# 4GA6ZUQ_gH4
# ids remain:  121
# file dumped
# zA7S1T3lTMM
# ids remain:  120
# file dumped
# 37DC_V8Vcgc
# ids remain:  119
# file dumped
# JGSut0cTyJs
# ids remain:  118
# file dumped
# 5C_QyG38diI
# ids remain:  117
# file dumped
# 1Uh2sIghVZk
# ids remain:  116
# file dumped
# 1qYa0S3G1yQ
# ids remain:  115
# file dumped
# wqUaeA0DrFM
# ids remain:  114
# file dumped
# d-X9T9CpA1A
# ids remain:  113
# file dumped
# 78DS_j-RrUs
# ids remain:  112
# file dumped
# 1igEzfj2iSw
# ids remain:  111
# file dumped
# yQSmjFMg7_E
# ids remain:  110
# file dumped
# rq--BWNLWrs
# ids remain:  109
# file dumped
# c_cljKX6-ag
# ids remain:  108
# file dumped
# VGyGkUZQIH0
# ids remain:  107
# file dumped
# m01P2qmANDo
# ids remain:  106
# file dumped
# DoEQKS2KCEA
# ids remain:  105
# file dumped
# YhYcxP6qGbU
# ids remain:  104
# file dumped
# qpCoUTv5YlI
# ids remain:  103
# file dumped
# kmz_Rp-CihA
# ids remain:  102
# file dumped
# EmAo4bLaDSo
# ids remain:  101
# file dumped
# PSRXoIIdvAc
# ids remain:  100
# file dumped
# 9kGfdO67UbY
# ids remain:  99
# file dumped
# 4B3qPQ53jN0
# ids remain:  98
# file dumped
# mtVAa5xa1sc
# ids remain:  97
# file dumped
# zif0Lmhrivc
# ids remain:  96
# file dumped
# 1KVij6Cmqo4
# ids remain:  95
# file dumped
# XzSnYVBaEjI
# ids remain:  94
# file dumped
# R9DWTt37khU
# ids remain:  93
# file dumped
# zaLWI3s5tp4
# ids remain:  92
# file dumped
# aaVMbbAacg4
# ids remain:  91
# file dumped
# HlfAc1J857E
# ids remain:  90
# file dumped
# JMyazvsZxN0
# ids remain:  89
# file dumped
# zj3lXsri0no
# ids remain:  88
# file dumped
# XuClJbJqMr4
# ids remain:  87
# file dumped
# affRFhIN1yQ
# ids remain:  86
# file dumped
# Jg647Ga0K3o
# ids remain:  85
# file dumped
# bcfDJhtQHvI
# ids remain:  84
# file dumped
# Z7ObZur_vOE
# ids remain:  83
# file dumped
# RIuT7ha71lo
# ids remain:  82
# file dumped
# T3eijnZxTKY
# ids remain:  81
# file dumped
# uG87ZjM6Slg
# ids remain:  80
# file dumped
# 1Ct0UcJODB0
# ids remain:  79
# file dumped
# Tsjf0L3x9QQ
# ids remain:  78
# file dumped
# ED_UlxOGPys
# ids remain:  77
# file dumped
# iqwtkWFahjI
# ids remain:  76
# file dumped
# OWPQoZz-Qv4
# ids remain:  75
# file dumped
# 3LJaN1zSgtw
# ids remain:  74
# file dumped
# Ltoz7Tc9GcM
# ids remain:  73
# file dumped
# _4kBQBzZz04
# ids remain:  72
# file dumped
# lwIVtBNocdk
# ids remain:  71
# file dumped
# NnY8JsVfD5k
# ids remain:  70
# file dumped
# 2T1RLye5Z_w
# ids remain:  69
# file dumped
# a7HMOpgThjw
# ids remain:  68
# file dumped
# UrTI2oeh8UY
# ids remain:  67
# file dumped
# ped-SUjN9to
# ids remain:  66
# file dumped
# pmkQw_YgfPU
# ids remain:  65
# file dumped
# m0ZdUmzvzUI
# ids remain:  64
# file dumped
# xgW_bAaEsFE
# ids remain:  63
# file dumped
# jgQhGNuLgQA
# ids remain:  62
# file dumped
# 6z3f_t0BezY
# ids remain:  61
# file dumped
# m7FqVsrLQ9w
# ids remain:  60
# file dumped
# S_aB8b8A12Q
# ids remain:  59
# file dumped
# ZJBSpC54-eA
# ids remain:  58
# file dumped
# iG4aMhVIP1k
# ids remain:  57
# file dumped
# d4kQxam2mSA
# ids remain:  56
# file dumped
# DkDwOKe3_2E
# ids remain:  55
# file dumped
# 7cnVMkyz3JY
# ids remain:  54
# file dumped
# 4eimvd8N6Lc
# ids remain:  53
# file dumped
# j1tA43gVFAA
# ids remain:  52
# file dumped
# vc6XL7lFPjw
# ids remain:  51
# file dumped
# mJLjaKzu7PQ
# ids remain:  50
# file dumped
# bmG4zvstrlg
# ids remain:  49
# file dumped
# lAPLKkkJaNM
# ids remain:  48
# file dumped
# m9Z1jnehYEA
# ids remain:  47
# file dumped
# gT4qIPBfs6A
# ids remain:  46
# file dumped
# 5CwExfrc4Qw
# ids remain:  45
# file dumped
# XDDJfBlK6oM
# ids remain:  44
# file dumped
# w0QvLBlIfR0
# ids remain:  43
# file dumped
# KZSM0jEZ43I
# ids remain:  42
# file dumped
# 8Q64bZ7CEOE
# ids remain:  41
# file dumped
# 4zXZy_G_cIw
# ids remain:  40
# file dumped
# iYVyZX0Xbv8
# ids remain:  39
# file dumped
# 7xUkd2C1LMM
# ids remain:  38
# file dumped
# ZhVWiNo67yc
# ids remain:  37
# file dumped
# u_Tjj0N3HbI
# ids remain:  36
# file dumped
# 5ekDHTGtRzE
# ids remain:  35
# file dumped
# mT16aNbBoNM
# ids remain:  34
# file dumped
# sB617GdwSuk
# ids remain:  33
# file dumped
# 966hQyam2BY
# ids remain:  32
# file dumped
# fBGHAJkDYOs
# ids remain:  31
# file dumped
# H2E9_WHiWmw
# ids remain:  30
# file dumped
# W0c71QipbyY
# ids remain:  29
# file dumped
# aBiRNyb4vNc
# ids remain:  28
# file dumped
# zbhLqxWRUFc
# ids remain:  27
# file dumped
# H8a8AeiYQ7U
# ids remain:  26
# file dumped
# O6Zl4_tr4ic
# ids remain:  25
# file dumped
# sHkh34UkWTY
# ids remain:  24
# file dumped
# iAUT5l_IkwI
# ids remain:  23
# file dumped
# H4O6GHCly60
# ids remain:  22
# file dumped
# zPUPL4QrPZE
# ids remain:  21
# file dumped
# UlC9WQKT45w
# ids remain:  20
# file dumped
# k2nAASeirKY
# ids remain:  19
# file dumped
# iTrtAH3aJwI
# ids remain:  18
# file dumped
# CC04Cl9oGz8
# ids remain:  17
# file dumped
# h-k0-Z9b4Cw
# ids remain:  16
# file dumped
# fdAc1jlmCkQ
# ids remain:  15
# file dumped
# 34oGgWlMTFA
# ids remain:  14
# file dumped
# D6oUiXEXBLk
# ids remain:  13
# file dumped
# 64ifgxlgaVc
# ids remain:  12
# file dumped
# ZzcUoAwYWU8
# ids remain:  11
# file dumped
# 660bcHHZ5fs
# ids remain:  10
# file dumped
# tkfdqOZkCkw
# ids remain:  9
# file dumped
# xBeHSU5d1zs
# ids remain:  8
# file dumped
# EgS8MtUhCYo
# ids remain:  7
# file dumped
# MEWzxXvp3V0
# ids remain:  6
# file dumped
# qZ0RDDA6eMs
# ids remain:  5
# file dumped
# 2xakhFwXJuM
# ids remain:  4
# file dumped
# vE2fGGMRQEg
# ids remain:  3
# file dumped
# hcLAwlt3-2o
# ids remain:  2
# file dumped
# Lp21-TdQHMA
# ids remain:  1
# file dumped
# iMjesHNZOUw
# ids remain:  0
# file dumped

# %% [markdown]
# #  read and save JSON files collected

# %%
# read josn files and make a list with json files
# (make 1 change)

path_to_json = folder_url

json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]
json_files;  
len(json_files)
# Out:
# 283

# %%
# create a data frame with all json files:

df = pd.DataFrame()
for file in json_files:
    file_path = path_to_json + file
    with open(file_path) as data_file:    
        data = json.load(data_file)
        df = df.append(pd.json_normalize(data))
df.shape
# Out:
# (283, 49)

# %%
df.head(2)
# Out:
#             kind                         etag           id  \
# 0  youtube#video  c5odWXJRV0If7a_r3xMs20MQrZk  0bdZWrW6HnA
# 0  youtube#video  DGx7vhyuj9dFJeo9bxCCPcJi_Q4  0cKnFtVcbcc
#
#     snippet.publishedAt         snippet.channelId  \
# 0  2013-06-05T23:01:56Z  UCi8e0iOVk1fEOogdfu4YgfA
# 0  2021-11-30T15:25:49Z  UCtn2JIYrqmkhloz4ctRns5w
#
#                                        snippet.title  \
# 0  Paranoia Official Trailer #1 (2013) - Liam Hem...
# 0          TOP 10 BEST FLOWER TATTOO DESIGNS IN 2022
#
#                                  snippet.description  \
# 0  Subscribe to TRAILERS: http://bit.ly/sxaw6h\nS...
# 0  The Chainsmokers - Closer (Lyric) ft. Halsey\n...
#
#                    snippet.thumbnails.default.url  \
# 0  https://i.ytimg.com/vi/0bdZWrW6HnA/default.jpg
# 0  https://i.ytimg.com/vi/0cKnFtVcbcc/default.jpg
#
#    snippet.thumbnails.default.width  snippet.thumbnails.default.height  ...  \
# 0                               120                                 90  ...
# 0                               120                                 90  ...
#
#   status.publicStatsViewable  status.madeForKids  statistics.viewCount  \
# 0                       True               False              11112647
# 0                       True               False                   730
#
#   statistics.likeCount  statistics.dislikeCount  statistics.favoriteCount  \
# 0                70068                     1479                         0
# 0                   15                        2                         0
#
#   statistics.commentCount  snippet.defaultLanguage  \
# 0                    1247                      NaN
# 0                       0                      NaN
#
#    contentDetails.regionRestriction.blocked  \
# 0                                       NaN
# 0                                       NaN
#
#   contentDetails.contentRating.ytRating
# 0                                   NaN
# 0                                   NaN
#
# [2 rows x 49 columns]

# %%
# save this dataframe with the search name as csv file:

save_csv_url = r"C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Videos_details/{} --scraped.csv".format(path_to_json.split('/')[1])
df.to_csv(save_csv_url, index=None)

# %% [markdown]
# # save channels IDs to collect cannels info

# %%
# make new df with channels IDs:
new_channels_id_df = pd.DataFrame(df['snippet.channelId'])

# for the same batch read channels we have then add the news:
channel_id_file_url = r'C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\channels_ids_batch-4.csv'
channel_id_df = pd.read_csv(channel_id_file_url)
print("channels count before adding: ", channel_id_df.shape)
# append the two dfs together and update the file to have the new IDs
total_channels_ids = new_channel_id_df.append(channel_id_df['id'], ignore_index=True)
total_channels_ids = pd.DataFrame(total_channels_ids, columns=['id'])
total_channels_ids.to_csv(channel_id_file_url, index=None )
print("channels count after adding: ", total_channels_ids.shape)
# Out:
# channels count before adding:  (567, 1)
# channels count after adding:  (850, 1)
