# %%
path_to_csv = './'
csv_files = [pos_csv for pos_csv in os.listdir(path_to_csv) if pos_csv.endswith('.csv')]
len(csv_files)
# Out:
# 11

# %%
li = []

for filename in csv_files:
    df = pd.read_csv(path_to_csv+"/"+filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)
frame.shape
# Out:
# (2491, 1)

# %%
frame.duplicated().sum()
# Out:
# 62

# %%
totals = pd.read_csv(r'C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\IDs_for_all_videos_we_have_data_for.csv')
totals.duplicated().sum()

# %% [markdown]
# #  Collect data from youtube for videos using video ID

# %%
import pandas as pd
import json
import requests
from io import StringIO
from csv import reader
import os
import glob

# %%
class YTstats:
    '''
    this class takes api_key and video id
    then obtain data for the video
    '''
  
    def __init__(self, api_key, video_id):
        self.api_key = api_key
        self.video_id = video_id
        self.video_statistics = None
  
    def get_video_statistics(self):
        url = f'https://www.googleapis.com/youtube/v3/videos?id={self.video_id}&key={self.api_key}&part=snippet,contentDetails,statistics,status'
        json_url = requests.get(url)
        data = json.loads(json_url.text)
  
        try:
            data = data["items"]#[0]["statistics"]
        except:
            data = None
  
        self.video_statistics = data
        return data
  
    def dump(self):
        if self.video_statistics is None:
            print('nothing happend')
            return 
  
        video_title = self.video_id
        #video_title = video_title.replace(" ", "_")
  
        # generate a json file with all the statistics data of the youtube video
        file_name = video_title + '.json'
        with open(file_name, 'w') as f:
            json.dump(self.video_statistics, f, indent=4)
        print('file dumped')

# %% [markdown]
# ### Start from here

# %% [markdown]
# # cleaning the ids - read them then delete any id we obtained before

# %%
# file url and folder url:
file_url = "./26- scraped ids by david  - amber heard lawsuit.csv"
folder_url = "./26- amber heard lawsuit/"

# %%
# read videos IDs we get by search:

new_ids = pd.read_csv(file_url)
new_ids.shape
# Out:
# (648, 1)

# %%
# remvove duplicates from its
new_ids.drop_duplicates(inplace=True, keep='first')
print(new_ids.shape)
# Out:
# (642, 1)

# %%
# read totals ids we have data for it:
total_ids = pd.read_csv(r'C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping/IDs_for_all_videos_we_have_data_for.csv')

# %%
#make lists for new and old IDs to comparing
new_ids_list = list(new_ids['id'])
total_ids_list = list(total_ids['id'])
print("total IDs size = {}\nnew IDs size = {}".format(len(total_ids_list) , len(new_ids_list)))
# Out:
# total IDs size = 9903
# new IDs size = 642

# %%
# see if we collected a video id we have it and save it to a list with name: not_duplicated_ids:
not_duplicated_ids = []
for new_id in new_ids_list:
    if new_id not in total_ids_list:
        not_duplicated_ids.append(new_id)
len(not_duplicated_ids)
# Out:
# 76

# %%
# update the csv file to have no duplicated with any ID all the time
not_duplicated_ids_df = pd.DataFrame(not_duplicated_ids, columns=['id'])
not_duplicated_ids_df.to_csv(file_url, index=None)

# %%
# adding new IDs to the IDs_for_all_videos_we_have_data_for file:
new_total_ids = total_ids.append(not_duplicated_ids_df)

new_total_ids_df = pd.DataFrame(new_total_ids, columns=['id'])
new_total_ids_df.to_csv(r'C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping/IDs_for_all_videos_we_have_data_for.csv', index=None)

# %% [markdown]
# ### end of cleaning
#
# # Obtaining

# %%
#read data from youtube file and extratc video code for each and make a list of the videos code:

# read dat for the same file we just dropped duplicate from:
address = file_url
Amber_Heard = pd.read_csv(address)
Amber_Heard = Amber_Heard.melt().drop('variable',axis=1).rename({'value':'id'},axis=1)
Amber_Heard = list(Amber_Heard['id']) # make a list with IDs we will obtain data from
len(Amber_Heard)
# Out:
# 373

# %%
Amber_Heard[:3] #first 3 items
# Out:
# ['mxp7wU5IJHo', 'hSqfTBOxn8M', 'MKROFQdxbro']

# %%
# recive data using API and save it on PC

API_KEY = "AIzaSyA-0KfpLK04NpQN1XghxhSlzG-WkC3DHLs"
API_KEY2 = "AIzaSyCQHI5RSbHoKGh6sPPnnOywja7qLS6TXnA"
API_KEY3 = "AIzaSyBcoNKqXd-bQ--bsLwKplkdHkGdKPtaa_8"

# read IDs form list to obtaining data:
while len(Amber_Heard) != 0:
    
    for video in Amber_Heard:
        print(video)
        yt = YTstats(API_KEY, video)
        yt.get_video_statistics()
        Amber_Heard.remove(video)
        print('ids remain: ', len(Amber_Heard))
        yt.dump()
# Out:
# mxp7wU5IJHo
# ids remain:  372
# file dumped
# MKROFQdxbro
# ids remain:  371
# file dumped
# ST736m9nJZs
# ids remain:  370
# file dumped
# qDYLTaVPY4k
# ids remain:  369
# file dumped
# DGQjpnJBJYw
# ids remain:  368
# file dumped
# SegyFa913kE
# ids remain:  367
# file dumped
# QO-tINWr4XA
# ids remain:  366
# file dumped
# bAqY8UrIOR8
# ids remain:  365
# file dumped
# iYU0hXDRAkQ
# ids remain:  364
# file dumped
# BXmkK4xkTVY
# ids remain:  363
# file dumped
# trJ-or6RvA0
# ids remain:  362
# file dumped
# UDf7Gf6KIfY
# ids remain:  361
# file dumped
# 8cVOjGctXBI
# ids remain:  360
# file dumped
# TzKa67GySWM
# ids remain:  359
# file dumped
# BYeXo-NC8_c
# ids remain:  358
# file dumped
# d3WI8yLZ2r8
# ids remain:  357
# file dumped
# mqNncJUjc-s
# ids remain:  356
# file dumped
# NIDwo7I6z7g
# ids remain:  355
# file dumped
# o_HoVb8j6ds
# ids remain:  354
# file dumped
# hHWS-c0jHOo
# ids remain:  353
# file dumped
# xoG3okmQCO8
# ids remain:  352
# file dumped
# 6duVyvsMjO0
# ids remain:  351
# file dumped
# TB6vjb5Z1fk
# ids remain:  350
# file dumped
# oNa4ZAF0WL8
# ids remain:  349
# file dumped
# 0RGyTOVLI1o
# ids remain:  348
# file dumped
# fINx301drFc
# ids remain:  347
# file dumped
# c1u3YnhPLJA
# ids remain:  346
# file dumped
# iiLI5GZxkR0
# ids remain:  345
# file dumped
# 5zrnv-px7DI
# ids remain:  344
# file dumped
# flVwJXdlVGc
# ids remain:  343
# file dumped
# IbpVmb098C0
# ids remain:  342
# file dumped
# lMIR4VwowUI
# ids remain:  341
# file dumped
# Tfa4w7q20v0
# ids remain:  340
# file dumped
# VH34WqwkGJU
# ids remain:  339
# file dumped
# QN1hW1r-FPg
# ids remain:  338
# file dumped
# WtEWOH5yTBQ
# ids remain:  337
# file dumped
# yK2OhQEIWi8
# ids remain:  336
# file dumped
# WmmWLdaqshs
# ids remain:  335
# file dumped
# 12zkFit_EQM
# ids remain:  334
# file dumped
# VJGyN0vM6Ks
# ids remain:  333
# file dumped
# vRs_CfeliaQ
# ids remain:  332
# file dumped
# uJWITPn6lzc
# ids remain:  331
# file dumped
# fcXGcSLUsgY
# ids remain:  330
# file dumped
# nWwGc3OxU1Q
# ids remain:  329
# file dumped
# Y7KWx9dUI6U
# ids remain:  328
# file dumped
# obyBz2tlAX8
# ids remain:  327
# file dumped
# ENE1oNQGXGU
# ids remain:  326
# file dumped
# DG4IVbAmKbs
# ids remain:  325
# file dumped
# PQckbydM5MA
# ids remain:  324
# file dumped
# qniTuZYwNO0
# ids remain:  323
# file dumped
# yu5uMhGP3vI
# ids remain:  322
# file dumped
# O5rkFy7_y44
# ids remain:  321
# file dumped
# fX313CaR454
# ids remain:  320
# file dumped
# YTjkhrX7VKE
# ids remain:  319
# file dumped
# qc8CUidOOwc
# ids remain:  318
# file dumped
# qiGFnwfFsnQ
# ids remain:  317
# file dumped
# E6dcp-f2zuQ
# ids remain:  316
# file dumped
# XIMFIMAO7vM
# ids remain:  315
# file dumped
# o9HZfVbcHcI
# ids remain:  314
# file dumped
# B2j-LQgOq4E
# ids remain:  313
# file dumped
# 4dUzpmPTY7w
# ids remain:  312
# file dumped
# cJSYaF3HIXc
# ids remain:  311
# file dumped
# CKPGmSXK-Iw
# ids remain:  310
# file dumped
# TK-L7MK1SuU
# ids remain:  309
# file dumped
# HOSsiJQZgb0
# ids remain:  308
# file dumped
# Q6_t_mlrv0A
# ids remain:  307
# file dumped
# 5XVy0Jk2fLI
# ids remain:  306
# file dumped
# IIjdcFL5IQw
# ids remain:  305
# file dumped
# xj4wDIJWAZE
# ids remain:  304
# file dumped
# e3DY2uKW4NA
# ids remain:  303
# file dumped
# 4-dxvmAxytU
# ids remain:  302
# file dumped
# Gi9esRAqd9s
# ids remain:  301
# file dumped
# mwmz5TdqQuA
# ids remain:  300
# file dumped
# feUyVKbqKEg
# ids remain:  299
# file dumped
# KZ-tCc3S8V8
# ids remain:  298
# file dumped
# bSvd3xjZNfk
# ids remain:  297
# file dumped
# 1bgKyXrtNsc
# ids remain:  296
# file dumped
# 41x_WfHP3bE
# ids remain:  295
# file dumped
# CSYjwjiKuws
# ids remain:  294
# file dumped
# CgnqWX_91II
# ids remain:  293
# file dumped
# gNBJAyLS4j8
# ids remain:  292
# file dumped
# XwHcHeHuGIs
# ids remain:  291
# file dumped
# W1WcWV6X_mo
# ids remain:  290
# file dumped
# mEP9kIvZC4U
# ids remain:  289
# file dumped
# dhgEeg5FBgk
# ids remain:  288
# file dumped
# R9ApNqXXRR4
# ids remain:  287
# file dumped
# zWbv1wm71gs
# ids remain:  286
# file dumped
# imiYHBuNj4M
# ids remain:  285
# file dumped
# Xqw-wMFA4Ls
# ids remain:  284
# file dumped
# o4NgrfsMTss
# ids remain:  283
# file dumped
# CoGo2fka7kU
# ids remain:  282
# file dumped
# A9JdyX8zDfo
# ids remain:  281
# file dumped
# HfP4qD1-6oQ
# ids remain:  280
# file dumped
# qSL2HJK7n2s
# ids remain:  279
# file dumped
# ADbOHbO-oRE
# ids remain:  278
# file dumped
# eDewJ69Qv0U
# ids remain:  277
# file dumped
# KdWPImv6Ki8
# ids remain:  276
# file dumped
# 2-ggYzIWO0g
# ids remain:  275
# file dumped
# OC9P0dmdvNc
# ids remain:  274
# file dumped
# v9kmWOtSlds
# ids remain:  273
# file dumped
# eEt5z_dTibQ
# ids remain:  272
# file dumped
# djEJf2uc6tQ
# ids remain:  271
# file dumped
# Vc-ODsbLEzc
# ids remain:  270
# file dumped
# DybHooDvBgo
# ids remain:  269
# file dumped
# YuYr19xpe3I
# ids remain:  268
# file dumped
# BcxoGzOwjEA
# ids remain:  267
# file dumped
# aikckTGttyA
# ids remain:  266
# file dumped
# pllIbVGB0ZI
# ids remain:  265
# file dumped
# siD8ad1nx4k
# ids remain:  264
# file dumped
# 7bOorxp8LEE
# ids remain:  263
# file dumped
# ZTGEXBPRWEk
# ids remain:  262
# file dumped
# 4d0QPrVbDQ0
# ids remain:  261
# file dumped
# 6MYBdNuM9Cw
# ids remain:  260
# file dumped
# Tsgojs2oaVw
# ids remain:  259
# file dumped
# te8udrHHFDQ
# ids remain:  258
# file dumped
# H_ecq-EDDYc
# ids remain:  257
# file dumped
# DpNGiAziRhk
# ids remain:  256
# file dumped
# iFQFGOY3RQ0
# ids remain:  255
# file dumped
# _WRArAtL8ew
# ids remain:  254
# file dumped
# cfE57quZjPA
# ids remain:  253
# file dumped
# jFMBdhBrssI
# ids remain:  252
# file dumped
# jzqv--M0erk
# ids remain:  251
# file dumped
# 79YMBN0e2L0
# ids remain:  250
# file dumped
# TDrGHP9Z8vw
# ids remain:  249
# file dumped
# OyREzWcCPDo
# ids remain:  248
# file dumped
# 4jVUaT8UHtw
# ids remain:  247
# file dumped
# scLoydIP46A
# ids remain:  246
# file dumped
# 8lIctjq2sG0
# ids remain:  245
# file dumped
# qleuIHg5PsI
# ids remain:  244
# file dumped
# m_TqMOaL_XQ
# ids remain:  243
# file dumped
# 5rB4Qa2C9Po
# ids remain:  242
# file dumped
# dP9ziYHX0t4
# ids remain:  241
# file dumped
# CmWFL4w4Fnw
# ids remain:  240
# file dumped
# 0cUQqPxw3hc
# ids remain:  239
# file dumped
# 1jsE2VZPWPs
# ids remain:  238
# file dumped
# Es3YU2wCGlE
# ids remain:  237
# file dumped
# 314CbAWK1DQ
# ids remain:  236
# file dumped
# 0wxaIqc8o6s
# ids remain:  235
# file dumped
# 9deeHM6vEUs
# ids remain:  234
# file dumped
# 2NOzX-3WSMw
# ids remain:  233
# file dumped
# 8hsfBNQ8jA0
# ids remain:  232
# file dumped
# sM728a0UT24
# ids remain:  231
# file dumped
# buui5PkSd7c
# ids remain:  230
# file dumped
# ummBVUpQiOk
# ids remain:  229
# file dumped
# Uexwiga7a2U
# ids remain:  228
# file dumped
# MNhS-siwwPM
# ids remain:  227
# file dumped
# BnpdoAIhiyo
# ids remain:  226
# file dumped
# Wzvx4bbHJVQ
# ids remain:  225
# file dumped
# G54ylg--I9E
# ids remain:  224
# file dumped
# QmFqTnhmSZ4
# ids remain:  223
# file dumped
# A1YzwRIgUtI
# ids remain:  222
# file dumped
# jUq03HS2qVk
# ids remain:  221
# file dumped
# wuAbLIexkAw
# ids remain:  220
# file dumped
# dBkT5Q7LN6I
# ids remain:  219
# file dumped
# C79nHzODu0o
# ids remain:  218
# file dumped
# 3VjBVoV5hTU
# ids remain:  217
# file dumped
# V6Ps2uSXBxU
# ids remain:  216
# file dumped
# moadN2ayQ78
# ids remain:  215
# file dumped
# ShFpGNbUM4A
# ids remain:  214
# file dumped
# HZwMX6T5Jhk
# ids remain:  213
# file dumped
# MZna1q3ZOP4
# ids remain:  212
# file dumped
# zdR-I35Ladk
# ids remain:  211
# file dumped
# jyIBNIOcjdI
# ids remain:  210
# file dumped
# lMFdws8Rvfs
# ids remain:  209
# file dumped
# 6NXWTq60yN4
# ids remain:  208
# file dumped
# fQvCZ5ZsnGM
# ids remain:  207
# file dumped
# x5LZDd9y4Uw
# ids remain:  206
# file dumped
# YKaFY8GWZ1o
# ids remain:  205
# file dumped
# I_sjSC5upd4
# ids remain:  204
# file dumped
# LQv9V8XlI-g
# ids remain:  203
# file dumped
# dk2WFzc5mVg
# ids remain:  202
# file dumped
# oidu102A5ds
# ids remain:  201
# file dumped
# qA1nGPM9yHA
# ids remain:  200
# file dumped
# zOHhaMvk-XM
# ids remain:  199
# file dumped
# OVm1LvRak2U
# ids remain:  198
# file dumped
# jVlaQWJNTWM
# ids remain:  197
# file dumped
# gC1g-M9vA-4
# ids remain:  196
# file dumped
# Y7pteqWRYu4
# ids remain:  195
# file dumped
# lyu7v7nWzfo
# ids remain:  194
# file dumped
# 5FUE7I_J-Pc
# ids remain:  193
# file dumped
# FbjhzVvzNz0
# ids remain:  192
# file dumped
# 4QFDpN70rZg
# ids remain:  191
# file dumped
# MFtDFXtuslY
# ids remain:  190
# file dumped
# Cv0YBbZdjys
# ids remain:  189
# file dumped
# xV-MwRkjb0Y
# ids remain:  188
# file dumped
# Ea4kpCYQ7G4
# ids remain:  187
# file dumped
# 8MJzo7ki8JY
# ids remain:  186
# file dumped
# hSqfTBOxn8M
# ids remain:  185
# file dumped
# hIRhzXWSrWU
# ids remain:  184
# file dumped
# LiTWctLYoSo
# ids remain:  183
# file dumped
# s2bYHcOIWe4
# ids remain:  182
# file dumped
# 2mjUYbyDl98
# ids remain:  181
# file dumped
# AZr4nvawOqU
# ids remain:  180
# file dumped
# gw-7ETW0cHM
# ids remain:  179
# file dumped
# wN15KVD7n80
# ids remain:  178
# file dumped
# KckbneGsDvE
# ids remain:  177
# file dumped
# gEBGvnRTHzI
# ids remain:  176
# file dumped
# h6z41qQuJVk
# ids remain:  175
# file dumped
# JjdejTS7hsM
# ids remain:  174
# file dumped
# 0-wl5nNGZq4
# ids remain:  173
# file dumped
# nHCEEFBU8HE
# ids remain:  172
# file dumped
# CBtLOVdB9MU
# ids remain:  171
# file dumped
# 7qXPK_FRWBQ
# ids remain:  170
# file dumped
# SpWMGMwubwU
# ids remain:  169
# file dumped
# 3C5TVyH_UAw
# ids remain:  168
# file dumped
# MMleMA7-RL4
# ids remain:  167
# file dumped
# 6fs0xfLoMdI
# ids remain:  166
# file dumped
# eGnfbtRqdjc
# ids remain:  165
# file dumped
# Nf9q1wQHEfI
# ids remain:  164
# file dumped
# 6dEQzB06VuE
# ids remain:  163
# file dumped
# q1IKSLj7jfQ
# ids remain:  162
# file dumped
# eMDpe8zcSvo
# ids remain:  161
# file dumped
# gp_vrDL7YOo
# ids remain:  160
# file dumped
# ukJVpSUOM1U
# ids remain:  159
# file dumped
# ZX83_m1_loE
# ids remain:  158
# file dumped
# wkL00gW99Ok
# ids remain:  157
# file dumped
# fVgjpp_8584
# ids remain:  156
# file dumped
# 4dudw71gkZM
# ids remain:  155
# file dumped
# ItylhAyc_bw
# ids remain:  154
# file dumped
# ZDK2rznUXX4
# ids remain:  153
# file dumped
# NaWUXbvHimc
# ids remain:  152
# file dumped
# ohJxd_syJ0M
# ids remain:  151
# file dumped
# ta7kek0E5JY
# ids remain:  150
# file dumped
# 2dkHwDi4-QY
# ids remain:  149
# file dumped
# LILPm3fiItU
# ids remain:  148
# file dumped
# GW7quw7O2Ns
# ids remain:  147
# file dumped
# H6PZM23Iu5Y
# ids remain:  146
# file dumped
# bEHqlKiTlq8
# ids remain:  145
# file dumped
# y_NB0YHaO38
# ids remain:  144
# file dumped
# JwSm85zbRvQ
# ids remain:  143
# file dumped
# D_u_1JeISc4
# ids remain:  142
# file dumped
# S24Q1GjOwtw
# ids remain:  141
# file dumped
# lUwvV6GQ8DI
# ids remain:  140
# file dumped
# PiZ0iinudJs
# ids remain:  139
# file dumped
# EZp7mqYYTFM
# ids remain:  138
# file dumped
# ofJhtuvruGA
# ids remain:  137
# file dumped
# B4b1mXUFZCk
# ids remain:  136
# file dumped
# EIzjr7kVgjU
# ids remain:  135
# file dumped
# IFLOww098bc
# ids remain:  134
# file dumped
# 0Pi_x_4_gm4
# ids remain:  133
# file dumped
# dQLWmOEX95A
# ids remain:  132
# file dumped
# Fo8D0Yhw_00
# ids remain:  131
# file dumped
# v-H9-e1waL4
# ids remain:  130
# file dumped
# nRiI2waOLag
# ids remain:  129
# file dumped
# k_XMN4ici9I
# ids remain:  128
# file dumped
# twZX0QYLzuk
# ids remain:  127
# file dumped
# Grv1RJkdyqI
# ids remain:  126
# file dumped
# Sc4e6Ywwhog
# ids remain:  125
# file dumped
# rg1-MWAjqPU
# ids remain:  124
# file dumped
# tfvSO0406cg
# ids remain:  123
# file dumped
# _3-kizWli2w
# ids remain:  122
# file dumped
# jZebm88374k
# ids remain:  121
# file dumped
# eEqRrZvfbQk
# ids remain:  120
# file dumped
# p0H4HKaC5go
# ids remain:  119
# file dumped
# upfh0qeUuE0
# ids remain:  118
# file dumped
# rlq0NySUihY
# ids remain:  117
# file dumped
# C3P_LdVczdg
# ids remain:  116
# file dumped
# bfmvDJ55fxE
# ids remain:  115
# file dumped
# 3RcZsdgcEHk
# ids remain:  114
# file dumped
# Lc3fzQzsA00
# ids remain:  113
# file dumped
# BXlnrFpCu0c
# ids remain:  112
# file dumped
# G11pfzMfHak
# ids remain:  111
# file dumped
# Db-dt5U3MCc
# ids remain:  110
# file dumped
# L9YwzQVvIao
# ids remain:  109
# file dumped
# 6DMyeAd2FQY
# ids remain:  108
# file dumped
# PmEDAzqswh8
# ids remain:  107
# file dumped
# klY7Mt7vliA
# ids remain:  106
# file dumped
# SBIckQnR7QA
# ids remain:  105
# file dumped
# c0vqKd78GPw
# ids remain:  104
# file dumped
# mGkxmq8if2g
# ids remain:  103
# file dumped
# uVxc7Ox0ixE
# ids remain:  102
# file dumped
# mNdjqx6vKy4
# ids remain:  101
# file dumped
# t9oLncRrl2c
# ids remain:  100
# file dumped
# uUaJ2dayDjM
# ids remain:  99
# file dumped
# In6M2oR2MKE
# ids remain:  98
# file dumped
# wOTaSschCPI
# ids remain:  97
# file dumped
# nspxAG12Cpc
# ids remain:  96
# file dumped
# 5eDN9T-OfZg
# ids remain:  95
# file dumped
# 2libFy224FI
# ids remain:  94
# file dumped
# bO7PgQ-DtZk
# ids remain:  93
# file dumped
# XJ0Ykptvq54
# ids remain:  92
# file dumped
# yCxNXyH7gNk
# ids remain:  91
# file dumped
# 7G_eO_LBKMs
# ids remain:  90
# file dumped
# 6EylXrKp3n0
# ids remain:  89
# file dumped
# hweXOXDJTMs
# ids remain:  88
# file dumped
# 8iYneqcdfmQ
# ids remain:  87
# file dumped
# 0V8y_H0rH3I
# ids remain:  86
# file dumped
# 7qRjJtLIZXQ
# ids remain:  85
# file dumped
# EpRoQ1GjM-U
# ids remain:  84
# file dumped
# tTAb32LCW-c
# ids remain:  83
# file dumped
# DNW7xlIGgkQ
# ids remain:  82
# file dumped
# w6OWydr98IU
# ids remain:  81
# file dumped
# iByoIQoBVkM
# ids remain:  80
# file dumped
# qzlaqqJns-w
# ids remain:  79
# file dumped
# 9JGxzzJAqXM
# ids remain:  78
# file dumped
# 33scVEdVOJM
# ids remain:  77
# file dumped
# Hj9ZlmfNwPg
# ids remain:  76
# file dumped
# TUhE5lYiFfM
# ids remain:  75
# file dumped
# wkN6RzcLgUA
# ids remain:  74
# file dumped
# U8xbqgwvx7I
# ids remain:  73
# file dumped
# EFBpaM-8J1I
# ids remain:  72
# file dumped
# 675kuTxtjAE
# ids remain:  71
# file dumped
# 4xLzxwOkdOY
# ids remain:  70
# file dumped
# JXUNEFw9sQs
# ids remain:  69
# file dumped
# v7WXfv-QZck
# ids remain:  68
# file dumped
# e38Bz6pUWJY
# ids remain:  67
# file dumped
# E4LkSDXCHnY
# ids remain:  66
# file dumped
# WyR20igdrds
# ids remain:  65
# file dumped
# mdNc3HA9PmE
# ids remain:  64
# file dumped
# VGY6Phz7JbQ
# ids remain:  63
# file dumped
# O6sytd-IW3Y
# ids remain:  62
# file dumped
# JcGD2B_GtUc
# ids remain:  61
# file dumped
# nI_OfkQOG6Q
# ids remain:  60
# file dumped
# or_MDJnmihc
# ids remain:  59
# file dumped
# 6oZErY25bck
# ids remain:  58
# file dumped
# GPHNDeor0Ec
# ids remain:  57
# file dumped
# oyPQq81oRIA
# ids remain:  56
# file dumped
# Qv6owV1IVHg
# ids remain:  55
# file dumped
# CQzb5F0-1jM
# ids remain:  54
# file dumped
# W92LSYGopEI
# ids remain:  53
# file dumped
# nRGBB20jg2c
# ids remain:  52
# file dumped
# s59rkFku4QU
# ids remain:  51
# file dumped
# ZVx8WS8ndgU
# ids remain:  50
# file dumped
# SIEPY2OVnn0
# ids remain:  49
# file dumped
# bATPXjOKebI
# ids remain:  48
# file dumped
# nbS5dh1G7Gc
# ids remain:  47
# file dumped
# yWmcUAMMmV4
# ids remain:  46
# file dumped
# cltNVIuoEaI
# ids remain:  45
# file dumped
# um5sD8SVgnY
# ids remain:  44
# file dumped
# AIAqklVF_k8
# ids remain:  43
# file dumped
# RBoq_-deUXY
# ids remain:  42
# file dumped
# 2ugSbOG1MDk
# ids remain:  41
# file dumped
# OPPE3kVkvEo
# ids remain:  40
# file dumped
# Ue7fdH9pY0c
# ids remain:  39
# file dumped
# 8yuFrfB3ohA
# ids remain:  38
# file dumped
# ryOr67pxlHI
# ids remain:  37
# file dumped
# Djg1kVSdfkc
# ids remain:  36
# file dumped
# jbcc9iGfu6I
# ids remain:  35
# file dumped
# AtTDtIlHzoU
# ids remain:  34
# file dumped
# P07j_CxjT44
# ids remain:  33
# file dumped
# eQ4zb5ITr9g
# ids remain:  32
# file dumped
# kPiSfhfc-ZA
# ids remain:  31
# file dumped
# paFkFbDoR5I
# ids remain:  30
# file dumped
# Xtth0XW6fqE
# ids remain:  29
# file dumped
# _hZL3-ZsZVw
# ids remain:  28
# file dumped
# CpP2e8GQGI4
# ids remain:  27
# file dumped
# DlQMtukduy4
# ids remain:  26
# file dumped
# bZ1mGVu5584
# ids remain:  25
# file dumped
# _qSWlJRpCtA
# ids remain:  24
# file dumped
# wQuRcfMwYX8
# ids remain:  23
# file dumped
# QfqZeAvyFkw
# ids remain:  22
# file dumped
# 9ifMUIWjIzI
# ids remain:  21
# file dumped
# R6syxgUxiuc
# ids remain:  20
# file dumped
# TeVJgQ7UCWw
# ids remain:  19
# file dumped
# 6eBLEJXx0ug
# ids remain:  18
# file dumped
# j1SBZtCQjnM
# ids remain:  17
# file dumped
# kdPQUZWbZE4
# ids remain:  16
# file dumped
# CHIJxVqoB_U
# ids remain:  15
# file dumped
# MJ-511g86XI
# ids remain:  14
# file dumped
# BGSADZh_gDk
# ids remain:  13
# file dumped
# 13e-AACqjf4
# ids remain:  12
# file dumped
# VQQRzUohfjg
# ids remain:  11
# file dumped
# XDjnSGsCynw
# ids remain:  10
# file dumped
# kdWsqv7mVj0
# ids remain:  9
# file dumped
# PMXm6xbKmAY
# ids remain:  8
# file dumped
# xB6vI76tGN0
# ids remain:  7
# file dumped
# zwZ2QB7wMM4
# ids remain:  6
# file dumped
# q3JtJzs4kas
# ids remain:  5
# file dumped
# uCC0QlrApUY
# ids remain:  4
# file dumped
# _xavfLyGgZU
# ids remain:  3
# file dumped
# c-lqL3yhZI0
# ids remain:  2
# file dumped
# A7rKRZzy9yM
# ids remain:  1
# file dumped
# TYtRbfMa6O4
# ids remain:  0
# file dumped

# %% [markdown]
# #  read and save JSON files collected

# %%
# read josn files and make a list with json files
# (make 1 change)

path_to_json = folder_url

json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]
json_files;  
len(json_files)
# Out:
# 373

# %%
# create a data frame with all json files:

df = pd.DataFrame()
for file in json_files:
    file_path = path_to_json + file
    with open(file_path) as data_file:    
        data = json.load(data_file)
        df = df.append(pd.json_normalize(data))
df.shape
# Out:
# (373, 49)

# %%
df.head(2)
# Out:
#             kind                         etag           id  \
# 0  youtube#video  rRRLLyW-OpsLMpTinf7nfm7Ehs4  0-wl5nNGZq4
# 0  youtube#video  30oPkBzdHl4lvWSkSTKUUbNAsUI  0cUQqPxw3hc
#
#     snippet.publishedAt         snippet.channelId  \
# 0  2016-06-21T13:04:52Z  UC0U8tmHFHbyuYc18APnnyzg
# 0  2019-09-20T17:46:52Z  UCb--64Gl51jIEVE-GLDAVTg
#
#                                        snippet.title  \
# 0  Comic Doug Stanhope calls Amber Heard lawsuit ...
# 0  Candace Owens at hearing on Confronting White ...
#
#                                  snippet.description  \
# 0  Johnny Depp's friend Doug Stanhope is speaking...
# 0  Candace Owens to Kathleen Belew: "The audacity...
#
#                    snippet.thumbnails.default.url  \
# 0  https://i.ytimg.com/vi/0-wl5nNGZq4/default.jpg
# 0  https://i.ytimg.com/vi/0cUQqPxw3hc/default.jpg
#
#    snippet.thumbnails.default.width  snippet.thumbnails.default.height  ...  \
# 0                               120                                 90  ...
# 0                               120                                 90  ...
#
#   status.madeForKids  statistics.viewCount  statistics.likeCount  \
# 0              False                  1495                    22
# 0              False               3872801                 80711
#
#   statistics.dislikeCount  statistics.favoriteCount  statistics.commentCount  \
# 0                      11                         0                        0
# 0                    3982                         0                    17911
#
#   snippet.defaultLanguage  snippet.defaultAudioLanguage  \
# 0                     NaN                           NaN
# 0                      en                            en
#
#    contentDetails.regionRestriction.blocked  \
# 0                                       NaN
# 0                                       NaN
#
#   contentDetails.contentRating.ytRating
# 0                                   NaN
# 0                                   NaN
#
# [2 rows x 49 columns]

# %%
# save this dataframe with the search name as csv file:

save_csv_url = r"C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Videos_details/{} --scraped.csv".format(path_to_json.split('/')[1])
df.to_csv(save_csv_url, index=None)

# %% [markdown]
# # save channels IDs to collect cannels info

# %%
# make new df with channels IDs:
new_channels_id_df = pd.DataFrame(df['snippet.channelId'])

# for the same batch read channels we have then add the news:
channel_id_file_url = r'C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\channels_ids_batch-4.csv'
channel_id_df = pd.read_csv(channel_id_file_url)
print("channels count before adding: ", channel_id_df.shape)
# append the two dfs together and update the file to have the new IDs
total_channels_ids = new_channels_id_df.append(channel_id_df['id'], ignore_index=True)
total_channels_ids = pd.DataFrame(total_channels_ids, columns=['id'])
total_channels_ids.to_csv(channel_id_file_url, index=None )
print("channels count after adding: ", total_channels_ids.shape)
# Out:
# channels count before adding:  (0, 1)
# channels count after adding:  (374, 1)
