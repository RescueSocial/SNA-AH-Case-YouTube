# %%
import pandas as pd
import json
import requests
from io import StringIO
from csv import reader
import os
import glob

# %% [markdown]
# https://youtube.googleapis.com/youtube/v3/channels?part=snippet&id=UC8-Th83bH_thdKZDJCrn88g&key=AIzaSyCQHI5RSbHoKGh6sPPnnOywja7qLS6TXnA

# %% [markdown]
# https://youtube.googleapis.com/youtube/v3/channels?part=snippet&part=contentDetails&id=UC8-Th83bH_thdKZDJCrn88g&key=AIzaSyCQHI5RSbHoKGh6sPPnnOywja7qLS6TXnA

# %% [markdown]
# https://youtube.googleapis.com/youtube/v3/channels?part=snippet&part=contentDetails&part=brandingSettings&part=contentOwnerDetails&part=id&part=localizations&part=statistics&part=status&part=topicDetails&id=UC8-Th83bH_thdKZDJCrn88g&maxResults=200&key=AIzaSyCQHI5RSbHoKGh6sPPnnOywja7qLS6TXnA&pageToken=''

# %%
channels_id = pd.read_csv('total_channels_id.csv')
channels_id = list(channels_id['id'])
len(channels_id)
# Out:
# 5003

# %%
class YTstats:
  
    def __init__(self, api_key, channel_id):
        self.api_key = api_key
        self.channel_id = channel_id
        self.video_statistics = None
  
    def get_video_statistics(self):
        url = f'https://youtube.googleapis.com/youtube/v3/channels?part=snippet&part=contentDetails&part=brandingSettings&part=contentOwnerDetails&part=id&part=localizations&part=statistics&part=status&part=topicDetails&id={self.channel_id}&maxResults=200&key={self.api_key}'
        json_url = requests.get(url)
        data = json.loads(json_url.text)
        nextPageToken = data.get("nextPageToken")
        
        i = 0
        a = ''
        if nextPageToken:
            while nextPageToken != a:
                a = nextPageToken
                i += 1
                url = f'https://youtube.googleapis.com/youtube/v3/channels?part=snippet&part=contentDetails&part=brandingSettings&part=contentOwnerDetails&part=id&part=localizations&part=statistics&part=status&part=topicDetails&id={self.channel_id}&maxResults=200&key={self.api_key}&pageToken={nextPageToken}'
                json_url = requests.get(url)
                data1 = json.loads(json_url.text)
                nextPageToken = data1.get("nextPageToken")
                data['items'] = data['items'] + data1['items']
                
                if nextPageToken is None:
                    break
                print('page number:', i+1)
              #  print(nextPageToken, len(data['items']))
            
            
        try:
            data = data["items"]#[0]["statistics"]
        except:
            data = None
  
        self.video_statistics = data
        return data
  
    def dump(self):
        if self.video_statistics is None:
            print('nothing happend')
            return 
  
        video_title = self.channel_id
        video_title = video_title.replace(" ", "_")
  
        # generate a json file with all the statistics data of the youtube video
        file_name = video_title + '.json'
        with open(file_name, 'w') as f:
            json.dump(self.video_statistics, f, indent=4)
        print('file dumped')

# %%
# recive data using API and save it on PC
# (make 1 change)

API_KEY = "AIzaSyCQHI5RSbHoKGh6sPPnnOywja7qLS6TXnA"
API_KEY2 = "AIzaSyA-0KfpLK04NpQN1XghxhSlzG-WkC3DHLs"  

# paste the channel id here
while len(channels_id) !=0:
    
    for video in channels_id:
        print(video)
        yt = YTstats(API_KEY, video)
        yt.get_video_statistics()
        yt.dump()
        channels_id.remove(video)
        print('channels to scrape remain: ', len(channels_id))
        break
# Out:
# UCg4QdTAOo4ZrSEtRD8qj40Q
# file dumped
# channels to scrape remain:  3525
# UCls8-Q2uoCQrXJ-R1HbCs4g
# file dumped
# channels to scrape remain:  3524
# UCAmaiEYnoTgj-dmjp8DpepQ
# file dumped
# channels to scrape remain:  3523
# UCzZP87a9JmKQgM0OD-K60wQ
# file dumped
# channels to scrape remain:  3522
# UCzJ1kK3mGupL2V0YZ-lOMVQ
# file dumped
# channels to scrape remain:  3521
# UCBTIp2pvN1OtfT5iKwuwGIw
# file dumped
# channels to scrape remain:  3520
# UCmxGEYcKS5W4YnROt4-uoZA
# file dumped
# channels to scrape remain:  3519
# UCTUVsO-sL2FW1KqUP6DPC4A
# file dumped
# channels to scrape remain:  3518
# UC3zAGYlUh608g7afQKe1HfA
# file dumped
# channels to scrape remain:  3517
# UCioMwqTXbO2GsWMEMlLFEug
# file dumped
# channels to scrape remain:  3516
# UC-lZTlG05ETwyjDS1JQCv3w
# file dumped
# channels to scrape remain:  3515
# UCsEaTDlh3kfgl17DnaRFW2g
# file dumped
# channels to scrape remain:  3514
# UCPOZEn6lzysXJaN0VmaH30A
# file dumped
# channels to scrape remain:  3513
# UCHTK-2W11Vh1V4uwofOfR4w
# file dumped
# channels to scrape remain:  3512
# UCZlnshKh_exh1WBP9P-yPdQ
# file dumped
# channels to scrape remain:  3511
# UCnxixOEOpFzA74FNAD92gAg
# file dumped
# channels to scrape remain:  3510
# UCioMwqTXbO2GsWMEMlLFEug
# file dumped
# channels to scrape remain:  3509
# UCqex0rRFRYvpPwU6n-Jk3zA
# file dumped
# channels to scrape remain:  3508
# UCMrpRnyBJhgVBy3rm0K4P5w
# file dumped
# channels to scrape remain:  3507
# UCE-GLhKd7iMzDeR1_Wyt6Nw
# file dumped
# channels to scrape remain:  3506
# UCAVgFwnRKj2Ny8M2emfYm9w
# file dumped
# channels to scrape remain:  3505
# UCBj9CK26FWtLGrZ8auy1VJA
# file dumped
# channels to scrape remain:  3504
# UC_gQFJZzAbLTVoxAnoYWzyQ
# file dumped
# channels to scrape remain:  3503
# UCuhS2wb4EgcjdwPG-g6z3dg
# file dumped
# channels to scrape remain:  3502
# UClx_IR8_yVIKdFVUTdmaZTw
# file dumped
# channels to scrape remain:  3501
# UC8AGq7bm-x4teGcvQonvnPw
# file dumped
# channels to scrape remain:  3500
# UC3L8u5qG07djPUwWo6VQVLA
# file dumped
# channels to scrape remain:  3499
# UCYWG3xsrIBKH_HC82e4rAOg
# file dumped
# channels to scrape remain:  3498
# UCtMNeiW7rOdKOXhCexxQAyA
# file dumped
# channels to scrape remain:  3497
# UCRJNKeG_dGauXnLZuHnTjEA
# file dumped
# channels to scrape remain:  3496
# UCfwE_ODI1YTbdjkzuSi1Nag
# file dumped
# channels to scrape remain:  3495
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  3494
# UC3l-bobp_xuBlL_lRRS5RmA
# file dumped
# channels to scrape remain:  3493
# UCnClOuzfbOj3ZcUKs2GahjA
# file dumped
# channels to scrape remain:  3492
# UCEautOaHl_i82rbwSr6VFrg
# file dumped
# channels to scrape remain:  3491
# UCzQXwP-JvZxbp0vGdLSp5TQ
# file dumped
# channels to scrape remain:  3490
# UCRJNKeG_dGauXnLZuHnTjEA
# file dumped
# channels to scrape remain:  3489
# UCAk03rcNVtLK1_LlgRTOh2w
# file dumped
# channels to scrape remain:  3488
# UC5RoL7fduM5ZQCVgAhD_RWw
# file dumped
# channels to scrape remain:  3487
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  3486
# UCbiT0LUIbQj6CQScvWHJeKQ
# file dumped
# channels to scrape remain:  3485
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  3484
# UC-lZTlG05ETwyjDS1JQCv3w
# file dumped
# channels to scrape remain:  3483
# UCIaJzG5TPWQIiV1bRRcQdmw
# file dumped
# channels to scrape remain:  3482
# UC8adimFVj-TL1OqboO_KbsQ
# file dumped
# channels to scrape remain:  3481
# UCjZyUJ_QYcaX_7GUTjjZHdw
# file dumped
# channels to scrape remain:  3480
# UCDPc5dbz5mTTKGV8ejo8vAw
# file dumped
# channels to scrape remain:  3479
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  3478
# UCzdBteP334_fj0NKmGmGzHQ
# file dumped
# channels to scrape remain:  3477
# UCjZyUJ_QYcaX_7GUTjjZHdw
# file dumped
# channels to scrape remain:  3476
# UC1nJzvNaB_ql4RHrzgozrQQ
# file dumped
# channels to scrape remain:  3475
# UCzj5pofLaoZmp4ILL9dg4dA
# file dumped
# channels to scrape remain:  3474
# UCzKrJ5NSA9o7RHYRG12kHZw
# file dumped
# channels to scrape remain:  3473
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  3472
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  3471
# UCtC8m_F7jX2fGOQ3_nomg4g
# file dumped
# channels to scrape remain:  3470
# UC3l-bobp_xuBlL_lRRS5RmA
# file dumped
# channels to scrape remain:  3469
# UCj9peGCfg5X6PrinJKAyCDw
# file dumped
# channels to scrape remain:  3468
# UCRJNKeG_dGauXnLZuHnTjEA
# file dumped
# channels to scrape remain:  3467
# UCDuBZ7pjryDhRx9qKg3MrOg
# file dumped
# channels to scrape remain:  3466
# UCRJNKeG_dGauXnLZuHnTjEA
# file dumped
# channels to scrape remain:  3465
# UC1DGpYiEiqBrQtYXFbLhMVQ
# file dumped
# channels to scrape remain:  3464
# UC3l-bobp_xuBlL_lRRS5RmA
# file dumped
# channels to scrape remain:  3463
# UCE-GLhKd7iMzDeR1_Wyt6Nw
# file dumped
# channels to scrape remain:  3462
# UCctJ98bs1bDo8ckDOcP2QfQ
# file dumped
# channels to scrape remain:  3461
# UC0e1j78PchE9bO-AD033dkw
# file dumped
# channels to scrape remain:  3460
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  3459
# UC6iULsIwWoHYy9o-qMWbPtQ
# file dumped
# channels to scrape remain:  3458
# UCAmaiEYnoTgj-dmjp8DpepQ
# file dumped
# channels to scrape remain:  3457
# UCsEaTDlh3kfgl17DnaRFW2g
# file dumped
# channels to scrape remain:  3456
# UClSAHKY9t1n_4NtfNZLS0WA
# file dumped
# channels to scrape remain:  3455
# UC7pXM9iwUBU1SIe5n76Rucg
# file dumped
# channels to scrape remain:  3454
# UCUT7-8PSQkgyJrEiEfvvzcA
# file dumped
# channels to scrape remain:  3453
# UCRJNKeG_dGauXnLZuHnTjEA
# file dumped
# channels to scrape remain:  3452
# UClx_IR8_yVIKdFVUTdmaZTw
# file dumped
# channels to scrape remain:  3451
# UC2jQ1YnBikp-Hm_C7oOb1mQ
# file dumped
# channels to scrape remain:  3450
# UCWA4Wlrqqk9i011TTOn_qWA
# file dumped
# channels to scrape remain:  3449
# UCAmaiEYnoTgj-dmjp8DpepQ
# file dumped
# channels to scrape remain:  3448
# UCsRWxbIHPAxAc0l_x-l7pBA
# file dumped
# channels to scrape remain:  3447
# UCauL_l75NckrgcVCwY1eCwg
# file dumped
# channels to scrape remain:  3446
# UCRJNKeG_dGauXnLZuHnTjEA
# file dumped
# channels to scrape remain:  3445
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  3444
# UCoZKfneKKuRxyDGIZCJzMpw
# file dumped
# channels to scrape remain:  3443
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  3442
# UC0camCasN9RIAWh5Vox3LoA
# file dumped
# channels to scrape remain:  3441
# UCA3jAm4lnCEeoVD-RjvykUQ
# file dumped
# channels to scrape remain:  3440
# UC48CqsQVp-G-V3dFQ6LJ0LA
# file dumped
# channels to scrape remain:  3439
# UCEIBC3UsbyCO7tRPX1UgqyQ
# file dumped
# channels to scrape remain:  3438
# UCG-mgv-RGb6KgmVRg78e7vA
# file dumped
# channels to scrape remain:  3437
# UCGQM-QlnVfwVHTWwEY6xa1A
# file dumped
# channels to scrape remain:  3436
# UCPLdgSpFaFm_xPr19uSB0Ig
# file dumped
# channels to scrape remain:  3435
# UCeZ08MGEmhSrewV-_NSL1cw
# file dumped
# channels to scrape remain:  3434
# UCKhGUjHHG_7345AlifXMllA
# file dumped
# channels to scrape remain:  3433
# UC2rJLq19N0dGrxfib80M_fg
# file dumped
# channels to scrape remain:  3432
# UC52X5wxOL_s5yw0dQk7NtgA
# file dumped
# channels to scrape remain:  3431
# UCox6of1JgyRJGQhrlosyjwQ
# file dumped
# channels to scrape remain:  3430
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  3429
# UC3L8u5qG07djPUwWo6VQVLA
# file dumped
# channels to scrape remain:  3428
# UCXMfxL7Wc6gVWbAJQq4NZcQ
# file dumped
# channels to scrape remain:  3427
# UCesysVZlO9RYjJOiBCcrYJA
# file dumped
# channels to scrape remain:  3426
# UCnClOuzfbOj3ZcUKs2GahjA
# file dumped
# channels to scrape remain:  3425
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  3424
# UC3l-bobp_xuBlL_lRRS5RmA
# file dumped
# channels to scrape remain:  3423
# UC6jgzx2g3nlbaYkd8EMweKA
# file dumped
# channels to scrape remain:  3422
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  3421
# UCWBgTc2dQN8h3oXLRXyV-yw
# file dumped
# channels to scrape remain:  3420
# UCD-1jAmL42qnEszozefaa1g
# file dumped
# channels to scrape remain:  3419
# UCE-GLhKd7iMzDeR1_Wyt6Nw
# file dumped
# channels to scrape remain:  3418
# UCE-GLhKd7iMzDeR1_Wyt6Nw
# file dumped
# channels to scrape remain:  3417
# UCZMsvbAhhRblVGXmEXW8TSA
# file dumped
# channels to scrape remain:  3416
# UCIQz7nN_zTfIoSOh7HasYIQ
# file dumped
# channels to scrape remain:  3415
# UCPLkgoRQsOWSjKlFOy--Y8g
# file dumped
# channels to scrape remain:  3414
# UCuWeBHxVe6C69JTBpiY-Y8Q
# file dumped
# channels to scrape remain:  3413
# UC4qk9TtGhBKCkoWz5qGJcGg
# file dumped
# channels to scrape remain:  3412
# UCpqiQ8q14kT1sdlZ0gD0bGg
# file dumped
# channels to scrape remain:  3411
# UCwbQL-LZ4-CPWsJB4tTi4Rg
# file dumped
# channels to scrape remain:  3410
# UC_k6u_Mpe3gtYTR5lsEd1Pw
# file dumped
# channels to scrape remain:  3409
# UCD-1jAmL42qnEszozefaa1g
# file dumped
# channels to scrape remain:  3408
# UCRJNKeG_dGauXnLZuHnTjEA
# file dumped
# channels to scrape remain:  3407
# UCTHb57pkZsg0SFI-rsXHGaQ
# file dumped
# channels to scrape remain:  3406
# UCpqiQ8q14kT1sdlZ0gD0bGg
# file dumped
# channels to scrape remain:  3405
# UCSAvJ1tv9PRBVHfaH1Xqxzg
# file dumped
# channels to scrape remain:  3404
# UCbp3fkS6cxI1aekmIPIDCGg
# file dumped
# channels to scrape remain:  3403
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  3402
# UCS-LOIqrR8BQuIALAVsjNzw
# file dumped
# channels to scrape remain:  3401
# UCkcA2R9LuiaR_E_f_3whYFg
# file dumped
# channels to scrape remain:  3400
# UCQ-UjECJSbjSiqzZfWFFuzQ
# file dumped
# channels to scrape remain:  3399
# UCjZyUJ_QYcaX_7GUTjjZHdw
# file dumped
# channels to scrape remain:  3398
# UCcfS47VXepMM2RqazIKz4BQ
# file dumped
# channels to scrape remain:  3397
# UC1lfqJT2OdW4qy7AF6iScCA
# file dumped
# channels to scrape remain:  3396
# UCjNWvlu4LNpqL6wpaEc8Q8w
# file dumped
# channels to scrape remain:  3395
# UCh4kZnE9IHQhjr8jFd5nNNw
# file dumped
# channels to scrape remain:  3394
# UCQtRgDHY0SrHylkpD3Ei2Mg
# file dumped
# channels to scrape remain:  3393
# UCIQz7nN_zTfIoSOh7HasYIQ
# file dumped
# channels to scrape remain:  3392
# UCtGeReZOXJ1WLmUzkeuvr-g
# file dumped
# channels to scrape remain:  3391
# UCFi_m3dUvDD_CL7t-KTHrzA
# file dumped
# channels to scrape remain:  3390
# UCospR8ojm4TTRQ9Qx9flkhQ
# file dumped
# channels to scrape remain:  3389
# UCpqiQ8q14kT1sdlZ0gD0bGg
# file dumped
# channels to scrape remain:  3388
# UCpqiQ8q14kT1sdlZ0gD0bGg
# file dumped
# channels to scrape remain:  3387
# UCsoK3B_Uw1za9m8v_If7erA
# file dumped
# channels to scrape remain:  3386
# UCg8IXlnvP0uQ-ANWrsAivfg
# file dumped
# channels to scrape remain:  3385
# UCRJNKeG_dGauXnLZuHnTjEA
# file dumped
# channels to scrape remain:  3384
# UC3l-bobp_xuBlL_lRRS5RmA
# file dumped
# channels to scrape remain:  3383
# UCpKuIzDo5RoLmEk_BB_up3g
# file dumped
# channels to scrape remain:  3382
# UCxaylBf0QBQk99sHdYYB2Vw
# file dumped
# channels to scrape remain:  3381
# UC6vI5bdfmtiFkth1hVAmIvQ
# file dumped
# channels to scrape remain:  3380
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  3379
# UCHTK-2W11Vh1V4uwofOfR4w
# file dumped
# channels to scrape remain:  3378
# UC56Klsv3wBlmUjEBB2JLJqA
# file dumped
# channels to scrape remain:  3377
# UCsRWxbIHPAxAc0l_x-l7pBA
# file dumped
# channels to scrape remain:  3376
# UC_jwYANHgWXCa6wReG5gCvg
# file dumped
# channels to scrape remain:  3375
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  3374
# UCpqiQ8q14kT1sdlZ0gD0bGg
# file dumped
# channels to scrape remain:  3373
# UCRVvH6k7SSNPG1Z3WrQR6VA
# file dumped
# channels to scrape remain:  3372
# UCuGAF2PJVfX_9zHYhaR1KHA
# file dumped
# channels to scrape remain:  3371
# UCG2QYlhnYYxksvv6ve11ijw
# file dumped
# channels to scrape remain:  3370
# UCtGeReZOXJ1WLmUzkeuvr-g
# file dumped
# channels to scrape remain:  3369
# UCFUo7P9bdQ_a82_DqK3clYw
# file dumped
# channels to scrape remain:  3368
# UCE-GLhKd7iMzDeR1_Wyt6Nw
# file dumped
# channels to scrape remain:  3367
# UCVngqxYJ9W2yQuFHKJnj0uA
# file dumped
# channels to scrape remain:  3366
# UCVngqxYJ9W2yQuFHKJnj0uA
# file dumped
# channels to scrape remain:  3365
# UC-lZTlG05ETwyjDS1JQCv3w
# file dumped
# channels to scrape remain:  3364
# UCoC8wK7Hbj1saQUBlFVaJkA
# file dumped
# channels to scrape remain:  3363
# UCAVgFwnRKj2Ny8M2emfYm9w
# file dumped
# channels to scrape remain:  3362
# UCXN0SJDWW4EGeoVCLAfLYkQ
# file dumped
# channels to scrape remain:  3361
# UCjIrSTZV4IdYdddFm2pjBnA
# file dumped
# channels to scrape remain:  3360
# UCAC8bBmbBuoKazG0e6eXDbw
# file dumped
# channels to scrape remain:  3359
# UC2u7pu8O0PjAKiXenYJnnqw
# file dumped
# channels to scrape remain:  3358
# UCXN0SJDWW4EGeoVCLAfLYkQ
# file dumped
# channels to scrape remain:  3357
# UCE3T6CUnnpbkk5C7V2m1Ckg
# file dumped
# channels to scrape remain:  3356
# UC52X5wxOL_s5yw0dQk7NtgA
# file dumped
# channels to scrape remain:  3355
# UCtHjN1W8ub-wz24tNe30cZg
# file dumped
# channels to scrape remain:  3354
# UCJmUrIx6ignVc1ZSgNNk35w
# file dumped
# channels to scrape remain:  3353
# UCRJNKeG_dGauXnLZuHnTjEA
# file dumped
# channels to scrape remain:  3352
# UCK6ffF4KAh2zUBVUMR28rCg
# file dumped
# channels to scrape remain:  3351
# UCHY7Za12hh1sDKQpju2s28Q
# file dumped
# channels to scrape remain:  3350
# UCXN0SJDWW4EGeoVCLAfLYkQ
# file dumped
# channels to scrape remain:  3349
# UCcfS47VXepMM2RqazIKz4BQ
# file dumped
# channels to scrape remain:  3348
# UCKMa5Ifs7IsV_UhCV73tXMQ
# file dumped
# channels to scrape remain:  3347
# UC-NINtNMPM75eaqh07RCy_Q
# file dumped
# channels to scrape remain:  3346
# UCRJNKeG_dGauXnLZuHnTjEA
# file dumped
# channels to scrape remain:  3345
# UCE-GLhKd7iMzDeR1_Wyt6Nw
# file dumped
# channels to scrape remain:  3344
# UCj5EBpBwtO74klDmBTzVmzQ
# file dumped
# channels to scrape remain:  3343
# UCAVgFwnRKj2Ny8M2emfYm9w
# file dumped
# channels to scrape remain:  3342
# UCUqs0iLumESUa1MBXssLf_w
# file dumped
# channels to scrape remain:  3341
# UCFi_m3dUvDD_CL7t-KTHrzA
# file dumped
# channels to scrape remain:  3340
# UCtm5vndJJJM4sYZSTEDd17g
# file dumped
# channels to scrape remain:  3339
# UCWIAbK_LN2oqdNETA2LJCrg
# file dumped
# channels to scrape remain:  3338
# UC6eC9mEH0NOs1Koc47h392Q
# file dumped
# channels to scrape remain:  3337
# UCAk03rcNVtLK1_LlgRTOh2w
# file dumped
# channels to scrape remain:  3336
# UCnClOuzfbOj3ZcUKs2GahjA
# file dumped
# channels to scrape remain:  3335
# UCoC8wK7Hbj1saQUBlFVaJkA
# file dumped
# channels to scrape remain:  3334
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  3333
# UCAVgFwnRKj2Ny8M2emfYm9w
# file dumped
# channels to scrape remain:  3332
# UC48CqsQVp-G-V3dFQ6LJ0LA
# file dumped
# channels to scrape remain:  3331
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  3330
# UC3PAykIfA37sYoFYk72iesQ
# file dumped
# channels to scrape remain:  3329
# UCrm-zm6jheiVfiy2wMZzMBQ
# file dumped
# channels to scrape remain:  3328
# UCdUn5TnxJaLo_H207P-SMzQ
# file dumped
# channels to scrape remain:  3327
# UCeZ08MGEmhSrewV-_NSL1cw
# file dumped
# channels to scrape remain:  3326
# UCSyQKM_hMYbYBJvJz2F3VjQ
# file dumped
# channels to scrape remain:  3325
# UCTdUT-QHtuhZR0xbYVgpR4Q
# file dumped
# channels to scrape remain:  3324
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  3323
# UC6pjkDcsWXfRPf5WJxGCp5Q
# file dumped
# channels to scrape remain:  3322
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  3321
# UCXN0SJDWW4EGeoVCLAfLYkQ
# file dumped
# channels to scrape remain:  3320
# UC5h6RmkA4H-3RpR1wHgGSpA
# file dumped
# channels to scrape remain:  3319
# UChb_swYplE6HjVMRVYTgTTw
# file dumped
# channels to scrape remain:  3318
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  3317
# UCAVgFwnRKj2Ny8M2emfYm9w
# file dumped
# channels to scrape remain:  3316
# UC3l-bobp_xuBlL_lRRS5RmA
# file dumped
# channels to scrape remain:  3315
# UClWiYCxi2SAFw_quShqxQ5g
# file dumped
# channels to scrape remain:  3314
# UCgmvz6qxtga4W6n1mfmM0Zw
# file dumped
# channels to scrape remain:  3313
# UCfq6m31fwbeS-TTxyuQOYng
# file dumped
# channels to scrape remain:  3312
# UCEOVI4AmQE01FDKNFunkV2w
# file dumped
# channels to scrape remain:  3311
# UCinGCtfmkbSTCH7C8BF6HZA
# file dumped
# channels to scrape remain:  3310
# UCQMbf4NfHCJO0WP8NpSqgCA
# file dumped
# channels to scrape remain:  3309
# UCJC50viKXjQTODJX7YLUGvw
# file dumped
# channels to scrape remain:  3308
# UCy2Cra7aLAAMVxkA9rSYCxg
# file dumped
# channels to scrape remain:  3307
# UCp30JTpPVnCpt4SBziyTU1w
# file dumped
# channels to scrape remain:  3306
# UCuLtLhpFF--OV4nogFqi9Zg
# file dumped
# channels to scrape remain:  3305
# UCWIj8e2_-uK1m886ADSYO6g
# file dumped
# channels to scrape remain:  3304
# UCMDE1HTEYGOsr9G2CIPd5Vg
# file dumped
# channels to scrape remain:  3303
# UCAmaiEYnoTgj-dmjp8DpepQ
# file dumped
# channels to scrape remain:  3302
# UCjmJDM5pRKbUlVIzDYYWb6g
# file dumped
# channels to scrape remain:  3301
# UCfwE_ODI1YTbdjkzuSi1Nag
# file dumped
# channels to scrape remain:  3300
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  3299
# UClSq-iF4f5Iek8FC-pT3wkQ
# file dumped
# channels to scrape remain:  3298
# UCS3otpN84Vmnhe8rmf0VsdQ
# file dumped
# channels to scrape remain:  3297
# UC3l-bobp_xuBlL_lRRS5RmA
# file dumped
# channels to scrape remain:  3296
# UC5tNhzKaPN--rZ6qHo4GAVQ
# file dumped
# channels to scrape remain:  3295
# UC-GKXw7ByZRK7sz7NCnLMpQ
# file dumped
# channels to scrape remain:  3294
# UCybF_bgvjVTAPIm8HT-TNdQ
# file dumped
# channels to scrape remain:  3293
# UC8nUp-kTNtu7gGRVG-g4Msg
# file dumped
# channels to scrape remain:  3292
# UC2CSlDXdQl9Zf0amHfVd7aQ
# file dumped
# channels to scrape remain:  3291
# UCAmaiEYnoTgj-dmjp8DpepQ
# file dumped
# channels to scrape remain:  3290
# UCFhdMuy1pMqA9iVXZB7MunA
# file dumped
# channels to scrape remain:  3289
# UCUX2KgYRRNNhnXrSsmgWi6Q
# file dumped
# channels to scrape remain:  3288
# UC4ltvXoxGZobqqduv9iXOWg
# file dumped
# channels to scrape remain:  3287
# UCzFlZQT-2QkstPSqBfRWO8Q
# file dumped
# channels to scrape remain:  3286
# UC8AGq7bm-x4teGcvQonvnPw
# file dumped
# channels to scrape remain:  3285
# UCAmaiEYnoTgj-dmjp8DpepQ
# file dumped
# channels to scrape remain:  3284
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  3283
# UCqW9ZAW0ZNqfWo9PZ3OX4Fg
# file dumped
# channels to scrape remain:  3282
# UCfwE_ODI1YTbdjkzuSi1Nag
# file dumped
# channels to scrape remain:  3281
# UCQ83TInb9qtvdjErDxs2JCw
# file dumped
# channels to scrape remain:  3280
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  3279
# UCjxnmLLbrw-Yn9o6J68XWkw
# file dumped
# channels to scrape remain:  3278
# UCZ0o1IeuSSceEixZbSATWtw
# file dumped
# channels to scrape remain:  3277
# UCAk03rcNVtLK1_LlgRTOh2w
# file dumped
# channels to scrape remain:  3276
# UCVDzOO4rzuAniSmow_un0Kw
# file dumped
# channels to scrape remain:  3275
# UCOuZ1mCRvbQseTiDff9m-YA
# file dumped
# channels to scrape remain:  3274
# UCJ6nMHaJPZvsJ-HmUmj1SeA
# file dumped
# channels to scrape remain:  3273
# UCjFzDGMRSpfdPwqT4din1AA
# file dumped
# channels to scrape remain:  3272
# UC_E5g3anvlGVhwcMprbYhxQ
# file dumped
# channels to scrape remain:  3271
# UCjp0v7iYfhkn6da7IYKq8Yw
# file dumped
# channels to scrape remain:  3270
# UC-lZTlG05ETwyjDS1JQCv3w
# file dumped
# channels to scrape remain:  3269
# UCwRGjo8e3mmgoOpEkClTD0w
# file dumped
# channels to scrape remain:  3268
# UCos9SEOxvUbckVfr3eQISzw
# file dumped
# channels to scrape remain:  3267
# UCAk03rcNVtLK1_LlgRTOh2w
# file dumped
# channels to scrape remain:  3266
# UCRJNKeG_dGauXnLZuHnTjEA
# file dumped
# channels to scrape remain:  3265
# UCHr2DeHbsqHNqt5-jK5-36Q
# file dumped
# channels to scrape remain:  3264
# UCbxjDfYwfF8RjYBp5htJ38Q
# file dumped
# channels to scrape remain:  3263
# UCalfv1kRCXYcQsTymuBSirQ
# file dumped
# channels to scrape remain:  3262
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  3261
# UCZ8Sxmkweh65HetaZfR8YuA
# file dumped
# channels to scrape remain:  3260
# UCda8lNA3iwSoV1r3o-ViEhQ
# file dumped
# channels to scrape remain:  3259
# UCLtmbjOdwqGzOGAuGEoUlHQ
# file dumped
# channels to scrape remain:  3258
# UCAjuNg3wPDs1MVwdrRyOcBw
# file dumped
# channels to scrape remain:  3257
# UC_jwYANHgWXCa6wReG5gCvg
# file dumped
# channels to scrape remain:  3256
# UCHr2DeHbsqHNqt5-jK5-36Q
# file dumped
# channels to scrape remain:  3255
# UCIQ5iN8wzGkKyXJeX6eR50Q
# file dumped
# channels to scrape remain:  3254
# UCqmQ5X4Y036ZGz3JUx77JVg
# file dumped
# channels to scrape remain:  3253
# UC4ltvXoxGZobqqduv9iXOWg
# file dumped
# channels to scrape remain:  3252
# UCi-Z5K5YUAAiWNhP2x6UjNw
# file dumped
# channels to scrape remain:  3251
# UC-lZTlG05ETwyjDS1JQCv3w
# file dumped
# channels to scrape remain:  3250
# UCcrXOqPJU1uaXJLlH2ZYvtQ
# file dumped
# channels to scrape remain:  3249
# UCs5aTnqCZunCSZ7nxBBtXCQ
# file dumped
# channels to scrape remain:  3248
# UCqh7RMx5BPU9k0D3MAVtGQg
# file dumped
# channels to scrape remain:  3247
# UCYagkFew0HvUXKxxPjlCBHA
# file dumped
# channels to scrape remain:  3246
# UCAmaiEYnoTgj-dmjp8DpepQ
# file dumped
# channels to scrape remain:  3245
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  3244
# UCgZxH5cl_o4iFQRF1CLD9yA
# file dumped
# channels to scrape remain:  3243
# UCt5xAxvpEaJz90G1kEd9RiQ
# file dumped
# channels to scrape remain:  3242
# UC-lZTlG05ETwyjDS1JQCv3w
# file dumped
# channels to scrape remain:  3241
# UCqh7RMx5BPU9k0D3MAVtGQg
# file dumped
# channels to scrape remain:  3240
# UCIQz7nN_zTfIoSOh7HasYIQ
# file dumped
# channels to scrape remain:  3239
# UCAmaiEYnoTgj-dmjp8DpepQ
# file dumped
# channels to scrape remain:  3238
# UCdBOfjkrFNvuC_GHImBStDA
# file dumped
# channels to scrape remain:  3237
# UCWOV10ZmdWhMupb_pVdT3ig
# file dumped
# channels to scrape remain:  3236
# UCAmaiEYnoTgj-dmjp8DpepQ
# file dumped
# channels to scrape remain:  3235
# UCJuq64HSc8KWJ3grvDrU3VA
# file dumped
# channels to scrape remain:  3234
# UClG1AcuVOU5Cn-ivHm3JRoA
# file dumped
# channels to scrape remain:  3233
# UC4ltvXoxGZobqqduv9iXOWg
# file dumped
# channels to scrape remain:  3232
# UCjFzDGMRSpfdPwqT4din1AA
# file dumped
# channels to scrape remain:  3231
# UClx_IR8_yVIKdFVUTdmaZTw
# file dumped
# channels to scrape remain:  3230
# UCVrD2WcTHwTJo4A2r0mjK1A
# file dumped
# channels to scrape remain:  3229
# UCItUt3WERyBpO7bSQ6YRzKw
# file dumped
# channels to scrape remain:  3228
# UCZ0o1IeuSSceEixZbSATWtw
# file dumped
# channels to scrape remain:  3227
# UCtgJ0VMkNcHscJbyeVQc1yg
# file dumped
# channels to scrape remain:  3226
# UC76Ox8Kmn2RGXdm8A1EJoPQ
# file dumped
# channels to scrape remain:  3225
# UCx2ElriDd7dvqIfDj4qKAtA
# file dumped
# channels to scrape remain:  3224
# UCiP2WApQujz37NquEZqekrQ
# file dumped
# channels to scrape remain:  3223
# UCMn_W4pe7msJS77koaT96gg
# file dumped
# channels to scrape remain:  3222
# UCaznLylX-htDnmx4rafzuFQ
# file dumped
# channels to scrape remain:  3221
# UCONY2iGTxZGV-2dBcOq8c7Q
# file dumped
# channels to scrape remain:  3220
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  3219
# UC-lZTlG05ETwyjDS1JQCv3w
# file dumped
# channels to scrape remain:  3218
# UCzcRQ3vRNr6fJ1A9rqFn7QA
# file dumped
# channels to scrape remain:  3217
# UCZJJTxA36ZPNTJ1WFIByaeA
# file dumped
# channels to scrape remain:  3216
# UCmxfZa-sV27MUDqy-iJIsfA
# file dumped
# channels to scrape remain:  3215
# UCna9xXPjpvLC1o1VqNSuq_w
# file dumped
# channels to scrape remain:  3214
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  3213
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  3212
# UCJpDZpmL5dAMnxx4hDMzPxw
# file dumped
# channels to scrape remain:  3211
# UC6aXQXanIVFmwTd1JvBm0cw
# file dumped
# channels to scrape remain:  3210
# UCu-cVVMn41qUA-pwdEhNqhg
# file dumped
# channels to scrape remain:  3209
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  3208
# UCjyPrt8jLXObFQfp2S7cqPg
# file dumped
# channels to scrape remain:  3207
# UCm0UlppNLh97fSBWdcIYjPg
# file dumped
# channels to scrape remain:  3206
# UCVxzTQDruKuxiHvK36BSYkQ
# file dumped
# channels to scrape remain:  3205
# UC_qhUbjKaM1bKaBT2urtC0g
# file dumped
# channels to scrape remain:  3204
# UCIZdrburxQ6Yp_Kvc5pHCGg
# file dumped
# channels to scrape remain:  3203
# UCKaEE1L7e8n2fE6PUz7ST9w
# file dumped
# channels to scrape remain:  3202
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  3201
# UCD1g6bvkci2-M48sgI-lTXQ
# file dumped
# channels to scrape remain:  3200
# UCclc80TgD5XVehdYNXEx59w
# file dumped
# channels to scrape remain:  3199
# UCbPP62WclGeB9sdlMcqkwOA
# file dumped
# channels to scrape remain:  3198
# UC3xYBkXU07A4R6MlvqGT0gg
# file dumped
# channels to scrape remain:  3197
# UCkbTToezbJlEr5qCOpU_BVA
# nothing happend
# channels to scrape remain:  3196
# UCac3z1rgsgOUXYPd46osebQ
# file dumped
# channels to scrape remain:  3195
# UC-lZTlG05ETwyjDS1JQCv3w
# file dumped
# channels to scrape remain:  3194
# UC_jwYANHgWXCa6wReG5gCvg
# file dumped
# channels to scrape remain:  3193
# UCQMbf4NfHCJO0WP8NpSqgCA
# file dumped
# channels to scrape remain:  3192
# UCt5xAxvpEaJz90G1kEd9RiQ
# file dumped
# channels to scrape remain:  3191
# UCt80DwpQzBKscH2zg9pX_DA
# file dumped
# channels to scrape remain:  3190
# UCKnjJVc0H1g9O5utg1U-E6Q
# file dumped
# channels to scrape remain:  3189
# UCKfpsoVQFEgiXpxFbZjBgnA
# file dumped
# channels to scrape remain:  3188
# UC2fzD8sT3wsmNpxyNuAxSCQ
# file dumped
# channels to scrape remain:  3187
# UCgZxH5cl_o4iFQRF1CLD9yA
# file dumped
# channels to scrape remain:  3186
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  3185
# UCAmaiEYnoTgj-dmjp8DpepQ
# file dumped
# channels to scrape remain:  3184
# UC60GSF5j14YvwWS96lmB2Rg
# file dumped
# channels to scrape remain:  3183
# UCO6cSNvOaDs-kjALLQLNhQw
# file dumped
# channels to scrape remain:  3182
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  3181
# UCG2QYlhnYYxksvv6ve11ijw
# file dumped
# channels to scrape remain:  3180
# UCmxfZa-sV27MUDqy-iJIsfA
# file dumped
# channels to scrape remain:  3179
# UC-lZTlG05ETwyjDS1JQCv3w
# file dumped
# channels to scrape remain:  3178
# UCNi0Nkb2HOEGFFZRMu9tMTg
# file dumped
# channels to scrape remain:  3177
# UCna9xXPjpvLC1o1VqNSuq_w
# file dumped
# channels to scrape remain:  3176
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  3175
# UClhBBawGA38WrFjrYfQlyHg
# file dumped
# channels to scrape remain:  3174
# UCgKkNPU2Ib7_TcyAl8M2S-w
# file dumped
# channels to scrape remain:  3173
# UC10GoVi7dXvXcXHE6NqRuhg
# file dumped
# channels to scrape remain:  3172
# UCD1g6bvkci2-M48sgI-lTXQ
# file dumped
# channels to scrape remain:  3171
# UCPvmpCN7gyaTTdkMAo8VtEw
# file dumped
# channels to scrape remain:  3170
# UCES5EABu77gRm8F80k0rc3Q
# file dumped
# channels to scrape remain:  3169
# UCpc9YphcwZ1dFKq2OUkEWvw
# file dumped
# channels to scrape remain:  3168
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  3167
# UCUwneOC8l4m9T0ype97vFIA
# file dumped
# channels to scrape remain:  3166
# UCpc9YphcwZ1dFKq2OUkEWvw
# file dumped
# channels to scrape remain:  3165
# UC6YOUpbbJduVEb42qF9pMVQ
# file dumped
# channels to scrape remain:  3164
# UCMn_W4pe7msJS77koaT96gg
# file dumped
# channels to scrape remain:  3163
# UCybF_bgvjVTAPIm8HT-TNdQ
# file dumped
# channels to scrape remain:  3162
# UCZ0o1IeuSSceEixZbSATWtw
# file dumped
# channels to scrape remain:  3161
# UCD7RnjScQO2i0Q8xlyKlJkw
# file dumped
# channels to scrape remain:  3160
# UC_qE8B3s4O-zEgOBT4A9X5w
# file dumped
# channels to scrape remain:  3159
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  3158
# UCmvw85F2N6Hb1EOvkismODQ
# file dumped
# channels to scrape remain:  3157
# UCbEXJssKERaJXrYZvyTj0gA
# file dumped
# channels to scrape remain:  3156
# UC-lZTlG05ETwyjDS1JQCv3w
# file dumped
# channels to scrape remain:  3155
# UCnVLwveOtxRSS8wXYYWrVGA
# file dumped
# channels to scrape remain:  3154
# UC62XKn6Htc8tjNVBAoiriIg
# file dumped
# channels to scrape remain:  3153
# UC3uyGOSfgQFpBK7KI6qAgdA
# file dumped
# channels to scrape remain:  3152
# UCxPZ3c5xIVuw9KSNFpGIzMw
# file dumped
# channels to scrape remain:  3151
# UCPop3S-D5ZN716l-LtzHWQA
# file dumped
# channels to scrape remain:  3150
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  3149
# UCHSRXOvnz0Nmq7WJrmaAUxA
# file dumped
# channels to scrape remain:  3148
# UCP5Q315vMoQoMWUukmWOGGw
# file dumped
# channels to scrape remain:  3147
# UCu-cVVMn41qUA-pwdEhNqhg
# file dumped
# channels to scrape remain:  3146
# UCmQynT5NWU3Vsa9t0OGUhcA
# file dumped
# channels to scrape remain:  3145
# UC4ltvXoxGZobqqduv9iXOWg
# file dumped
# channels to scrape remain:  3144
# UCNRpbMhrfnrKLRLahNDIQeg
# file dumped
# channels to scrape remain:  3143
# UCFHaCjqbt5xz8L-pQnLY92A
# file dumped
# channels to scrape remain:  3142
# UC-lZTlG05ETwyjDS1JQCv3w
# file dumped
# channels to scrape remain:  3141
# UCmvw85F2N6Hb1EOvkismODQ
# file dumped
# channels to scrape remain:  3140
# UCArIYwZmtyhk5mZH8jhlhLA
# file dumped
# channels to scrape remain:  3139
# UC7wfDXJFvF7VIBbZBYce3pQ
# file dumped
# channels to scrape remain:  3138
# UC_9X5BZaKmRBGfu-J5myoOg
# file dumped
# channels to scrape remain:  3137
# UCUUCl-8jhe9r79W6hdegRjg
# file dumped
# channels to scrape remain:  3136
# UCG2QYlhnYYxksvv6ve11ijw
# file dumped
# channels to scrape remain:  3135
# UChOGMlGxF1vDD4bfH60H3hQ
# file dumped
# channels to scrape remain:  3134
# UC5tNhzKaPN--rZ6qHo4GAVQ
# file dumped
# channels to scrape remain:  3133
# UCqGjEbwn6wGz1QYCtKV2yig
# file dumped
# channels to scrape remain:  3132
# UCWxzChFQLLvFEx-S8n7zoaQ
# file dumped
# channels to scrape remain:  3131
# UC-lZTlG05ETwyjDS1JQCv3w
# file dumped
# channels to scrape remain:  3130
# UCzj5pofLaoZmp4ILL9dg4dA
# file dumped
# channels to scrape remain:  3129
# UC0axkTk6m1is8iWJKqKXgtQ
# file dumped
# channels to scrape remain:  3128
# UC4ltvXoxGZobqqduv9iXOWg
# file dumped
# channels to scrape remain:  3127
# UCAmaiEYnoTgj-dmjp8DpepQ
# file dumped
# channels to scrape remain:  3126
# UCdhFkH_ekHNWby6c0vLBHKw
# file dumped
# channels to scrape remain:  3125
# UCJ1_1KIoIejboQ5lb8UXQ2A
# file dumped
# channels to scrape remain:  3124
# UCbplxuhHAQpRgYDgwgyHqpQ
# file dumped
# channels to scrape remain:  3123
# UCACDRb6GqitLOFNYOmIrTRw
# file dumped
# channels to scrape remain:  3122
# UCzRokyPmIDG7HzQzn84yDNw
# file dumped
# channels to scrape remain:  3121
# UC-lZTlG05ETwyjDS1JQCv3w
# file dumped
# channels to scrape remain:  3120
# UCO6cSNvOaDs-kjALLQLNhQw
# file dumped
# channels to scrape remain:  3119
# UCGl9hxFXep_3KMe662E_pzQ
# file dumped
# channels to scrape remain:  3118
# UCtsOFYS141nQ4znc_9xpFDQ
# file dumped
# channels to scrape remain:  3117
# UCNL6Rxxy-LtEdwH3YPbVS2g
# file dumped
# channels to scrape remain:  3116
# UC3KEiIZBtsTB6P7278uKuug
# file dumped
# channels to scrape remain:  3115
# UCjmJDM5pRKbUlVIzDYYWb6g
# file dumped
# channels to scrape remain:  3114
# UClHSA6ckj_gqIFDjDpLgsNg
# file dumped
# channels to scrape remain:  3113
# UCHZnVxVND4LXp6fObt0wFaw
# file dumped
# channels to scrape remain:  3112
# UCO2EFMFF07y9BikFGKGIlkw
# file dumped
# channels to scrape remain:  3111
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  3110
# UCM1tL-yyv9CUTs-vXxHEofg
# file dumped
# channels to scrape remain:  3109
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  3108
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  3107
# UC5uPWsBlTy0kP5g_ykrAPMQ
# file dumped
# channels to scrape remain:  3106
# UCGATWHffIVA_RKfyekWJ5-Q
# file dumped
# channels to scrape remain:  3105
# UC6vegmfG_dKUtqIkDQi5BAQ
# file dumped
# channels to scrape remain:  3104
# UCAmaiEYnoTgj-dmjp8DpepQ
# file dumped
# channels to scrape remain:  3103
# UCCdicbO4cLE4s1wbXjJSuSg
# file dumped
# channels to scrape remain:  3102
# UCmxfZa-sV27MUDqy-iJIsfA
# file dumped
# channels to scrape remain:  3101
# UCdXfiJzQiZvmDWclb0M4j_A
# file dumped
# channels to scrape remain:  3100
# UCt8NFgdPp4Now_jBogXc-bg
# file dumped
# channels to scrape remain:  3099
# UC3l-bobp_xuBlL_lRRS5RmA
# file dumped
# channels to scrape remain:  3098
# UCL89Opg7KVwX7CWE9IVOHlQ
# file dumped
# channels to scrape remain:  3097
# UCwBV-eg1dAkzrdjqJfyEj0w
# file dumped
# channels to scrape remain:  3096
# UC3l-bobp_xuBlL_lRRS5RmA
# file dumped
# channels to scrape remain:  3095
# UCcvD8ANBq3H9i1ozzznAn1A
# file dumped
# channels to scrape remain:  3094
# UCAmaiEYnoTgj-dmjp8DpepQ
# file dumped
# channels to scrape remain:  3093
# UC0_qB62KPUmZwiZ3g8JjZfA
# file dumped
# channels to scrape remain:  3092
# UClx_IR8_yVIKdFVUTdmaZTw
# file dumped
# channels to scrape remain:  3091
# UCAnLJyjTg5la5qJuLkakQig
# file dumped
# channels to scrape remain:  3090
# UC-lZTlG05ETwyjDS1JQCv3w
# file dumped
# channels to scrape remain:  3089
# UC-lZTlG05ETwyjDS1JQCv3w
# file dumped
# channels to scrape remain:  3088
# UCUwneOC8l4m9T0ype97vFIA
# file dumped
# channels to scrape remain:  3087
# UCeDfJbQQxvcZjNqswM4cQTA
# file dumped
# channels to scrape remain:  3086
# UCTxu216Ebjanl7G5k9C61yw
# file dumped
# channels to scrape remain:  3085
# UC24GN7KQmW-KZJXpIAT7oOA
# file dumped
# channels to scrape remain:  3084
# UCDLVW6ZaqZ8YGXXEab0ubYA
# file dumped
# channels to scrape remain:  3083
# UCpek-Cvj0yf18HMupt1hBhA
# file dumped
# channels to scrape remain:  3082
# UC7d_K-X7zCQM2iLyIijinTA
# file dumped
# channels to scrape remain:  3081
# UC-lZTlG05ETwyjDS1JQCv3w
# file dumped
# channels to scrape remain:  3080
# UCzyUP8w1KCVqFNvX5EtwaMw
# file dumped
# channels to scrape remain:  3079
# UCAmaiEYnoTgj-dmjp8DpepQ
# file dumped
# channels to scrape remain:  3078
# UCRTovm1XtDKp0CMvwZPGTzA
# file dumped
# channels to scrape remain:  3077
# UCeQ3wOcF4tkm_vQHEC2jY1w
# file dumped
# channels to scrape remain:  3076
# UCjmJDM5pRKbUlVIzDYYWb6g
# file dumped
# channels to scrape remain:  3075
# UCjmJDM5pRKbUlVIzDYYWb6g
# file dumped
# channels to scrape remain:  3074
# UCgTOAPMLldS_vZsJQJiW4kA
# file dumped
# channels to scrape remain:  3073
# UCGEd23xt1Kqz3-K-ZqBj5VQ
# file dumped
# channels to scrape remain:  3072
# UC-lZTlG05ETwyjDS1JQCv3w
# file dumped
# channels to scrape remain:  3071
# UCQjEve3u8tXBUYvXxeD1cuQ
# file dumped
# channels to scrape remain:  3070
# UCIijZcLhEp9EmkuPaCPwHbQ
# file dumped
# channels to scrape remain:  3069
# UCIQz7nN_zTfIoSOh7HasYIQ
# file dumped
# channels to scrape remain:  3068
# UC-lZTlG05ETwyjDS1JQCv3w
# file dumped
# channels to scrape remain:  3067
# UCA3w_6AdBOkrHhbAQkDA90Q
# file dumped
# channels to scrape remain:  3066
# UCqtc118chzxCUJExjeWbeEA
# file dumped
# channels to scrape remain:  3065
# UCwzpRsY9c1HNsJ8d4_2POJQ
# file dumped
# channels to scrape remain:  3064
# UC-lZTlG05ETwyjDS1JQCv3w
# file dumped
# channels to scrape remain:  3063
# UCZnEaY0PbgBPrcIvVZg27RQ
# file dumped
# channels to scrape remain:  3062
# UCzyUP8w1KCVqFNvX5EtwaMw
# file dumped
# channels to scrape remain:  3061
# UCygApzSdzKTm1UBccs9Bmdw
# file dumped
# channels to scrape remain:  3060
# UCwYzZs_hwA6NdaQp6Hjhe5w
# file dumped
# channels to scrape remain:  3059
# UC79ARH3OohgqqBdgMetw3Nw
# file dumped
# channels to scrape remain:  3058
# UC8msOgi2CPRQKqwSK-nKwtA
# file dumped
# channels to scrape remain:  3057
# UCkvlsiTVge8_oWjjw6Z5bCw
# file dumped
# channels to scrape remain:  3056
# UCxwx0lV-rfH4CsZNeRqcKhw
# file dumped
# channels to scrape remain:  3055
# UCQMbf4NfHCJO0WP8NpSqgCA
# file dumped
# channels to scrape remain:  3054
# UCgZxH5cl_o4iFQRF1CLD9yA
# file dumped
# channels to scrape remain:  3053
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  3052
# UCLGQyKSBZVMn1R1iyrTWv1Q
# file dumped
# channels to scrape remain:  3051
# UC-bk3CDvTwt2TqPHykduhcQ
# file dumped
# channels to scrape remain:  3050
# UC7JGB6SrWxxeU33FHvffBBg
# file dumped
# channels to scrape remain:  3049
# UCE4iQ0PViAhzJ3PhOQfc70Q
# file dumped
# channels to scrape remain:  3048
# UCmxfZa-sV27MUDqy-iJIsfA
# file dumped
# channels to scrape remain:  3047
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  3046
# UC9ctsJZ2aD1nCexfqj342NQ
# file dumped
# channels to scrape remain:  3045
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  3044
# UC_9X5BZaKmRBGfu-J5myoOg
# file dumped
# channels to scrape remain:  3043
# UCjFzDGMRSpfdPwqT4din1AA
# file dumped
# channels to scrape remain:  3042
# UCiP2WApQujz37NquEZqekrQ
# file dumped
# channels to scrape remain:  3041
# UCGA2OgjW608QEaGwxA7aRTg
# file dumped
# channels to scrape remain:  3040
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  3039
# UCGA2OgjW608QEaGwxA7aRTg
# file dumped
# channels to scrape remain:  3038
# UCRODg1zhbcN8btCqpOe5NiA
# file dumped
# channels to scrape remain:  3037
# UCMESKXGTElMLFhB58ayLOwQ
# file dumped
# channels to scrape remain:  3036
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  3035
# UCDe64ULdc_aBcjmVT5je-WA
# file dumped
# channels to scrape remain:  3034
# UC-lZTlG05ETwyjDS1JQCv3w
# file dumped
# channels to scrape remain:  3033
# UCG2QYlhnYYxksvv6ve11ijw
# file dumped
# channels to scrape remain:  3032
# UCFJ6uYN--i-X3v01iyNXRQA
# file dumped
# channels to scrape remain:  3031
# UCS45_hLgexn49BUqbsYyooA
# file dumped
# channels to scrape remain:  3030
# UCAk03rcNVtLK1_LlgRTOh2w
# file dumped
# channels to scrape remain:  3029
# UC_9X5BZaKmRBGfu-J5myoOg
# file dumped
# channels to scrape remain:  3028
# UCaqWE7d5A3A-YRXHOy4-C0w
# file dumped
# channels to scrape remain:  3027
# UCHTK-2W11Vh1V4uwofOfR4w
# file dumped
# channels to scrape remain:  3026
# UCjnFMWzN9Q3wHvqCQ-N1w-Q
# file dumped
# channels to scrape remain:  3025
# UCG2QYlhnYYxksvv6ve11ijw
# file dumped
# channels to scrape remain:  3024
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  3023
# UCuLtLhpFF--OV4nogFqi9Zg
# file dumped
# channels to scrape remain:  3022
# UC2NIZzZPU8rv21an6do_w6A
# file dumped
# channels to scrape remain:  3021
# UCpqBUBMaK1-Myi1xTWPLW6g
# file dumped
# channels to scrape remain:  3020
# UCfy9oXYEdsQqUq15--Esm-A
# file dumped
# channels to scrape remain:  3019
# UCAk03rcNVtLK1_LlgRTOh2w
# file dumped
# channels to scrape remain:  3018
# UCEYiwJvGVvl0TvQPOGh1aOw
# file dumped
# channels to scrape remain:  3017
# UCAk03rcNVtLK1_LlgRTOh2w
# file dumped
# channels to scrape remain:  3016
# UCLHyr--aSt6c7TLJf9fQeEA
# file dumped
# channels to scrape remain:  3015
# UCghETqJXjCtbiRJsEv8Ir8g
# file dumped
# channels to scrape remain:  3014
# UCTHaIqxDrVasKbUVhcB4OVg
# file dumped
# channels to scrape remain:  3013
# UCmxfZa-sV27MUDqy-iJIsfA
# file dumped
# channels to scrape remain:  3012
# UCu-cVVMn41qUA-pwdEhNqhg
# file dumped
# channels to scrape remain:  3011
# UC8AGq7bm-x4teGcvQonvnPw
# file dumped
# channels to scrape remain:  3010
# UC6i6OnrKWGEfZSmVpoS_ilA
# file dumped
# channels to scrape remain:  3009
# UC8AGq7bm-x4teGcvQonvnPw
# file dumped
# channels to scrape remain:  3008
# UCbxjDfYwfF8RjYBp5htJ38Q
# file dumped
# channels to scrape remain:  3007
# UC8mQqnYuQVHTrCszwIAniLg
# file dumped
# channels to scrape remain:  3006
# UCgKkNPU2Ib7_TcyAl8M2S-w
# file dumped
# channels to scrape remain:  3005
# UCMDE1HTEYGOsr9G2CIPd5Vg
# file dumped
# channels to scrape remain:  3004
# UCAk03rcNVtLK1_LlgRTOh2w
# file dumped
# channels to scrape remain:  3003
# UCAk03rcNVtLK1_LlgRTOh2w
# file dumped
# channels to scrape remain:  3002
# UCIQ5iN8wzGkKyXJeX6eR50Q
# file dumped
# channels to scrape remain:  3001
# UC8AGq7bm-x4teGcvQonvnPw
# file dumped
# channels to scrape remain:  3000
# UC8AGq7bm-x4teGcvQonvnPw
# file dumped
# channels to scrape remain:  2999
# UCyikCi8MF1Bx4tpJEy2BSqw
# file dumped
# channels to scrape remain:  2998
# UCL7G6E5Gd0Ck0ZmhkDWr7Yw
# file dumped
# channels to scrape remain:  2997
# UCrz0vkmhuAEEVk6EimcnYLQ
# file dumped
# channels to scrape remain:  2996
# UCgKkNPU2Ib7_TcyAl8M2S-w
# file dumped
# channels to scrape remain:  2995
# UCO-CGWElPtF4jz6FlDiI_UQ
# file dumped
# channels to scrape remain:  2994
# UCu-cVVMn41qUA-pwdEhNqhg
# file dumped
# channels to scrape remain:  2993
# UC8AGq7bm-x4teGcvQonvnPw
# file dumped
# channels to scrape remain:  2992
# UCu-cVVMn41qUA-pwdEhNqhg
# file dumped
# channels to scrape remain:  2991
# UCqh7RMx5BPU9k0D3MAVtGQg
# file dumped
# channels to scrape remain:  2990
# UCmz5OJtgli-1XfSpeVINqXg
# file dumped
# channels to scrape remain:  2989
# UCYyDbdaja1UDNdFSwUrYVGA
# file dumped
# channels to scrape remain:  2988
# UClx_IR8_yVIKdFVUTdmaZTw
# file dumped
# channels to scrape remain:  2987
# UCzuyI_oLbWMSejvh11TKUfQ
# file dumped
# channels to scrape remain:  2986
# UCIWAE43G_fgePOrolgdOpjA
# file dumped
# channels to scrape remain:  2985
# UCAk03rcNVtLK1_LlgRTOh2w
# file dumped
# channels to scrape remain:  2984
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  2983
# UCO6cSNvOaDs-kjALLQLNhQw
# file dumped
# channels to scrape remain:  2982
# UCSeEPeq9Neg3rZ0kq7Hc8_Q
# file dumped
# channels to scrape remain:  2981
# UC8AGq7bm-x4teGcvQonvnPw
# file dumped
# channels to scrape remain:  2980
# UCVDzOO4rzuAniSmow_un0Kw
# file dumped
# channels to scrape remain:  2979
# UC0tsYkrfiuj_8nV962jBdmw
# file dumped
# channels to scrape remain:  2978
# UCj0n0297y1dga0zqlkL7Heg
# file dumped
# channels to scrape remain:  2977
# UCR4a3ZaMqmIEBJvmRz4HafA
# file dumped
# channels to scrape remain:  2976
# UCu-cVVMn41qUA-pwdEhNqhg
# file dumped
# channels to scrape remain:  2975
# UClx_IR8_yVIKdFVUTdmaZTw
# file dumped
# channels to scrape remain:  2974
# UC3l-bobp_xuBlL_lRRS5RmA
# file dumped
# channels to scrape remain:  2973
# UCu-cVVMn41qUA-pwdEhNqhg
# file dumped
# channels to scrape remain:  2972
# UCXRwN5Tuq8ALPoTZgvI9KFQ
# file dumped
# channels to scrape remain:  2971
# UCbxjDfYwfF8RjYBp5htJ38Q
# file dumped
# channels to scrape remain:  2970
# UCFciR4fFWh_V6aS_2qHLFiA
# file dumped
# channels to scrape remain:  2969
# UCdbGmGftDi8dq4Zz5GAh-Kg
# file dumped
# channels to scrape remain:  2968
# UCbplxuhHAQpRgYDgwgyHqpQ
# file dumped
# channels to scrape remain:  2967
# UCZzFwj4uCJHEwD1s1h3ky7A
# file dumped
# channels to scrape remain:  2966
# UC_nG5aisxOrTsnCarnytxVw
# file dumped
# channels to scrape remain:  2965
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  2964
# UCjmJDM5pRKbUlVIzDYYWb6g
# file dumped
# channels to scrape remain:  2963
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  2962
# UCG2QYlhnYYxksvv6ve11ijw
# file dumped
# channels to scrape remain:  2961
# UC8AGq7bm-x4teGcvQonvnPw
# file dumped
# channels to scrape remain:  2960
# UCD9mhWv66iXbjAPfcdpRETA
# file dumped
# channels to scrape remain:  2959
# UCfzvM8Wy5Y34jrxXKmq69Dg
# file dumped
# channels to scrape remain:  2958
# UCrJ-Fv5oIEbIk8qcVqqQS_A
# file dumped
# channels to scrape remain:  2957
# UCO6cSNvOaDs-kjALLQLNhQw
# file dumped
# channels to scrape remain:  2956
# UCcrXOqPJU1uaXJLlH2ZYvtQ
# file dumped
# channels to scrape remain:  2955
# UCHvnMsLnyQZscrq-fOckiiw
# file dumped
# channels to scrape remain:  2954
# UC2jXtsIZXdy6uAjEg1zyMYg
# file dumped
# channels to scrape remain:  2953
# UCAmaiEYnoTgj-dmjp8DpepQ
# file dumped
# channels to scrape remain:  2952
# UCtGeReZOXJ1WLmUzkeuvr-g
# file dumped
# channels to scrape remain:  2951
# UCt6R11TR39h8J7Py33JzG3w
# file dumped
# channels to scrape remain:  2950
# UCdtXPiqI2cLorKaPrfpKc4g
# file dumped
# channels to scrape remain:  2949
# UCRTXfZSZq9RVWKcIO8nXXaA
# file dumped
# channels to scrape remain:  2948
# UCcrXOqPJU1uaXJLlH2ZYvtQ
# file dumped
# channels to scrape remain:  2947
# UCj8gILpOgOIX6k3NExdky9Q
# file dumped
# channels to scrape remain:  2946
# UCv5vbEwaUh0LO6dwVa0iVEw
# file dumped
# channels to scrape remain:  2945
# UCO6cSNvOaDs-kjALLQLNhQw
# file dumped
# channels to scrape remain:  2944
# UCbiT0LUIbQj6CQScvWHJeKQ
# file dumped
# channels to scrape remain:  2943
# UCuWeBHxVe6C69JTBpiY-Y8Q
# file dumped
# channels to scrape remain:  2942
# UCDi89zKKAOE-5IBMcEVmDWw
# file dumped
# channels to scrape remain:  2941
# UCIKQ--H8rzvD7WXsdsJhPbA
# file dumped
# channels to scrape remain:  2940
# UCNORzM683gWkYFoAJOkpkyw
# file dumped
# channels to scrape remain:  2939
# UCRJNKeG_dGauXnLZuHnTjEA
# file dumped
# channels to scrape remain:  2938
# UCMdrlq5FxUwG8Lmf0GOuD7g
# file dumped
# channels to scrape remain:  2937
# UC04Oq9LYYryzq9uTXKaQ6WQ
# file dumped
# channels to scrape remain:  2936
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  2935
# UC0jZ4LEA9d56SFONhGh6_xg
# file dumped
# channels to scrape remain:  2934
# UCzVc7Mv2L7hR1k4nNTvORgQ
# file dumped
# channels to scrape remain:  2933
# UCbNgKGd9ltgeYyio-PRAOOA
# file dumped
# channels to scrape remain:  2932
# UCX_RUMooJKyFjkPh5xJgtPQ
# file dumped
# channels to scrape remain:  2931
# UCR4wTAyVbbX-IiBiGCgIBTg
# file dumped
# channels to scrape remain:  2930
# UC2KekYVX0xHLa4G9WmcIeJQ
# file dumped
# channels to scrape remain:  2929
# UCt5xAxvpEaJz90G1kEd9RiQ
# file dumped
# channels to scrape remain:  2928
# UCdtXPiqI2cLorKaPrfpKc4g
# file dumped
# channels to scrape remain:  2927
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  2926
# UCrQXfvJFnC8qTc064vM0U-Q
# file dumped
# channels to scrape remain:  2925
# UCLqKx4XooKe4fBuL9Xm9Lbg
# file dumped
# channels to scrape remain:  2924
# UCx01RPMx7FHkxX4mSGmUCtg
# file dumped
# channels to scrape remain:  2923
# UCE8aa83wFg-VE1zcaVCZdIA
# file dumped
# channels to scrape remain:  2922
# UCZc51rYiUbdGj7cbah53M-A
# file dumped
# channels to scrape remain:  2921
# UC_Atf2Fw8nR8kOb40fA24DA
# file dumped
# channels to scrape remain:  2920
# UCNPxjrBh3_YJkwwjoiHMW5g
# file dumped
# channels to scrape remain:  2919
# UCRvXN-ffIKnW0vY9c5n1yFw
# file dumped
# channels to scrape remain:  2918
# UCbiT0LUIbQj6CQScvWHJeKQ
# file dumped
# channels to scrape remain:  2917
# UC3gNmTGu-TTbFPpfSs5kNkg
# file dumped
# channels to scrape remain:  2916
# UCW2txsxMhJ4ye1mY8diR3Zw
# file dumped
# channels to scrape remain:  2915
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  2914
# UCzcRQ3vRNr6fJ1A9rqFn7QA
# file dumped
# channels to scrape remain:  2913
# UCBWE3D00E5Y8mvyjKEvLFWw
# file dumped
# channels to scrape remain:  2912
# UCqhUJp9rCgcpZg3TsTxBGsA
# file dumped
# channels to scrape remain:  2911
# UCt5xAxvpEaJz90G1kEd9RiQ
# file dumped
# channels to scrape remain:  2910
# UCfupACwUQmP2H6pDehATVXA
# file dumped
# channels to scrape remain:  2909
# UCmCCkvYB9vYZd_WNd2dY50g
# file dumped
# channels to scrape remain:  2908
# UCNjc2f7zhhRUs5ric61Eg1Q
# file dumped
# channels to scrape remain:  2907
# UCIKQ--H8rzvD7WXsdsJhPbA
# file dumped
# channels to scrape remain:  2906
# UCMGpnhesdaLcztCXaWi1Aig
# file dumped
# channels to scrape remain:  2905
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  2904
# UCEhqLp_cLYiFPKxrco4Ud1g
# file dumped
# channels to scrape remain:  2903
# UCadzQPeW8Q6-htfgTDGMP7Q
# file dumped
# channels to scrape remain:  2902
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  2901
# UC5oQWmWD3vRDssIiA2dkjDg
# file dumped
# channels to scrape remain:  2900
# UCKy1dAqELo0zrOtPkf0eTMw
# file dumped
# channels to scrape remain:  2899
# UCzcRQ3vRNr6fJ1A9rqFn7QA
# file dumped
# channels to scrape remain:  2898
# UCCtlOBjjMjukbxXm8-3jaZg
# file dumped
# channels to scrape remain:  2897
# UCs4EnuxcpR0JE-M72lh1-Sg
# file dumped
# channels to scrape remain:  2896
# UCzYXwUtlpkxOW2U8_iVxWZg
# file dumped
# channels to scrape remain:  2895
# UCGrjyK9065vRZtK3KMVKdIg
# file dumped
# channels to scrape remain:  2894
# UC1_IxWqKu-oFhQQbTkdXe2A
# file dumped
# channels to scrape remain:  2893
# UC8AGq7bm-x4teGcvQonvnPw
# file dumped
# channels to scrape remain:  2892
# UCPWyFO73ioAzxCiNdlCP8mA
# file dumped
# channels to scrape remain:  2891
# UCz4O6cXWN5OvoTIJYIE8wxQ
# file dumped
# channels to scrape remain:  2890
# UCmQynT5NWU3Vsa9t0OGUhcA
# file dumped
# channels to scrape remain:  2889
# UCa-RxF2PWFubaAOLOlR0jQg
# file dumped
# channels to scrape remain:  2888
# UCnHM63hP5auNS7AsASFUBog
# file dumped
# channels to scrape remain:  2887
# UCRX7UEyE8kp35mPrgC2sosA
# file dumped
# channels to scrape remain:  2886
# UCo_X2QB96A7xxZhzMKnlujw
# file dumped
# channels to scrape remain:  2885
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  2884
# UCxnQRFoNbzvbYbnnweyn1tA
# file dumped
# channels to scrape remain:  2883
# UC4KA3qEEEM7lj7I9NCWgOAQ
# file dumped
# channels to scrape remain:  2882
# UCe_cL_BVwgTu3KnGRutE1gQ
# file dumped
# channels to scrape remain:  2881
# UCj9Nw3PbY-J8iFYYVsB1gGQ
# file dumped
# channels to scrape remain:  2880
# UCLYNM2WaoZ3OYBTdBQ9WoXA
# file dumped
# channels to scrape remain:  2879
# UCMrpRnyBJhgVBy3rm0K4P5w
# file dumped
# channels to scrape remain:  2878
# UCG7UD4hnlZoqvmffZFdXtFg
# file dumped
# channels to scrape remain:  2877
# UCIQFqVBCYKWB0lt2dKhUAvw
# file dumped
# channels to scrape remain:  2876
# UCf2phVQFaoCvGc067DodxTg
# file dumped
# channels to scrape remain:  2875
# UChrW3m1MC9T-zFyVl6EKlRA
# file dumped
# channels to scrape remain:  2874
# UCnNZAVbeGwkRfgApKPH507Q
# file dumped
# channels to scrape remain:  2873
# UC_M_hBR62RCpzS_vr-0pTwQ
# file dumped
# channels to scrape remain:  2872
# UCfwE_ODI1YTbdjkzuSi1Nag
# file dumped
# channels to scrape remain:  2871
# UC3l-bobp_xuBlL_lRRS5RmA
# file dumped
# channels to scrape remain:  2870
# UCAmaiEYnoTgj-dmjp8DpepQ
# file dumped
# channels to scrape remain:  2869
# UCUOYkKqPRP3B8Oc_iEu6iOQ
# file dumped
# channels to scrape remain:  2868
# UCfSid2F_I5J8AdhD_wcBqlw
# file dumped
# channels to scrape remain:  2867
# UCgfwpWHhnrIrKaJexZ6M77w
# file dumped
# channels to scrape remain:  2866
# UC8AGq7bm-x4teGcvQonvnPw
# file dumped
# channels to scrape remain:  2865
# UCwCezqK84-2fyCq3aaqAQTA
# file dumped
# channels to scrape remain:  2864
# UCbrqt_T_h5RzhEOz4CZp3-Q
# file dumped
# channels to scrape remain:  2863
# UC-GAhNmY6bkuuRPUSaRI_oQ
# file dumped
# channels to scrape remain:  2862
# UCLYWn9efs0ZhlwYV7fIZguA
# file dumped
# channels to scrape remain:  2861
# UCL2_rOgNgby-060FDn-AgxA
# file dumped
# channels to scrape remain:  2860
# UC-lZTlG05ETwyjDS1JQCv3w
# file dumped
# channels to scrape remain:  2859
# UCOV_7GPTARoxvgoZmvrS2Hw
# file dumped
# channels to scrape remain:  2858
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  2857
# UCpTM9qUfrPEwH0POQy8-9hQ
# file dumped
# channels to scrape remain:  2856
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  2855
# UC-GAhNmY6bkuuRPUSaRI_oQ
# file dumped
# channels to scrape remain:  2854
# UCAmaiEYnoTgj-dmjp8DpepQ
# file dumped
# channels to scrape remain:  2853
# UCDIjP0_6cFfelAHyJRdkwTQ
# file dumped
# channels to scrape remain:  2852
# UCowT0LDUEtJOiKmGSVvqOhA
# file dumped
# channels to scrape remain:  2851
# UCJuq64HSc8KWJ3grvDrU3VA
# file dumped
# channels to scrape remain:  2850
# UCIQz7nN_zTfIoSOh7HasYIQ
# file dumped
# channels to scrape remain:  2849
# UC8sTKRRTf4Lr9V1VXlNTvJw
# file dumped
# channels to scrape remain:  2848
# UCWM6mpKHAxMMizkki_Hc1FA
# file dumped
# channels to scrape remain:  2847
# UCVx2cC2IPqQccNHNbPzSfOg
# file dumped
# channels to scrape remain:  2846
# UCj_HOI5YWo_8hoQzmNjhynQ
# file dumped
# channels to scrape remain:  2845
# UC6iaGdGccO2WKj0me6iuvOQ
# file dumped
# channels to scrape remain:  2844
# UC-NINtNMPM75eaqh07RCy_Q
# file dumped
# channels to scrape remain:  2843
# UCZ8Sxmkweh65HetaZfR8YuA
# file dumped
# channels to scrape remain:  2842
# UCeXQd0KrlX3BT2udmlMkUkQ
# file dumped
# channels to scrape remain:  2841
# UCEnqBREwYT7O57vuu6KpfnQ
# file dumped
# ...
# channels to scrape remain:  233
# UCdL-_xSl-H6KQAnOo64S4oQ
# file dumped
# channels to scrape remain:  232
# UCyDxgBqN7roi53DS5B81vNQ
# file dumped
# channels to scrape remain:  231
# UCTKxI0lo3NBD0UKXA5L5BKA
# file dumped
# channels to scrape remain:  230
# UCYFLiYPfKhnPVOu8zWi0Oxw
# file dumped
# channels to scrape remain:  229
# UCKs7rWKkPb1l9U1JWUK2Jrg
# file dumped
# channels to scrape remain:  228
# UC5QrkxKNVsdfvlKbW48Uohg
# file dumped
# channels to scrape remain:  227
# UCCz47F7HL8nVLFZ5PinayuQ
# file dumped
# channels to scrape remain:  226
# UCzKRNPtHdaLdGpoWszQI9oA
# file dumped
# channels to scrape remain:  225
# UCbGqVIL6UDZTeqOHqfm88-Q
# file dumped
# channels to scrape remain:  224
# UCsEaTDlh3kfgl17DnaRFW2g
# file dumped
# channels to scrape remain:  223
# UCjp4EWKV8Uri6ngCrsbYEKQ
# file dumped
# channels to scrape remain:  222
# UCjnFMWzN9Q3wHvqCQ-N1w-Q
# file dumped
# channels to scrape remain:  221
# UCRQvFrknnePuzaERPYhOXlw
# file dumped
# channels to scrape remain:  220
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  219
# UCt5xAxvpEaJz90G1kEd9RiQ
# file dumped
# channels to scrape remain:  218
# UCzKRNPtHdaLdGpoWszQI9oA
# file dumped
# channels to scrape remain:  217
# UCG2QYlhnYYxksvv6ve11ijw
# file dumped
# channels to scrape remain:  216
# UCANzTjkQzurC4qtzB5t8AvA
# file dumped
# channels to scrape remain:  215
# UC25vIS749wwzwExQFwvpHeQ
# file dumped
# channels to scrape remain:  214
# UCWCfetL17htjdAsNbG2Pakg
# file dumped
# channels to scrape remain:  213
# UCzxQjpe-zGONoBW1TYzTFyA
# file dumped
# channels to scrape remain:  212
# UCma_D36af3Joy2dGB1Ci2pw
# file dumped
# channels to scrape remain:  211
# UCVBZ7bN9BPx3LkMkWSMQL1g
# file dumped
# channels to scrape remain:  210
# UCC4RIwjtWgIIJzXJRxHwuUQ
# file dumped
# channels to scrape remain:  209
# UCH3P5m6Y7e_RaiPa6F3uZfA
# file dumped
# channels to scrape remain:  208
# UCZs5EaNiNeyc4jOn3CqD3Gg
# file dumped
# channels to scrape remain:  207
# UC3ZCIQoqXaa6xAouwmGTD6g
# file dumped
# channels to scrape remain:  206
# UChjDtGelMNkllI5S22oO_aA
# file dumped
# channels to scrape remain:  205
# UCzQUP1qoWDoEbmsQxvdjxgQ
# file dumped
# channels to scrape remain:  204
# UC1K4zDtyAMtJq3PZ1RVmFuQ
# file dumped
# channels to scrape remain:  203
# UCC4hnr0VpuFg_pUOPR6IejQ
# file dumped
# channels to scrape remain:  202
# UCwkB9Yi-O-Ee6Wi3ioppPsw
# file dumped
# channels to scrape remain:  201
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  200
# UCn-iflDJoWfZEvi5NW3tBCg
# file dumped
# channels to scrape remain:  199
# UClfpeSZF_cVwLwuUPHmvnuQ
# file dumped
# channels to scrape remain:  198
# UCmz5OJtgli-1XfSpeVINqXg
# file dumped
# channels to scrape remain:  197
# UC8K6EoNtbMcUfTfxryz4p4w
# file dumped
# channels to scrape remain:  196
# UCIr4vkCsn0tdTW2xZ1jRG1g
# file dumped
# channels to scrape remain:  195
# UC_wCeRoxuPuwWO6z_Q3hUuw
# file dumped
# channels to scrape remain:  194
# UCAlI03sUGRf6g797JGQ5rOg
# file dumped
# channels to scrape remain:  193
# UCtFQDgA8J8_iiwc5-KoAQlg
# file dumped
# channels to scrape remain:  192
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  191
# UCP1hdrxYHdebGqbQawOMRpQ
# file dumped
# channels to scrape remain:  190
# UCqn52uZfESSKB85oILH02UQ
# file dumped
# channels to scrape remain:  189
# UC9jj-YYSGUXvY2J2nYw9dNQ
# file dumped
# channels to scrape remain:  188
# UCzwAr7ne4CzL-DHpPcVN-PA
# file dumped
# channels to scrape remain:  187
# UCDvU_xZLvi0_l1xN-gCKhIQ
# file dumped
# channels to scrape remain:  186
# UCG2QYlhnYYxksvv6ve11ijw
# file dumped
# channels to scrape remain:  185
# UCwEDGPu-JCXZpOjiuW5bpXg
# file dumped
# channels to scrape remain:  184
# UClx_IR8_yVIKdFVUTdmaZTw
# file dumped
# channels to scrape remain:  183
# UCFkc1n5TeOp-ObORUzHqYhQ
# file dumped
# channels to scrape remain:  182
# UCZOO98jeYj_---IrM9GZTdg
# file dumped
# channels to scrape remain:  181
# UCz4O6fVjog6QktiKyOc1pBw
# file dumped
# channels to scrape remain:  180
# UCR4a3ZaMqmIEBJvmRz4HafA
# file dumped
# channels to scrape remain:  179
# UCi77VxMBRwL32pZAXcMGKhw
# file dumped
# channels to scrape remain:  178
# UCghETqJXjCtbiRJsEv8Ir8g
# file dumped
# channels to scrape remain:  177
# UCC_0vyFTKk1Nlodo4QsiQkw
# file dumped
# channels to scrape remain:  176
# UCt5xAxvpEaJz90G1kEd9RiQ
# file dumped
# channels to scrape remain:  175
# UCMrpRnyBJhgVBy3rm0K4P5w
# file dumped
# channels to scrape remain:  174
# UC4zcMHyrT_xyWlgy5WGpFFQ
# file dumped
# channels to scrape remain:  173
# UCeZ08MGEmhSrewV-_NSL1cw
# file dumped
# channels to scrape remain:  172
# UC2Jh9r8jRnJ0ykF5wjHt3kQ
# file dumped
# channels to scrape remain:  171
# UCghETqJXjCtbiRJsEv8Ir8g
# file dumped
# channels to scrape remain:  170
# UCKY5PiEq8Tl9r7f3qittXng
# file dumped
# channels to scrape remain:  169
# UCAmaiEYnoTgj-dmjp8DpepQ
# file dumped
# channels to scrape remain:  168
# UC7pYkdpCfDo7U1j4_pbF5Iw
# file dumped
# channels to scrape remain:  167
# UC-RY_mNm2zlULbSJM75xmaA
# file dumped
# channels to scrape remain:  166
# UCJuq64HSc8KWJ3grvDrU3VA
# file dumped
# channels to scrape remain:  165
# UC4ltvXoxGZobqqduv9iXOWg
# file dumped
# channels to scrape remain:  164
# UCdlmsFz1JfF6ondl7bkVlJA
# file dumped
# channels to scrape remain:  163
# UCbiT0LUIbQj6CQScvWHJeKQ
# file dumped
# channels to scrape remain:  162
# UCMrpRnyBJhgVBy3rm0K4P5w
# file dumped
# channels to scrape remain:  161
# UCO6cSNvOaDs-kjALLQLNhQw
# file dumped
# channels to scrape remain:  160
# UCAmaiEYnoTgj-dmjp8DpepQ
# file dumped
# channels to scrape remain:  159
# UCIQz7nN_zTfIoSOh7HasYIQ
# file dumped
# channels to scrape remain:  158
# UCsAKRVq2n1vcHBzNu1ZikgA
# file dumped
# channels to scrape remain:  157
# UCOp24og-YLLuvUP4yrJ2cJA
# file dumped
# channels to scrape remain:  156
# UCOp24og-YLLuvUP4yrJ2cJA
# file dumped
# channels to scrape remain:  155
# UCOp24og-YLLuvUP4yrJ2cJA
# file dumped
# channels to scrape remain:  154
# UCfwE_ODI1YTbdjkzuSi1Nag
# file dumped
# channels to scrape remain:  153
# UCZMsvbAhhRblVGXmEXW8TSA
# file dumped
# channels to scrape remain:  152
# UC3l-bobp_xuBlL_lRRS5RmA
# file dumped
# channels to scrape remain:  151
# UCuqfqlNFgvfiMLoC85-KrvA
# file dumped
# channels to scrape remain:  150
# UCeZ08MGEmhSrewV-_NSL1cw
# file dumped
# channels to scrape remain:  149
# UCvAxX35uA174B1Fovd0TScA
# file dumped
# channels to scrape remain:  148
# UCG2QYlhnYYxksvv6ve11ijw
# file dumped
# channels to scrape remain:  147
# UCOp24og-YLLuvUP4yrJ2cJA
# file dumped
# channels to scrape remain:  146
# UCSFy-1JrpZf0tFlRZfo-Rvw
# file dumped
# channels to scrape remain:  145
# UCjsExtizDZK6SMBw6pSZOPQ
# file dumped
# channels to scrape remain:  144
# UCcvD8ANBq3H9i1ozzznAn1A
# file dumped
# channels to scrape remain:  143
# UC-NINtNMPM75eaqh07RCy_Q
# file dumped
# channels to scrape remain:  142
# UCUINm_sTF9Q_ESf8fO25OdQ
# file dumped
# channels to scrape remain:  141
# UC_GKLVFv1csDbY25x9bXZBg
# file dumped
# channels to scrape remain:  140
# UCtsOFYS141nQ4znc_9xpFDQ
# file dumped
# channels to scrape remain:  139
# UCeVCuy7hFA8IFvqJGJMjX_A
# file dumped
# channels to scrape remain:  138
# UC-NINtNMPM75eaqh07RCy_Q
# file dumped
# channels to scrape remain:  137
# UCWWJHLPw0fKJ_G6X3Dhjbrw
# file dumped
# channels to scrape remain:  136
# UCYIbCrykGh2g0BvrykJc6Ow
# file dumped
# channels to scrape remain:  135
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  134
# UCcvD8ANBq3H9i1ozzznAn1A
# file dumped
# channels to scrape remain:  133
# UCv7YFWATebnJ1ty4cwMKgsQ
# file dumped
# channels to scrape remain:  132
# UCNWVoMKRr63-nlItezqerpQ
# file dumped
# channels to scrape remain:  131
# UCbiT0LUIbQj6CQScvWHJeKQ
# file dumped
# channels to scrape remain:  130
# UCTnFdC5jhEClcYhTn9wo-VQ
# file dumped
# channels to scrape remain:  129
# UCG2QYlhnYYxksvv6ve11ijw
# file dumped
# channels to scrape remain:  128
# UCG2QYlhnYYxksvv6ve11ijw
# file dumped
# channels to scrape remain:  127
# UCUINm_sTF9Q_ESf8fO25OdQ
# file dumped
# channels to scrape remain:  126
# UCnPwWqXVYBDGvFAs3SCX_Ow
# file dumped
# channels to scrape remain:  125
# UCfkpM3RuyUHqY4nRlP-egNA
# file dumped
# channels to scrape remain:  124
# UCNttYr07FLI6jzz_VUMeF6w
# file dumped
# channels to scrape remain:  123
# UCZlEJAH7-8FhfOVjul54pzQ
# file dumped
# channels to scrape remain:  122
# UCxX35sSh_sH_SOoENaFXAig
# file dumped
# channels to scrape remain:  121
# UCAk03rcNVtLK1_LlgRTOh2w
# file dumped
# channels to scrape remain:  120
# UCZZHPXsg6LopvdOKF7qM6cQ
# file dumped
# channels to scrape remain:  119
# UCG5YJCzWV8ech3Fx4NhSyxg
# file dumped
# channels to scrape remain:  118
# UCFQgi22Ht00CpaOQLtvZx2A
# file dumped
# channels to scrape remain:  117
# UCAmaiEYnoTgj-dmjp8DpepQ
# file dumped
# channels to scrape remain:  116
# UC1iR8jkp4lT2_MuPE6vjTLQ
# file dumped
# channels to scrape remain:  115
# UCcvD8ANBq3H9i1ozzznAn1A
# file dumped
# channels to scrape remain:  114
# UCTXNz3gjAypWp3EhlIATEJQ
# file dumped
# channels to scrape remain:  113
# UC10GoVi7dXvXcXHE6NqRuhg
# file dumped
# channels to scrape remain:  112
# UC-lZTlG05ETwyjDS1JQCv3w
# file dumped
# channels to scrape remain:  111
# UC0rPD-lnyw6x6vBAR9SOtcw
# file dumped
# channels to scrape remain:  110
# UCGeFheQ5Xl2fjbhuo7B7KFw
# file dumped
# channels to scrape remain:  109
# UCAk03rcNVtLK1_LlgRTOh2w
# file dumped
# channels to scrape remain:  108
# UCOp24og-YLLuvUP4yrJ2cJA
# file dumped
# channels to scrape remain:  107
# UCOp24og-YLLuvUP4yrJ2cJA
# file dumped
# channels to scrape remain:  106
# UC_gUM8rL-Lrg6O3adPW9K1g
# file dumped
# channels to scrape remain:  105
# UCvrd6VtgWF7CwaZH1S0N-Qg
# file dumped
# channels to scrape remain:  104
# UCAk03rcNVtLK1_LlgRTOh2w
# file dumped
# channels to scrape remain:  103
# UCdiN18CfZ2pyGUtzfu19n7Q
# file dumped
# channels to scrape remain:  102
# UC1MmeRcwZ8_hXkj0TPk-jPg
# file dumped
# channels to scrape remain:  101
# UCfwE_ODI1YTbdjkzuSi1Nag
# file dumped
# channels to scrape remain:  100
# UCQjh-JVPNWfY-KsZS3RgRHw
# file dumped
# channels to scrape remain:  99
# UCeZ08MGEmhSrewV-_NSL1cw
# file dumped
# channels to scrape remain:  98
# UCOp24og-YLLuvUP4yrJ2cJA
# file dumped
# channels to scrape remain:  97
# UC_D7dC1lgBYIisIYM_SF9jQ
# file dumped
# channels to scrape remain:  96
# UCv4Ehzvpp-1AV7UDGBvAMhQ
# file dumped
# channels to scrape remain:  95
# UCsEtj_Op0p8vCXjR6OakbNA
# file dumped
# channels to scrape remain:  94
# UCO6cSNvOaDs-kjALLQLNhQw
# file dumped
# channels to scrape remain:  93
# UCmxfZa-sV27MUDqy-iJIsfA
# file dumped
# channels to scrape remain:  92
# UCu9SQC4ajTVzvOq-9Ao_a1w
# file dumped
# channels to scrape remain:  91
# UCvAxX35uA174B1Fovd0TScA
# file dumped
# channels to scrape remain:  90
# UCMSGqNgJ5gDLx6E_aaV4-Ug
# file dumped
# channels to scrape remain:  89
# UCAmaiEYnoTgj-dmjp8DpepQ
# file dumped
# channels to scrape remain:  88
# UChqUTb7kYRX8-EiaN3XFrSQ
# file dumped
# channels to scrape remain:  87
# UCG2QYlhnYYxksvv6ve11ijw
# file dumped
# channels to scrape remain:  86
# UCvPifZUF8usnsIDKmFUVSQQ
# file dumped
# channels to scrape remain:  85
# UCOp24og-YLLuvUP4yrJ2cJA
# file dumped
# channels to scrape remain:  84
# UCUINm_sTF9Q_ESf8fO25OdQ
# file dumped
# channels to scrape remain:  83
# UCPw6DAw_AUOYgrnFEbFpHjw
# file dumped
# channels to scrape remain:  82
# UCUINm_sTF9Q_ESf8fO25OdQ
# file dumped
# channels to scrape remain:  81
# UCXxOrboGdCpVGsPuFhJXFqw
# file dumped
# channels to scrape remain:  80
# UCoHtJO5LWXWnqBNjBlXiKyQ
# file dumped
# channels to scrape remain:  79
# UCO6cSNvOaDs-kjALLQLNhQw
# file dumped
# channels to scrape remain:  78
# UC-NINtNMPM75eaqh07RCy_Q
# file dumped
# channels to scrape remain:  77
# UCAmaiEYnoTgj-dmjp8DpepQ
# file dumped
# channels to scrape remain:  76
# UCfwE_ODI1YTbdjkzuSi1Nag
# file dumped
# channels to scrape remain:  75
# UCOp24og-YLLuvUP4yrJ2cJA
# file dumped
# channels to scrape remain:  74
# UCAk03rcNVtLK1_LlgRTOh2w
# file dumped
# channels to scrape remain:  73
# UCqWx5OyAZtk1fngM7SsnS0g
# file dumped
# channels to scrape remain:  72
# UCMbuTdu_hY2anASO5ooIZXw
# file dumped
# channels to scrape remain:  71
# UCbiT0LUIbQj6CQScvWHJeKQ
# file dumped
# channels to scrape remain:  70
# UCAmaiEYnoTgj-dmjp8DpepQ
# file dumped
# channels to scrape remain:  69
# UCbiT0LUIbQj6CQScvWHJeKQ
# file dumped
# channels to scrape remain:  68
# UC0__jFZJluRp9pddY-EB77g
# file dumped
# channels to scrape remain:  67
# UCqWx5OyAZtk1fngM7SsnS0g
# file dumped
# channels to scrape remain:  66
# UCS0xsjNhFbjnvdfMr4B5oxg
# file dumped
# channels to scrape remain:  65
# UC86dbj-lbDks_hZ5gRKL49Q
# file dumped
# channels to scrape remain:  64
# UCU-hmpjPlkq8eeB74hRPncA
# file dumped
# channels to scrape remain:  63
# UC-lZTlG05ETwyjDS1JQCv3w
# file dumped
# channels to scrape remain:  62
# UCOp24og-YLLuvUP4yrJ2cJA
# file dumped
# channels to scrape remain:  61
# UCOp24og-YLLuvUP4yrJ2cJA
# file dumped
# channels to scrape remain:  60
# UCAmaiEYnoTgj-dmjp8DpepQ
# file dumped
# channels to scrape remain:  59
# UCtsOFYS141nQ4znc_9xpFDQ
# file dumped
# channels to scrape remain:  58
# UC3l-bobp_xuBlL_lRRS5RmA
# file dumped
# channels to scrape remain:  57
# UCVY5DajJFwUJ6AA0oTZ1eYA
# file dumped
# channels to scrape remain:  56
# UCbiT0LUIbQj6CQScvWHJeKQ
# file dumped
# channels to scrape remain:  55
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# file dumped
# channels to scrape remain:  54
# UCULldxqht8mAVpBPTQlEAlA
# file dumped
# channels to scrape remain:  53
# UCzOKCkUEjveoFbRWexEZeSw
# file dumped
# channels to scrape remain:  52
# UCAxriNBFZQPTsj9vBOSnhkA
# file dumped
# channels to scrape remain:  51
# UCRMyYnrPaoiLtSMzgEUrSHQ
# file dumped
# channels to scrape remain:  50
# UCAmaiEYnoTgj-dmjp8DpepQ
# file dumped
# channels to scrape remain:  49
# UCCea0NSLYEfbEeppFnpxvCA
# file dumped
# channels to scrape remain:  48
# UCs5aTnqCZunCSZ7nxBBtXCQ
# file dumped
# channels to scrape remain:  47
# UCOp24og-YLLuvUP4yrJ2cJA
# file dumped
# channels to scrape remain:  46
# UC5-ghDPnGGfrjt3MNBjfJHw
# file dumped
# channels to scrape remain:  45
# UCOp24og-YLLuvUP4yrJ2cJA
# file dumped
# channels to scrape remain:  44
# UC-lZTlG05ETwyjDS1JQCv3w
# file dumped
# channels to scrape remain:  43
# UCuWeBHxVe6C69JTBpiY-Y8Q
# file dumped
# channels to scrape remain:  42
# UClHofEiTcGYPMA9jqaFbmGA
# file dumped
# channels to scrape remain:  41
# UCzRyPH6NfBIfiUGwXaekV3Q
# file dumped
# channels to scrape remain:  40
# UC-NINtNMPM75eaqh07RCy_Q
# file dumped
# channels to scrape remain:  39
# UCBeyuzUWyvDAVpS_ibwMwnA
# file dumped
# channels to scrape remain:  38
# UCbiT0LUIbQj6CQScvWHJeKQ
# file dumped
# channels to scrape remain:  37
# UCAk03rcNVtLK1_LlgRTOh2w
# file dumped
# channels to scrape remain:  36
# UCAk03rcNVtLK1_LlgRTOh2w
# file dumped
# channels to scrape remain:  35
# UCq3hBt71fezQ2dzAKY_3wIw
# file dumped
# channels to scrape remain:  34
# UCWcYWgG2wKD_-aK9Sy_9zaw
# file dumped
# channels to scrape remain:  33
# UCOp24og-YLLuvUP4yrJ2cJA
# file dumped
# channels to scrape remain:  32
# UCOp24og-YLLuvUP4yrJ2cJA
# file dumped
# channels to scrape remain:  31
# UCtOtBWnGiL-f1mdRnmAKF9g
# file dumped
# channels to scrape remain:  30
# UC0inxIIgPjJTeSVuDd8CzLA
# file dumped
# channels to scrape remain:  29
# UCw3fku0sH3qA3c3pZeJwdAw
# file dumped
# channels to scrape remain:  28
# UCiFuWdu-3NDtV8UPhBJLRCw
# file dumped
# channels to scrape remain:  27
# UCEdTGX9qSzK2g0GW2BklGfQ
# file dumped
# channels to scrape remain:  26
# UCvjPBcB5xe5QQxQb7nwmp-Q
# file dumped
# channels to scrape remain:  25
# UCG2QYlhnYYxksvv6ve11ijw
# file dumped
# channels to scrape remain:  24
# UCuWeBHxVe6C69JTBpiY-Y8Q
# file dumped
# channels to scrape remain:  23
# UCjgCdcb-z8MNZInajCu84sg
# file dumped
# channels to scrape remain:  22
# UCuWeBHxVe6C69JTBpiY-Y8Q
# file dumped
# channels to scrape remain:  21
# UCZMsvbAhhRblVGXmEXW8TSA
# file dumped
# channels to scrape remain:  20
# UCh4kZnE9IHQhjr8jFd5nNNw
# file dumped
# channels to scrape remain:  19
# UCOp24og-YLLuvUP4yrJ2cJA
# file dumped
# channels to scrape remain:  18
# UCAk03rcNVtLK1_LlgRTOh2w
# file dumped
# channels to scrape remain:  17
# UC-NINtNMPM75eaqh07RCy_Q
# file dumped
# channels to scrape remain:  16
# UCLV1Jw4IZVGbOR-z9ZgKp-Q
# file dumped
# channels to scrape remain:  15
# UCw3fku0sH3qA3c3pZeJwdAw
# file dumped
# channels to scrape remain:  14
# UCtJhpRxy9ythT1VCVOp1yLQ
# file dumped
# channels to scrape remain:  13
# UCbiT0LUIbQj6CQScvWHJeKQ
# file dumped
# channels to scrape remain:  12
# UCbiT0LUIbQj6CQScvWHJeKQ
# file dumped
# channels to scrape remain:  11
# UC3l-bobp_xuBlL_lRRS5RmA
# file dumped
# channels to scrape remain:  10
# UCBXnFjh6EidsfYe8yTX5JIA
# file dumped
# channels to scrape remain:  9
# UCIQz7nN_zTfIoSOh7HasYIQ
# file dumped
# channels to scrape remain:  8
# UCw3fku0sH3qA3c3pZeJwdAw
# file dumped
# channels to scrape remain:  7
# UCODqBn77UBZEh8o4iSG1xXQ
# file dumped
# channels to scrape remain:  6
# UCf2Aup2fwT3G2ZYqCdM6nnw
# file dumped
# channels to scrape remain:  5
# UCG2QYlhnYYxksvv6ve11ijw
# file dumped
# channels to scrape remain:  4
# UC4ltvXoxGZobqqduv9iXOWg
# file dumped
# channels to scrape remain:  3
# UCgbVeU_cHAFCyx5_J6RSgHg
# file dumped
# channels to scrape remain:  2
# UCxvE6krmQKUsfekdbgvzuZw
# file dumped
# channels to scrape remain:  1
# UC0__jFZJluRp9pddY-EB77g
# file dumped
# channels to scrape remain:  0

# %% [markdown]
# # read josn file and combine:

# %%
# read josn files and make a list with json files
# (make 1 change)

path_to_json = r'C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Account info'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]
json_files;  
len(json_files)
# Out:
# 2251

# %%
# create a data frame with all json files:
# (make 1 change)

df = pd.DataFrame()
for file in json_files:
    file_path = r"C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\Account info/" + file
    with open(file_path) as data_file:    
        data = json.load(data_file)
        df = df.append(pd.json_normalize(data))
df.shape
# Out:
# (2251, 140)

# %%
df.head()
# Out:
#               kind                         etag                        id  \
# 0  youtube#channel  aGaNuQu2tj1UYhsES8LoUc-hLts  UC-00bNSHaBikLCRZGs-4nLg
# 0  youtube#channel  80GVgSeIzvyno0mB4_I1XX6QhCc  UC-1Hd_LdAj766JDS_ILKEig
# 0  youtube#channel  ayfR-Z-BPakCySmtv0VGhs7p51s  UC-2MJlKSq9_pYk5-bdvMhnw
# 0  youtube#channel  zS-GKA1--CfWfNmT4uzM73ZvEXw  UC-2YHgc363EdcusLIBbgxzg
# 0  youtube#channel  ozpUwrRYJdJiXBkDoMBr8lXQU0E  UC-6MU0asLZ1fAcQYe20AuYw
#
#                                              snippet  \
# 0  {'title': 'Closhure', 'description': 'Hello th...
# 0  {'title': 'DanceSnapz', 'description': '', 'cu...
# 0  {'title': 'Denver7 – The Denver Channel', 'des...
# 0  {'title': 'Joe Scott', 'description': 'Ask Que...
# 0  {'title': 'Celebrity TMZ', 'description': 'In ...
#
#                                       contentDetails  \
# 0  {'relatedPlaylists': {'likes': '', 'uploads': ...
# 0  {'relatedPlaylists': {'likes': '', 'uploads': ...
# 0  {'relatedPlaylists': {'likes': '', 'uploads': ...
# 0  {'relatedPlaylists': {'likes': '', 'uploads': ...
# 0  {'relatedPlaylists': {'likes': '', 'uploads': ...
#
#                                           statistics  \
# 0  {'viewCount': '1985415', 'subscriberCount': '1...
# 0  {'viewCount': '81141616', 'subscriberCount': '...
# 0  {'viewCount': '392615087', 'subscriberCount': ...
# 0  {'viewCount': '225004062', 'subscriberCount': ...
# 0  {'viewCount': '298792', 'subscriberCount': '43...
#
#                                         topicDetails  \
# 0  {'topicIds': ['/m/02vxn', '/m/0f2f9', '/m/02jj...
# 0  {'topicIds': ['/m/02jjt', '/m/05qjc', '/m/0f2f...
# 0  {'topicIds': ['/m/098wr'], 'topicCategories': ...
# 0  {'topicIds': ['/m/098wr', '/m/01k8wb', '/m/019...
# 0  {'topicIds': ['/m/02jjt', '/m/02vxn'], 'topicC...
#
#                                               status  \
# 0  {'privacyStatus': 'public', 'isLinked': True, ...
# 0  {'privacyStatus': 'public', 'isLinked': True, ...
# 0  {'privacyStatus': 'public', 'isLinked': True, ...
# 0  {'privacyStatus': 'public', 'isLinked': True, ...
# 0  {'privacyStatus': 'public', 'isLinked': True, ...
#
#                                     brandingSettings contentOwnerDetails  \
# 0  {'channel': {'title': 'Closhure', 'description...                  {}
# 0  {'channel': {'title': 'DanceSnapz', 'keywords'...                  {}
# 0  {'channel': {'title': 'Denver7 – The Denver Ch...                  {}
# 0  {'channel': {'title': 'Joe Scott', 'descriptio...                  {}
# 0  {'channel': {'title': 'Celebrity TMZ', 'descri...                  {}
#
#                                        localizations
# 0  {'en_US': {'title': 'Closhure', 'description':...
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN

# %%
df = df[df.columns.drop(list(df.filter(regex='thumbnails')))]

# %%
df.shape
# Out:
# (2251, 32)

# %%
column_head_list = list(df.columns)

# %%
column_head_list
# Out:
# ['kind',
#  'etag',
#  'id',
#  'snippet.title',
#  'snippet.description',
#  'snippet.customUrl',
#  'snippet.publishedAt',
#  'snippet.defaultLanguage',
#  'snippet.localized.title',
#  'snippet.localized.description',
#  'snippet.country',
#  'contentDetails.relatedPlaylists.likes',
#  'contentDetails.relatedPlaylists.uploads',
#  'statistics.viewCount',
#  'statistics.subscriberCount',
#  'statistics.hiddenSubscriberCount',
#  'statistics.videoCount',
#  'topicDetails.topicIds',
#  'topicDetails.topicCategories',
#  'status.privacyStatus',
#  'status.isLinked',
#  'status.longUploadsStatus',
#  'status.madeForKids',
#  'brandingSettings.channel.title',
#  'brandingSettings.channel.description',
#  'brandingSettings.channel.keywords',
#  'brandingSettings.channel.defaultLanguage',
#  'brandingSettings.channel.country',
#  'brandingSettings.image.bannerExternalUrl',
#  'brandingSettings.channel.unsubscribedTrailer',
#  'brandingSettings.channel.moderateComments',
#  'brandingSettings.channel.trackingAnalyticsAccountId']

# %%
df.to_csv(r'C:\Users\David\Amber Heard Case\Youtube\Data\combined files for accounts\combined accounts info batch1&2.csv')

# %%
df['id'].min()
# Out:
# '0'

# %%
a = df[df['id'] == 'UCiKGMZZmZXK-RpbKJGXgH3Q']

# %%
a = dict(a)

# %%
a
# Out:
# {'kind': 0    youtube#channel
#  Name: kind, dtype: object,
#  'etag': 0    OeiIxHLNcDUQRpVY8U1w0TWeQyg
#  Name: etag, dtype: object,
#  'id': 0    UCiKGMZZmZXK-RpbKJGXgH3Q
#  Name: id, dtype: object,
#  'snippet.title': 0    Access
#  Name: snippet.title, dtype: object,
#  'snippet.description': 0    “Access Hollywood,” currently in its 24th seas...
#  Name: snippet.description, dtype: object,
#  'snippet.customUrl': 0    accessonline
#  Name: snippet.customUrl, dtype: object,
#  'snippet.publishedAt': 0    2006-05-04T19:09:28Z
#  Name: snippet.publishedAt, dtype: object,
#  'snippet.defaultLanguage': 0    NaN
#  Name: snippet.defaultLanguage, dtype: object,
#  'snippet.localized.title': 0    Access
#  Name: snippet.localized.title, dtype: object,
#  'snippet.localized.description': 0    “Access Hollywood,” currently in its 24th seas...
#  Name: snippet.localized.description, dtype: object,
#  'snippet.country': 0    US
#  Name: snippet.country, dtype: object,
#  'contentDetails.relatedPlaylists.likes': 0
#  Name: contentDetails.relatedPlaylists.likes, dtype: object,
#  'contentDetails.relatedPlaylists.uploads': 0    UUiKGMZZmZXK-RpbKJGXgH3Q
#  Name: contentDetails.relatedPlaylists.uploads, dtype: object,
#  'statistics.viewCount': 0    1144994484
#  Name: statistics.viewCount, dtype: object,
#  'statistics.subscriberCount': 0    1300000
#  Name: statistics.subscriberCount, dtype: object,
#  'statistics.hiddenSubscriberCount': 0    False
#  Name: statistics.hiddenSubscriberCount, dtype: bool,
#  'statistics.videoCount': 0    25521
#  Name: statistics.videoCount, dtype: object,
#  'topicDetails.topicIds': 0    [/m/02jjt, /m/0f2f9]
#  Name: topicDetails.topicIds, dtype: object,
#  'topicDetails.topicCategories': 0    [https://en.wikipedia.org/wiki/Entertainment, ...
#  Name: topicDetails.topicCategories, dtype: object,
#  'status.privacyStatus': 0    public
#  Name: status.privacyStatus, dtype: object,
#  'status.isLinked': 0    True
#  Name: status.isLinked, dtype: bool,
#  'status.longUploadsStatus': 0    longUploadsUnspecified
#  Name: status.longUploadsStatus, dtype: object,
#  'status.madeForKids': 0    False
#  Name: status.madeForKids, dtype: object,
#  'brandingSettings.channel.title': 0    Access
#  Name: brandingSettings.channel.title, dtype: object,
#  'brandingSettings.channel.description': 0    “Access Hollywood,” currently in its 24th seas...
#  Name: brandingSettings.channel.description, dtype: object,
#  'brandingSettings.channel.keywords': 0    "Access Hollywood" Interview Celebrity Enterta...
#  Name: brandingSettings.channel.keywords, dtype: object,
#  'brandingSettings.channel.defaultLanguage': 0    NaN
#  Name: brandingSettings.channel.defaultLanguage, dtype: object,
#  'brandingSettings.channel.country': 0    US
#  Name: brandingSettings.channel.country, dtype: object,
#  'brandingSettings.image.bannerExternalUrl': 0    https://yt3.ggpht.com/6oCC5LFNkLFmoHMPPYxDAnsn...
#  Name: brandingSettings.image.bannerExternalUrl, dtype: object,
#  'brandingSettings.channel.unsubscribedTrailer': 0    XXLrHaE26B8
#  Name: brandingSettings.channel.unsubscribedTrailer, dtype: object,
#  'brandingSettings.channel.moderateComments': 0    NaN
#  Name: brandingSettings.channel.moderateComments, dtype: object,
#  'brandingSettings.channel.trackingAnalyticsAccountId': 0    NaN
#  Name: brandingSettings.channel.trackingAnalyticsAccountId, dtype: object}
