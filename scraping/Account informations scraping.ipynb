# %%
import pandas as pd
import json
import requests
from io import StringIO
from csv import reader
import os
import glob

# %% [markdown]
# https://youtube.googleapis.com/youtube/v3/channels?part=snippet&id=UC8-Th83bH_thdKZDJCrn88g&key=AIzaSyCQHI5RSbHoKGh6sPPnnOywja7qLS6TXnA

# %% [markdown]
# https://youtube.googleapis.com/youtube/v3/channels?part=snippet&part=contentDetails&id=UC8-Th83bH_thdKZDJCrn88g&key=AIzaSyCQHI5RSbHoKGh6sPPnnOywja7qLS6TXnA

# %% [markdown]
# https://youtube.googleapis.com/youtube/v3/channels?part=snippet&part=contentDetails&part=brandingSettings&part=contentOwnerDetails&part=id&part=localizations&part=statistics&part=status&part=topicDetails&id=UC8-Th83bH_thdKZDJCrn88g&maxResults=200&key=AIzaSyCQHI5RSbHoKGh6sPPnnOywja7qLS6TXnA&pageToken=''

# %%
channels_id = pd.read_csv('total_channels_id.csv')
channels_id = list(channels_id['id'])
len(channels_id)
# Out:
# 5003

# %%
class YTstats:
  
    def __init__(self, api_key, channel_id):
        self.api_key = api_key
        self.channel_id = channel_id
        self.video_statistics = None
  
    def get_video_statistics(self):
        url = f'https://youtube.googleapis.com/youtube/v3/channels?part=snippet&part=contentDetails&part=brandingSettings&part=contentOwnerDetails&part=id&part=localizations&part=statistics&part=status&part=topicDetails&id={self.channel_id}&maxResults=200&key={self.api_key}'
        json_url = requests.get(url)
        data = json.loads(json_url.text)
        nextPageToken = data.get("nextPageToken")
        
        i = 0
        a = ''
        if nextPageToken:
            while nextPageToken != a:
                a = nextPageToken
                i += 1
                url = f'https://youtube.googleapis.com/youtube/v3/channels?part=snippet&part=contentDetails&part=brandingSettings&part=contentOwnerDetails&part=id&part=localizations&part=statistics&part=status&part=topicDetails&id={self.channel_id}&maxResults=200&key={self.api_key}&pageToken={nextPageToken}'
                json_url = requests.get(url)
                data1 = json.loads(json_url.text)
                nextPageToken = data1.get("nextPageToken")
                data['items'] = data['items'] + data1['items']
                
                if nextPageToken is None:
                    break
                print('page number:', i+1)
              #  print(nextPageToken, len(data['items']))
            
            
        try:
            data = data["items"]#[0]["statistics"]
        except:
            data = None
  
        self.video_statistics = data
        return data
  
    def dump(self):
        if self.video_statistics is None:
            print('nothing happend')
            return 
  
        video_title = self.channel_id
        video_title = video_title.replace(" ", "_")
  
        # generate a json file with all the statistics data of the youtube video
        file_name = video_title + '.json'
        with open(file_name, 'w') as f:
            json.dump(self.video_statistics, f, indent=4)
        print('file dumped')

# %%
# recive data using API and save it on PC
# (make 1 change)

API_KEY = "AIzaSyCQHI5RSbHoKGh6sPPnnOywja7qLS6TXnA"
  
 # paste the channel id here
for video in channels_id:
    print(video)
    yt = YTstats(API_KEY, video)
    yt.get_video_statistics()
    yt.dump()
    channels_id.remove(video)
    print('channels to scrape remain: ', len(channels_id))
# Out:
# UCoMdktPbSTixAyNGwb-UYkQ
# nothing happend
# channels to scrape remain:  3886
# UCDGrExEIXyDYVGiLHoZ1caQ
# nothing happend
# channels to scrape remain:  3885
# UCmxGEYcKS5W4YnROt4-uoZA
# nothing happend
# channels to scrape remain:  3884
# UCttaiawOR1n05CJqmaf0uPw
# nothing happend
# channels to scrape remain:  3883
# UC9_3h1t3FEvhC-1toDU3fww
# nothing happend
# channels to scrape remain:  3882
# UCSVrN4tjiFyzQ2l7fC9mElw
# nothing happend
# channels to scrape remain:  3881
# UC_UtiZsR2Tozkk7IZRAQTnQ
# nothing happend
# channels to scrape remain:  3880
# UCfupACwUQmP2H6pDehATVXA
# nothing happend
# channels to scrape remain:  3879
# UC6KnKTMVr44BIrNeo8bSwfw
# nothing happend
# channels to scrape remain:  3878
# UCO8MQqy42F8B9Lnk7iQvp1A
# nothing happend
# channels to scrape remain:  3877
# UCAY3SylOdhF-loAV8-_p4QA
# file dumped
# channels to scrape remain:  3876
# UChFsYLqPUyLiZnfRog6wiZA
# nothing happend
# channels to scrape remain:  3875
# UCornjZ9hbsGhuunO4O9uTuw
# nothing happend
# channels to scrape remain:  3874
# UCbrs4z9mxeHsvU7zfe990cQ
# nothing happend
# channels to scrape remain:  3873
# UC9AJa2-Kn6Dp1pp_DpFvkuw
# nothing happend
# channels to scrape remain:  3872
# UCgMv-yISSCyZc5pOrTA83iQ
# nothing happend
# channels to scrape remain:  3871
# UCKtVwafyliw0kNWNuUu9gmg
# nothing happend
# channels to scrape remain:  3870
# UCbL5Yws6Ymu0a3LgXLN48xQ
# file dumped
# channels to scrape remain:  3869
# UCVvatXYUruJCKstNSll99lQ
# nothing happend
# channels to scrape remain:  3868
# UCyErsn5XDx6OD9I1KtM1Z4w
# nothing happend
# channels to scrape remain:  3867
# UCdt-HsC0P6JO-YQUp9yAnyA
# nothing happend
# channels to scrape remain:  3866
# UC0P4_2nrwEMw2A1TCsfQYdg
# nothing happend
# channels to scrape remain:  3865
# UCfupACwUQmP2H6pDehATVXA
# nothing happend
# channels to scrape remain:  3864
# UClD1ikUW1dti_nuCP1Pg4Qw
# nothing happend
# channels to scrape remain:  3863
# UCsHjmojzbg9DBSpot_NXUYg
# nothing happend
# channels to scrape remain:  3862
# UCKY5PiEq8Tl9r7f3qittXng
# nothing happend
# channels to scrape remain:  3861
# UCzyUP8w1KCVqFNvX5EtwaMw
# nothing happend
# channels to scrape remain:  3860
# UCM5s_toCOXpbNbu-48z9s5g
# nothing happend
# channels to scrape remain:  3859
# UCdz_axEWrkJRfZQ5yE5xoAQ
# nothing happend
# channels to scrape remain:  3858
# UC-HvkbTWtG_AC0d-PjQ-9YA
# nothing happend
# channels to scrape remain:  3857
# UCHfbxFx6sbO4QfM7OVwlKTw
# nothing happend
# channels to scrape remain:  3856
# UClx_IR8_yVIKdFVUTdmaZTw
# nothing happend
# channels to scrape remain:  3855
# UC9_3h1t3FEvhC-1toDU3fww
# nothing happend
# channels to scrape remain:  3854
# UCj2TXPCJHe78wNG0E5g1idw
# nothing happend
# channels to scrape remain:  3853
# UCmeRyZNSg0tPAw8F5zPSDZg
# nothing happend
# channels to scrape remain:  3852
# UClx_IR8_yVIKdFVUTdmaZTw
# nothing happend
# channels to scrape remain:  3851
# UClx_IR8_yVIKdFVUTdmaZTw
# file dumped
# channels to scrape remain:  3850
# UC9kMczoE2QQ11rRi1uuBAjQ
# nothing happend
# channels to scrape remain:  3849
# UC8TkLYOTDmT_AMPIOai-gAw
# nothing happend
# channels to scrape remain:  3848
# UClx_IR8_yVIKdFVUTdmaZTw
# nothing happend
# channels to scrape remain:  3847
# UC1oDOPHfjlds-nsT8h0_hig
# nothing happend
# channels to scrape remain:  3846
# UCdHls7paEwPFhQU7byV5BtQ
# nothing happend
# channels to scrape remain:  3845
# UClx_IR8_yVIKdFVUTdmaZTw
# nothing happend
# channels to scrape remain:  3844
# UCEl7FPZZxo84xUTEKewsRng
# nothing happend
# channels to scrape remain:  3843
# UCpfURmLbv0Sq4miJ3DzlZhA
# nothing happend
# channels to scrape remain:  3842
# UCVxBA3Cbu3pm8w8gEIoMEog
# nothing happend
# channels to scrape remain:  3841
# UCFr0o_0E3DjY4N_4J7HzgKQ
# file dumped
# channels to scrape remain:  3840
# UCPZb1f7mKXuH3nOcOOpju5Q
# nothing happend
# channels to scrape remain:  3839
# UCC3lnlFZid2nJsBH434Cwtg
# nothing happend
# channels to scrape remain:  3838
# UClx_IR8_yVIKdFVUTdmaZTw
# nothing happend
# channels to scrape remain:  3837
# UCtqVaytYuUi_Q2t7X-kGfEA
# nothing happend
# channels to scrape remain:  3836
# UC-HvkbTWtG_AC0d-PjQ-9YA
# nothing happend
# channels to scrape remain:  3835
# UCSB_VGbeXaACKeOHs6-BW7w
# nothing happend
# channels to scrape remain:  3834
# UCvsx4mTL00o5NisMGUdOtnQ
# nothing happend
# channels to scrape remain:  3833
# UCKs9uDEgMp0jIQZGQYQRfSg
# nothing happend
# channels to scrape remain:  3832
# UClx_IR8_yVIKdFVUTdmaZTw
# nothing happend
# channels to scrape remain:  3831
# UCm7lHFkt2yB_WzL67aruVBQ
# nothing happend
# channels to scrape remain:  3830
# UC9k-yiEpRHMNVOnOi_aQK8w
# nothing happend
# channels to scrape remain:  3829
# UC_jwYANHgWXCa6wReG5gCvg
# nothing happend
# channels to scrape remain:  3828
# UCjsOOp5U8PCVBWzCs2pcoJA
# nothing happend
# channels to scrape remain:  3827
# UClx_IR8_yVIKdFVUTdmaZTw
# nothing happend
# channels to scrape remain:  3826
# UC9_3h1t3FEvhC-1toDU3fww
# nothing happend
# channels to scrape remain:  3825
# UChJz83ul6FVbYQtJ76UJIQQ
# nothing happend
# channels to scrape remain:  3824
# UCdtXPiqI2cLorKaPrfpKc4g
# nothing happend
# channels to scrape remain:  3823
# UCtYK20bWrSkL1W94noRRTKQ
# nothing happend
# channels to scrape remain:  3822
# UC5xKHjBFYaO-WSGc1j41xKQ
# nothing happend
# channels to scrape remain:  3821
# UC44umO-4X6Hy7yDS9LDaBMw
# nothing happend
# channels to scrape remain:  3820
# UCo-3Qu7AoKwo0co8v79mcYw
# nothing happend
# channels to scrape remain:  3819
# UCyAN55vvo8odHHg7QY1pf5w
# nothing happend
# channels to scrape remain:  3818
# UClPmKCbZdW8yuVtm5ulGthg
# nothing happend
# channels to scrape remain:  3817
# UC0NI5mPkm7JaLXVUdNXy_XQ
# nothing happend
# channels to scrape remain:  3816
# UCvVq8bEmY431dorJsjQn7Rw
# nothing happend
# channels to scrape remain:  3815
# UCgTOAPMLldS_vZsJQJiW4kA
# nothing happend
# channels to scrape remain:  3814
# UCw7FSgzdHFeaIKk4qUD_nEA
# nothing happend
# channels to scrape remain:  3813
# UCttaiawOR1n05CJqmaf0uPw
# nothing happend
# channels to scrape remain:  3812
# UCdtXPiqI2cLorKaPrfpKc4g
# nothing happend
# channels to scrape remain:  3811
# UC9FF5KM0KwEsHQeGFDm_vpQ
# nothing happend
# channels to scrape remain:  3810
# UCiKE6mqbKmGGlNAtccn04MA
# nothing happend
# channels to scrape remain:  3809
# UCiKGMZZmZXK-RpbKJGXgH3Q
# nothing happend
# channels to scrape remain:  3808
# UCOp24og-YLLuvUP4yrJ2cJA
# nothing happend
# channels to scrape remain:  3807
# UCNvywYiv2rpARNbn2yxvoCw
# nothing happend
# channels to scrape remain:  3806
# UCg178cchFvhCClnLWSR5iAw
# nothing happend
# channels to scrape remain:  3805
# UC_gUM8rL-Lrg6O3adPW9K1g
# nothing happend
# channels to scrape remain:  3804
# UCKpKjR-b7yDXpvG1vLJVRMg
# nothing happend
# channels to scrape remain:  3803
# UCiKGMZZmZXK-RpbKJGXgH3Q
# nothing happend
# channels to scrape remain:  3802
# UCKcCf2EiHUbUlBg9ZzOdwaQ
# nothing happend
# channels to scrape remain:  3801
# UCUD4-ngT1Gj-dkluNFO5Nzg
# nothing happend
# channels to scrape remain:  3800
# UCyny-dfYPbE-CjAkzkZqF8A
# nothing happend
# channels to scrape remain:  3799
# UCQxO6eA3RElgwGAVCfIXG_g
# nothing happend
# channels to scrape remain:  3798
# UCStwoQqpSAm70KDYeMuw_Jg
# nothing happend
# channels to scrape remain:  3797
# UCoRpKmC6a-DdEa1ohxlCgUA
# nothing happend
# channels to scrape remain:  3796
# UC5MHSwQ2menwYF2DqKoJsZg
# nothing happend
# channels to scrape remain:  3795
# UClx_IR8_yVIKdFVUTdmaZTw
# nothing happend
# channels to scrape remain:  3794
# UC-HvkbTWtG_AC0d-PjQ-9YA
# nothing happend
# channels to scrape remain:  3793
# UCoMdktPbSTixAyNGwb-UYkQ
# nothing happend
# channels to scrape remain:  3792
# UCgTOAPMLldS_vZsJQJiW4kA
# nothing happend
# channels to scrape remain:  3791
# UC7EDIC3ONWZpN3DLkRzmhww
# nothing happend
# channels to scrape remain:  3790
# UCxU-4Yl1E0xb55Du-r_VOmQ
# nothing happend
# channels to scrape remain:  3789
# UCa-bX3gZC3YnCThlGM5d38Q
# nothing happend
# channels to scrape remain:  3788
# UCP1hdrxYHdebGqbQawOMRpQ
# nothing happend
# channels to scrape remain:  3787
# UCP1hdrxYHdebGqbQawOMRpQ
# nothing happend
# channels to scrape remain:  3786
# UCiKGMZZmZXK-RpbKJGXgH3Q
# nothing happend
# channels to scrape remain:  3785
# UCnt2IBvxywb99E-IMlovwPw
# nothing happend
# channels to scrape remain:  3784
# UClx_IR8_yVIKdFVUTdmaZTw
# nothing happend
# channels to scrape remain:  3783
# UCP1hdrxYHdebGqbQawOMRpQ
# nothing happend
# channels to scrape remain:  3782
# UCSAcQWrCnU0HhtiNinSywcw
# nothing happend
# channels to scrape remain:  3781
# UCoMdktPbSTixAyNGwb-UYkQ
# nothing happend
# channels to scrape remain:  3780
# UCVBZ7bN9BPx3LkMkWSMQL1g
# nothing happend
# channels to scrape remain:  3779
# UCME81PohuzT1JMCsEtvsD2w
# nothing happend
# channels to scrape remain:  3778
# UCVSNOxehfALut52NbkfRBaA
# nothing happend
# channels to scrape remain:  3777
# UCXd0vrOJJyQjH93Rp29E6lw
# nothing happend
# channels to scrape remain:  3776
# UClx_IR8_yVIKdFVUTdmaZTw
# nothing happend
# channels to scrape remain:  3775
# UCDxohNlg033VJysBMEFsFmg
# nothing happend
# channels to scrape remain:  3774
# UCfHRX7ihY8WnSV53NnpKOvQ
# nothing happend
# channels to scrape remain:  3773
# UCP1hdrxYHdebGqbQawOMRpQ
# nothing happend
# channels to scrape remain:  3772
# UC2z6TzoTg6mG0__fprVM0Pg
# nothing happend
# channels to scrape remain:  3771
# UCP1hdrxYHdebGqbQawOMRpQ
# nothing happend
# channels to scrape remain:  3770
# UCP1hdrxYHdebGqbQawOMRpQ
# nothing happend
# channels to scrape remain:  3769
# UCVgO39Bk5sMo66-6o6Spn6Q
# nothing happend
# channels to scrape remain:  3768
# UCfOG0nr5eKCbr3bwwGPPD6Q
# nothing happend
# channels to scrape remain:  3767
# UC-RQtY6MpSkCkaTRQP6G8PQ
# nothing happend
# channels to scrape remain:  3766
# UCI4NUaIMk14z09i7cOj21HQ
# nothing happend
# channels to scrape remain:  3765
# UCP1hdrxYHdebGqbQawOMRpQ
# nothing happend
# channels to scrape remain:  3764
# UCWZMbNAYuV5jRBiCJPsb8iA
# nothing happend
# channels to scrape remain:  3763
# UCMYdetcn43b1ueK0Enb7uMQ
# nothing happend
# channels to scrape remain:  3762
# UC-yXuc1__OzjwpsJPlxYUCQ
# nothing happend
# channels to scrape remain:  3761
# UCttspZesZIDEwwpVIgoZtWQ
# nothing happend
# channels to scrape remain:  3760
# UCbndldfNjGFxZh8tqpfYLMA
# nothing happend
# channels to scrape remain:  3759
# UCebA7V0hwbLl0iFVqQf8d3w
# nothing happend
# channels to scrape remain:  3758
# UCbu2SsF-Or3Rsn3NxqODImw
# nothing happend
# channels to scrape remain:  3757
# UCUINm_sTF9Q_ESf8fO25OdQ
# nothing happend
# channels to scrape remain:  3756
# UChvrjsVdHVprbSTs0u22VNg
# nothing happend
# channels to scrape remain:  3755
# UC1kTetQW6UUPsZpXkVo5iNg
# nothing happend
# channels to scrape remain:  3754
# UCQB8Dy0bCYIylbbI8isOmsA
# nothing happend
# channels to scrape remain:  3753
# UCKWLdR-g4nSWaI8z_MWDqpw
# nothing happend
# channels to scrape remain:  3752
# UCwdogH5kbb9wGy2Amvw6KeQ
# nothing happend
# channels to scrape remain:  3751
# UC7RQon_YwCnp_LbPtEwW65w
# nothing happend
# channels to scrape remain:  3750
# UCAAmkc2sRESFoEtiKRTaTRA
# nothing happend
# channels to scrape remain:  3749
# UC5dfVU9AP52FqgdMA-ElnCQ
# nothing happend
# channels to scrape remain:  3748
# UCyulTHJUWSGB9oKzOpCl3jg
# nothing happend
# channels to scrape remain:  3747
# UCf9sxYLkcxQtd6CyigXFzww
# nothing happend
# channels to scrape remain:  3746
# UCNzsYU0aWwjERj-9Y9HUEng
# nothing happend
# channels to scrape remain:  3745
# UCVSxQ2QXbQpFBY2VsovZ3Ng
# nothing happend
# channels to scrape remain:  3744
# UC1TXbXEwxru6_ceL-WJZk4g
# nothing happend
# channels to scrape remain:  3743
# UCj9peGCfg5X6PrinJKAyCDw
# nothing happend
# channels to scrape remain:  3742
# UCOp24og-YLLuvUP4yrJ2cJA
# nothing happend
# channels to scrape remain:  3741
# UCV4F2f1AiVZktKIv_H6pk5Q
# nothing happend
# channels to scrape remain:  3740
# UCF3TU0vPy1VXPDPW35i1XYA
# nothing happend
# channels to scrape remain:  3739
# UCe9JQN67fXOpATmbLuR9Upw
# nothing happend
# channels to scrape remain:  3738
# UC0L1suV8pVgO4pCAIBNGx5w
# nothing happend
# channels to scrape remain:  3737
# UCmXowOTCAsI37IahflB80Mw
# nothing happend
# channels to scrape remain:  3736
# UCbGqVIL6UDZTeqOHqfm88-Q
# nothing happend
# channels to scrape remain:  3735
# UC0L1suV8pVgO4pCAIBNGx5w
# nothing happend
# channels to scrape remain:  3734
# UCYNSqJqmp1UUL_EAi-5MvwA
# nothing happend
# channels to scrape remain:  3733
# UC0Ri4yolakY_tb7RdcvzQ2g
# nothing happend
# channels to scrape remain:  3732
# UC8XH9kpilkuss4bVeRZD1kw
# nothing happend
# channels to scrape remain:  3731
# UCN7wb2rnmJ8dwzUKUAVJ0Gg
# nothing happend
# channels to scrape remain:  3730
# UCqkf4DybfLN428Y8SOB7SMw
# nothing happend
# channels to scrape remain:  3729
# UC-NINtNMPM75eaqh07RCy_Q
# nothing happend
# channels to scrape remain:  3728
# UCgTOAPMLldS_vZsJQJiW4kA
# nothing happend
# channels to scrape remain:  3727
# UC8EmDCwnG1kAMsUcrW2h7YA
# nothing happend
# channels to scrape remain:  3726
# UC-NINtNMPM75eaqh07RCy_Q
# nothing happend
# channels to scrape remain:  3725
# UCKx9cZzLGtK6ONbvfIA0eVQ
# nothing happend
# channels to scrape remain:  3724
# UC6qZ_DaeHh0OoS7YNUdtm0A
# nothing happend
# channels to scrape remain:  3723
# UCcWHNLPs0qyWilEgol3JXBg
# nothing happend
# channels to scrape remain:  3722
# UC9k-yiEpRHMNVOnOi_aQK8w
# nothing happend
# channels to scrape remain:  3721
# UCABqYaOEelRq1CAwNER4bNQ
# nothing happend
# channels to scrape remain:  3720
# UC2kPBrZ28yIRn_DdVEWSpUg
# nothing happend
# channels to scrape remain:  3719
# UC4ldztgLyJUSVSJkiknVSNw
# nothing happend
# channels to scrape remain:  3718
# UCELg5iAA-Iq0Z8gg5GTMa4Q
# nothing happend
# channels to scrape remain:  3717
# UC8IHAQMuiJdY6ALuhG7iU8Q
# nothing happend
# channels to scrape remain:  3716
# UCFOmZGFw8j2dYiSIhETG0hQ
# nothing happend
# channels to scrape remain:  3715
# UCbGqVIL6UDZTeqOHqfm88-Q
# nothing happend
# channels to scrape remain:  3714
# UCfOG0nr5eKCbr3bwwGPPD6Q
# nothing happend
# channels to scrape remain:  3713
# UCF7mvCrNAdsW102VQQNTgCw
# nothing happend
# channels to scrape remain:  3712
# UCdg5VCB9mW2l1h-f4WTe4_Q
# nothing happend
# channels to scrape remain:  3711
# UC7brTzc5xCEMvpDiRwqWsFA
# nothing happend
# channels to scrape remain:  3710
# UCMDHJ_ARuhNo4P5Fp7JGcjg
# nothing happend
# channels to scrape remain:  3709
# UCKWLdR-g4nSWaI8z_MWDqpw
# nothing happend
# channels to scrape remain:  3708
# UCgF7YFF8z-J4nygkVhavWrQ
# nothing happend
# channels to scrape remain:  3707
# UC3N5y6UWKJaKqoU2b_0MfTQ
# nothing happend
# channels to scrape remain:  3706
# UCGHi_s4RrqUh4hsS4mLbiPg
# nothing happend
# channels to scrape remain:  3705
# UCUINm_sTF9Q_ESf8fO25OdQ
# nothing happend
# channels to scrape remain:  3704
# UC0DZmkupLYwc0yDsfocLh0A
# nothing happend
# channels to scrape remain:  3703
# UC-NINtNMPM75eaqh07RCy_Q
# nothing happend
# channels to scrape remain:  3702
# UC9HlWVtENbiMQzVRmnbJxtw
# nothing happend
# channels to scrape remain:  3701
# UC4kNnrAX9awrM_WtkFF6RXw
# nothing happend
# channels to scrape remain:  3700
# UC-lZTlG05ETwyjDS1JQCv3w
# nothing happend
# channels to scrape remain:  3699
# UCGz67CBdYtW_vzIt9dEs4Eg
# nothing happend
# channels to scrape remain:  3698
# UCgd3NHJ5QGc3LQZwTXSxTrw
# nothing happend
# channels to scrape remain:  3697
# UC1yR66mG1Q6PFz-98fD-OPw
# nothing happend
# channels to scrape remain:  3696
# UC2Bil0FhnT0IY3WToEm1uPw
# nothing happend
# channels to scrape remain:  3695
# UC1ciY6kR3yj3kaKZ6R7ewAg
# nothing happend
# channels to scrape remain:  3694
# UCw4ccFtBN7dhQBcHmE0qylg
# nothing happend
# channels to scrape remain:  3693
# UC4f8fqC_X0fXKBFagTR-u6Q
# nothing happend
# channels to scrape remain:  3692
# UC2a9zmrdjvLsrRgi4G4blWw
# nothing happend
# channels to scrape remain:  3691
# UCFlheJ0BKXo7r6-EcBbNEjw
# file dumped
# channels to scrape remain:  3690
# UC9-B1Z21lS-asqjbQFXop4g
# nothing happend
# channels to scrape remain:  3689
# UCw1kX10EN_ip11g2RwUk3-Q
# nothing happend
# channels to scrape remain:  3688
# UCcoB7_8vWOW88GIFe_SXv6A
# nothing happend
# channels to scrape remain:  3687
# UC0JJ1p6PmIUIxop2kzd6v8g
# nothing happend
# channels to scrape remain:  3686
# UC-lZTlG05ETwyjDS1JQCv3w
# nothing happend
# channels to scrape remain:  3685
# UC_e543N8hiWiItuYlW-wwVw
# nothing happend
# channels to scrape remain:  3684
# UCumPkH2cMfwHBd88hfE5mig
# nothing happend
# channels to scrape remain:  3683
# UCUsN5ZwHx2kILm84-jPDeXw
# nothing happend
# channels to scrape remain:  3682
# UCDPM_n1atn2ijUwHd0NNRQw
# nothing happend
# channels to scrape remain:  3681
# UCJAO8hGZqb36EKmpbtiOFZw
# nothing happend
# channels to scrape remain:  3680
# UC9k-yiEpRHMNVOnOi_aQK8w
# nothing happend
# channels to scrape remain:  3679
# UCdtXPiqI2cLorKaPrfpKc4g
# nothing happend
# channels to scrape remain:  3678
# UCoEqHpK5VNVEBRvwL0EW8Gw
# nothing happend
# channels to scrape remain:  3677
# UC0JJ1p6PmIUIxop2kzd6v8g
# nothing happend
# channels to scrape remain:  3676
# UCTCjFFoX1un-j7ni4B6HJ3Q
# nothing happend
# channels to scrape remain:  3675
# UCLw6wkB9hUunjyGEMdj2Vqw
# nothing happend
# channels to scrape remain:  3674
# UC_h-Fhd4EdT-Ui-KDQZlbQA
# nothing happend
# channels to scrape remain:  3673
# UCQwzWG3NliowM021P5JUV4w
# nothing happend
# channels to scrape remain:  3672
# UC9YHyj7QSkkSg2pjQ7M8Khg
# nothing happend
# channels to scrape remain:  3671
# UCl-aQ8JD0-RvfeZBWFR5jnQ
# nothing happend
# channels to scrape remain:  3670
# UC1_IxWqKu-oFhQQbTkdXe2A
# nothing happend
# channels to scrape remain:  3669
# UCLw6wkB9hUunjyGEMdj2Vqw
# file dumped
# channels to scrape remain:  3668
# UCRA5Q_4jcOHIh2lQiLUzofg
# nothing happend
# channels to scrape remain:  3667
# UCnQC_G5Xsjhp9fEJKuIcrSw
# nothing happend
# channels to scrape remain:  3666
# UCOEFSWsktdvCps-zDNSD1yA
# nothing happend
# channels to scrape remain:  3665
# UCUINm_sTF9Q_ESf8fO25OdQ
# nothing happend
# channels to scrape remain:  3664
# UCYIcmpMvomDsjSPGrG7Yszw
# nothing happend
# channels to scrape remain:  3663
# UCbiT0LUIbQj6CQScvWHJeKQ
# nothing happend
# channels to scrape remain:  3662
# UCOEFSWsktdvCps-zDNSD1yA
# nothing happend
# channels to scrape remain:  3661
# UCOo_v3eVbfET7_zi2KLOP9g
# nothing happend
# channels to scrape remain:  3660
# UCzmkeda2XiYpETOP5MjotrQ
# nothing happend
# channels to scrape remain:  3659
# UCzyUP8w1KCVqFNvX5EtwaMw
# nothing happend
# channels to scrape remain:  3658
# UC-GAhNmY6bkuuRPUSaRI_oQ
# nothing happend
# channels to scrape remain:  3657
# UCfSJLKYTw4yeuxInZ9gOf8w
# nothing happend
# channels to scrape remain:  3656
# UCWkfvm1YaPY8H1rQY6fB60Q
# nothing happend
# channels to scrape remain:  3655
# UC3YPxxRrP5qERmw2DAQSSwg
# nothing happend
# channels to scrape remain:  3654
# UCba7gaWfP4u-093io-hAfdQ
# nothing happend
# channels to scrape remain:  3653
# UCzYfz8uibvnB7Yc1LjePi4g
# nothing happend
# channels to scrape remain:  3652
# UCLzf8UFn260KKesYfes7NAA
# nothing happend
# channels to scrape remain:  3651
# UCRXiA3h1no_PFkb1JCP0yMA
# nothing happend
# channels to scrape remain:  3650
# UCtD-2nsKZg6jyUviLNfGnAg
# nothing happend
# channels to scrape remain:  3649
# UC-GAhNmY6bkuuRPUSaRI_oQ
# nothing happend
# channels to scrape remain:  3648
# UCQVezpgfqPy9_pYVAXj6LyA
# nothing happend
# channels to scrape remain:  3647
# UCylyoo597NuFFyJS_HwHubQ
# nothing happend
# channels to scrape remain:  3646
# UC0YpCsvynhbjTzrS9AIRjiQ
# nothing happend
# channels to scrape remain:  3645
# UCEAMmEsk4dCOsa4p22LzIXg
# nothing happend
# channels to scrape remain:  3644
# UC2IYyHgCMcvMv4ACDCdKmiA
# nothing happend
# channels to scrape remain:  3643
# UC4UkKUNzwgBjyEsAlvqDqCg
# file dumped
# channels to scrape remain:  3642
# UCXTcOUK4-Oy933BDO3DbXLQ
# nothing happend
# channels to scrape remain:  3641
# UCy8YFzbkvYTQOQxjgE3UTBQ
# nothing happend
# channels to scrape remain:  3640
# UCy8YFzbkvYTQOQxjgE3UTBQ
# nothing happend
# channels to scrape remain:  3639
# UCtD-2nsKZg6jyUviLNfGnAg
# nothing happend
# channels to scrape remain:  3638
# UC2KekYVX0xHLa4G9WmcIeJQ
# nothing happend
# channels to scrape remain:  3637
# UCtD-2nsKZg6jyUviLNfGnAg
# nothing happend
# channels to scrape remain:  3636
# UCnSFZ-olBoLGLRUS_3RI2Aw
# nothing happend
# channels to scrape remain:  3635
# UCDPc5dbz5mTTKGV8ejo8vAw
# nothing happend
# channels to scrape remain:  3634
# UCHKj8lQU131wWzQdSPwU7pA
# nothing happend
# channels to scrape remain:  3633
# UCylyoo597NuFFyJS_HwHubQ
# nothing happend
# channels to scrape remain:  3632
# UCPRAvLtPv1NSxVzaoCE-4NQ
# nothing happend
# channels to scrape remain:  3631
# UCy8YFzbkvYTQOQxjgE3UTBQ
# nothing happend
# channels to scrape remain:  3630
# UCvmmAYXP3O2OlDC3alE1Hag
# nothing happend
# channels to scrape remain:  3629
# UCBXOFnNTULFaAnj24PAeblg
# nothing happend
# channels to scrape remain:  3628
# UCUINm_sTF9Q_ESf8fO25OdQ
# file dumped
# channels to scrape remain:  3627
# UC-lZTlG05ETwyjDS1JQCv3w
# nothing happend
# channels to scrape remain:  3626
# UCn896xjjlOv5Uvk02FVHUKw
# nothing happend
# channels to scrape remain:  3625
# UCHwYWmUa2l19pPMAunLMHIA
# nothing happend
# channels to scrape remain:  3624
# UCS94J1s6-qc8v7btCdS2pNg
# nothing happend
# channels to scrape remain:  3623
# UCpf78xcANIGhaCqX65dZbEA
# nothing happend
# channels to scrape remain:  3622
# UC2sloW3tudsSaEpxiqd9hTQ
# nothing happend
# channels to scrape remain:  3621
# UClx_IR8_yVIKdFVUTdmaZTw
# nothing happend
# channels to scrape remain:  3620
# UCL_f53ZEJxp8TtlOkHwMV9Q
# nothing happend
# channels to scrape remain:  3619
# UCfwE_ODI1YTbdjkzuSi1Nag
# nothing happend
# channels to scrape remain:  3618
# UCXTcOUK4-Oy933BDO3DbXLQ
# nothing happend
# channels to scrape remain:  3617
# UCAxriNBFZQPTsj9vBOSnhkA
# nothing happend
# channels to scrape remain:  3616
# UCLw6wkB9hUunjyGEMdj2Vqw
# nothing happend
# channels to scrape remain:  3615
# UCy8YFzbkvYTQOQxjgE3UTBQ
# nothing happend
# channels to scrape remain:  3614
# UCCjE3Unqg5x1tq_YbGVhO-Q
# nothing happend
# channels to scrape remain:  3613
# UCvmmAYXP3O2OlDC3alE1Hag
# nothing happend
# channels to scrape remain:  3612
# UCp0hYYBW6IMayGgR-WeoCvQ
# nothing happend
# channels to scrape remain:  3611
# UCpf78xcANIGhaCqX65dZbEA
# nothing happend
# channels to scrape remain:  3610
# UCPZJ9gQTXilR18LYUSr6hTg
# nothing happend
# channels to scrape remain:  3609
# UCXjgVf0DuctqiK0Ll1rX2gA
# nothing happend
# channels to scrape remain:  3608
# UC_Q5j2_Xfopl6L-tnoJ1vVA
# nothing happend
# channels to scrape remain:  3607
# UCzIdYMdAtTsWucGCZyZvN6w
# nothing happend
# channels to scrape remain:  3606
# UCaFhPje-_jfvLywSdL1MOCg
# nothing happend
# channels to scrape remain:  3605
# UCUPCA_OTKQbuqSWzJuDA7cw
# nothing happend
# channels to scrape remain:  3604
# UCGWPLfa2Z0t8tKM2Y1dlwNQ
# nothing happend
# channels to scrape remain:  3603
# UCAk03rcNVtLK1_LlgRTOh2w
# nothing happend
# channels to scrape remain:  3602
# UCnQC_G5Xsjhp9fEJKuIcrSw
# nothing happend
# channels to scrape remain:  3601
# UCnClOuzfbOj3ZcUKs2GahjA
# nothing happend
# channels to scrape remain:  3600
# UCF-app7i03xbW7gQndSlQBg
# nothing happend
# channels to scrape remain:  3599
# UCy8YFzbkvYTQOQxjgE3UTBQ
# nothing happend
# channels to scrape remain:  3598
# UCLzf8UFn260KKesYfes7NAA
# nothing happend
# channels to scrape remain:  3597
# UCy8YFzbkvYTQOQxjgE3UTBQ
# nothing happend
# channels to scrape remain:  3596
# UCAk03rcNVtLK1_LlgRTOh2w
# nothing happend
# channels to scrape remain:  3595
# UC4qGmRZ7aLOLfVsSdj5Se2A
# nothing happend
# channels to scrape remain:  3594
# UCIk2OuKT6k-KRZdQ3dKtgkQ
# nothing happend
# channels to scrape remain:  3593
# UC1F1u9vPMjAyqSqntUVWEBQ
# nothing happend
# channels to scrape remain:  3592
# UC1_IxWqKu-oFhQQbTkdXe2A
# nothing happend
# channels to scrape remain:  3591
# UCpp1DmO1SVgAb48goF_zpQQ
# nothing happend
# channels to scrape remain:  3590
# UC-GAhNmY6bkuuRPUSaRI_oQ
# nothing happend
# channels to scrape remain:  3589
# UC2GreET5BeuM-dqqBwgGRiw
# nothing happend
# channels to scrape remain:  3588
# UCXTcOUK4-Oy933BDO3DbXLQ
# nothing happend
# channels to scrape remain:  3587
# UCr-rCvgg21KqfrnGopaQeGw
# nothing happend
# channels to scrape remain:  3586
# UCns1IdFyM7Yk459IAgmLlUA
# nothing happend
# channels to scrape remain:  3585
# UC76Ox8Kmn2RGXdm8A1EJoPQ
# nothing happend
# channels to scrape remain:  3584
# UCsEaTDlh3kfgl17DnaRFW2g
# nothing happend
# channels to scrape remain:  3583
# UCrbOGAL69wgXhsRlfozpDiA
# nothing happend
# channels to scrape remain:  3582
# UCjE1-UXvX1HEF2V_XryA_lw
# nothing happend
# channels to scrape remain:  3581
# UCUINm_sTF9Q_ESf8fO25OdQ
# nothing happend
# channels to scrape remain:  3580
# UCMvLMoLRXJWVPKt13TRgGqw
# nothing happend
# channels to scrape remain:  3579
# UC4PziMH5MvvsmqM0VCZTy-g
# nothing happend
# channels to scrape remain:  3578
# UCdRVe2tTgsNA7xVzW1qszSA
# nothing happend
# channels to scrape remain:  3577
# UCwClkA2_fv3Zo36qKN5fcew
# nothing happend
# channels to scrape remain:  3576
# UCAmaiEYnoTgj-dmjp8DpepQ
# nothing happend
# channels to scrape remain:  3575
# UCBTIp2pvN1OtfT5iKwuwGIw
# nothing happend
# channels to scrape remain:  3574
# UC3zAGYlUh608g7afQKe1HfA
# nothing happend
# channels to scrape remain:  3573
# UCsEaTDlh3kfgl17DnaRFW2g
# nothing happend
# channels to scrape remain:  3572
# UCZlnshKh_exh1WBP9P-yPdQ
# nothing happend
# channels to scrape remain:  3571
# UC_gQFJZzAbLTVoxAnoYWzyQ
# nothing happend
# channels to scrape remain:  3570
# UCtMNeiW7rOdKOXhCexxQAyA
# nothing happend
# channels to scrape remain:  3569
# UCnClOuzfbOj3ZcUKs2GahjA
# nothing happend
# channels to scrape remain:  3568
# UCAk03rcNVtLK1_LlgRTOh2w
# nothing happend
# channels to scrape remain:  3567
# UCbiT0LUIbQj6CQScvWHJeKQ
# nothing happend
# channels to scrape remain:  3566
# UC8adimFVj-TL1OqboO_KbsQ
# nothing happend
# channels to scrape remain:  3565
# UCzdBteP334_fj0NKmGmGzHQ
# nothing happend
# channels to scrape remain:  3564
# UCzKrJ5NSA9o7RHYRG12kHZw
# nothing happend
# channels to scrape remain:  3563
# UC1DGpYiEiqBrQtYXFbLhMVQ
# nothing happend
# channels to scrape remain:  3562
# UCctJ98bs1bDo8ckDOcP2QfQ
# nothing happend
# channels to scrape remain:  3561
# UCAmaiEYnoTgj-dmjp8DpepQ
# nothing happend
# channels to scrape remain:  3560
# UClSAHKY9t1n_4NtfNZLS0WA
# nothing happend
# channels to scrape remain:  3559
# UCRJNKeG_dGauXnLZuHnTjEA
# nothing happend
# channels to scrape remain:  3558
# UCWA4Wlrqqk9i011TTOn_qWA
# nothing happend
# channels to scrape remain:  3557
# UCRJNKeG_dGauXnLZuHnTjEA
# nothing happend
# channels to scrape remain:  3556
# UCeooMl4PFAM9kLPHvavt2KQ
# nothing happend
# channels to scrape remain:  3555
# UC48CqsQVp-G-V3dFQ6LJ0LA
# nothing happend
# channels to scrape remain:  3554
# UCGQM-QlnVfwVHTWwEY6xa1A
# nothing happend
# channels to scrape remain:  3553
# UCKhGUjHHG_7345AlifXMllA
# nothing happend
# channels to scrape remain:  3552
# UC52X5wxOL_s5yw0dQk7NtgA
# nothing happend
# channels to scrape remain:  3551
# UC3L8u5qG07djPUwWo6VQVLA
# nothing happend
# channels to scrape remain:  3550
# UCnClOuzfbOj3ZcUKs2GahjA
# nothing happend
# channels to scrape remain:  3549
# UC3l-bobp_xuBlL_lRRS5RmA
# nothing happend
# channels to scrape remain:  3548
# UCE-GLhKd7iMzDeR1_Wyt6Nw
# nothing happend
# channels to scrape remain:  3547
# UCRJNKeG_dGauXnLZuHnTjEA
# nothing happend
# channels to scrape remain:  3546
# UCbp3fkS6cxI1aekmIPIDCGg
# nothing happend
# channels to scrape remain:  3545
# UCS-LOIqrR8BQuIALAVsjNzw
# nothing happend
# channels to scrape remain:  3544
# UCjNWvlu4LNpqL6wpaEc8Q8w
# nothing happend
# channels to scrape remain:  3543
# UCIQz7nN_zTfIoSOh7HasYIQ
# nothing happend
# channels to scrape remain:  3542
# UCospR8ojm4TTRQ9Qx9flkhQ
# nothing happend
# channels to scrape remain:  3541
# UCpqiQ8q14kT1sdlZ0gD0bGg
# nothing happend
# channels to scrape remain:  3540
# UCRJNKeG_dGauXnLZuHnTjEA
# nothing happend
# channels to scrape remain:  3539
# UCxaylBf0QBQk99sHdYYB2Vw
# file dumped
# channels to scrape remain:  3538
# UCHTK-2W11Vh1V4uwofOfR4w
# nothing happend
# channels to scrape remain:  3537
# UCsRWxbIHPAxAc0l_x-l7pBA
# nothing happend
# channels to scrape remain:  3536
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  3535
# UCuGAF2PJVfX_9zHYhaR1KHA
# nothing happend
# channels to scrape remain:  3534
# UCtGeReZOXJ1WLmUzkeuvr-g
# nothing happend
# channels to scrape remain:  3533
# UCVngqxYJ9W2yQuFHKJnj0uA
# nothing happend
# channels to scrape remain:  3532
# UCAC8bBmbBuoKazG0e6eXDbw
# nothing happend
# channels to scrape remain:  3531
# UC52X5wxOL_s5yw0dQk7NtgA
# nothing happend
# channels to scrape remain:  3530
# UCJmUrIx6ignVc1ZSgNNk35w
# nothing happend
# channels to scrape remain:  3529
# UCK6ffF4KAh2zUBVUMR28rCg
# nothing happend
# channels to scrape remain:  3528
# UCcfS47VXepMM2RqazIKz4BQ
# nothing happend
# channels to scrape remain:  3527
# UC-NINtNMPM75eaqh07RCy_Q
# nothing happend
# channels to scrape remain:  3526
# UCE-GLhKd7iMzDeR1_Wyt6Nw
# nothing happend
# channels to scrape remain:  3525
# UCUqs0iLumESUa1MBXssLf_w
# nothing happend
# channels to scrape remain:  3524
# UC6eC9mEH0NOs1Koc47h392Q
# nothing happend
# channels to scrape remain:  3523
# UCnClOuzfbOj3ZcUKs2GahjA
# nothing happend
# channels to scrape remain:  3522
# UCeooMl4PFAM9kLPHvavt2KQ
# nothing happend
# channels to scrape remain:  3521
# UCeooMl4PFAM9kLPHvavt2KQ
# file dumped
# channels to scrape remain:  3520
# UCdUn5TnxJaLo_H207P-SMzQ
# nothing happend
# channels to scrape remain:  3519
# UCeooMl4PFAM9kLPHvavt2KQ
# nothing happend
# channels to scrape remain:  3518
# UCXN0SJDWW4EGeoVCLAfLYkQ
# nothing happend
# channels to scrape remain:  3517
# UCAVgFwnRKj2Ny8M2emfYm9w
# file dumped
# channels to scrape remain:  3516
# UCgmvz6qxtga4W6n1mfmM0Zw
# nothing happend
# channels to scrape remain:  3515
# UCy2Cra7aLAAMVxkA9rSYCxg
# nothing happend
# channels to scrape remain:  3514
# UCAmaiEYnoTgj-dmjp8DpepQ
# nothing happend
# channels to scrape remain:  3513
# UCS3otpN84Vmnhe8rmf0VsdQ
# nothing happend
# channels to scrape remain:  3512
# UC5tNhzKaPN--rZ6qHo4GAVQ
# nothing happend
# channels to scrape remain:  3511
# UC2CSlDXdQl9Zf0amHfVd7aQ
# nothing happend
# channels to scrape remain:  3510
# UCFhdMuy1pMqA9iVXZB7MunA
# nothing happend
# channels to scrape remain:  3509
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# nothing happend
# channels to scrape remain:  3508
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# nothing happend
# channels to scrape remain:  3507
# UCAk03rcNVtLK1_LlgRTOh2w
# nothing happend
# channels to scrape remain:  3506
# UCJ6nMHaJPZvsJ-HmUmj1SeA
# nothing happend
# channels to scrape remain:  3505
# UC-lZTlG05ETwyjDS1JQCv3w
# nothing happend
# channels to scrape remain:  3504
# UCAk03rcNVtLK1_LlgRTOh2w
# nothing happend
# channels to scrape remain:  3503
# UCMAwi5fm2yOSEeKd_Qv0Z2Q
# nothing happend
# channels to scrape remain:  3502
# UCAjuNg3wPDs1MVwdrRyOcBw
# nothing happend
# channels to scrape remain:  3501
# UCHr2DeHbsqHNqt5-jK5-36Q
# nothing happend
# channels to scrape remain:  3500
# UCi-Z5K5YUAAiWNhP2x6UjNw
# nothing happend
# channels to scrape remain:  3499
# UCcrXOqPJU1uaXJLlH2ZYvtQ
# nothing happend
# channels to scrape remain:  3498
# UCAmaiEYnoTgj-dmjp8DpepQ
# file dumped
# channels to scrape remain:  3497
# UC-lZTlG05ETwyjDS1JQCv3w
# nothing happend
# channels to scrape remain:  3496
# UCAmaiEYnoTgj-dmjp8DpepQ
# nothing happend
# channels to scrape remain:  3495
# UCAmaiEYnoTgj-dmjp8DpepQ
# nothing happend
# channels to scrape remain:  3494
# UC4ltvXoxGZobqqduv9iXOWg
# nothing happend
# channels to scrape remain:  3493
# UCVrD2WcTHwTJo4A2r0mjK1A
# nothing happend
# channels to scrape remain:  3492
# UC76Ox8Kmn2RGXdm8A1EJoPQ
# nothing happend
# channels to scrape remain:  3491
# UCaznLylX-htDnmx4rafzuFQ
# nothing happend
# channels to scrape remain:  3490
# UC-lZTlG05ETwyjDS1JQCv3w
# nothing happend
# channels to scrape remain:  3489
# UCeooMl4PFAM9kLPHvavt2KQ
# nothing happend
# channels to scrape remain:  3488
# UCJpDZpmL5dAMnxx4hDMzPxw
# nothing happend
# channels to scrape remain:  3487
# UCjyPrt8jLXObFQfp2S7cqPg
# nothing happend
# channels to scrape remain:  3486
# UCIZdrburxQ6Yp_Kvc5pHCGg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6924/3390686911.py in <module>
#       8     print(video)
#       9     yt = YTstats(API_KEY, video)
# ---> 10     yt.get_video_statistics()
#      11     yt.dump()
#      12     channels_id.remove(video)
#
# ~\AppData\Local\Temp/ipykernel_6924/1791910834.py in get_video_statistics(self)
#       8     def get_video_statistics(self):
#       9         url = f'https://youtube.googleapis.com/youtube/v3/channels?part=snippet&part=contentDetails&part=brandingSettings&part=contentOwnerDetails&part=id&part=localizations&part=statistics&part=status&part=topicDetails&id={self.channel_id}&maxResults=200&key={self.api_key}'
# ---> 10         json_url = requests.get(url)
#      11         data = json.loads(json_url.text)
#      12         nextPageToken = data.get("nextPageToken")
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         # Trigger any extra validation we need to do.
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#     384             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1008         # Force connect early to allow us to validate the connection.
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#    1012         if not conn.is_verified:
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     414             context.load_default_certs()
#     415
# --> 416         self.sock = ssl_wrap_socket(
#     417             sock=conn,
#     418             keyfile=self.key_file,
#
# ~\anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     400     if ca_certs or ca_cert_dir or ca_cert_data:
#     401         try:
# --> 402             context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     403         except (IOError, OSError) as e:
#     404             raise SSLError(e)
#
# KeyboardInterrupt:

# %%
df = pd.read_csv(r'C:\Users\David\OneDrive\Documents\Social Media Analysis\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\combined files\scraped comments- JSON -1.csv')

# %%
channel_ids = df['snippet.topLevelComment.snippet.authorChannelId.value']

# %%
channel_ids.drop_duplicates(inplace=True)

# %%
channel_ids.to_csv('channels_id.csv')

# %%
channel_ids.shape
# Out:
# (10276,)

# %% [markdown]
# # claning scraped ids

# %%
# read scraped ids:
file_url = "./videos_data/13- scraped ids by david  - amber heard job.csv"
new_scraped_ids = pd.read_csv(file_url)
new_scraped_ids.shape
# Out:
# (722, 1)

# %%
# remvove duplicates from its
new_scraped_ids.drop_duplicates(inplace=True)
print(new_scraped_ids.shape)
# Out:
# (717, 1)

# %%
# read totals ids we scraped all the time:
total_ids = pd.read_csv('./total.csv')

# %%
#make lists to comparing
new_ids_list = list(new_scraped_ids['id'])
total_ids_list = list(total_ids['id'])
len(total_ids_list)
# Out:
# 4061

# %%
# see if we collected a video id we have it
not_duplicated_ids = []
for new_id in new_ids_list:
    if new_id not in total_ids_list:
        not_duplicated_ids.append(new_id)
len(not_duplicated_ids)
# Out:
# 393

# %%
# update the csv file to have no duplicated with any ID all the time
not_duplicated_ids_df = pd.DataFrame(not_duplicated_ids, columns=['id'])
not_duplicated_ids_df.to_csv(file_url, index=None)

# %%
total_id_df = pd.read_csv('./total.csv')
total_id_df[total_id_df['id'] == 'hbzIMuH-gug']
# Out:
#                id
# 2062  hbzIMuH-gug
