# %%
import pandas as pd
import os

# %%
ls "../../[CSV] Combined by year [6893 videos](videos, comments and channels) (final 25Dec21)/combined channels info by year"
# Out:
#  Volume in drive D has no label.
#  Volume Serial Number is 4623-EF98
#
#  Directory of D:\New folder\[CSV] Combined by year [6893 videos](videos, comments and channels) (final 25Dec21)\combined channels info by year
#
# 12/26/2021  02:00 PM    <DIR>          .
# 12/26/2021  02:00 PM    <DIR>          ..
# 12/25/2021  01:10 AM         8,990,826 channles_info_2008-2013.csv
# 12/25/2021  01:24 AM        25,645,625 channles_info_2014.csv
# 12/25/2021  12:13 AM        14,046,633 channles_info_2015.csv
# 12/25/2021  12:24 AM        26,616,411 channles_info_2016.csv
# 12/24/2021  11:22 PM        23,032,718 channles_info_2017.csv
# 12/26/2021  02:00 PM       100,570,157 channles_info_2018.csv
# 12/24/2021  08:46 PM        60,045,164 channles_info_2019.csv
# 12/24/2021  05:31 PM       323,916,426 channles_info_2020.csv
# 12/23/2021  11:28 PM       251,573,878 channles_info_2021.csv
#                9 File(s)    834,437,838 bytes
#                2 Dir(s)  63,938,199,552 bytes free

# %%
channels_data = os.listdir(
    "../../[CSV] Combined by year [6893 videos](videos, comments and channels) (final 25Dec21)/combined channels info by year"
)

# %%
channels_data_paths = [
    "../../[CSV] Combined by year [6893 videos](videos, comments and channels) (final 25Dec21)/combined channels info by year/"
    + i
    for i in channels_data
]

# %%
channels_data_paths
# Out:
# ['../../[CSV] Combined by year [6893 videos](videos, comments and channels) (final 25Dec21)/combined channels info by year/channles_info_2008-2013.csv',
#  '../../[CSV] Combined by year [6893 videos](videos, comments and channels) (final 25Dec21)/combined channels info by year/channles_info_2014.csv',
#  '../../[CSV] Combined by year [6893 videos](videos, comments and channels) (final 25Dec21)/combined channels info by year/channles_info_2015.csv',
#  '../../[CSV] Combined by year [6893 videos](videos, comments and channels) (final 25Dec21)/combined channels info by year/channles_info_2016.csv',
#  '../../[CSV] Combined by year [6893 videos](videos, comments and channels) (final 25Dec21)/combined channels info by year/channles_info_2017.csv',
#  '../../[CSV] Combined by year [6893 videos](videos, comments and channels) (final 25Dec21)/combined channels info by year/channles_info_2018.csv',
# ...

# %%
len(channels_data_paths)
# Out:
# 9

# %%
df0 = pd.read_csv(channels_data_paths[0])
df14 = pd.read_csv(channels_data_paths[1])
df15 = pd.read_csv(channels_data_paths[2])
df16 = pd.read_csv(channels_data_paths[3])
df17 = pd.read_csv(channels_data_paths[4])
df18 = pd.read_csv(channels_data_paths[5])
df19 = pd.read_csv(channels_data_paths[6])
df20 = pd.read_csv(channels_data_paths[7])
df21 = pd.read_csv(channels_data_paths[8])

# %%
df_channels = pd.concat([df0, df14, df15, df16, df17, df18, df19, df20, df21])

# %%
df_channels
# Out:
#                    kind                         etag  \
# 0       youtube#channel  9xWBmgJRinhToZwPS8aicoZgDEY
# 1       youtube#channel  keNfPOTzrt8SBeRPvkAeX0JMKws
# 2       youtube#channel  o4YiXuwtwbBgAAJOudKvaU9EH8o
# 3       youtube#channel  1d-q4hifYCDuO2tl6zyuvsglKt0
# 4       youtube#channel  koU4v4cx_bfh5sxWClu4lDoQmL0
# ...                 ...                          ...
# 347613  youtube#channel  -dETwBGWUcXGn87otjwddaC72mQ
# 347614  youtube#channel  nhIHPRGzst71DGEwKBFUdeZ_gkw
# 347615  youtube#channel  cBQZ-R-eJAxFW371DjIt6p55lxw
# 347616  youtube#channel  pAOlNCi6RAd6xiD96kkqK8FNLqo
# 347617  youtube#channel  _dZCowjlfo-pPGFHb-PijgaJGLU
#
#                               id       snippet.title snippet.description  \
# 0       UC--0k43d5M8nmtdf319cEBw   This Side Of Life                 NaN
# 1       UC--88vmCfoADXKrbkr55QBQ         memberWinny                 NaN
# 2       UC--x-JoynEq-qzYTdsxkHog    yarinka collucci                 NaN
# ...

# %%
df_channels["snippet.publishedAt"] = pd.to_datetime(df_channels["snippet.publishedAt"])

# %%
df_channels["snippet.publishedAt"].min()
# Out:
# Timestamp('2005-07-17 14:56:42+0000', tz='UTC')

# %%
df_channels["snippet.publishedAt"].max()
# Out:
# Timestamp('2021-12-07 17:53:46.592160+0000', tz='UTC')

# %%
df_channels["snippet.publishedAt"].dt.year.value_counts()
# Out:
# 2013    120180
# 2016    114355
# 2014    111237
# 2015    109241
# 2020    103670
# 2017    102350
# 2018     91637
# 2012     90331
# 2011     79978
# 2019     73385
# 2010     33386
# 2021     29513
# 2009     26042
# 2006     24730
# 2007     24006
# 2008     20890
# 2005       280
# Name: snippet.publishedAt, dtype: int64

# %%
df_channels[df_channels["snippet.publishedAt"].dt.year == 2021]["snippet.publishedAt"].dt.month.value_counts()
# Out:
# 1     5940
# 2     4027
# 3     3773
# 4     3033
# 5     2989
# 6     2377
# 7     2150
# 8     1837
# 9     1475
# 10    1123
# 11     703
# 12      86
# Name: snippet.publishedAt, dtype: int64

# %%
df_channels_4_months = df_channels[
    (df_channels["snippet.publishedAt"].astype(str) >= "2021-01-01 00:00:00")
    & (df_channels["snippet.publishedAt"].astype(str) < "2021-05-01 00:00:00")
]

# %%
df_channels_4_months.reset_index().drop(columns=["index"])
# Out:
#                   kind                         etag                        id  \
# 0      youtube#channel  9wkQ3eLHc1cH2rfuuAcdtQHcvSA  UC--zjieqNgTZF4TcQtxudZg
# 1      youtube#channel  3d6LWNFcTYP3SIF9MjGuTPRm8Bw  UC-4Hg6knp-Eo3n-yePx15fw
# 2      youtube#channel  H45D2i1wvzxbeWy57S1v55GVXLA  UC-4IcDiJ-K9eNcGH8cA4_LQ
# 3      youtube#channel  0bkNaou76qJPhKM55VPW1X-lTLs  UC-77Wuv1bi4b3gqZgdFhUYA
# 4      youtube#channel  84kqjaZaZx6AVQ6vy6VJBa4WzO4  UC-7yCENb086EeMxv3jI9oGA
# ...                ...                          ...                       ...
# 16768  youtube#channel  _0vEhV_qC0bQhaywoBVsOu6q4Q8  UCZ_8m7dWKnvMBZwzrkj-ZHg
# 16769  youtube#channel  fXL4VtAmhAT0MPS6nbEhsEMpgY4  UCz_bDmYH_PSgw0sVXrEZZpw
# 16770  youtube#channel  N3oJe5VKajo_GWPadtB0Eq20Ik8  UCZ_Me6nWNS2vhVEi9YGkv1Q
# 16771  youtube#channel  faNa6T08lzK4UQlsREriGJ4DlH0  UCZ_OsmQvaSZ3VhknViDfd7w
# 16772  youtube#channel  __bI3zH__JzY7jw-3Kk4Kef7pmw  UCz_rXvkd92AfWAH-E9fV8JA
#
#               snippet.title  \
# ...

# %%
df_channels_4_months
# Out:
#                    kind                         etag  \
# 8       youtube#channel  9wkQ3eLHc1cH2rfuuAcdtQHcvSA
# 47      youtube#channel  3d6LWNFcTYP3SIF9MjGuTPRm8Bw
# 48      youtube#channel  H45D2i1wvzxbeWy57S1v55GVXLA
# 76      youtube#channel  0bkNaou76qJPhKM55VPW1X-lTLs
# 85      youtube#channel  84kqjaZaZx6AVQ6vy6VJBa4WzO4
# ...                 ...                          ...
# 347592  youtube#channel  _0vEhV_qC0bQhaywoBVsOu6q4Q8
# 347594  youtube#channel  fXL4VtAmhAT0MPS6nbEhsEMpgY4
# 347604  youtube#channel  N3oJe5VKajo_GWPadtB0Eq20Ik8
# 347607  youtube#channel  faNa6T08lzK4UQlsREriGJ4DlH0
# 347610  youtube#channel  __bI3zH__JzY7jw-3Kk4Kef7pmw
#
#                               id         snippet.title  \
# 8       UC--zjieqNgTZF4TcQtxudZg              Maria N.
# 47      UC-4Hg6knp-Eo3n-yePx15fw        Josiah Rhodius
# 48      UC-4IcDiJ-K9eNcGH8cA4_LQ                Whoami
# 76      UC-77Wuv1bi4b3gqZgdFhUYA              Joe Blow
# ...

# %%
df14["snippet.publishedAt"] = pd.to_datetime(df14["snippet.publishedAt"])

# %%
# 2014 data
df14["snippet.publishedAt"].min(), df14["snippet.publishedAt"].max()
# Out:
# (Timestamp('2005-10-12 04:45:58+0000', tz='UTC'),
#  Timestamp('2016-02-28 03:48:08+0000', tz='UTC'))

# %%
# 2015 data
df15["snippet.publishedAt"].min(), df15["snippet.publishedAt"].max()
# Out:
# ('2006-01-19T04:04:24Z', '2015-12-31T14:57:34Z')

# %%
# 2016 data
df16["snippet.publishedAt"].min(), df16["snippet.publishedAt"].max()
# Out:
# ('2005-08-31T11:30:49Z', '2016-12-30T16:40:13Z')

# %%
# 2017 data
df17["snippet.publishedAt"].min(), df17["snippet.publishedAt"].max()
# Out:
# ('2005-11-06T04:55:10Z', '2017-12-29T03:12:29Z')

# %%
# 2018 data
df18["snippet.publishedAt"].min(), df18["snippet.publishedAt"].max()
# Out:
# ('2005-07-17T14:56:42Z', '2021-12-01T18:04:21.162217Z')

# %%
# 2019 data
df19["snippet.publishedAt"].min(), df19["snippet.publishedAt"].max()
# Out:
# ('2005-10-25T04:12:21Z', '2021-11-24T14:08:06.173374Z')

# %%
# 2020 data
df20["snippet.publishedAt"].min(), df20["snippet.publishedAt"].max()
# Out:
# ('2005-09-03T15:34:23Z', '2020-12-31T23:49:18.201278Z')

# %%
# 2021 data
df21["snippet.publishedAt"].min(), df21["snippet.publishedAt"].max()
# Out:
# ('2005-07-19T23:34:30Z', '2021-12-07T17:53:46.59216Z')

# %%
df_channels
# Out:
#                    kind                         etag  \
# 0       youtube#channel  9xWBmgJRinhToZwPS8aicoZgDEY
# 1       youtube#channel  keNfPOTzrt8SBeRPvkAeX0JMKws
# 2       youtube#channel  o4YiXuwtwbBgAAJOudKvaU9EH8o
# 3       youtube#channel  1d-q4hifYCDuO2tl6zyuvsglKt0
# 4       youtube#channel  koU4v4cx_bfh5sxWClu4lDoQmL0
# ...                 ...                          ...
# 347613  youtube#channel  -dETwBGWUcXGn87otjwddaC72mQ
# 347614  youtube#channel  nhIHPRGzst71DGEwKBFUdeZ_gkw
# 347615  youtube#channel  cBQZ-R-eJAxFW371DjIt6p55lxw
# 347616  youtube#channel  pAOlNCi6RAd6xiD96kkqK8FNLqo
# 347617  youtube#channel  _dZCowjlfo-pPGFHb-PijgaJGLU
#
#                               id       snippet.title snippet.description  \
# 0       UC--0k43d5M8nmtdf319cEBw   This Side Of Life                 NaN
# 1       UC--88vmCfoADXKrbkr55QBQ         memberWinny                 NaN
# 2       UC--x-JoynEq-qzYTdsxkHog    yarinka collucci                 NaN
# ...

# %%
df_21 = df_channels[
    (df_channels["snippet.publishedAt"].astype(str) >= "2021-01-01 00:00:00")
    & (df_channels["snippet.publishedAt"].astype(str) < "2022-01-01 00:00:00")
]

# %%
df_21.shape
# Out:
# (29513, 41)

# %%
df_20 = df_channels[
    (df_channels["snippet.publishedAt"].astype(str) >= "2020-01-01 00:00:00")
    & (df_channels["snippet.publishedAt"].astype(str) < "2021-01-01 00:00:00")
]

# %%
df_20.shape
# Out:
# (103670, 41)

# %%
df_19 = df_channels[
    (df_channels["snippet.publishedAt"].astype(str) >= "2019-01-01 00:00:00")
    & (df_channels["snippet.publishedAt"].astype(str) < "2020-01-01 00:00:00")
]

# %%
df_19.shape
# Out:
# (73385, 41)

# %%
df_18 = df_channels[
    (df_channels["snippet.publishedAt"].astype(str) >= "2018-01-01 00:00:00")
    & (df_channels["snippet.publishedAt"].astype(str) < "2019-01-01 00:00:00")
]

# %%
df_18.shape
# Out:
# (91637, 41)

# %%
df_17 = df_channels[
    (df_channels["snippet.publishedAt"].astype(str) >= "2017-01-01 00:00:00")
    & (df_channels["snippet.publishedAt"].astype(str) < "2018-01-01 00:00:00")
]

# %%
df_17.shape
# Out:
# (102350, 41)

# %%
df_16 = df_channels[
    (df_channels["snippet.publishedAt"].astype(str) >= "2016-01-01 00:00:00")
    & (df_channels["snippet.publishedAt"].astype(str) < "2017-01-01 00:00:00")
]

# %%
df_16.shape
# Out:
# (114355, 41)

# %%
df_15 = df_channels[
    (df_channels["snippet.publishedAt"].astype(str) >= "2015-01-01 00:00:00")
    & (df_channels["snippet.publishedAt"].astype(str) < "2016-01-01 00:00:00")
]

# %%
df_15.shape
# Out:
# (109241, 41)

# %%
df_14 = df_channels[
    (df_channels["snippet.publishedAt"].astype(str) >= "2014-01-01 00:00:00")
    & (df_channels["snippet.publishedAt"].astype(str) < "2015-01-01 00:00:00")
]

# %%
df_14.shape
# Out:
# (111237, 41)

# %%
df_to_13 = df_channels[
    df_channels["snippet.publishedAt"].astype(str) < "2014-01-01 00:00:00"
]

# %%
df_to_13.shape
# Out:
# (419823, 41)
