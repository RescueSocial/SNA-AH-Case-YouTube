# %%
import pandas as pd

# %%
cd ..
# Out:
# D:\New folder (2)

# %%
cd "Filtered Data"
# Out:
# D:\New folder (2)\Filtered Data

# %%
ls
# Out:
#  Volume in drive D has no label.
#  Volume Serial Number is 4623-EF98
#
#  Directory of D:\New folder (2)\Filtered Data
#
# 12/20/2021  09:15 PM    <DIR>          .
# 12/20/2021  09:15 PM    <DIR>          ..
# 12/12/2021  11:33 PM       634,954,679 combined files for videos comments info batch 1.csv
# 12/15/2021  11:13 AM       617,952,589 combined files for videos comments info batch 2.csv
# 12/15/2021  11:33 AM       248,907,504 combined files for videos comments info batch 3.csv
# 12/12/2021  11:30 PM       128,779,150 combined files for videos comments info batch 4.csv
# 12/20/2021  09:24 PM     1,393,902,878 initial_merged_data.csv
#                5 File(s)  3,024,496,800 bytes
#                2 Dir(s)  59,083,964,416 bytes free

# %%
df_original = pd.read_csv("initial_merged_data.csv", low_memory=False)

# %%
df = df_original.copy()

# %%
df.head(1)
# Out:
#    index                         etag                          id  \
# 0      0  HWRVF49a2ObDyvftwuVdJKNhyD8  UgyWYCQS7evmvfmJS-N4AaABAg
#
#   snippet.videoId snippet.topLevelComment.etag  snippet.topLevelComment.id  \
# 0     14SUI93R_k8  Iovx9zUM7fOXxqPCM-3iKToEaKw  UgyWYCQS7evmvfmJS-N4AaABAg
#
#   snippet.topLevelComment.snippet.videoId  \
# 0                             14SUI93R_k8
#
#   snippet.topLevelComment.snippet.textDisplay  \
# 0             Are you going to see Aquaman 2?
#
#   snippet.topLevelComment.snippet.textOriginal  \
# 0              Are you going to see Aquaman 2?
#
#   snippet.topLevelComment.snippet.authorDisplayName  ...  \
# 0                                    InformOverload  ...
#
#   snippet.topLevelComment.snippet.authorChannelId.value  \
# 0                           UC-NINtNMPM75eaqh07RCy_Q
#
#   snippet.topLevelComment.snippet.canRate  \
# 0                                    True
#
#    snippet.topLevelComment.snippet.likeCount  \
# ...

# %%
df.tail(1)
# Out:
#           index                         etag                          id  \
# 1702094  120213  3QejFaK_rNcrlEc_94HP8C8Urq0  UgzgZHG0CRvc_zKHgut4AaABAg
#
#         snippet.videoId snippet.topLevelComment.etag  \
# 1702094     Wsn4aXVptWU  iShSomRtKR4ffGzusCTnC8yFssg
#
#          snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 1702094  UgzgZHG0CRvc_zKHgut4AaABAg                             Wsn4aXVptWU
#
#         snippet.topLevelComment.snippet.textDisplay  \
# 1702094                                           😂
#
#         snippet.topLevelComment.snippet.textOriginal  \
# 1702094                                            😂
#
#         snippet.topLevelComment.snippet.authorDisplayName  ...  \
# 1702094                                         Crispy Co  ...
#
#         snippet.topLevelComment.snippet.authorChannelId.value  \
# 1702094                           UCrGYhxT7EHyrpcyGmgjYOMQ
#
#         snippet.topLevelComment.snippet.canRate  \
# ...

# %%
df.shape
# Out:
# (1702095, 21)

# %%
# drop index column (old index for batches separated data)
df.drop(columns=["index"], inplace=True)

# %%
def get_columns_info(df):
    print("{:<55} |  {:<13} |  {:<12} |".format("Column", "DType", "NUnique"))
    print("-" * 90)
    for col in df.columns:
        print("{:<55} |  {:<13} |  {:<12} |".format(col, str(type(df[col][0]))[8:-2], df[col].nunique()))
        print("-" * 90)

# %%
get_columns_info(df)
# Out:
# Column                                                  |  DType         |  NUnique      |
# ------------------------------------------------------------------------------------------
# etag                                                    |  str           |  1693524      |
# ------------------------------------------------------------------------------------------
# id                                                      |  str           |  1693341      |
# ------------------------------------------------------------------------------------------
# snippet.videoId                                         |  str           |  5314         |
# ------------------------------------------------------------------------------------------
# snippet.topLevelComment.etag                            |  str           |  1693479      |
# ------------------------------------------------------------------------------------------
# ...

# %%
df.etag.value_counts()
# Out:
# D4kDirXZ_NwglYch6fvPrPhgq9s    2
# SIxOVrRqI9dg2R8MRbhRuX1U9tQ    2
# rH4I2YMQ9Bjo5EC0vwnJKGy_b70    2
# 2vgdvWXvQSGC5-vuEqvZqNcGbks    2
# 6qgI8n1Olo-WqeFEA779jiFxpFs    2
#                               ..
# TJqyANXtSDBdIaUPKufQ0wsfu_Q    1
# gxIlk7EKETxTXLEd0I2Q6ysV9JM    1
# Z2UStltDjBR8qrhe1cMt4uSofy4    1
# BWdoF0JhqC_h5BJVHFgZw8pxj8c    1
# bZf0qnfqU2dWDPDqTfLNUtMICxU    1
# Name: etag, Length: 1693524, dtype: int64

# %%
df.etag.value_counts().index[0]
# Out:
# 'D4kDirXZ_NwglYch6fvPrPhgq9s'

# %%
df[df['etag'] == 'D4kDirXZ_NwglYch6fvPrPhgq9s']
# Out:
#                                 etag                          id  \
# 1699316  D4kDirXZ_NwglYch6fvPrPhgq9s  Ugzy1muQekaThx0tqCt4AaABAg
# 1699681  D4kDirXZ_NwglYch6fvPrPhgq9s  Ugzy1muQekaThx0tqCt4AaABAg
#
#         snippet.videoId snippet.topLevelComment.etag  \
# 1699316     yNsBNU9JDUk  slgF9T3YhI6X09fVM-LYIBiWjCA
# 1699681     yNsBNU9JDUk  slgF9T3YhI6X09fVM-LYIBiWjCA
#
#          snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 1699316  Ugzy1muQekaThx0tqCt4AaABAg                             yNsBNU9JDUk
# 1699681  Ugzy1muQekaThx0tqCt4AaABAg                             yNsBNU9JDUk
#
#                snippet.topLevelComment.snippet.textDisplay  \
# 1699316  Fudge Amber Turd!!!  She’s such a nasty person...
# 1699681  Fudge Amber Turd!!!  She’s such a nasty person...
#
#               snippet.topLevelComment.snippet.textOriginal  \
# 1699316  Fudge Amber Turd!!!  She’s such a nasty person...
# 1699681  Fudge Amber Turd!!!  She’s such a nasty person...
#
# ...

# %%
df[df['etag'] == df.etag.value_counts().index[1]]
# Out:
#                                 etag                          id  \
# 1582916  SIxOVrRqI9dg2R8MRbhRuX1U9tQ  UgzE4u9JlquF_TsmueJ4AaABAg
# 1583210  SIxOVrRqI9dg2R8MRbhRuX1U9tQ  UgzE4u9JlquF_TsmueJ4AaABAg
#
#         snippet.videoId snippet.topLevelComment.etag  \
# 1582916     MoNTBFo9eqE  EDt8AGdXmk4GD1XC8NYfyOzMKJo
# 1583210     MoNTBFo9eqE  EDt8AGdXmk4GD1XC8NYfyOzMKJo
#
#          snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 1582916  UgzE4u9JlquF_TsmueJ4AaABAg                             MoNTBFo9eqE
# 1583210  UgzE4u9JlquF_TsmueJ4AaABAg                             MoNTBFo9eqE
#
#                snippet.topLevelComment.snippet.textDisplay  \
# 1582916  Does this mean she was creating/destroying evi...
# 1583210  Does this mean she was creating/destroying evi...
#
#               snippet.topLevelComment.snippet.textOriginal  \
# 1582916  Does this mean she was creating/destroying evi...
# 1583210  Does this mean she was creating/destroying evi...
#
# ...

# %%
df[df['etag'] == df.etag.value_counts().index[2]]
# Out:
#                                etag                          id  \
# 3192    rH4I2YMQ9Bjo5EC0vwnJKGy_b70  UgzsVI1rW94u9JjKxyx4AaABAg
# 656992  rH4I2YMQ9Bjo5EC0vwnJKGy_b70  UgzsVI1rW94u9JjKxyx4AaABAg
#
#        snippet.videoId snippet.topLevelComment.etag  \
# 3192       -elJS12UOnI  1S0t2ZngzRfFquhIuDIMZvY2-c4
# 656992     -elJS12UOnI  1S0t2ZngzRfFquhIuDIMZvY2-c4
#
#         snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 3192    UgzsVI1rW94u9JjKxyx4AaABAg                             -elJS12UOnI
# 656992  UgzsVI1rW94u9JjKxyx4AaABAg                             -elJS12UOnI
#
#               snippet.topLevelComment.snippet.textDisplay  \
# 3192    So they want to hire a husband beater to play ...
# 656992  So they want to hire a husband beater to play ...
#
#              snippet.topLevelComment.snippet.textOriginal  \
# 3192    So they want to hire a husband beater to play ...
# 656992  So they want to hire a husband beater to play ...
#
# ...

# %%
df[df['etag'] == df.etag.value_counts().index[3]]
# Out:
#                                etag                          id  \
# 492896  2vgdvWXvQSGC5-vuEqvZqNcGbks  UgwSNHqcCRGylHD6pg14AaABAg
# 772554  2vgdvWXvQSGC5-vuEqvZqNcGbks  UgwSNHqcCRGylHD6pg14AaABAg
#
#        snippet.videoId snippet.topLevelComment.etag  \
# 492896     -sKyN0_D_ec  Kuo4FedPIXIO3Jv0UlpDWtTcrFU
# 772554     -sKyN0_D_ec  Kuo4FedPIXIO3Jv0UlpDWtTcrFU
#
#         snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 492896  UgwSNHqcCRGylHD6pg14AaABAg                             -sKyN0_D_ec
# 772554  UgwSNHqcCRGylHD6pg14AaABAg                             -sKyN0_D_ec
#
#               snippet.topLevelComment.snippet.textDisplay  \
# 492896  She actually seems mentally unstable. Like she...
# 772554  She actually seems mentally unstable. Like she...
#
#              snippet.topLevelComment.snippet.textOriginal  \
# 492896  She actually seems mentally unstable. Like she...
# 772554  She actually seems mentally unstable. Like she...
#
# ...

# %%
df[df.duplicated()].sort_values('snippet.topLevelComment.snippet.publishedAt')
# Out:
#                                 etag                          id  \
# 1607601  ahvqG13IueIS30tdlB2qZzPQeAs        Ugha4eA4RYuzPHgCoAEC
# 1658729  M80fG6L9kOw2IMkvQhqQfiDGutY        UgiLU4yEj85tT3gCoAEC
# 1658728  FSWR3D-SKB01tteFZDa7z4VNYX0        UghhwhmufbPmqXgCoAEC
# 1658727  -3bupp3YlYx46DKLO64POSePt38        Ugh4LobCdxGdgngCoAEC
# 1658726  VlM2q6ZAVHM9vDhd4EuiduFNNlI        UgiR4126ZBJaz3gCoAEC
# ...                              ...                         ...
# 1687944  zAIKZd5UhSj5fEXbEmkEdbPdXZ0  UgwpQv6Q7HJVAD7dDgx4AaABAg
# 1658432  PVbD41kNfEms0qzXtrFWzwWyoew  UgzkgVyVxN4Gi5Yztq14AaABAg
# 1658431  9gDUdm0UVv0WdDWu3dt9MUEdako  Ugz4WAsfa_Tv3WWQQO94AaABAg
# 1658430  DfCjGkGKH8zsTn8c08K8EENSn6g  UgxuAHHFmPCkgcPXHbh4AaABAg
# 1658429  u4Ny2H7XcTxNoDCBzYSXv2LBJXk  UgwmJI1wQhLUWQYKcfZ4AaABAg
#
#         snippet.videoId snippet.topLevelComment.etag  \
# 1607601     Y7KWx9dUI6U  vQRtVMf0_ZRxf-edFEWyO3qSxBw
# 1658729     6DgzkGeaYnU  Q4qkBHN4f_hwQi0ftmhcRG1I6xQ
# ...

# %%
df[df['etag'] == "ahvqG13IueIS30tdlB2qZzPQeAs"]
# Out:
#                                 etag                    id snippet.videoId  \
# 1607552  ahvqG13IueIS30tdlB2qZzPQeAs  Ugha4eA4RYuzPHgCoAEC     Y7KWx9dUI6U
# 1607601  ahvqG13IueIS30tdlB2qZzPQeAs  Ugha4eA4RYuzPHgCoAEC     Y7KWx9dUI6U
#
#         snippet.topLevelComment.etag snippet.topLevelComment.id  \
# 1607552  vQRtVMf0_ZRxf-edFEWyO3qSxBw       Ugha4eA4RYuzPHgCoAEC
# 1607601  vQRtVMf0_ZRxf-edFEWyO3qSxBw       Ugha4eA4RYuzPHgCoAEC
#
#         snippet.topLevelComment.snippet.videoId  \
# 1607552                             Y7KWx9dUI6U
# 1607601                             Y7KWx9dUI6U
#
#         snippet.topLevelComment.snippet.textDisplay  \
# 1607552                                  team amber
# 1607601                                  team amber
#
#         snippet.topLevelComment.snippet.textOriginal  \
# 1607552                                   team amber
# 1607601                                   team amber
#
#         snippet.topLevelComment.snippet.authorDisplayName  \
# ...

# %%
# drop duplicates
df.drop_duplicates(keep="first", inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [etag, id, snippet.videoId, snippet.topLevelComment.etag, snippet.topLevelComment.id, snippet.topLevelComment.snippet.videoId, snippet.topLevelComment.snippet.textDisplay, snippet.topLevelComment.snippet.textOriginal, snippet.topLevelComment.snippet.authorDisplayName, snippet.topLevelComment.snippet.authorChannelUrl, snippet.topLevelComment.snippet.authorChannelId.value, snippet.topLevelComment.snippet.canRate, snippet.topLevelComment.snippet.likeCount, snippet.topLevelComment.snippet.publishedAt, snippet.topLevelComment.snippet.updatedAt, snippet.canReply, snippet.totalReplyCount, snippet.isPublic, replies.comments, snippet.topLevelComment.snippet.moderationStatus]
# Index: []

# %%
df["etag"].nunique(), df.shape[0]
# Out:
# (1693524, 1693524)

# %%
df["id"].nunique(), df.shape[0]
# Out:
# (1693341, 1693524)

# %%
sum(df["id"].duplicated())
# Out:
# 183

# %%
df[df["id"].duplicated()].
# Out:
#                                 etag                          id  \
# 643104   -Zq9q4OGnDTDdUyt26-hnLTLoNA  UgzdTTitSBT3_gIVPgR4AaABAg
# 643132   Ff4SFXvG9YLv1KVyS-c4-20SiF4  UgzwcOB4Rnt0U1gAReF4AaABAg
# 643153   bpCJoPxAnP_FAAI4SOclEJwwQm8  UgzCoiNc0lpEflaYr6F4AaABAg
# 643206   IOjwN8KGft62kIuln7Ff6OCWjg8  Ugy-2MKJJs_XgzRNB_J4AaABAg
# 643225   4-b2JFTJ3IH70gqXjE3uRQbf3bc  UgxuTWck-E7xWh8_z8R4AaABAg
# ...                              ...                         ...
# 1629313  oopa9wsKTuYPrURUUZmMja4lc2E  UgzR8TLLoQPkl5BNjet4AaABAg
# 1667562  LeAWWuBZv1cgLvHkT78Pz_guKOI  UgwTr6CWkorRJY7c3yh4AaABAg
# 1678801  D3BjMc9h-Yf4zV76p7PW3TBtDpA  UgyZ1rXHYtkziSmpURl4AaABAg
# 1678802  _Je2DinlFbPTYtE01GQX5tKe4_g  UgyPj7VE-zd8eH-pAal4AaABAg
# 1690763  Hh0tWoRh88daPrhkWlfmW2_hnGY  UgwJpPXLJf5PXYPnU5p4AaABAg
#
#         snippet.videoId snippet.topLevelComment.etag  \
# 643104      -cqVoAzrhs8  Oh2oOI6OuxQnpnnZss_g3KHLuO0
# 643132      -cqVoAzrhs8  N37Er1YdFsMcymYPL0yHyuYkzmo
# ...

# %%
df[df.id == "UgzdTTitSBT3_gIVPgR4AaABAg"]
# Out:
#                                etag                          id  \
# 445446  j5SOTkY4S9VO7C842YDW-KfPdBc  UgzdTTitSBT3_gIVPgR4AaABAg
# 643104  -Zq9q4OGnDTDdUyt26-hnLTLoNA  UgzdTTitSBT3_gIVPgR4AaABAg
#
#        snippet.videoId snippet.topLevelComment.etag  \
# 445446     -cqVoAzrhs8  XN9Lr71wBE20sk9KjPJkjnxbso0
# 643104     -cqVoAzrhs8  Oh2oOI6OuxQnpnnZss_g3KHLuO0
#
#         snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 445446  UgzdTTitSBT3_gIVPgR4AaABAg                             -cqVoAzrhs8
# 643104  UgzdTTitSBT3_gIVPgR4AaABAg                             -cqVoAzrhs8
#
#        snippet.topLevelComment.snippet.textDisplay  \
# 445446                  Do amber respect anyone!!!
# 643104                  Do amber respect anyone!!!
#
#        snippet.topLevelComment.snippet.textOriginal  \
# 445446                   Do amber respect anyone!!!
# 643104                   Do amber respect anyone!!!
#
#        snippet.topLevelComment.snippet.authorDisplayName  \
# ...

# %%
set((df["id"] == df["snippet.topLevelComment.id"]).values)
# Out:
# {True}

# %% [markdown]
# The **id** column is the same as **snippet.topLevelComment.id**

# %%
# drop id column
df.drop(columns=["id"], inplace=True)

# %%
set((df["snippet.videoId"] == df["snippet.topLevelComment.snippet.videoId"]).values)
# Out:
# {True}

# %% [markdown]
# The **snippet.videoId** column is the same as **snippet.topLevelComment.snippet.videoId**

# %%
# drop snippet.videoId column
df.drop(columns=["snippet.videoId"], inplace=True)

# %%
df.head(1)
# Out:
#                           etag snippet.topLevelComment.etag  \
# 0  HWRVF49a2ObDyvftwuVdJKNhyD8  Iovx9zUM7fOXxqPCM-3iKToEaKw
#
#    snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 0  UgyWYCQS7evmvfmJS-N4AaABAg                             14SUI93R_k8
#
#   snippet.topLevelComment.snippet.textDisplay  \
# 0             Are you going to see Aquaman 2?
#
#   snippet.topLevelComment.snippet.textOriginal  \
# 0              Are you going to see Aquaman 2?
#
#   snippet.topLevelComment.snippet.authorDisplayName  \
# 0                                    InformOverload
#
#     snippet.topLevelComment.snippet.authorChannelUrl  \
# 0  http://www.youtube.com/channel/UC-NINtNMPM75ea...
#
#   snippet.topLevelComment.snippet.authorChannelId.value  \
# 0                           UC-NINtNMPM75eaqh07RCy_Q
#
#    snippet.topLevelComment.snippet.canRate  \
# 0                                     True
#
#    snippet.topLevelComment.snippet.likeCount  \
# ...

# %%
df.drop(columns=["snippet.topLevelComment.snippet.textDisplay"], inplace=True)

# %%
df.head(1)
# Out:
#                           etag snippet.topLevelComment.etag  \
# 0  HWRVF49a2ObDyvftwuVdJKNhyD8  Iovx9zUM7fOXxqPCM-3iKToEaKw
#
#    snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 0  UgyWYCQS7evmvfmJS-N4AaABAg                             14SUI93R_k8
#
#   snippet.topLevelComment.snippet.textOriginal  \
# 0              Are you going to see Aquaman 2?
#
#   snippet.topLevelComment.snippet.authorDisplayName  \
# 0                                    InformOverload
#
#     snippet.topLevelComment.snippet.authorChannelUrl  \
# 0  http://www.youtube.com/channel/UC-NINtNMPM75ea...
#
#   snippet.topLevelComment.snippet.authorChannelId.value  \
# 0                           UC-NINtNMPM75eaqh07RCy_Q
#
#    snippet.topLevelComment.snippet.canRate  \
# 0                                     True
#
#    snippet.topLevelComment.snippet.likeCount  \
# 0                                       94.0
#
#   snippet.topLevelComment.snippet.publishedAt  \
# ...

# %%
set((df["snippet.topLevelComment.snippet.updatedAt"] == df["snippet.topLevelComment.snippet.publishedAt"]).values)
# Out:
# {False, True}

# %%
df[~(df["snippet.topLevelComment.snippet.updatedAt"] == df["snippet.topLevelComment.snippet.publishedAt"])]
# Out:
#                                 etag snippet.topLevelComment.etag  \
# 12       nrFlokf6WF6jodWvTCI_d-rEPy4  KGw-YqKck699CwP6oflu1mQt3UQ
# 33       9bSSmEwwkPNzst-nDFqoALPdyZQ  2zV8cIoLTWuru8KDeIf9uG7jvlk
# 34       Ts5Y6eQRT2RHbCTLHvxArxZKWBk  VWHtlXOXIpdrnn5tXJy37tmowIY
# 48       Rsmg-ct8BJQX0XV4BFzX1wq5bEg  zvf0BLKj2F1ioUNRs-dvxh3Oy1w
# 69       8PXhM6hIEHGa4GaxFaQoOkXox1c  uBBHsMx3Amzx0xcB86fKDV0Pb88
# ...                              ...                          ...
# 1702079  w5EZad20sop4IzxCP-UNcq4X4u8  Zpl0ckfy0MqqnsT82pu98SjjiH8
# 1702080  5OA2gt2JK4YW0973Nw6iNiW17nE  KTLrz9acLsVmWC9V1HH4oWXsHyk
# 1702082  N_J50COrofYRzSQ5Glr-9zQDFB0  QuWPtZp0B_L9d854sBC-85oxdls
# 1702087  mfSy9fPvkc9MbdLbonIsa0urDRk  qemvV2OXUlR6N6GPNDGHcStTlgo
# 1702093  Djgx-tI8TbgiuAiI8YP6csDZCro  ApmfWVz2fdgj77pYH0Iw2eIupmE
#
#          snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 12       Ugw4WlHPY6QpNS5UInp4AaABAg                             14SUI93R_k8
# ...

# %% [markdown]
# |                       Old Name                        |                                                                                           Definition                                                                                            | New Name |
# | :---------------------------------------------------- | :---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | :------- |
# | etag                                                  | The ETag (or entity tag) An ETag's job, in context of a conditional get is to differentiate a resource from another version of itself. If a resource is updated (changed), so to must its ETag. | a        |
# | id                                                    | a                                                                                                                                                                                               | a        |
# | video_id                                              | video id                                                                                                                                                                                               | a        |
# | topLevelComment_etag                                  | a                                                                                                                                                                                               | a        |
# | topLevelComment_id                                    | a                                                                                                                                                                                               | a        |
# | topLevelComment_snippet_videoId                       | a                                                                                                                                                                                               | a        |
# | snippet.topLevelComment.snippet.textDisplay           | a                                                                                                                                                                                               | a        |
# | snippet.topLevelComment.snippet.textOriginal          | a                                                                                                                                                                                               | a        |
# | snippet.topLevelComment.snippet.authorDisplayName     | a                                                                                                                                                                                               | a        |
# | snippet.topLevelComment.snippet.authorChannelUrl      | a                                                                                                                                                                                               | a        |
# | snippet.topLevelComment.snippet.authorChannelId.value | a                                                                                                                                                                                               | a        |
# | snippet.topLevelComment.snippet.canRate               | a                                                                                                                                                                                               | a        |
# | snippet.topLevelComment.snippet.likeCount             | a                                                                                                                                                                                               | a        |
# | snippet.topLevelComment.snippet.publishedAt           | a                                                                                                                                                                                               | a        |
# | snippet.topLevelComment.snippet.updatedAt             | a                                                                                                                                                                                               | a        |
# | snippet.canReply                                      | a                                                                                                                                                                                               | a        |
# | snippet.totalReplyCount                               | a                                                                                                                                                                                               | a        |
# | snippet.isPublic                                      | a                                                                                                                                                                                               | a        |
# | replies.comments                                      | a                                                                                                                                                                                               | a        |
# | snippet.topLevelComment.snippet.moderationStatus      | a                                                                                                                                                                                               | a        |
