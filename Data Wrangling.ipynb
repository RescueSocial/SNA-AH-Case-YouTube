# %%
import pandas as pd
pd.set_option('display.max_columns', 100)

# %%
cd ..
# Out:
# D:\New folder (2)

# %%
cd "Filtered Data"
# Out:
# D:\New folder (2)\Filtered Data

# %%
ls
# Out:
#  Volume in drive D has no label.
#  Volume Serial Number is 4623-EF98
#
#  Directory of D:\New folder (2)\Filtered Data
#
# 12/20/2021  09:15 PM    <DIR>          .
# 12/20/2021  09:15 PM    <DIR>          ..
# 12/12/2021  11:33 PM       634,954,679 combined files for videos comments info batch 1.csv
# 12/15/2021  11:13 AM       617,952,589 combined files for videos comments info batch 2.csv
# 12/15/2021  11:33 AM       248,907,504 combined files for videos comments info batch 3.csv
# 12/12/2021  11:30 PM       128,779,150 combined files for videos comments info batch 4.csv
# 12/20/2021  09:24 PM     1,393,902,878 initial_merged_data.csv
#                5 File(s)  3,024,496,800 bytes
#                2 Dir(s)  59,083,194,368 bytes free

# %%
df_original = pd.read_csv("initial_merged_data.csv", low_memory=False)

# %%
df = df_original.copy()

# %%
df.head(1)
# Out:
#    index                         etag                          id  \
# 0      0  HWRVF49a2ObDyvftwuVdJKNhyD8  UgyWYCQS7evmvfmJS-N4AaABAg
#
#   snippet.videoId snippet.topLevelComment.etag  snippet.topLevelComment.id  \
# 0     14SUI93R_k8  Iovx9zUM7fOXxqPCM-3iKToEaKw  UgyWYCQS7evmvfmJS-N4AaABAg
#
#   snippet.topLevelComment.snippet.videoId  \
# 0                             14SUI93R_k8
#
#   snippet.topLevelComment.snippet.textDisplay  \
# 0             Are you going to see Aquaman 2?
#
#   snippet.topLevelComment.snippet.textOriginal  \
# 0              Are you going to see Aquaman 2?
#
#   snippet.topLevelComment.snippet.authorDisplayName  ...  \
# 0                                    InformOverload  ...
#
#   snippet.topLevelComment.snippet.authorChannelId.value  \
# 0                           UC-NINtNMPM75eaqh07RCy_Q
#
#   snippet.topLevelComment.snippet.canRate  \
# 0                                    True
#
#    snippet.topLevelComment.snippet.likeCount  \
# ...

# %%
df.tail(1)
# Out:
#           index                         etag                          id  \
# 1702094  120213  3QejFaK_rNcrlEc_94HP8C8Urq0  UgzgZHG0CRvc_zKHgut4AaABAg
#
#         snippet.videoId snippet.topLevelComment.etag  \
# 1702094     Wsn4aXVptWU  iShSomRtKR4ffGzusCTnC8yFssg
#
#          snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 1702094  UgzgZHG0CRvc_zKHgut4AaABAg                             Wsn4aXVptWU
#
#         snippet.topLevelComment.snippet.textDisplay  \
# 1702094                                           😂
#
#         snippet.topLevelComment.snippet.textOriginal  \
# 1702094                                            😂
#
#         snippet.topLevelComment.snippet.authorDisplayName  ...  \
# 1702094                                         Crispy Co  ...
#
#         snippet.topLevelComment.snippet.authorChannelId.value  \
# 1702094                           UCrGYhxT7EHyrpcyGmgjYOMQ
#
#         snippet.topLevelComment.snippet.canRate  \
# ...

# %%
df.shape
# Out:
# (1702095, 21)

# %%
# drop index column (old index for batches separated data)
df.drop(columns=["index"], inplace=True)

# %%
def get_columns_info(df):
    print("{:<55} |  {:<13} |  {:<12} |".format("Column", "DType", "NUnique"))
    print("-" * 90)
    for col in df.columns:
        print("{:<55} |  {:<13} |  {:<12} |".format(col, str(type(df[col][0]))[8:-2], df[col].nunique()))
        print("-" * 90)

# %%
get_columns_info(df)
# Out:
# Column                                                  |  DType         |  NUnique      |
# ------------------------------------------------------------------------------------------
# etag                                                    |  str           |  1693524      |
# ------------------------------------------------------------------------------------------
# id                                                      |  str           |  1693341      |
# ------------------------------------------------------------------------------------------
# snippet.videoId                                         |  str           |  5314         |
# ------------------------------------------------------------------------------------------
# snippet.topLevelComment.etag                            |  str           |  1693479      |
# ------------------------------------------------------------------------------------------
# ...

# %%
df.etag.value_counts()
# Out:
# ANkxl7VU-4K9l2XflYgUhvPxsCQ    2
# eBJvZQiRXL3OFwq4O1u0-tq1P_0    2
# JPW43AQjjWmKR6Sln-pKaNiqqjI    2
# zSHkjKBkVT92QhJV089R-pAa5kY    2
# 6pQehYcd3kn7S8Fsq6G1RXkEEoc    2
#                               ..
# Cw_hK_ZUbiKVnL7S0219g33ofE0    1
# DTzms_RELisar7e02NvRDwdWuq4    1
# U6vWq58fpXoxWBsoYf178UUwJKo    1
# 75irKSkDFDi9o9mdR98zBccp4vU    1
# 3nIjA-5laa_mr_fj80rpc-MaAOI    1
# Name: etag, Length: 1693524, dtype: int64

# %%
df.etag.value_counts().index[0]
# Out:
# 'ANkxl7VU-4K9l2XflYgUhvPxsCQ'

# %%
df[df['etag'] == 'D4kDirXZ_NwglYch6fvPrPhgq9s']
# Out:
#                                 etag                          id  \
# 1699316  D4kDirXZ_NwglYch6fvPrPhgq9s  Ugzy1muQekaThx0tqCt4AaABAg
# 1699681  D4kDirXZ_NwglYch6fvPrPhgq9s  Ugzy1muQekaThx0tqCt4AaABAg
#
#         snippet.videoId snippet.topLevelComment.etag  \
# 1699316     yNsBNU9JDUk  slgF9T3YhI6X09fVM-LYIBiWjCA
# 1699681     yNsBNU9JDUk  slgF9T3YhI6X09fVM-LYIBiWjCA
#
#          snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 1699316  Ugzy1muQekaThx0tqCt4AaABAg                             yNsBNU9JDUk
# 1699681  Ugzy1muQekaThx0tqCt4AaABAg                             yNsBNU9JDUk
#
#                snippet.topLevelComment.snippet.textDisplay  \
# 1699316  Fudge Amber Turd!!!  She’s such a nasty person...
# 1699681  Fudge Amber Turd!!!  She’s such a nasty person...
#
#               snippet.topLevelComment.snippet.textOriginal  \
# 1699316  Fudge Amber Turd!!!  She’s such a nasty person...
# 1699681  Fudge Amber Turd!!!  She’s such a nasty person...
#
# ...

# %%
df[df['etag'] == df.etag.value_counts().index[1]]
# Out:
#                                 etag                    id snippet.videoId  \
# 1689120  eBJvZQiRXL3OFwq4O1u0-tq1P_0  UgjHaLzePkrrk3gCoAEC     hnKYtXxMVU8
# 1689398  eBJvZQiRXL3OFwq4O1u0-tq1P_0  UgjHaLzePkrrk3gCoAEC     hnKYtXxMVU8
#
#         snippet.topLevelComment.etag snippet.topLevelComment.id  \
# 1689120  WRG_bYTGTwnfNxl-XbmVVohM60w       UgjHaLzePkrrk3gCoAEC
# 1689398  WRG_bYTGTwnfNxl-XbmVVohM60w       UgjHaLzePkrrk3gCoAEC
#
#         snippet.topLevelComment.snippet.videoId  \
# 1689120                             hnKYtXxMVU8
# 1689398                             hnKYtXxMVU8
#
#                snippet.topLevelComment.snippet.textDisplay  \
# 1689120  Its not a crap storm = it is a victim and her ...
# 1689398  Its not a crap storm = it is a victim and her ...
#
#               snippet.topLevelComment.snippet.textOriginal  \
# 1689120  Its not a crap storm = it is a victim and her ...
# 1689398  Its not a crap storm = it is a victim and her ...
#
# ...

# %%
df[df['etag'] == df.etag.value_counts().index[2]]
# Out:
#                                 etag                          id  \
# 495963   JPW43AQjjWmKR6Sln-pKaNiqqjI  UgzGcDe83cIhIofxte14AaABAg
# 1223912  JPW43AQjjWmKR6Sln-pKaNiqqjI  UgzGcDe83cIhIofxte14AaABAg
#
#         snippet.videoId snippet.topLevelComment.etag  \
# 495963      -XI7pxiK2L8  sLURnA0lSevOTYIOQ6KsCCnL7LQ
# 1223912     -XI7pxiK2L8  sLURnA0lSevOTYIOQ6KsCCnL7LQ
#
#          snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 495963   UgzGcDe83cIhIofxte14AaABAg                             -XI7pxiK2L8
# 1223912  UgzGcDe83cIhIofxte14AaABAg                             -XI7pxiK2L8
#
#                snippet.topLevelComment.snippet.textDisplay  \
# 495963   I think marriage counseling can really help (d...
# 1223912  I think marriage counseling can really help (d...
#
#               snippet.topLevelComment.snippet.textOriginal  \
# 495963   I think marriage counseling can really help (d...
# 1223912  I think marriage counseling can really help (d...
#
# ...

# %%
df[df['etag'] == df.etag.value_counts().index[3]]
# Out:
#                                 etag                          id  \
# 1655611  zSHkjKBkVT92QhJV089R-pAa5kY  UgygGWGRCKfCQpfGX894AaABAg
# 1656058  zSHkjKBkVT92QhJV089R-pAa5kY  UgygGWGRCKfCQpfGX894AaABAg
#
#         snippet.videoId snippet.topLevelComment.etag  \
# 1655611     DpNGiAziRhk  BAhvO5bYikKssNjBhEgp6MlXjXM
# 1656058     DpNGiAziRhk  BAhvO5bYikKssNjBhEgp6MlXjXM
#
#          snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 1655611  UgygGWGRCKfCQpfGX894AaABAg                             DpNGiAziRhk
# 1656058  UgygGWGRCKfCQpfGX894AaABAg                             DpNGiAziRhk
#
#                snippet.topLevelComment.snippet.textDisplay  \
# 1655611  50mil? It seems too small for all the things s...
# 1656058  50mil? It seems too small for all the things s...
#
#               snippet.topLevelComment.snippet.textOriginal  \
# 1655611  50mil? It seems too small for all the things s...
# 1656058  50mil? It seems too small for all the things s...
#
# ...

# %%
df[df.duplicated()].sort_values('snippet.topLevelComment.snippet.publishedAt')
# Out:
#                                 etag                          id  \
# 1607601  ahvqG13IueIS30tdlB2qZzPQeAs        Ugha4eA4RYuzPHgCoAEC
# 1658729  M80fG6L9kOw2IMkvQhqQfiDGutY        UgiLU4yEj85tT3gCoAEC
# 1658728  FSWR3D-SKB01tteFZDa7z4VNYX0        UghhwhmufbPmqXgCoAEC
# 1658727  -3bupp3YlYx46DKLO64POSePt38        Ugh4LobCdxGdgngCoAEC
# 1658726  VlM2q6ZAVHM9vDhd4EuiduFNNlI        UgiR4126ZBJaz3gCoAEC
# ...                              ...                         ...
# 1687944  zAIKZd5UhSj5fEXbEmkEdbPdXZ0  UgwpQv6Q7HJVAD7dDgx4AaABAg
# 1658432  PVbD41kNfEms0qzXtrFWzwWyoew  UgzkgVyVxN4Gi5Yztq14AaABAg
# 1658431  9gDUdm0UVv0WdDWu3dt9MUEdako  Ugz4WAsfa_Tv3WWQQO94AaABAg
# 1658430  DfCjGkGKH8zsTn8c08K8EENSn6g  UgxuAHHFmPCkgcPXHbh4AaABAg
# 1658429  u4Ny2H7XcTxNoDCBzYSXv2LBJXk  UgwmJI1wQhLUWQYKcfZ4AaABAg
#
#         snippet.videoId snippet.topLevelComment.etag  \
# 1607601     Y7KWx9dUI6U  vQRtVMf0_ZRxf-edFEWyO3qSxBw
# 1658729     6DgzkGeaYnU  Q4qkBHN4f_hwQi0ftmhcRG1I6xQ
# ...

# %%
df[df['etag'] == "ahvqG13IueIS30tdlB2qZzPQeAs"]
# Out:
#                                 etag                    id snippet.videoId  \
# 1607552  ahvqG13IueIS30tdlB2qZzPQeAs  Ugha4eA4RYuzPHgCoAEC     Y7KWx9dUI6U
# 1607601  ahvqG13IueIS30tdlB2qZzPQeAs  Ugha4eA4RYuzPHgCoAEC     Y7KWx9dUI6U
#
#         snippet.topLevelComment.etag snippet.topLevelComment.id  \
# 1607552  vQRtVMf0_ZRxf-edFEWyO3qSxBw       Ugha4eA4RYuzPHgCoAEC
# 1607601  vQRtVMf0_ZRxf-edFEWyO3qSxBw       Ugha4eA4RYuzPHgCoAEC
#
#         snippet.topLevelComment.snippet.videoId  \
# 1607552                             Y7KWx9dUI6U
# 1607601                             Y7KWx9dUI6U
#
#         snippet.topLevelComment.snippet.textDisplay  \
# 1607552                                  team amber
# 1607601                                  team amber
#
#         snippet.topLevelComment.snippet.textOriginal  \
# 1607552                                   team amber
# 1607601                                   team amber
#
#         snippet.topLevelComment.snippet.authorDisplayName  \
# ...

# %%
# drop duplicates
df.drop_duplicates(keep="first", inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [etag, id, snippet.videoId, snippet.topLevelComment.etag, snippet.topLevelComment.id, snippet.topLevelComment.snippet.videoId, snippet.topLevelComment.snippet.textDisplay, snippet.topLevelComment.snippet.textOriginal, snippet.topLevelComment.snippet.authorDisplayName, snippet.topLevelComment.snippet.authorChannelUrl, snippet.topLevelComment.snippet.authorChannelId.value, snippet.topLevelComment.snippet.canRate, snippet.topLevelComment.snippet.likeCount, snippet.topLevelComment.snippet.publishedAt, snippet.topLevelComment.snippet.updatedAt, snippet.canReply, snippet.totalReplyCount, snippet.isPublic, replies.comments, snippet.topLevelComment.snippet.moderationStatus]
# Index: []

# %%
df["etag"].nunique(), df.shape[0]
# Out:
# (1693524, 1693524)

# %%
df["id"].nunique(), df.shape[0]
# Out:
# (1693341, 1693524)

# %%
sum(df["id"].duplicated())
# Out:
# 183

# %%
df[df["id"].duplicated()]
# Out:
#                                 etag                          id  \
# 643104   -Zq9q4OGnDTDdUyt26-hnLTLoNA  UgzdTTitSBT3_gIVPgR4AaABAg
# 643132   Ff4SFXvG9YLv1KVyS-c4-20SiF4  UgzwcOB4Rnt0U1gAReF4AaABAg
# 643153   bpCJoPxAnP_FAAI4SOclEJwwQm8  UgzCoiNc0lpEflaYr6F4AaABAg
# 643206   IOjwN8KGft62kIuln7Ff6OCWjg8  Ugy-2MKJJs_XgzRNB_J4AaABAg
# 643225   4-b2JFTJ3IH70gqXjE3uRQbf3bc  UgxuTWck-E7xWh8_z8R4AaABAg
# ...                              ...                         ...
# 1629313  oopa9wsKTuYPrURUUZmMja4lc2E  UgzR8TLLoQPkl5BNjet4AaABAg
# 1667562  LeAWWuBZv1cgLvHkT78Pz_guKOI  UgwTr6CWkorRJY7c3yh4AaABAg
# 1678801  D3BjMc9h-Yf4zV76p7PW3TBtDpA  UgyZ1rXHYtkziSmpURl4AaABAg
# 1678802  _Je2DinlFbPTYtE01GQX5tKe4_g  UgyPj7VE-zd8eH-pAal4AaABAg
# 1690763  Hh0tWoRh88daPrhkWlfmW2_hnGY  UgwJpPXLJf5PXYPnU5p4AaABAg
#
#         snippet.videoId snippet.topLevelComment.etag  \
# 643104      -cqVoAzrhs8  Oh2oOI6OuxQnpnnZss_g3KHLuO0
# 643132      -cqVoAzrhs8  N37Er1YdFsMcymYPL0yHyuYkzmo
# ...

# %%
df[df.id == "UgzdTTitSBT3_gIVPgR4AaABAg"]
# Out:
#                                etag                          id  \
# 445446  j5SOTkY4S9VO7C842YDW-KfPdBc  UgzdTTitSBT3_gIVPgR4AaABAg
# 643104  -Zq9q4OGnDTDdUyt26-hnLTLoNA  UgzdTTitSBT3_gIVPgR4AaABAg
#
#        snippet.videoId snippet.topLevelComment.etag  \
# 445446     -cqVoAzrhs8  XN9Lr71wBE20sk9KjPJkjnxbso0
# 643104     -cqVoAzrhs8  Oh2oOI6OuxQnpnnZss_g3KHLuO0
#
#         snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 445446  UgzdTTitSBT3_gIVPgR4AaABAg                             -cqVoAzrhs8
# 643104  UgzdTTitSBT3_gIVPgR4AaABAg                             -cqVoAzrhs8
#
#        snippet.topLevelComment.snippet.textDisplay  \
# 445446                  Do amber respect anyone!!!
# 643104                  Do amber respect anyone!!!
#
#        snippet.topLevelComment.snippet.textOriginal  \
# 445446                   Do amber respect anyone!!!
# 643104                   Do amber respect anyone!!!
#
#        snippet.topLevelComment.snippet.authorDisplayName  \
# ...

# %%
set((df["id"] == df["snippet.topLevelComment.id"]).values)
# Out:
# {True}

# %% [markdown]
# The **id** column is the same as **snippet.topLevelComment.id**

# %%
# drop id column
df.drop(columns=["id"], inplace=True)

# %%
set((df["snippet.videoId"] == df["snippet.topLevelComment.snippet.videoId"]).values)
# Out:
# {True}

# %% [markdown]
# The **snippet.videoId** column is the same as **snippet.topLevelComment.snippet.videoId**

# %%
# drop snippet.videoId column
df.drop(columns=["snippet.videoId"], inplace=True)

# %%
df.head(1)
# Out:
#                           etag snippet.topLevelComment.etag  \
# 0  HWRVF49a2ObDyvftwuVdJKNhyD8  Iovx9zUM7fOXxqPCM-3iKToEaKw
#
#    snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 0  UgyWYCQS7evmvfmJS-N4AaABAg                             14SUI93R_k8
#
#   snippet.topLevelComment.snippet.textDisplay  \
# 0             Are you going to see Aquaman 2?
#
#   snippet.topLevelComment.snippet.textOriginal  \
# 0              Are you going to see Aquaman 2?
#
#   snippet.topLevelComment.snippet.authorDisplayName  \
# 0                                    InformOverload
#
#     snippet.topLevelComment.snippet.authorChannelUrl  \
# 0  http://www.youtube.com/channel/UC-NINtNMPM75ea...
#
#   snippet.topLevelComment.snippet.authorChannelId.value  \
# 0                           UC-NINtNMPM75eaqh07RCy_Q
#
#    snippet.topLevelComment.snippet.canRate  \
# 0                                     True
#
#    snippet.topLevelComment.snippet.likeCount  \
# ...

# %%
df.drop(columns=["snippet.topLevelComment.snippet.textDisplay"], inplace=True)

# %%
df.head(1)
# Out:
#                           etag snippet.topLevelComment.etag  \
# 0  HWRVF49a2ObDyvftwuVdJKNhyD8  Iovx9zUM7fOXxqPCM-3iKToEaKw
#
#    snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 0  UgyWYCQS7evmvfmJS-N4AaABAg                             14SUI93R_k8
#
#   snippet.topLevelComment.snippet.textOriginal  \
# 0              Are you going to see Aquaman 2?
#
#   snippet.topLevelComment.snippet.authorDisplayName  \
# 0                                    InformOverload
#
#     snippet.topLevelComment.snippet.authorChannelUrl  \
# 0  http://www.youtube.com/channel/UC-NINtNMPM75ea...
#
#   snippet.topLevelComment.snippet.authorChannelId.value  \
# 0                           UC-NINtNMPM75eaqh07RCy_Q
#
#    snippet.topLevelComment.snippet.canRate  \
# 0                                     True
#
#    snippet.topLevelComment.snippet.likeCount  \
# 0                                       94.0
#
#   snippet.topLevelComment.snippet.publishedAt  \
# ...

# %%
set((df["snippet.topLevelComment.snippet.updatedAt"] == df["snippet.topLevelComment.snippet.publishedAt"]).values)
# Out:
# {False, True}

# %%
df[~(df["snippet.topLevelComment.snippet.updatedAt"] == df["snippet.topLevelComment.snippet.publishedAt"])]
# Out:
#                                 etag snippet.topLevelComment.etag  \
# 12       nrFlokf6WF6jodWvTCI_d-rEPy4  KGw-YqKck699CwP6oflu1mQt3UQ
# 33       9bSSmEwwkPNzst-nDFqoALPdyZQ  2zV8cIoLTWuru8KDeIf9uG7jvlk
# 34       Ts5Y6eQRT2RHbCTLHvxArxZKWBk  VWHtlXOXIpdrnn5tXJy37tmowIY
# 48       Rsmg-ct8BJQX0XV4BFzX1wq5bEg  zvf0BLKj2F1ioUNRs-dvxh3Oy1w
# 69       8PXhM6hIEHGa4GaxFaQoOkXox1c  uBBHsMx3Amzx0xcB86fKDV0Pb88
# ...                              ...                          ...
# 1702079  w5EZad20sop4IzxCP-UNcq4X4u8  Zpl0ckfy0MqqnsT82pu98SjjiH8
# 1702080  5OA2gt2JK4YW0973Nw6iNiW17nE  KTLrz9acLsVmWC9V1HH4oWXsHyk
# 1702082  N_J50COrofYRzSQ5Glr-9zQDFB0  QuWPtZp0B_L9d854sBC-85oxdls
# 1702087  mfSy9fPvkc9MbdLbonIsa0urDRk  qemvV2OXUlR6N6GPNDGHcStTlgo
# 1702093  Djgx-tI8TbgiuAiI8YP6csDZCro  ApmfWVz2fdgj77pYH0Iw2eIupmE
#
#          snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 12       Ugw4WlHPY6QpNS5UInp4AaABAg                             14SUI93R_k8
# ...

# %%
different_text = pd.DataFrame(~(df_original[
    ~(
        df_original["snippet.topLevelComment.snippet.updatedAt"]
        == df_original["snippet.topLevelComment.snippet.publishedAt"]
    )
]["snippet.topLevelComment.snippet.textDisplay"] == df_original[
    ~(
        df_original["snippet.topLevelComment.snippet.updatedAt"]
        == df_original["snippet.topLevelComment.snippet.publishedAt"]
    )
][
    "snippet.topLevelComment.snippet.textOriginal"
]))

# %%
list(different_text[different_text[0] == True].index)
# Out:
# [82,
#  108,
#  115,
#  118,
#  132,
#  225,
#  246,
#  254,
#  263,
#  276,
#  281,
#  332,
#  345,
#  412,
#  413,
#  421,
#  441,
#  461,
#  465,
#  534,
#  581,
#  666,
#  686,
#  708,
#  713,
#  716,
#  739,
#  749,
#  761,
#  835,
#  877,
#  879,
#  905,
#  941,
#  951,
#  972,
#  1001,
#  1041,
#  1056,
#  1082,
#  1088,
#  1099,
#  1100,
#  1121,
#  1151,
#  1222,
#  1237,
#  1244,
#  1251,
#  1264,
#  1268,
#  1290,
#  1325,
#  1367,
#  1410,
#  1414,
#  1430,
#  1476,
#  1494,
#  1498,
#  1517,
#  1554,
#  1563,
#  1570,
#  1578,
#  1580,
#  1586,
#  1621,
#  1642,
#  1650,
#  1665,
#  1668,
#  1675,
#  1714,
#  1722,
#  1735,
#  1742,
#  1748,
#  1751,
#  1753,
#  1754,
#  1770,
#  1823,
#  1830,
#  1833,
#  1840,
#  1842,
#  1912,
#  1927,
#  1928,
#  1935,
#  1951,
#  1966,
#  1994,
#  2112,
#  2152,
#  2154,
#  2185,
#  2201,
#  2213,
#  2250,
#  2294,
#  2334,
#  2411,
#  2496,
#  2716,
#  2740,
#  2818,
#  2848,
#  2857,
#  2945,
#  3002,
#  3011,
#  3015,
#  3043,
# ...

# %%
df_original.iloc[
    df_original.index.isin(list(different_text[different_text[0] == True].index))
    ]
# Out:
#           index                         etag                          id  \
# 82           82  cVYqo4ztmuS_9L3l9_baFIsS92g  UgxyQns6z-5qNRUMx8N4AaABAg
# 108         108  N5J6U9jmHgJGPBwmF72FVizilCc  Ugxl7RLqRCYkxBHagR94AaABAg
# 115         115  ctpucewjJ6ZClH3xclWmo5rlQ_k  UgyPRbCi4QESygd3MyB4AaABAg
# 118         118  Shi8Qa_NKFgC3TylS5p9MqoLsIY  UgwroovFv9Ms75gIDvh4AaABAg
# 132         132  rDmCJgOUjqMoGjUrWorH6hRwN0o  Ugxo5rzdM_mRPfNmE-Z4AaABAg
# ...         ...                          ...                         ...
# 1702039  120158  oxFWGSEKsx1D4J8BP79G6NGipLA  UgyrF5FZr1-Ji2jrKy14AaABAg
# 1702041  120160  F9LN9TbaqTuxbfSOuZAW6n88VNc  UgwbpuUmQLuzRh290sJ4AaABAg
# 1702064  120183  gb2ZAgnSORsDNj3cOqFDePhRmFQ  Ugx9viffA8gaSQHto7p4AaABAg
# 1702075  120194  Tiarwe9ncjz382X_DdUIlSIkyks  UgwiEeay8Js9rY_QyEB4AaABAg
# 1702082  120201  N_J50COrofYRzSQ5Glr-9zQDFB0  UgxX5qoZvLLdccs5jcV4AaABAg
#
#         snippet.videoId snippet.topLevelComment.etag  \
# ...

# %% [markdown]
# No need to **textDisplay**

# %%
df.head(1)
# Out:
#                           etag snippet.topLevelComment.etag  \
# 0  HWRVF49a2ObDyvftwuVdJKNhyD8  Iovx9zUM7fOXxqPCM-3iKToEaKw
#
#    snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 0  UgyWYCQS7evmvfmJS-N4AaABAg                             14SUI93R_k8
#
#   snippet.topLevelComment.snippet.textOriginal  \
# 0              Are you going to see Aquaman 2?
#
#   snippet.topLevelComment.snippet.authorDisplayName  \
# 0                                    InformOverload
#
#     snippet.topLevelComment.snippet.authorChannelUrl  \
# 0  http://www.youtube.com/channel/UC-NINtNMPM75ea...
#
#   snippet.topLevelComment.snippet.authorChannelId.value  \
# 0                           UC-NINtNMPM75eaqh07RCy_Q
#
#    snippet.topLevelComment.snippet.canRate  \
# 0                                     True
#
#    snippet.topLevelComment.snippet.likeCount  \
# 0                                       94.0
#
#   snippet.topLevelComment.snippet.publishedAt  \
# ...

# %%
df["snippet.topLevelComment.etag"].value_counts()
# Out:
# 7FiuhUdAi0SifF28sFglJ80PgI0    2
# NMKtC2m5xfLx_x453B4JUOuZoug    2
# RyjCnjt3yT7Bt6-6-Bhn-NCKjk0    2
# sF8nKiKpDmwRxbfo8zk1xdhw_1U    2
# clN8tNqzJBVW2M4N-peByU-wowk    2
#                               ..
# TwHfjWjPbdDvCKhdkt8Qgsk8xXc    1
# -nLfpGh93WPCQW6Cjdgld5dWo-c    1
# Rt9UZ-kfEBulTbAZL50zKlX6efg    1
# 5ESARzwo-khLcQZIifEaukD4fRk    1
# GmwMj5HAyQMt-lz_q50VzH_H1fk    1
# Name: snippet.topLevelComment.etag, Length: 1693479, dtype: int64

# %%
df["snippet.topLevelComment.id"].value_counts().head(10)
# Out:
# UgwJpPXLJf5PXYPnU5p4AaABAg    2
# UgxVrH7CKnulEVw5bBx4AaABAg    2
# UgxC7YTUn9iu8KZWHBN4AaABAg    2
# UgxozucbP5isuwjbfp94AaABAg    2
# UgzeMwTwtB2QufMU9c14AaABAg    2
# UgxpxjAUbB4rL8EjVUl4AaABAg    2
# Ugx0W87eoUzKqx9s8Hx4AaABAg    2
# UgyPvI8GuAoS4Iy-DVJ4AaABAg    2
# UgxEmh_MiHte2A6SE414AaABAg    2
# Ugyy_KwYNcR68h6KKWh4AaABAg    2
# Name: snippet.topLevelComment.id, dtype: int64

# %% [markdown]
# **replies.comments**

# %%
df[df["snippet.topLevelComment.etag"] == "nUhmi7XSfJNGwXLh_z1wm0IghO8"]
# Out:
#                                etag snippet.topLevelComment.etag  \
# 113482  uDAojw-EFuk17mLlU6M33eo87x4  nUhmi7XSfJNGwXLh_z1wm0IghO8
# 736987  sgxhrape3SfR4ZvEjfP5kq6Mfek  nUhmi7XSfJNGwXLh_z1wm0IghO8
#
#         snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 113482  Ugx3TaFx2pj0clyas1x4AaABAg                             -qHw0PtrdQI
# 736987  Ugx3TaFx2pj0clyas1x4AaABAg                             -qHw0PtrdQI
#
#              snippet.topLevelComment.snippet.textOriginal  \
# 113482  Never heard of her before Johnny Depp married ...
# 736987  Never heard of her before Johnny Depp married ...
#
#        snippet.topLevelComment.snippet.authorDisplayName  \
# 113482                                    Margaret Shull
# 736987                                    Margaret Shull
#
#          snippet.topLevelComment.snippet.authorChannelUrl  \
# 113482  http://www.youtube.com/channel/UCQcKJcxVDSQmlc...
# 736987  http://www.youtube.com/channel/UCQcKJcxVDSQmlc...
#
# ...

# %%
import ast
# checking one value
reply_comment = ast.literal_eval(
    df[df["snippet.topLevelComment.etag"] == "nUhmi7XSfJNGwXLh_z1wm0IghO8"][
        "replies.comments"
    ].values[0]
)[0]

# %%
reply_comment.keys()
# Out:
# dict_keys(['kind', 'etag', 'id', 'snippet'])

# %%
for k, v in reply_comment.items():
    print('-',k,':',v)
# Out:
# - kind : youtube#comment
# - etag : QlO_jxZ0DYYS-SGnVXBEF7AFvY8
# - id : Ugx3TaFx2pj0clyas1x4AaABAg.9LsoAcHqkbu9Lwtqb-GYKH
# ...

# %%
reply_comment["snippet"].keys()
# Out:
# dict_keys(['videoId', 'textDisplay', 'textOriginal', 'parentId', 'authorDisplayName', 'authorProfileImageUrl', 'authorChannelUrl', 'authorChannelId', 'canRate', 'viewerRating', 'likeCount', 'publishedAt', 'updatedAt'])

# %%
for k, v in reply_comment["snippet"].items():
    print('-',k,':',v)
# Out:
# - videoId : -qHw0PtrdQI
# - textDisplay : 💓Thanks for your utmost love and support which has brought me this far. It has been a hard time for me but your support has got me standing even in difficult times. I can&#39;t appreciate enough the support of fans who have been really active with issues relating to me...Private message on telegram @johnnydeppllofficial<br>  <br><br>      💓 Much Love ❤️
# - textOriginal : 💓Thanks for your utmost love and support which has brought me this far. It has been a hard time for me but your support has got me standing even in difficult times. I can't appreciate enough the support of fans who have been really active with issues relating to me...Private message on telegram @johnnydeppllofficial
#
#
#       💓 Much Love ❤️
# - parentId : Ugx3TaFx2pj0clyas1x4AaABAg
# - authorDisplayName : Michael Keaton
# - authorProfileImageUrl : https://yt3.ggpht.com/JH6BmofHFtEMWZeFcZHKMKWu2j2gH9j5MhGTUcZ7GhbNxAUIY1g8uoexDYdMc1H65o8cVN7S=s48-c-k-c0x00ffffff-no-rj
# ...

# %%
reply_comment2 = ast.literal_eval(
    df[df["snippet.topLevelComment.etag"] == "nUhmi7XSfJNGwXLh_z1wm0IghO8"][
        "replies.comments"
    ].values[1]
)[0]

# %%
for k, v in reply_comment2.items():
    print('-',k,':',v)
# Out:
# - kind : youtube#comment
# - etag : mb12IrzRoOnDCr8KKYGoAcRiQpA
# - id : Ugx3TaFx2pj0clyas1x4AaABAg.9LsoAcHqkbu9Lwtqb-GYKH
# ...

# %%
for k, v in reply_comment2["snippet"].items():
    print('-',k,':',v)
# Out:
# - videoId : -qHw0PtrdQI
# - textDisplay : 💓Thanks for your utmost love and support which has brought me this far. It has been a hard time for me but your support has got me standing even in difficult times. I can&#39;t appreciate enough the support of fans who have been really active with issues relating to me...Private message on telegram @johnnydeppllofficial<br>  <br><br>      💓 Much Love ❤️
# - textOriginal : 💓Thanks for your utmost love and support which has brought me this far. It has been a hard time for me but your support has got me standing even in difficult times. I can't appreciate enough the support of fans who have been really active with issues relating to me...Private message on telegram @johnnydeppllofficial
#
#
#       💓 Much Love ❤️
# - parentId : Ugx3TaFx2pj0clyas1x4AaABAg
# - authorDisplayName : Brendan Fraser
# - authorProfileImageUrl : https://yt3.ggpht.com/N8SY-BxVVxEil-uTwAO9H78AOHylevdFSvd0f3Psaa7sCh-n7ACYJo-Dde8qOKqCyC6U9CxFPA=s48-c-k-c0x00ffffff-no-rj
# ...

# %%
x =reply_comment
y = reply_comment2

# %%
diff_items = {k: x[k] for k in x if k in y and x[k] != y[k]}
print(diff_items)
# Out:
# {'etag': 'QlO_jxZ0DYYS-SGnVXBEF7AFvY8', 'snippet': {'videoId': '-qHw0PtrdQI', 'textDisplay': '💓Thanks for your utmost love and support which has brought me this far. It has been a hard time for me but your support has got me standing even in difficult times. I can&#39;t appreciate enough the support of fans who have been really active with issues relating to me...Private message on telegram @johnnydeppllofficial<br>  <br><br>      💓 Much Love ❤️', 'textOriginal': "💓Thanks for your utmost love and support which has brought me this far. It has been a hard time for me but your support has got me standing even in difficult times. I can't appreciate enough the support of fans who have been really active with issues relating to me...Private message on telegram @johnnydeppllofficial\n  \n\n      💓 Much Love ❤️", 'parentId': 'Ugx3TaFx2pj0clyas1x4AaABAg', 'authorDisplayName': 'Michael Keaton', 'authorProfileImageUrl': 'https://yt3.ggpht.com/JH6BmofHFtEMWZeFcZHKMKWu2j2gH9j5MhGTUcZ7GhbNxAUIY1g8
# ...

# %%
diff_items.keys()
# Out:
# dict_keys(['etag', 'snippet'])

# %% [markdown]
# **different etag and snippet**

# %%
x2 =reply_comment["snippet"]
y2 = reply_comment2["snippet"]

# %%
diff_items_2 = {k: x2[k] for k in x2 if k in y2 and x2[k] != y2[k]}
diff_items_2.keys()
# Out:
# dict_keys(['authorDisplayName', 'authorProfileImageUrl'])

# %%
x2['authorDisplayName'], y2['authorDisplayName']
# Out:
# ('Michael Keaton', 'Brendan Fraser')

# %%
df[df["snippet.topLevelComment.id"] == "UgxF-cblCwcjZF0Kxal4AaABAg"]
# Out:
#                                etag snippet.topLevelComment.etag  \
# 493597  qxLrUJ3htPqrBcVoIJfkXk_SggQ  Astl1crMO-_oGiS34HzIfggaOx0
# 773255  3ZaULPaa3y-qX8nWAW36XuS_j6A  7miFiI0Y2Key7MzrFuoTS6F-zf4
#
#         snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 493597  UgxF-cblCwcjZF0Kxal4AaABAg                             -sKyN0_D_ec
# 773255  UgxF-cblCwcjZF0Kxal4AaABAg                             -sKyN0_D_ec
#
#              snippet.topLevelComment.snippet.textOriginal  \
# 493597  To get away from domestic violence I went thro...
# 773255  To get away from domestic violence I went thro...
#
#        snippet.topLevelComment.snippet.authorDisplayName  \
# 493597                                               D C
# 773255                                               D C
#
#          snippet.topLevelComment.snippet.authorChannelUrl  \
# 493597  http://www.youtube.com/channel/UCLnq3iOIL_OtXB...
# 773255  http://www.youtube.com/channel/UCLnq3iOIL_OtXB...
#
# ...

# %%
df[df["snippet.topLevelComment.id"] == "Ugy4-M_X5wNuZeXmtnx4AaABAg"]
# Out:
#                                etag snippet.topLevelComment.etag  \
# 493624  KPbGeA7fWNsa8KaxxyppNH9YJjo  aGG4yeie9FowuryhD4fP6JXLfTE
# 773282  CDUe0sHYkLGL8iJzfR7hE9GBtao  8fINRFlsR4LI-MPXw7VQ2J3cy34
#
#         snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 493624  Ugy4-M_X5wNuZeXmtnx4AaABAg                             -sKyN0_D_ec
# 773282  Ugy4-M_X5wNuZeXmtnx4AaABAg                             -sKyN0_D_ec
#
#              snippet.topLevelComment.snippet.textOriginal  \
# 493624  It's incredible that an actress can't hide her...
# 773282  It's incredible that an actress can't hide her...
#
#        snippet.topLevelComment.snippet.authorDisplayName  \
# 493624                                         brandon c
# 773282                                         brandon c
#
#          snippet.topLevelComment.snippet.authorChannelUrl  \
# 493624  http://www.youtube.com/channel/UCyYySyjq9y8YYG...
# 773282  http://www.youtube.com/channel/UCyYySyjq9y8YYG...
#
# ...

# %%
df[df["snippet.topLevelComment.id"] == "Ugz9Tex7HhVb9HUqAnx4AaABAg"]
# Out:
#                                 etag snippet.topLevelComment.etag  \
# 94036    5gCTvKGeFIcK6HAGEKdRQxAeuBE  jzVenHtcgClmRLaK2Zrf9az6Lwo
# 1087299  kXQQ1wBlQUvi7rsRxIZ-6g4wDiE  jzVenHtcgClmRLaK2Zrf9az6Lwo
#
#          snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 94036    Ugz9Tex7HhVb9HUqAnx4AaABAg                             -t1aBONTmBs
# 1087299  Ugz9Tex7HhVb9HUqAnx4AaABAg                             -t1aBONTmBs
#
#               snippet.topLevelComment.snippet.textOriginal  \
# 94036    Hi \ thanks for the information\ I wanted to a...
# 1087299  Hi \ thanks for the information\ I wanted to a...
#
#         snippet.topLevelComment.snippet.authorDisplayName  \
# 94036                                          Patti C.64
# 1087299                                        Patti C.64
#
#           snippet.topLevelComment.snippet.authorChannelUrl  \
# 94036    http://www.youtube.com/channel/UCjYVAEjU190PUh...
# ...

# %%
def which_batch(index):
    if index <= 639105:
        return "batch 1"
    elif index <=  650378 + 639104:
        return "batch 2"
    elif index < 650378 + 639104 + 650378:
        return "batch 3"
    else:
        return "batch 4"

# %%
which_batch(94036)
# Out:
# 'batch 1'

# %%
which_batch(1087299)
# Out:
# 'batch 2'

# %%
df["snippet.topLevelComment.id"].value_counts()
# Out:
# UgwJpPXLJf5PXYPnU5p4AaABAg    2
# UgxVrH7CKnulEVw5bBx4AaABAg    2
# UgxC7YTUn9iu8KZWHBN4AaABAg    2
# UgxozucbP5isuwjbfp94AaABAg    2
# UgzeMwTwtB2QufMU9c14AaABAg    2
#                              ..
# Ugw6yLNuDu0xpbHHLf14AaABAg    1
# UgyKVxOjwv94AZ_Uwrx4AaABAg    1
# UgzItaYpGV0naERZiHZ4AaABAg    1
# UggA3UeEg9XqxXgCoAEC          1
# Ugyuv-iYbCSiiBuj1Kh4AaABAg    1
# Name: snippet.topLevelComment.id, Length: 1693341, dtype: int64

# %%
df[df["snippet.topLevelComment.id"] == "UgwEPAhvsLciR-oo0eF4AaABAg"]
# Out:
#                                etag snippet.topLevelComment.etag  \
# 493165  snuwS0G-OY3v3Mz9hYNULlZim7I  nxa7rm9pAoc7zp79WjXw1QYIIUk
# 772823  HrAyxyTcV3PsVzAAZKSx2nqnQ9U  BZynA84QiF4S_jzQ4LhZHHQSya0
#
#         snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 493165  UgwEPAhvsLciR-oo0eF4AaABAg                             -sKyN0_D_ec
# 772823  UgwEPAhvsLciR-oo0eF4AaABAg                             -sKyN0_D_ec
#
#              snippet.topLevelComment.snippet.textOriginal  \
# 493165  What a horrible woman, and her lawyer was gett...
# 772823  What a horrible woman, and her lawyer was gett...
#
#        snippet.topLevelComment.snippet.authorDisplayName  \
# 493165                                               G-o
# 772823                                               G-o
#
#          snippet.topLevelComment.snippet.authorChannelUrl  \
# 493165  http://www.youtube.com/channel/UCOPAo7Nn-TdveH...
# 772823  http://www.youtube.com/channel/UCOPAo7Nn-TdveH...
#
# ...

# %%
df[df["snippet.topLevelComment.id"] == "Ugw5obQ2mkF_g2lPnDV4AaABAg"]
# Out:
#                                 etag snippet.topLevelComment.etag  \
# 94019    PEq0kKPJtHpxaEWdAF856ICSf0M  mVxQkavKgp0apj9e22Nr3KzeLjU
# 1087283  qDColf2ag1Hu9O5IOR5-rqgEp_E  pIIwL4THwwVh3RLXhzNDhXSTX4I
#
#          snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 94019    Ugw5obQ2mkF_g2lPnDV4AaABAg                             -t1aBONTmBs
# 1087283  Ugw5obQ2mkF_g2lPnDV4AaABAg                             -t1aBONTmBs
#
#         snippet.topLevelComment.snippet.textOriginal  \
# 94019                         ‘You do you, Boo!’ 🥰💯😆
# 1087283                       ‘You do you, Boo!’ 🥰💯😆
#
#         snippet.topLevelComment.snippet.authorDisplayName  \
# 94019                                                 KIP
# 1087283                                    KiP HellaChica
#
#           snippet.topLevelComment.snippet.authorChannelUrl  \
# 94019    http://www.youtube.com/channel/UCqF6JMP5vpxc42...
# 1087283  http://www.youtube.com/channel/UCqF6JMP5vpxc42...
#
# ...

# %%
df[df["snippet.topLevelComment.id"] == "Ugy4-M_X5wNuZeXmtnx4AaABAg"]
# Out:
#                                etag snippet.topLevelComment.etag  \
# 493624  KPbGeA7fWNsa8KaxxyppNH9YJjo  aGG4yeie9FowuryhD4fP6JXLfTE
# 773282  CDUe0sHYkLGL8iJzfR7hE9GBtao  8fINRFlsR4LI-MPXw7VQ2J3cy34
#
#         snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 493624  Ugy4-M_X5wNuZeXmtnx4AaABAg                             -sKyN0_D_ec
# 773282  Ugy4-M_X5wNuZeXmtnx4AaABAg                             -sKyN0_D_ec
#
#              snippet.topLevelComment.snippet.textOriginal  \
# 493624  It's incredible that an actress can't hide her...
# 773282  It's incredible that an actress can't hide her...
#
#        snippet.topLevelComment.snippet.authorDisplayName  \
# 493624                                         brandon c
# 773282                                         brandon c
#
#          snippet.topLevelComment.snippet.authorChannelUrl  \
# 493624  http://www.youtube.com/channel/UCyYySyjq9y8YYG...
# 773282  http://www.youtube.com/channel/UCyYySyjq9y8YYG...
#
# ...

# %%
df[~df["replies.comments"].isnull()]["snippet.topLevelComment.id"].value_counts()
# Out:
# UgxDWHJv4aICXKPvMIR4AaABAg    2
# UgxVVFDgxUbgm9E2xEZ4AaABAg    2
# UgzmzzOK8Ld4ljoXrol4AaABAg    2
# UgwD80aO0M4ng0v-Cuh4AaABAg    2
# UgyD1xiavRnYcZUjJo14AaABAg    2
#                              ..
# UgyQsQM3JMkKAIAdNDB4AaABAg    1
# Ugz4IdnLs0UJ2NVJwXx4AaABAg    1
# Ugz86t1YaoIHl79B6wZ4AaABAg    1
# Ugxl4sN5O8Vd0CwBjRl4AaABAg    1
# Ugyuv-iYbCSiiBuj1Kh4AaABAg    1
# Name: snippet.topLevelComment.id, Length: 218583, dtype: int64

# %%
df[df["snippet.topLevelComment.id"] == "UgysWd1sMR-f3kJ9VEt4AaABAg"]
# Out:
#                                 etag snippet.topLevelComment.etag  \
# 495688   S88fEnKepQoTXzOBaujrC2kFAZc  tetJPr4osvV18SvRnUAGhTDSWUk
# 1223637  9Jx7Bk1E2FmjNan-y1REweChACQ  O5olo5zFakebmb4Gn2Dto9JGhDQ
#
#          snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 495688   UgysWd1sMR-f3kJ9VEt4AaABAg                             -XI7pxiK2L8
# 1223637  UgysWd1sMR-f3kJ9VEt4AaABAg                             -XI7pxiK2L8
#
#               snippet.topLevelComment.snippet.textOriginal  \
# 495688   She abused him and then played the victim. Hor...
# 1223637  She abused him and then played the victim. Hor...
#
#         snippet.topLevelComment.snippet.authorDisplayName  \
# 495688                                             j4Rose
# 1223637                                            j4Rose
#
#           snippet.topLevelComment.snippet.authorChannelUrl  \
# 495688   http://www.youtube.com/channel/UCgOK5erm5cvWSk...
# ...

# %%
len(ast.literal_eval(df[df["snippet.topLevelComment.id"] == "UgysWd1sMR-f3kJ9VEt4AaABAg"]["replies.comments"].values[0]))
# Out:
# 5

# %%
len(ast.literal_eval(df[df["snippet.topLevelComment.id"] == "UgysWd1sMR-f3kJ9VEt4AaABAg"]["replies.comments"].values[1]))
# Out:
# 5

# %%
df["snippet.isPublic"].value_counts()
# Out:
# True    1693524
# Name: snippet.isPublic, dtype: int64

# %%
df.shape
# Out:
# (1693524, 17)

# %%
# drop snippet.isPublic
df.drop(columns=["snippet.isPublic"], inplace=True)

# %%
df["snippet.canReply"].value_counts()
# Out:
# True     1693523
# False          1
# Name: snippet.canReply, dtype: int64

# %%
df[~df["snippet.canReply"]]
# Out:
#                                etag snippet.topLevelComment.etag  \
# 452965  AfTEF0Wom9b0fKdbFsrva8RsVHM  0NXV3SZrvLvWwC3MdgEAOecRCf8
#
#         snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 452965  Ugx5aRkdh0i92HAA0UN4AaABAg                             gcIYyGrQFTk
#
#              snippet.topLevelComment.snippet.textOriginal  \
# 452965  Say it with me kids: The Abuser Isn't Determin...
#
#        snippet.topLevelComment.snippet.authorDisplayName  \
# 452965                                         May Jones
#
#          snippet.topLevelComment.snippet.authorChannelUrl  \
# 452965  http://www.youtube.com/channel/UCnqga9sBpmHkvd...
#
#        snippet.topLevelComment.snippet.authorChannelId.value  \
# 452965                           UCnqga9sBpmHkvdCqLVmxo0g
#
#         snippet.topLevelComment.snippet.canRate  \
# 452965                                     True
#
#         snippet.topLevelComment.snippet.likeCount  \
# ...

# %%
df["snippet.topLevelComment.snippet.canRate"].value_counts()
# Out:
# True    1693524
# Name: snippet.topLevelComment.snippet.canRate, dtype: int64

# %%
# drop snippet.topLevelComment.snippet.canRate
df.drop(columns=["snippet.topLevelComment.snippet.canRate"], inplace=True)

# %%
df[["snippet.topLevelComment.snippet.authorChannelUrl", "snippet.topLevelComment.snippet.authorChannelId.value"]]
# Out:
#           snippet.topLevelComment.snippet.authorChannelUrl  \
# 0        http://www.youtube.com/channel/UC-NINtNMPM75ea...
# 1        http://www.youtube.com/channel/UCjpOdSdi4PkbwR...
# 2        http://www.youtube.com/channel/UCq60QM6P8MDx4F...
# 3        http://www.youtube.com/channel/UCnpqpYyphiGQ4x...
# 4        http://www.youtube.com/channel/UCdpfpM_3cSmCQ3...
# ...                                                    ...
# 1702090  http://www.youtube.com/channel/UCRg3KZifWUnzqu...
# 1702091  http://www.youtube.com/channel/UCKR14HJmoUDh73...
# 1702092  http://www.youtube.com/channel/UCtFDY41CuxB0v_...
# 1702093  http://www.youtube.com/channel/UCCNRJJ7jcr0NMS...
# 1702094  http://www.youtube.com/channel/UCrGYhxT7EHyrpc...
#
#         snippet.topLevelComment.snippet.authorChannelId.value
# 0                                 UC-NINtNMPM75eaqh07RCy_Q
# 1                                 UCjpOdSdi4PkbwRU4qB8fz0w
# 2                                 UCq60QM6P8MDx4FsVfvgS_Ng
# ...

# %%
df["snippet.topLevelComment.snippet.authorChannelUrl"].value_counts().head(10)
# Out:
# http://www.youtube.com/channel/UCkUPWp6pfAWrY8UqAukm-tQ    1336
# http://www.youtube.com/channel/UCYnuymLRHNVS3HwlRwIEwRA     908
# http://www.youtube.com/channel/UCzeIlZiqg2FEVtpqR-R6WCw     850
# http://www.youtube.com/channel/UCp9u3DC375IPgZfs2PZ94BA     770
# http://www.youtube.com/channel/UCr2vrWVP_8vleq3bnBizuzg     769
# http://www.youtube.com/channel/UC8TfvTdn4nAKPMuhw7-BGQQ     643
# http://www.youtube.com/channel/UC_uaPf9jLHCl8U2whsMkzeA     587
# http://www.youtube.com/channel/UCTOMjcnja9Ddxi3XePpCHcg     570
# http://www.youtube.com/channel/UCjYVAEjU190PUhVF446erGg     519
# http://www.youtube.com/channel/UCkn-xm4WQRyeGn0caCuuACA     484
# Name: snippet.topLevelComment.snippet.authorChannelUrl, dtype: int64

# %%
df["snippet.topLevelComment.snippet.authorChannelId.value"].value_counts()
# Out:
# UCkUPWp6pfAWrY8UqAukm-tQ    1336
# UCYnuymLRHNVS3HwlRwIEwRA     908
# UCzeIlZiqg2FEVtpqR-R6WCw     850
# UCp9u3DC375IPgZfs2PZ94BA     770
# UCr2vrWVP_8vleq3bnBizuzg     769
#                             ...
# UC_4yiaogOU03tNK7Y430-vA       1
# UCYOHzWeM9mARkfH3mwgN01w       1
# UCi7x20bFy2bbNC5SdztlydQ       1
# UCtmc0cGXs_OBsW2vJXGUkzA       1
# UClEfptG1jJXrbkwNumLd82Q       1
# Name: snippet.topLevelComment.snippet.authorChannelId.value, Length: 1089751, dtype: int64

# %%
df[
    df["snippet.topLevelComment.snippet.authorChannelUrl"]
    == "http://www.youtube.com/channel/UCkUPWp6pfAWrY8UqAukm-tQ"
]["snippet.topLevelComment.snippet.authorChannelId.value"].value_counts()
# Out:
# UCkUPWp6pfAWrY8UqAukm-tQ    1336
# Name: snippet.topLevelComment.snippet.authorChannelId.value, dtype: int64

# %%
df[
    df["snippet.topLevelComment.snippet.authorChannelUrl"]
    == "http://www.youtube.com/channel/UCkUPWp6pfAWrY8UqAukm-tQ"
]["snippet.topLevelComment.snippet.authorDisplayName"].value_counts()
# Out:
# Lorri Holder    1336
# Name: snippet.topLevelComment.snippet.authorDisplayName, dtype: int64

# %%
df[
    df["snippet.topLevelComment.snippet.authorChannelUrl"]
    == "http://www.youtube.com/channel/UCr2vrWVP_8vleq3bnBizuzg"
]["snippet.topLevelComment.snippet.authorDisplayName"].value_counts()
# Out:
# PureSparkles22    769
# Name: snippet.topLevelComment.snippet.authorDisplayName, dtype: int64

# %%
df[
    df["snippet.topLevelComment.snippet.authorChannelUrl"]
    == "http://www.youtube.com/channel/UCkn-xm4WQRyeGn0caCuuACA"
]["snippet.topLevelComment.snippet.authorDisplayName"].value_counts()
# Out:
# Emily Walker    484
# Name: snippet.topLevelComment.snippet.authorDisplayName, dtype: int64

# %%
df["snippet.topLevelComment.snippet.authorDisplayName"].value_counts().values.shape
# Out:
# (998676,)

# %%
df["snippet.topLevelComment.snippet.authorChannelUrl"].value_counts().values.shape
# Out:
# (1089751,)

# %%
df_authors = df.groupby(
    [
        "snippet.topLevelComment.snippet.authorDisplayName",
        "snippet.topLevelComment.snippet.authorChannelId.value",
    ]
)["etag"].count().sort_values(ascending=False).reset_index().rename(
    columns={"etag": "count"}
)

# %%
df_authors.rename(columns={
    "snippet.topLevelComment.snippet.authorDisplayName": "author",
    "snippet.topLevelComment.snippet.authorChannelId.value": "cahnned_id",
}, inplace=True)

# %%
df_authors
# Out:
#                                   author                cahnned_id  count
# 0                           Lorri Holder  UCkUPWp6pfAWrY8UqAukm-tQ   1336
# 1        Bobby Campbell aka (The Oracle)  UCYnuymLRHNVS3HwlRwIEwRA    908
# 2                           Lindsey Depp  UCzeIlZiqg2FEVtpqR-R6WCw    850
# 3                         Carla Castillo  UCp9u3DC375IPgZfs2PZ94BA    770
# 4                         PureSparkles22  UCr2vrWVP_8vleq3bnBizuzg    769
# ...                                  ...                       ...    ...
# 1090240                  Jocelyn Elliott  UCe-Q4SCtmvBzhW5AjaPhOog      1
# 1090241                 Jocelyn Ferreira  UCv6OlwpwmUS-omi76tu_N7A      1
# 1090242                   Jocelyn Flores  UCsoAQ9eLOwbV5X1lc-gL3CQ      1
# 1090243                   Jocelyn Fowler  UCFoLxtoXbLemMdeInIddcAQ      1
# 1090244                        🪴Noémie.B  UCOPrwFyZS_TxR584rvU0z4w      1
#
# [1090245 rows x 3 columns]

# %%
df_authors.author.value_counts()
# Out:
# Alex                   217
# J                      188
# M                      161
# Chris                  146
# Daniel                 138
#                       ...
# SANTHOSH SANTHOSH S      1
# eye                      1
# Anything goes            1
# Dirty Harry Potter       1
# Giovanni A               1
# Name: author, Length: 998676, dtype: int64

# %% [markdown]
# #### OK, Now we can see that disply name is not unique so Alex refers to all users has Alex as display name so we will only drop the cahnned url but keep the channel id

# %%
df.head(1)
# Out:
#                           etag snippet.topLevelComment.etag  \
# 0  HWRVF49a2ObDyvftwuVdJKNhyD8  Iovx9zUM7fOXxqPCM-3iKToEaKw
#
#    snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 0  UgyWYCQS7evmvfmJS-N4AaABAg                             14SUI93R_k8
#
#   snippet.topLevelComment.snippet.textOriginal  \
# 0              Are you going to see Aquaman 2?
#
#   snippet.topLevelComment.snippet.authorDisplayName  \
# 0                                    InformOverload
#
#     snippet.topLevelComment.snippet.authorChannelUrl  \
# 0  http://www.youtube.com/channel/UC-NINtNMPM75ea...
#
#   snippet.topLevelComment.snippet.authorChannelId.value  \
# 0                           UC-NINtNMPM75eaqh07RCy_Q
#
#    snippet.topLevelComment.snippet.likeCount  \
# 0                                       94.0
#
#   snippet.topLevelComment.snippet.publishedAt  \
# 0                        2021-03-19T17:03:31Z
#
#   snippet.topLevelComment.snippet.updatedAt  snippet.canReply  \
# ...

# %%
df.drop(columns=["snippet.topLevelComment.snippet.authorChannelUrl"], inplace=True)

# %%
df.head(1)
# Out:
#                           etag snippet.topLevelComment.etag  \
# 0  HWRVF49a2ObDyvftwuVdJKNhyD8  Iovx9zUM7fOXxqPCM-3iKToEaKw
#
#    snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 0  UgyWYCQS7evmvfmJS-N4AaABAg                             14SUI93R_k8
#
#   snippet.topLevelComment.snippet.textOriginal  \
# 0              Are you going to see Aquaman 2?
#
#   snippet.topLevelComment.snippet.authorDisplayName  \
# 0                                    InformOverload
#
#   snippet.topLevelComment.snippet.authorChannelId.value  \
# 0                           UC-NINtNMPM75eaqh07RCy_Q
#
#    snippet.topLevelComment.snippet.likeCount  \
# 0                                       94.0
#
#   snippet.topLevelComment.snippet.publishedAt  \
# 0                        2021-03-19T17:03:31Z
#
#   snippet.topLevelComment.snippet.updatedAt  snippet.canReply  \
# 0                      2021-03-19T17:03:31Z              True
#
# ...

# %%
df.shape
# Out:
# (1693524, 14)

# %%
likely_spam = df[~df["snippet.topLevelComment.snippet.moderationStatus"].isnull() ]

# %%
likely_spam
# Out:
#                                 etag snippet.topLevelComment.etag  \
# 6469     Ax_QJPIk77CkIXgGCqZBowI9Jq4  iolor353TEY8USmRNSMS5yWSWsw
# 7907     w5tB1ld1vWFqWFB6gqMAHFRGEnA  5isJVhzFbD4X1YQpbRQ-GKzFz-M
# 8276     p6b1OVMQDMd09eu62crlhLXnRZc  O_OoC4TPn90Wqa3xjG5t37ozGc8
# 8283     G3wGpP3d5n02ffNhXla7m0icMQk  -iJJp6KIRIBBOk6nT94Y-rLYDkU
# 8322     b18SV5GeLJi8W_IeLJvzPc7mzjk  Amifm_cQKteRFTllxgJJz_eUydQ
# ...                              ...                          ...
# 1698067  ckVXwevh1LaoYiGsfWY-Rj03x9I  QHa_T5JCr9B99DxYqZW_5ISq_G8
# 1698169  NZQ-yF3NKhJ34PiOsqkc3N7VXNQ  knvdZX48p9LiNV04SG3RaxkQEns
# 1698206  MtMOLs2nFKcw9uQc5Ptf6-UFRkU  xSCdiYF5R7ca16I4UdNzXy5tYTc
# 1698455  _JHb3CfVfkkyMPrRX65YbXMVpTI  mgJNymzGzeyHQY-tQHL44900i0U
# 1699170  g0JAfWEckj0dQdLWC5_DxJQjlr4  Nwi4ZmxA4eYFb5U6pRklM2eibZM
#
#          snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 6469     Ugwjvsdug7OZnsXjm5t4AaABAg                             AO7QHp_M4OU
# ...

# %%
df.drop(columns=["snippet.canReply"], inplace=True)

# %%
df.head(1)
# Out:
#                           etag snippet.topLevelComment.etag  \
# 0  HWRVF49a2ObDyvftwuVdJKNhyD8  Iovx9zUM7fOXxqPCM-3iKToEaKw
#
#    snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 0  UgyWYCQS7evmvfmJS-N4AaABAg                             14SUI93R_k8
#
#   snippet.topLevelComment.snippet.textOriginal  \
# 0              Are you going to see Aquaman 2?
#
#   snippet.topLevelComment.snippet.authorDisplayName  \
# 0                                    InformOverload
#
#   snippet.topLevelComment.snippet.authorChannelId.value  \
# 0                           UC-NINtNMPM75eaqh07RCy_Q
#
#    snippet.topLevelComment.snippet.likeCount  \
# 0                                       94.0
#
#   snippet.topLevelComment.snippet.publishedAt  \
# 0                        2021-03-19T17:03:31Z
#
#   snippet.topLevelComment.snippet.updatedAt  snippet.totalReplyCount  \
# 0                      2021-03-19T17:03:31Z                    213.0
#
# ...

# %%
df.rename(
    columns={
        "snippet.topLevelComment.etag": "tl_etag",
        "snippet.topLevelComment.id": "tl_id",
        "snippet.topLevelComment.snippet.videoId": "tl_video_id",
        "snippet.topLevelComment.snippet.textOriginal": "tl_text",
        "snippet.topLevelComment.snippet.authorDisplayName": "tl_author_display_name",
        "snippet.topLevelComment.snippet.authorChannelId.value": "tl_author_channed_id",
        "snippet.topLevelComment.snippet.likeCount": "tl_n_likes",
        "snippet.topLevelComment.snippet.publishedAt": "tl_comment_puplish_dtime",
        "snippet.topLevelComment.snippet.updatedAt": "tl_comment_update_time",
        "snippet.totalReplyCount": "n_replies",
        "snippet.topLevelComment.snippet.moderationStatus": "tl_moderation_status",
    }, inplace=True
)

# %%
df.head(1)
# Out:
#                           etag                      tl_etag  \
# 0  HWRVF49a2ObDyvftwuVdJKNhyD8  Iovx9zUM7fOXxqPCM-3iKToEaKw
#
#                         tl_id  tl_video_id                          tl_text  \
# 0  UgyWYCQS7evmvfmJS-N4AaABAg  14SUI93R_k8  Are you going to see Aquaman 2?
#
#   tl_author_display_name      tl_author_channed_id  tl_n_likes  \
# 0         InformOverload  UC-NINtNMPM75eaqh07RCy_Q        94.0
#
#   tl_comment_puplish_dtime tl_comment_update_time  n_replies  \
# 0     2021-03-19T17:03:31Z   2021-03-19T17:03:31Z      213.0
#
#                                     replies.comments tl_moderation_status
# 0  [{'kind': 'youtube#comment', 'etag': 'XxrLRzbE...                  NaN

# %%
df.columns
# Out:
# Index(['etag', 'tl_etag', 'tl_id', 'tl_video_id', 'tl_text',
#        'tl_author_display_name', 'tl_author_channed_id', 'tl_n_likes',
#        'tl_comment_puplish_dtime', 'tl_comment_update_time', 'n_replies',
#        'replies.comments', 'tl_moderation_status'],
#       dtype='object')

# %% [markdown]
# |          Column          |                          Definition                          |
# | :----------------------- | :----------------------------------------------------------- |
# | etag                     | Record (entity tag); **Unique for each record**                 |
# | tl_etag                  | Top Level Comment eTag                                       |
# | tl_id                    | Top Level Comment ID                                         |
# | tl_video_id              | Top Level Comment Video ID                                   |
# | tl_text                  | Top Level Comment Text                                       |
# | tl_author_display_name   | Top Level Comment Display name **Not Unique**                |
# | tl_author_channed_id     | Top Level Comment Channel ID   **Unique for each Author**    |
# | tl_n_likes               | Top Level Comment Number of Likes                            |
# | tl_comment_puplish_dtime | Top Level Comment Number Publish Date Time                   |
# | tl_comment_update_time   | Top Level Comment Number Update Date Time                    |
# | n_replies                | Number of Replies of each record                             |
# | replies.comments         | UNDER INVESTIGATIONS                                         |
# | tl_moderation_status     | Top Level Comment Moderation Status (Classified Spam or Not) |

# %%
df.shape
# Out:
# (1693524, 13)

# %%
df["tl_comment_puplish_dtime"] = pd.to_datetime(df["tl_comment_puplish_dtime"])

# %%
df["tl_comment_update_time"] = pd.to_datetime(df["tl_comment_update_time"])

# %%
df.tl_comment_puplish_dtime.min()
# Out:
# Timestamp('2008-03-26 00:56:59+0000', tz='UTC')

# %%
df.tl_comment_puplish_dtime.max()
# Out:
# Timestamp('2021-12-08 01:33:20+0000', tz='UTC')

# %% [markdown]
# The data collected between 26 march 2008 and 8 December 2021
